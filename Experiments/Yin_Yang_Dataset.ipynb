# %%
pip install mlxtend
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mlxtend
#   Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 11.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.16.2 in ./.local/lib/python3.10/site-packages (from mlxtend) (1.24.3)
# Requirement already satisfied: scipy>=1.2.1 in ./.local/lib/python3.10/site-packages (from mlxtend) (1.15.3)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/lib/python3/dist-packages (from mlxtend) (3.5.1)
# Requirement already satisfied: joblib>=0.13.2 in /usr/lib/python3/dist-packages (from mlxtend) (0.17.0)
# Collecting scikit-learn>=1.3.1
#   Downloading scikit_learn-1.7.1-cp310-cp310-manylinux_2_27_aarch64.manylinux_2_28_aarch64.whl (9.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 44.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pandas>=0.24.2 in ./.local/lib/python3.10/site-packages (from mlxtend) (2.3.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=0.24.2->mlxtend) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.local/lib/python3.10/site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.local/lib/python3.10/site-packages (from pandas>=0.24.2->mlxtend) (2.9.0.post0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/lib/python3/dist-packages (from scikit-learn>=1.3.1->mlxtend) (3.1.0)
# Collecting joblib>=0.13.2
#   Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.4/308.4 KB 98.9 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas>=0.24.2->mlxtend) (1.16.0)
# Installing collected packages: joblib, scikit-learn, mlxtend
# Successfully installed joblib-1.5.2 mlxtend-0.23.4 scikit-learn-1.7.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import os, math, warnings
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from mlxtend.plotting import plot_decision_regions

warnings.filterwarnings('ignore')

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from IPython.display import display, HTML
display(HTML("<style>.output_scroll {height:auto !important; max-height:none !important;}</style>"))

print("="*60)
print("GPU CONFIGURATION")
print("="*60)
gpus = tf.config.list_physical_devices('GPU')
USE_GPU = bool(gpus)
if USE_GPU:
    print(f"GPUs available: {len(gpus)}")
    for gpu in gpus:
        print("  -", gpu)
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU memory growth enabled")
    except RuntimeError as e:
        print(e)
else:
    print("No GPUs available, using CPU")

policy_name = 'mixed_float16' if USE_GPU else 'float32'
tf.keras.mixed_precision.set_global_policy(policy_name)
print(f"Mixed precision policy: {tf.keras.mixed_precision.global_policy().name}")
print("="*60 + "\n")

USE_XLA = USE_GPU 


def inv_softplus(y):
    """Inverse of softplus: given k>=0, return rho such that softplus(rho)=k."""
    y = np.maximum(float(y), 1e-6)
    return np.log(np.expm1(y))



def generate_yin_yang(num_points=1000, radius=1.0):
    """Generate Yin-Yang dataset for binary classification."""
    np.random.seed(0)  # For reproducibility
    theta = np.random.rand(num_points) * 2 * np.pi
    r = radius * np.sqrt(np.random.rand(num_points))
    x = r * np.cos(theta)
    y = r * np.sin(theta)

    labels = np.zeros(num_points)

    yin_mask = (x**2 + y**2 <= (radius**2)) & (x <= 0)
    labels[yin_mask] = 0

    yang_mask = (x**2 + y**2 <= (radius**2)) & (x > 0)
    labels[yang_mask] = 1

    small_yin_mask = ((x - radius/2)**2 + y**2 <= (radius/4)**2)
    labels[small_yin_mask] = 0

    small_yang_mask = ((x + radius/2)**2 + y**2 <= (radius/4)**2)
    labels[small_yang_mask] = 1

    return np.vstack([x, y]).T.astype(np.float32), labels.astype(np.int32)


class LASAActivation(tf.keras.layers.Layer):
    """
    Constrained LASA with window penalty near ±pi/2.

    penalty_mode: 'hinge' | 'cos2' | 'hybrid' (alpha*cos2 + hinge)
      hinge : pen = mean( [|cos(phi)| - sin(theta)]_+^2 )
      cos2  : pen = mean( cos(phi)^2 )
      hybrid: pen = alpha*cos2 + hinge

    k >= 0 is enforced:
      - enforce_gain_cap=False: k = softplus(rho)          (unbounded ≥ 0)
      - enforce_gain_cap=True : k = k_max * sigmoid(rho)   (0..k_max), k_max = gain_cap / sin(theta)
    """
    def __init__(self, theta_degrees=45.0, lambda_window=3e-4,
                 penalty_mode='hinge', hybrid_alpha=0.1,
                 enforce_gain_cap=False, gain_cap=1.25,
                 initial_frequency=1.6, name=None, **kwargs):
        super().__init__(name=name, **kwargs)
        self.theta_degrees     = float(theta_degrees)
        self.lambda_window     = float(lambda_window)
        self.penalty_mode      = str(penalty_mode)
        self.hybrid_alpha      = float(hybrid_alpha)
        self.enforce_gain_cap  = bool(enforce_gain_cap)
        self.gain_cap          = float(gain_cap)
        self.initial_frequency = float(initial_frequency)

    def build(self, input_shape):
  
        self.theta_rad = tf.constant(self.theta_degrees * math.pi/180.0, dtype=tf.float32)
        self.sin_theta = tf.sin(self.theta_rad)

    
        self.penalty_scale = self.add_weight(
            shape=(), name='penalty_scale', dtype=tf.float32, trainable=False,
            initializer=tf.keras.initializers.Constant(1.0)
        )

     
        if self.enforce_gain_cap:
            denom   = tf.maximum(self.sin_theta, tf.constant(1e-6, tf.float32))
            k_max_v = float(self.gain_cap) / float(denom.numpy())
            self.k_max = tf.constant(k_max_v, dtype=tf.float32)
            ratio = np.clip(self.initial_frequency / k_max_v, 1e-6, 1.0-1e-6)
            rho0  = np.log(ratio/(1.0 - ratio))  
        else:
            self.k_max = None
            rho0 = inv_softplus(self.initial_frequency)

        self.rho = self.add_weight(shape=(), name='rho', dtype=tf.float32, trainable=True,
                                   initializer=tf.keras.initializers.Constant(float(rho0)))

    @property
    def tau_value(self):
        """Effective k (>=0)."""
        if self.enforce_gain_cap:
            return self.k_max * tf.nn.sigmoid(self.rho)   
        return tf.nn.softplus(self.rho)                  

    # helpers for trainer
    def set_penalty_scale(self, scale):
        self.penalty_scale.assign(tf.cast(scale, tf.float32))

    def scale_down_penalty(self, factor=0.8, min_scale=0.05):
        new_scale = tf.maximum(self.penalty_scale * tf.cast(factor, tf.float32),
                               tf.constant(min_scale, tf.float32))
        self.penalty_scale.assign(new_scale)

    # penalty
    def _penalty(self, inputs, tau32):
        if self.lambda_window <= 0.0:
            return None
        x32     = tf.cast(inputs, tf.float32)
        cos_phi = tf.math.cos(tau32 * x32)
        abs_cos = tf.abs(cos_phi)

        if self.penalty_mode == 'hinge':
            margin = self.sin_theta
            viol   = tf.maximum(abs_cos - margin, 0.0)   
            pen    = tf.reduce_mean(tf.square(viol))
        elif self.penalty_mode == 'cos2':
            pen    = tf.reduce_mean(tf.square(cos_phi))
        elif self.penalty_mode == 'hybrid':
            margin = self.sin_theta
            viol   = tf.maximum(abs_cos - margin, 0.0)
            hinge  = tf.reduce_mean(tf.square(viol))
            cos2   = tf.reduce_mean(tf.square(cos_phi))
            pen    = self.hybrid_alpha * cos2 + hinge
        else:
            raise ValueError("penalty_mode must be 'hinge', 'cos2', or 'hybrid'.")

        lw32    = tf.cast(self.lambda_window, tf.float32)
        scale32 = tf.cast(self.penalty_scale, tf.float32)
        return lw32 * scale32 * pen

    def call(self, inputs):
        tau32 = tf.cast(self.tau_value, tf.float32)
        pen = self._penalty(inputs, tau32)
        if pen is not None:
            self.add_loss(pen)
        x32 = tf.cast(inputs, tf.float32)
        y32 = tf.math.sin(tau32 * x32)
        return tf.cast(y32, inputs.dtype)



class SwishActivation(tf.keras.layers.Layer):
    def call(self, inputs):
        x = tf.cast(inputs, tf.float32)
        y = x * tf.nn.sigmoid(x)
        return tf.cast(y, inputs.dtype)

class MishActivation(tf.keras.layers.Layer):
    def call(self, inputs):
        x = tf.cast(inputs, tf.float32)
        y = x * tf.math.tanh(tf.math.softplus(x))
        return tf.cast(y, inputs.dtype)



def create_model(activation_type,
                 hidden_units=[6],
                 initial_frequency=1.6,
                 theta_degrees=45.0, lambda_window=3e-4,
                 penalty_mode='hinge', hybrid_alpha=0.1,
                 enforce_gain_cap=False, gain_cap=1.25):
    with tf.device('/GPU:0' if USE_GPU else '/CPU:0'):
        model = tf.keras.Sequential([tf.keras.layers.Input(shape=(2,))])
        for i, units in enumerate(hidden_units):
            model.add(tf.keras.layers.Dense(units, name=f'dense_{i}'))
            a = activation_type.lower()
            if a == 'lasa':
                model.add(LASAActivation(
                    theta_degrees=theta_degrees,
                    lambda_window=lambda_window,
                    penalty_mode=penalty_mode, hybrid_alpha=hybrid_alpha,
                    enforce_gain_cap=enforce_gain_cap, gain_cap=gain_cap,
                    initial_frequency=initial_frequency,
                    name=f'lasa_{i}'
                ))
            elif a == 'relu':
                model.add(tf.keras.layers.ReLU(name=f'relu_{i}'))
            elif a == 'leaky_relu':
                model.add(tf.keras.layers.LeakyReLU(alpha=0.01, name=f'leaky_relu_{i}'))
            elif a == 'elu':
                model.add(tf.keras.layers.ELU(alpha=1.0, name=f'elu_{i}'))
            elif a == 'softplus':
                model.add(tf.keras.layers.Activation('softplus', name=f'softplus_{i}'))
            elif a == 'swish':
                model.add(SwishActivation(name=f'swish_{i}'))
            elif a == 'mish':
                model.add(MishActivation(name=f'mish_{i}'))
            elif a == 'gelu':
                model.add(tf.keras.layers.Lambda(lambda z: tf.nn.gelu(z), name=f'gelu_{i}'))
            elif a == 'sine':
                model.add(tf.keras.layers.Lambda(lambda z: tf.math.sin(z), name=f'sine_{i}'))
            elif a == 'sigmoid':
                model.add(tf.keras.layers.Activation('sigmoid', name=f'sigmoid_{i}'))
            elif a == 'tanh':
                model.add(tf.keras.layers.Activation('tanh', name=f'tanh_{i}'))
            else:
                raise ValueError(f"Unknown activation_type: {activation_type}")


        model.add(tf.keras.layers.Dense(1, activation='sigmoid', dtype='float32', name='output'))
    return model



class LASATrainer:
 
    def __init__(self, model,
                 lr_main=1e-3, lr_tau=1e-2,
                 clipnorm_main=1.0, clipnorm_tau=0.5,
                 penalty_warmup_epochs=8,
                 # validation guard
                 acc_eps=2.5e-3, loss_eps=1e-4,
                 reverse_tau_grads=True, revert_rho_to_snapshot=True,
                 shrink_tau_lr=True, tau_lr_decay=0.5, min_tau_lr=1e-5,
                 shrink_penalty=True, penalty_decay=0.8, min_penalty_scale=0.05,
                 # stagnation bump
                 stagnation_window=10, improve_threshold=0.05,
                 bump_delta_k=1.0, min_epochs_between_bumps=10,
                 # safety rule
                 acc_drop_threshold=0.02):
        self.model = model
        self.loss_fn = tf.keras.losses.BinaryCrossentropy()
        self.optimizer_main = tf.keras.optimizers.Adam(learning_rate=lr_main, clipnorm=clipnorm_main)
        self.optimizer_tau  = tf.keras.optimizers.Adam(learning_rate=lr_tau,  clipnorm=clipnorm_tau)
        self.penalty_warmup_epochs = int(penalty_warmup_epochs)

        self.acc_eps = float(acc_eps)
        self.loss_eps = float(loss_eps)
        self.reverse_tau_grads = bool(reverse_tau_grads)
        self.revert_rho_to_snapshot = bool(revert_rho_to_snapshot)
        self.shrink_tau_lr = bool(shrink_tau_lr)
        self.tau_lr_decay = float(tau_lr_decay)
        self.min_tau_lr = float(min_tau_lr)
        self.shrink_penalty = bool(shrink_penalty)
        self.penalty_decay = float(penalty_decay)
        self.min_penalty_scale = float(min_penalty_scale)

        self.stagnation_window = int(stagnation_window)
        self.improve_threshold = float(improve_threshold)
        self.bump_delta_k = float(bump_delta_k)
        self.min_epochs_between_bumps = int(min_epochs_between_bumps)

        self.acc_drop_threshold = float(acc_drop_threshold)

  
        self._partition_ready = False
        self.tau_idx, self.other_idx = [], []
        self._best_val_acc  = -np.inf
        self._best_val_loss =  np.inf
        self.val_acc_hist   = []
        self._last_bump_epoch = -10**9
        self.tau_grad_dir = tf.Variable(1.0, trainable=False, dtype=tf.float32)

     
        self.pending_bump = False          
        self.bump_pre_val_acc = None       
        self.rho_bump_snapshot = None     
        self.bump_reverted_once = False    
        self.final_bump_to_apply = False   
        self.final_bump_applied = False    
        self.disable_future_bumps = False  
        self.no_revert_mode = False       

    def _build_and_partition(self, sample_x):
        _ = self.model(sample_x)
        self.tau_idx, self.other_idx = [], []
        for i, v in enumerate(self.model.trainable_variables):
            if '/rho:' in v.name: self.tau_idx.append(i)
            else: self.other_idx.append(i)
        self._partition_ready = True

    def _set_penalty_scale(self, epoch_idx):
        scale = 1.0 if self.penalty_warmup_epochs <= 0 else min(1.0, (epoch_idx + 1) / self.penalty_warmup_epochs)
        for layer in self.model.layers:
            if isinstance(layer, LASAActivation):
                layer.set_penalty_scale(scale)

    def _decay_penalty_scale(self):
        if not self.shrink_penalty: return
        for layer in self.model.layers:
            if isinstance(layer, LASAActivation):
                layer.scale_down_penalty(self.penalty_decay, self.min_penalty_scale)

    def _snapshot_rho(self):
        return [self.model.trainable_variables[i].numpy().copy() for i in self.tau_idx]

    def _restore_rho(self, snap):
        for val, i in zip(snap, self.tau_idx):
            self.model.trainable_variables[i].assign(val)

    def _reset_tau_optimizer(self, new_lr):
        self.optimizer_tau = tf.keras.optimizers.Adam(learning_rate=new_lr, clipnorm=self.optimizer_tau.clipnorm)

    def _bump_all_k(self, delta):
       
        for layer in self.model.layers:
            if isinstance(layer, LASAActivation):
                k0 = float(layer.tau_value.numpy())
                if layer.enforce_gain_cap:
                    kmax = float(layer.k_max.numpy())
                    k1 = min(kmax * 0.999, k0 + float(delta))
                    ratio = np.clip(k1 / kmax, 1e-6, 1.0-1e-6)
                    rho_new = np.log(ratio/(1.0 - ratio))
                else:
                    k1 = max(0.0, k0 + float(delta))
                    rho_new = inv_softplus(k1)
                layer.rho.assign(np.float32(rho_new))

    def _current_k_values(self):
        ks = []
        for layer in self.model.layers:
            if isinstance(layer, LASAActivation):
                ks.append(float(layer.tau_value.numpy()))
        return ks

    @tf.function(jit_compile=USE_XLA)
    def _train_step(self, x_batch, y_batch):
        with tf.GradientTape() as tape:
            preds = self.model(x_batch, training=True)
            yb = tf.reshape(y_batch, (-1, 1))
            main_loss = self.loss_fn(yb, preds)
            reg_losses = tf.add_n(self.model.losses) if self.model.losses else tf.constant(0.0, dtype=main_loss.dtype)
            loss = main_loss + reg_losses
        grads = tape.gradient(loss, self.model.trainable_variables)

        tau_pairs = []
        for i in self.tau_idx:
            g = grads[i]; v = self.model.trainable_variables[i]
            if g is not None:
                g = tf.cast(g, tf.float32) * self.tau_grad_dir
                tau_pairs.append((g, v))
        other_pairs = []
        for i in self.other_idx:
            g = grads[i]; v = self.model.trainable_variables[i]
            if g is not None:
                other_pairs.append((g, v))

        if tau_pairs:   self.optimizer_tau.apply_gradients(tau_pairs)
        if other_pairs: self.optimizer_main.apply_gradients(other_pairs)

        return main_loss

    def _val_metrics(self, X_val, y_val):
        preds = self.model(X_val, training=False)
        yb = tf.reshape(y_val, (-1, 1))
        val_loss = float(self.loss_fn(yb, preds).numpy())
        y_pred = (preds.numpy() > 0.5).astype(int).flatten()
        val_acc = float(np.mean(y_pred == y_val.numpy()))
        return val_loss, val_acc

    def train(self, X_train, y_train, X_val, y_val, epochs=40, batch_size=32, verbose=True):
        X_train = tf.constant(X_train, dtype=tf.float32)
        y_train = tf.constant(y_train, dtype=tf.float32)
        X_val   = tf.constant(X_val,   dtype=tf.float32)
        y_val   = tf.constant(y_val,   dtype=tf.float32)

        if not self._partition_ready:
            self._build_and_partition(X_train[:1])

        ds = (tf.data.Dataset.from_tensor_slices((X_train, y_train))
              .shuffle(4096).batch(batch_size).prefetch(tf.data.AUTOTUNE))

        history = {'loss': [], 'val_accuracy': [], 'val_loss': [], 'k': []}

        for epoch in range(epochs):
      
            self._set_penalty_scale(epoch)

        
            if self.final_bump_to_apply and not self.final_bump_applied:
                self._bump_all_k(self.bump_delta_k)
                self.final_bump_applied = True
                self.final_bump_to_apply = False
                self.disable_future_bumps = True
                self.no_revert_mode = True

            rho_snap_epoch = self._snapshot_rho()  

            total_loss = 0.0
            nb = 0
            for xb, yb in ds:
                main_l = self._train_step(xb, yb)
                total_loss += float(main_l.numpy())
                nb += 1

            avg_loss = total_loss / max(nb, 1)
            val_loss, val_acc = self._val_metrics(X_val, y_val)

    
            if self.pending_bump and not self.final_bump_applied:
                if self.bump_pre_val_acc is not None:
                    drop = self.bump_pre_val_acc - val_acc
                    if drop > self.acc_drop_threshold and not self.bump_reverted_once:
                       
                        self._restore_rho(self.rho_bump_snapshot)
                        self.bump_reverted_once = True
                        self.pending_bump = False
                     
                        self.final_bump_to_apply = True
                       
                        val_loss, val_acc = self._val_metrics(X_val, y_val)
                if self.pending_bump:
                    self.pending_bump = False
         
            worse_acc  = (val_acc  < self._best_val_acc  - self.acc_eps)
            worse_loss = (val_loss > self._best_val_loss + self.loss_eps)
            if (worse_acc or worse_loss):
                if self.revert_rho_to_snapshot and not self.no_revert_mode:
                    self._restore_rho(rho_snap_epoch)
                if self.reverse_tau_grads:
                    self.tau_grad_dir.assign(-self.tau_grad_dir)
                if self.shrink_tau_lr:
                    new_lr = max(self.min_tau_lr, float(self.optimizer_tau.learning_rate.numpy()) * self.tau_lr_decay)
                    self._reset_tau_optimizer(new_lr)
                if self.shrink_penalty:
                    self._decay_penalty_scale()
          
                val_loss, val_acc = self._val_metrics(X_val, y_val)
        
            ep = epoch + 1
            self.val_acc_hist.append(val_acc)
            can_try_bump = (not self.disable_future_bumps) and (not self.final_bump_applied)
            if can_try_bump and ep >= self.stagnation_window and (ep - self._last_bump_epoch) >= self.min_epochs_between_bumps:
                acc_then = self.val_acc_hist[-self.stagnation_window]
                improve  = val_acc - acc_then
                if improve < self.improve_threshold:
                   
                    self.rho_bump_snapshot = self._snapshot_rho()
                    self.bump_pre_val_acc  = val_acc
              
                    self._bump_all_k(self.bump_delta_k)
                    self.pending_bump = True
                    self._last_bump_epoch = ep
            # ------------------------------------

         
            self._best_val_acc  = max(self._best_val_acc,  val_acc)
            self._best_val_loss = min(self._best_val_loss, val_loss)

        
            history['k'].append(self._current_k_values())

            history['loss'].append(avg_loss)
            history['val_accuracy'].append(val_acc)
            history['val_loss'].append(val_loss)

            if verbose:
                print(f"Epoch {epoch+1:03d} | loss: {avg_loss:.4f} | val_loss: {val_loss:.4f} | val_acc: {val_acc:.4f}")
        return history


class RegularTrainer:
    """Standard trainer for non-LASA activations (minimal logs)."""
    def __init__(self, model, lr=1e-3, clipnorm=1.0):
        self.model = model
        self.loss_fn = tf.keras.losses.BinaryCrossentropy()
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=lr, clipnorm=clipnorm)

    @tf.function(jit_compile=USE_XLA)
    def _train_step(self, x_batch, y_batch):
        with tf.GradientTape() as tape:
            preds = self.model(x_batch, training=True)
            yb = tf.reshape(y_batch, (-1, 1))
            loss = self.loss_fn(yb, preds)
        grads = tape.gradient(loss, self.model.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.model.trainable_variables))
        return loss

    def _val_metrics(self, X_val, y_val):
        preds = self.model(X_val, training=False)
        yb = tf.reshape(y_val, (-1, 1))
        val_loss = float(self.loss_fn(yb, preds).numpy())
        y_pred = (preds.numpy() > 0.5).astype(int).flatten()
        val_acc = float(np.mean(y_pred == y_val.numpy()))
        return val_loss, val_acc

    def train(self, X_train, y_train, X_val, y_val, epochs=40, batch_size=32, verbose=True):
        X_train = tf.constant(X_train, dtype=tf.float32)
        y_train = tf.constant(y_train, dtype=tf.float32)
        X_val   = tf.constant(X_val,   dtype=tf.float32)
        y_val   = tf.constant(y_val,   dtype=tf.float32)

        ds = (tf.data.Dataset.from_tensor_slices((X_train, y_train))
              .shuffle(4096).batch(batch_size).prefetch(tf.data.AUTOTUNE))

        history = {'loss': [], 'val_accuracy': [], 'val_loss': []}

        for epoch in range(epochs):
            total_loss = 0.0; nb = 0
            for xb, yb in ds:
                main_l = self._train_step(xb, yb)
                total_loss += float(main_l.numpy()); nb += 1

            avg_loss = total_loss / max(nb, 1)
            val_loss, val_acc = self._val_metrics(X_val, y_val)

            history['loss'].append(avg_loss)
            history['val_accuracy'].append(val_acc)
            history['val_loss'].append(val_loss)

            if verbose:
                print(f"Epoch {epoch+1:03d} | loss: {avg_loss:.4f} | val_loss: {val_loss:.4f} | val_acc: {val_acc:.4f}")
        return history


def plot_all_decision_boundaries(models, results, X_test, y_test):
    class Wrapper:
        def __init__(self, model): self.model = model
        def predict(self, X):
            X_tensor = tf.constant(X, dtype=tf.float32)
            preds = self.model(X_tensor)
            return (preds.numpy() > 0.5).astype(int).flatten()

    names = list(models.keys())
    n = len(names); cols = 4; rows = int(np.ceil(n / cols))
    fig, axes = plt.subplots(rows, cols, figsize=(4.6*cols, 4.2*rows))
    axes = np.array(axes).reshape(rows, cols)

    for idx, name in enumerate(names):
        r, c = divmod(idx, cols); ax = axes[r, c]
        wrapper = Wrapper(models[name])
        plot_decision_regions(X=X_test, y=y_test, clf=wrapper, ax=ax, legend=0)
        acc = results[name]['accuracy']
        ax.set_title(f"{name.upper()}  Acc: {acc:.4f}", fontsize=11, fontweight='bold')
        ax.set_xlabel('x1'); ax.set_ylabel('x2'); ax.grid(True, alpha=0.3)

    for idx in range(n, rows*cols):
        r, c = divmod(idx, cols)
        fig.delaxes(axes[r, c])

    plt.suptitle('Decision Boundaries Comparison (Yin-Yang Dataset)', fontsize=15, fontweight='bold')
    plt.tight_layout(); plt.show()

def plot_training_curves_comparison(results):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
    for name, data in results.items():
        ax1.plot(data['history']['loss'], label=f"{name}")
        ax1.plot(data['history']['val_loss'], linestyle='--', alpha=0.7, label=f"{name} (val)")
        ax2.plot(data['history']['val_accuracy'], label=f"{name}")
    ax1.set_title('Training & Validation Loss'); ax1.set_xlabel('Epoch'); ax1.set_ylabel('Loss'); ax1.grid(True); ax1.legend(ncol=2, fontsize=8)
    ax2.set_title('Validation Accuracy'); ax2.set_xlabel('Epoch'); ax2.set_ylabel('Accuracy'); ax2.grid(True); ax2.legend(ncol=2, fontsize=8)
    plt.tight_layout(); plt.show()

def print_comparison_table(results):
    print("\n" + "="*60)
    print("FINAL RESULTS COMPARISON")
    print("="*60)
    print(f"{'Rank':<6} {'Activation':<15} {'Accuracy':<12} {'Final Train Loss':<18}")
    print("-"*60)
    sorted_items = sorted(results.items(), key=lambda kv: kv[1]['accuracy'], reverse=True)
    for rank, (name, data) in enumerate(sorted_items, 1):
        print(f"{rank:<6} {name.upper():<15} {data['accuracy']:<12.4f} {data['final_loss']:<18.4f}")
    print("="*60)

def plot_k_evolution(results, model_key='lasa', title_suffix="Yin-Yang Dataset"):
    """Optional: plot k (per LASA layer) vs epoch."""
    if model_key not in results:
        print(f"[plot_k_evolution] '{model_key}' not in results."); return
    hist = results[model_key]['history']
    if 'k' not in hist or len(hist['k']) == 0:
        print("[plot_k_evolution] No k history found."); return

    K = np.array([np.array(ks, dtype=float) for ks in hist['k']], dtype=object)
    try:
        K = np.stack(K).astype(float)  
    except Exception:
        print("[plot_k_evolution] Ragged k history; cannot plot."); return

    plt.figure(figsize=(7, 4))
    for j in range(K.shape[1]):
        plt.plot(K[:, j], label=f'k[{j}]')
    plt.title(f'k evolution per LASA layer ({title_suffix})')
    plt.xlabel('Epoch'); plt.ylabel('k'); plt.grid(True, alpha=0.3)
    plt.legend(ncol=2)
    plt.tight_layout(); plt.show()


def run_all_activations_comparison_yin_yang(hidden_units=[6],
                                            num_points=2000, radius=1.0,
                                            test_size=0.2, random_state=42,
                                            epochs=40, batch_size=32,
                                            lr_main=1e-3,
                                            lr_tau=1e-2,
                                       
                                            initial_frequency=1.6,
                                            theta_degrees=45.0, lambda_window=3e-4,
                                            penalty_mode='hinge', hybrid_alpha=0.1,
                                            enforce_gain_cap=False, gain_cap=1.25,
                                            penalty_warmup_epochs=8,
                                         
                                            acc_eps=2.5e-3, loss_eps=1e-4,
                                            reverse_tau_grads=True, revert_rho_to_snapshot=True,
                                            shrink_tau_lr=True, tau_lr_decay=0.5, min_tau_lr=1e-5,
                                            shrink_penalty=True, penalty_decay=0.8, min_penalty_scale=0.05,
                                            stagnation_window=10, improve_threshold=0.05,
                                            bump_delta_k=1.0, min_epochs_between_bumps=10,
                                          
                                            acc_drop_threshold=0.02,
                                            verbose=True):
    activation_types = [
        'lasa', 'relu', 'leaky_relu', 'elu', 'softplus',
        'swish', 'mish', 'gelu', 'sine', 'sigmoid', 'tanh'
    ]

    print("="*60)
    print("ACTIVATION FUNCTIONS COMPARISON - Yin-Yang Dataset")
    print("="*60)
    print("Config:",
          f"\n  hidden_units={hidden_units}",
          f"\n  epochs={epochs}  batch_size={batch_size}",
          f"\n  lr_main={lr_main}  (lr_tau={lr_tau} for LASA only)",
          f"\n  dataset: num_points={num_points}, radius={radius}",
          f"\n  LASA: theta={theta_degrees}°, lambda_window={lambda_window}, penalty_mode={penalty_mode}, "
          f"enforce_gain_cap={enforce_gain_cap}, gain_cap={gain_cap}",
          f"\n  Rule: if post-bump drop > {acc_drop_threshold:.2f}, revert-once, then one final +1 bump and disable scheduler"
          )

    # data
    X, y = generate_yin_yang(num_points=num_points, radius=radius)
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, random_state=random_state, stratify=y
    )
    print(f"\nDataset: total={num_points} | train={len(X_train)} | test={len(X_test)}")
    print(f"Class counts: 0->{np.sum(y==0)}  1->{np.sum(y==1)}")

    results = {}
    models  = {}

    for act in activation_types:
        print("\n" + "-"*60)
        print(f"Training with {act.upper()} activation...")
        tf.keras.backend.clear_session()
        np.random.seed(random_state); tf.random.set_seed(random_state)

        model = create_model(
            activation_type=act,
            hidden_units=hidden_units,
            initial_frequency=initial_frequency,
            theta_degrees=theta_degrees, lambda_window=lambda_window,
            penalty_mode=penalty_mode, hybrid_alpha=hybrid_alpha,
            enforce_gain_cap=enforce_gain_cap, gain_cap=gain_cap
        )

        if act.lower() == 'lasa':
            trainer = LASATrainer(
                model,
                lr_main=lr_main, lr_tau=lr_tau,
                clipnorm_main=1.0, clipnorm_tau=0.5,
                penalty_warmup_epochs=penalty_warmup_epochs,
                acc_eps=acc_eps, loss_eps=loss_eps,
                reverse_tau_grads=reverse_tau_grads, revert_rho_to_snapshot=revert_rho_to_snapshot,
                shrink_tau_lr=shrink_tau_lr, tau_lr_decay=tau_lr_decay, min_tau_lr=min_tau_lr,
                shrink_penalty=shrink_penalty, penalty_decay=penalty_decay, min_penalty_scale=min_penalty_scale,
                stagnation_window=stagnation_window, improve_threshold=improve_threshold,
                bump_delta_k=bump_delta_k, min_epochs_between_bumps=min_epochs_between_bumps,
                acc_drop_threshold=acc_drop_threshold
            )
            hist = trainer.train(
                tf.constant(X_train), tf.constant(y_train, np.float32),
                tf.constant(X_test),  tf.constant(y_test,  np.float32),
                epochs=epochs, batch_size=batch_size, verbose=verbose
            )
        else:
            trainer = RegularTrainer(model, lr=lr_main, clipnorm=1.0)
            hist = trainer.train(
                tf.constant(X_train), tf.constant(y_train, np.float32),
                tf.constant(X_test),  tf.constant(y_test,  np.float32),
                epochs=epochs, batch_size=batch_size, verbose=verbose
            )

   
        preds = model(tf.constant(X_test, tf.float32))
        y_true = tf.constant(y_test, np.float32)
        y_true = tf.reshape(y_true, (-1, 1))
        final_loss = float(tf.keras.losses.BinaryCrossentropy()(y_true, preds).numpy())
        y_pred = (preds.numpy() > 0.5).astype(int).flatten()
        final_acc  = float(np.mean(y_pred == y_test))

        results[act] = {'accuracy': final_acc, 'history': hist, 'final_loss': hist['loss'][-1]}
        models[act]  = model

        print(f"[{act.upper()}] Acc: {final_acc:.4f} | Final train loss: {hist['loss'][-1]:.4f}")

    return models, results, X, y, X_test, y_test



if __name__ == "__main__":
    models, results, X, y, X_test, y_test = run_all_activations_comparison_yin_yang(
        hidden_units=[6],
        num_points=2000, radius=1.0,
        test_size=0.2, random_state=42,
        epochs=40, batch_size=32,
        lr_main=1e-3, lr_tau=1e-2,        
        initial_frequency=1.6,
        theta_degrees=45.0, lambda_window=3e-4,
        penalty_mode='hinge', hybrid_alpha=0.1,
        enforce_gain_cap=False, gain_cap=1.25,
        penalty_warmup_epochs=8,
        acc_eps=2.5e-3, loss_eps=1e-4,
        reverse_tau_grads=True, revert_rho_to_snapshot=True,
        shrink_tau_lr=True, tau_lr_decay=0.5, min_tau_lr=1e-5,
        shrink_penalty=True, penalty_decay=0.8, min_penalty_scale=0.05,
        stagnation_window=10, improve_threshold=0.05,
        bump_delta_k=1.0, min_epochs_between_bumps=10,
        acc_drop_threshold=0.02,          
        verbose=True
    )


    print("\n")
    print("="*60)
    print("ACTIVATIONS: lasa, relu, leaky_relu, elu, softplus, swish, mish, gelu, sine, sigmoid, tanh")
    print("="*60)
    print_comparison_table(results)
    plot_all_decision_boundaries(models, results, X_test, y_test)
    plot_training_curves_comparison(results)

  
    plot_k_evolution(results, model_key='lasa', title_suffix="Yin-Yang Dataset")
# Out:
# <style>.output_scroll {height:auto !important; max-height:none !important;}</style>
# ============================================================
# GPU CONFIGURATION
# ============================================================
# No GPUs available, using CPU
# Mixed precision policy: float32
# ============================================================
#
# ============================================================
# ACTIVATION FUNCTIONS COMPARISON - Yin-Yang Dataset
# ============================================================
# Config:
#   hidden_units=[6]
#   epochs=40  batch_size=32
#   lr_main=0.001  (lr_tau=0.01 for LASA only)
#   dataset: num_points=2000, radius=1.0
#   LASA: theta=45.0°, lambda_window=0.0003, penalty_mode=hinge, enforce_gain_cap=False, gain_cap=1.25
#   Rule: if post-bump drop > 0.02, revert-once, then one final +1 bump and disable scheduler
#
# Dataset: total=2000 | train=1600 | test=400
# Class counts: 0->1013  1->987
#
# ------------------------------------------------------------
# Training with LASA activation...
# Epoch 001 | loss: 0.6597 | val_loss: 0.6334 | val_acc: 0.8175
# Epoch 002 | loss: 0.6157 | val_loss: 0.5931 | val_acc: 0.8275
# Epoch 003 | loss: 0.5832 | val_loss: 0.5635 | val_acc: 0.8300
# Epoch 004 | loss: 0.5599 | val_loss: 0.5422 | val_acc: 0.8350
# Epoch 005 | loss: 0.5434 | val_loss: 0.5259 | val_acc: 0.8375
# Epoch 006 | loss: 0.5308 | val_loss: 0.5142 | val_acc: 0.8425
# Epoch 007 | loss: 0.5218 | val_loss: 0.5050 | val_acc: 0.8475
# Epoch 008 | loss: 0.5138 | val_loss: 0.4962 | val_acc: 0.8575
# Epoch 009 | loss: 0.5067 | val_loss: 0.4882 | val_acc: 0.8575
# Epoch 010 | loss: 0.4982 | val_loss: 0.4807 | val_acc: 0.8550
# Epoch 011 | loss: 0.4827 | val_loss: 0.4565 | val_acc: 0.8500
# Epoch 012 | loss: 0.4626 | val_loss: 0.4413 | val_acc: 0.8375
# Epoch 013 | loss: 0.4486 | val_loss: 0.4297 | val_acc: 0.8250
# Epoch 014 | loss: 0.4366 | val_loss: 0.4206 | val_acc: 0.8200
# Epoch 015 | loss: 0.4277 | val_loss: 0.4138 | val_acc: 0.8075
# Epoch 016 | loss: 0.4208 | val_loss: 0.4080 | val_acc: 0.8025
# Epoch 017 | loss: 0.4158 | val_loss: 0.4032 | val_acc: 0.8000
# Epoch 018 | loss: 0.4105 | val_loss: 0.3991 | val_acc: 0.8000
# Epoch 019 | loss: 0.4059 | val_loss: 0.3961 | val_acc: 0.8000
# Epoch 020 | loss: 0.4023 | val_loss: 0.3928 | val_acc: 0.7950
# Epoch 021 | loss: 0.4228 | val_loss: 0.3861 | val_acc: 0.8100
# Epoch 022 | loss: 0.3807 | val_loss: 0.3688 | val_acc: 0.8075
# Epoch 023 | loss: 0.3651 | val_loss: 0.3543 | val_acc: 0.8050
# Epoch 024 | loss: 0.3503 | val_loss: 0.3418 | val_acc: 0.8075
# Epoch 025 | loss: 0.3388 | val_loss: 0.3313 | val_acc: 0.8100
# Epoch 026 | loss: 0.3286 | val_loss: 0.3226 | val_acc: 0.8225
# Epoch 027 | loss: 0.3202 | val_loss: 0.3146 | val_acc: 0.8300
# Epoch 028 | loss: 0.3129 | val_loss: 0.3080 | val_acc: 0.8350
# Epoch 029 | loss: 0.3063 | val_loss: 0.3029 | val_acc: 0.8425
# Epoch 030 | loss: 0.3007 | val_loss: 0.2970 | val_acc: 0.8550
# Epoch 031 | loss: 0.3892 | val_loss: 0.3056 | val_acc: 0.8600
# Epoch 032 | loss: 0.3475 | val_loss: 0.3015 | val_acc: 0.8875
# Epoch 033 | loss: 0.2939 | val_loss: 0.2875 | val_acc: 0.8975
# Epoch 034 | loss: 0.2818 | val_loss: 0.2749 | val_acc: 0.9050
# Epoch 035 | loss: 0.2682 | val_loss: 0.2636 | val_acc: 0.9075
# Epoch 036 | loss: 0.2568 | val_loss: 0.2541 | val_acc: 0.9125
# Epoch 037 | loss: 0.2486 | val_loss: 0.2462 | val_acc: 0.9200
# Epoch 038 | loss: 0.2424 | val_loss: 0.2417 | val_acc: 0.9150
# Epoch 039 | loss: 0.2375 | val_loss: 0.2368 | val_acc: 0.9150
# Epoch 040 | loss: 0.2334 | val_loss: 0.2342 | val_acc: 0.9175
# [LASA] Acc: 0.9175 | Final train loss: 0.2334
#
# ------------------------------------------------------------
# Training with RELU activation...
# Epoch 001 | loss: 0.7165 | val_loss: 0.7095 | val_acc: 0.4725
# Epoch 002 | loss: 0.7044 | val_loss: 0.6972 | val_acc: 0.5575
# Epoch 003 | loss: 0.6921 | val_loss: 0.6842 | val_acc: 0.6550
# Epoch 004 | loss: 0.6793 | val_loss: 0.6707 | val_acc: 0.6900
# Epoch 005 | loss: 0.6660 | val_loss: 0.6564 | val_acc: 0.7175
# Epoch 006 | loss: 0.6526 | val_loss: 0.6423 | val_acc: 0.7900
# Epoch 007 | loss: 0.6390 | val_loss: 0.6281 | val_acc: 0.8200
# Epoch 008 | loss: 0.6253 | val_loss: 0.6134 | val_acc: 0.8350
# Epoch 009 | loss: 0.6117 | val_loss: 0.5990 | val_acc: 0.8450
# Epoch 010 | loss: 0.5980 | val_loss: 0.5845 | val_acc: 0.8575
# Epoch 011 | loss: 0.5847 | val_loss: 0.5703 | val_acc: 0.8675
# Epoch 012 | loss: 0.5718 | val_loss: 0.5564 | val_acc: 0.8675
# Epoch 013 | loss: 0.5595 | val_loss: 0.5436 | val_acc: 0.8650
# Epoch 014 | loss: 0.5477 | val_loss: 0.5306 | val_acc: 0.8575
# Epoch 015 | loss: 0.5367 | val_loss: 0.5196 | val_acc: 0.8550
# Epoch 016 | loss: 0.5271 | val_loss: 0.5103 | val_acc: 0.8475
# Epoch 017 | loss: 0.5190 | val_loss: 0.5028 | val_acc: 0.8475
# Epoch 018 | loss: 0.5126 | val_loss: 0.4962 | val_acc: 0.8500
# Epoch 019 | loss: 0.5069 | val_loss: 0.4910 | val_acc: 0.8425
# Epoch 020 | loss: 0.5018 | val_loss: 0.4861 | val_acc: 0.8475
# Epoch 021 | loss: 0.4972 | val_loss: 0.4818 | val_acc: 0.8450
# Epoch 022 | loss: 0.4930 | val_loss: 0.4777 | val_acc: 0.8475
# Epoch 023 | loss: 0.4892 | val_loss: 0.4741 | val_acc: 0.8500
# Epoch 024 | loss: 0.4858 | val_loss: 0.4709 | val_acc: 0.8500
# Epoch 025 | loss: 0.4828 | val_loss: 0.4679 | val_acc: 0.8500
# Epoch 026 | loss: 0.4800 | val_loss: 0.4652 | val_acc: 0.8500
# Epoch 027 | loss: 0.4773 | val_loss: 0.4628 | val_acc: 0.8500
# Epoch 028 | loss: 0.4750 | val_loss: 0.4604 | val_acc: 0.8525
# Epoch 029 | loss: 0.4728 | val_loss: 0.4583 | val_acc: 0.8500
# Epoch 030 | loss: 0.4707 | val_loss: 0.4561 | val_acc: 0.8525
# Epoch 031 | loss: 0.4691 | val_loss: 0.4542 | val_acc: 0.8550
# Epoch 032 | loss: 0.4674 | val_loss: 0.4528 | val_acc: 0.8500
# Epoch 033 | loss: 0.4659 | val_loss: 0.4510 | val_acc: 0.8525
# Epoch 034 | loss: 0.4645 | val_loss: 0.4495 | val_acc: 0.8525
# Epoch 035 | loss: 0.4632 | val_loss: 0.4481 | val_acc: 0.8500
# Epoch 036 | loss: 0.4619 | val_loss: 0.4468 | val_acc: 0.8500
# Epoch 037 | loss: 0.4606 | val_loss: 0.4456 | val_acc: 0.8500
# Epoch 038 | loss: 0.4595 | val_loss: 0.4443 | val_acc: 0.8500
# Epoch 039 | loss: 0.4584 | val_loss: 0.4430 | val_acc: 0.8525
# Epoch 040 | loss: 0.4573 | val_loss: 0.4419 | val_acc: 0.8525
# [RELU] Acc: 0.8525 | Final train loss: 0.4573
#
# ------------------------------------------------------------
# Training with LEAKY_RELU activation...
# Epoch 001 | loss: 0.7304 | val_loss: 0.7128 | val_acc: 0.5025
# Epoch 002 | loss: 0.6977 | val_loss: 0.6826 | val_acc: 0.5025
# Epoch 003 | loss: 0.6701 | val_loss: 0.6553 | val_acc: 0.6625
# Epoch 004 | loss: 0.6453 | val_loss: 0.6309 | val_acc: 0.6950
# Epoch 005 | loss: 0.6228 | val_loss: 0.6085 | val_acc: 0.7375
# Epoch 006 | loss: 0.6023 | val_loss: 0.5888 | val_acc: 0.7750
# Epoch 007 | loss: 0.5842 | val_loss: 0.5711 | val_acc: 0.8000
# Epoch 008 | loss: 0.5682 | val_loss: 0.5554 | val_acc: 0.8200
# Epoch 009 | loss: 0.5544 | val_loss: 0.5424 | val_acc: 0.8325
# Epoch 010 | loss: 0.5426 | val_loss: 0.5312 | val_acc: 0.8450
# Epoch 011 | loss: 0.5326 | val_loss: 0.5214 | val_acc: 0.8475
# Epoch 012 | loss: 0.5242 | val_loss: 0.5132 | val_acc: 0.8550
# Epoch 013 | loss: 0.5171 | val_loss: 0.5064 | val_acc: 0.8525
# Epoch 014 | loss: 0.5111 | val_loss: 0.5001 | val_acc: 0.8550
# Epoch 015 | loss: 0.5061 | val_loss: 0.4950 | val_acc: 0.8575
# Epoch 016 | loss: 0.5019 | val_loss: 0.4905 | val_acc: 0.8575
# Epoch 017 | loss: 0.4982 | val_loss: 0.4868 | val_acc: 0.8600
# Epoch 018 | loss: 0.4951 | val_loss: 0.4832 | val_acc: 0.8600
# Epoch 019 | loss: 0.4923 | val_loss: 0.4803 | val_acc: 0.8600
# Epoch 020 | loss: 0.4898 | val_loss: 0.4777 | val_acc: 0.8600
# Epoch 021 | loss: 0.4875 | val_loss: 0.4753 | val_acc: 0.8550
# Epoch 022 | loss: 0.4855 | val_loss: 0.4729 | val_acc: 0.8600
# Epoch 023 | loss: 0.4836 | val_loss: 0.4708 | val_acc: 0.8600
# Epoch 024 | loss: 0.4820 | val_loss: 0.4690 | val_acc: 0.8600
# Epoch 025 | loss: 0.4806 | val_loss: 0.4675 | val_acc: 0.8600
# Epoch 026 | loss: 0.4795 | val_loss: 0.4660 | val_acc: 0.8575
# Epoch 027 | loss: 0.4784 | val_loss: 0.4649 | val_acc: 0.8575
# Epoch 028 | loss: 0.4775 | val_loss: 0.4637 | val_acc: 0.8575
# Epoch 029 | loss: 0.4766 | val_loss: 0.4627 | val_acc: 0.8575
# Epoch 030 | loss: 0.4758 | val_loss: 0.4617 | val_acc: 0.8575
# Epoch 031 | loss: 0.4752 | val_loss: 0.4608 | val_acc: 0.8600
# Epoch 032 | loss: 0.4745 | val_loss: 0.4602 | val_acc: 0.8575
# Epoch 033 | loss: 0.4738 | val_loss: 0.4593 | val_acc: 0.8575
# Epoch 034 | loss: 0.4733 | val_loss: 0.4586 | val_acc: 0.8600
# Epoch 035 | loss: 0.4728 | val_loss: 0.4579 | val_acc: 0.8600
# Epoch 036 | loss: 0.4722 | val_loss: 0.4574 | val_acc: 0.8575
# Epoch 037 | loss: 0.4717 | val_loss: 0.4568 | val_acc: 0.8575
# Epoch 038 | loss: 0.4713 | val_loss: 0.4563 | val_acc: 0.8600
# Epoch 039 | loss: 0.4707 | val_loss: 0.4557 | val_acc: 0.8600
# Epoch 040 | loss: 0.4703 | val_loss: 0.4552 | val_acc: 0.8600
# [LEAKY_RELU] Acc: 0.8600 | Final train loss: 0.4703
#
# ------------------------------------------------------------
# Training with ELU activation...
# Epoch 001 | loss: 0.8766 | val_loss: 0.8544 | val_acc: 0.3325
# Epoch 002 | loss: 0.8249 | val_loss: 0.8071 | val_acc: 0.3625
# Epoch 003 | loss: 0.7828 | val_loss: 0.7676 | val_acc: 0.4050
# Epoch 004 | loss: 0.7479 | val_loss: 0.7348 | val_acc: 0.4625
# Epoch 005 | loss: 0.7185 | val_loss: 0.7062 | val_acc: 0.4675
# Epoch 006 | loss: 0.6929 | val_loss: 0.6818 | val_acc: 0.5225
# Epoch 007 | loss: 0.6705 | val_loss: 0.6596 | val_acc: 0.5750
# Epoch 008 | loss: 0.6501 | val_loss: 0.6390 | val_acc: 0.6600
# Epoch 009 | loss: 0.6315 | val_loss: 0.6202 | val_acc: 0.7125
# Epoch 010 | loss: 0.6141 | val_loss: 0.6025 | val_acc: 0.7650
# Epoch 011 | loss: 0.5980 | val_loss: 0.5860 | val_acc: 0.8075
# Epoch 012 | loss: 0.5831 | val_loss: 0.5708 | val_acc: 0.8300
# Epoch 013 | loss: 0.5696 | val_loss: 0.5571 | val_acc: 0.8425
# Epoch 014 | loss: 0.5576 | val_loss: 0.5445 | val_acc: 0.8475
# Epoch 015 | loss: 0.5471 | val_loss: 0.5339 | val_acc: 0.8525
# Epoch 016 | loss: 0.5382 | val_loss: 0.5247 | val_acc: 0.8500
# Epoch 017 | loss: 0.5307 | val_loss: 0.5172 | val_acc: 0.8450
# Epoch 018 | loss: 0.5247 | val_loss: 0.5105 | val_acc: 0.8450
# Epoch 019 | loss: 0.5196 | val_loss: 0.5054 | val_acc: 0.8450
# Epoch 020 | loss: 0.5156 | val_loss: 0.5014 | val_acc: 0.8450
# Epoch 021 | loss: 0.5126 | val_loss: 0.4981 | val_acc: 0.8425
# Epoch 022 | loss: 0.5103 | val_loss: 0.4953 | val_acc: 0.8425
# Epoch 023 | loss: 0.5084 | val_loss: 0.4932 | val_acc: 0.8425
# Epoch 024 | loss: 0.5070 | val_loss: 0.4916 | val_acc: 0.8425
# Epoch 025 | loss: 0.5060 | val_loss: 0.4904 | val_acc: 0.8425
# Epoch 026 | loss: 0.5053 | val_loss: 0.4892 | val_acc: 0.8425
# Epoch 027 | loss: 0.5046 | val_loss: 0.4885 | val_acc: 0.8400
# Epoch 028 | loss: 0.5042 | val_loss: 0.4878 | val_acc: 0.8425
# Epoch 029 | loss: 0.5038 | val_loss: 0.4873 | val_acc: 0.8400
# Epoch 030 | loss: 0.5035 | val_loss: 0.4868 | val_acc: 0.8425
# Epoch 031 | loss: 0.5034 | val_loss: 0.4864 | val_acc: 0.8425
# Epoch 032 | loss: 0.5031 | val_loss: 0.4864 | val_acc: 0.8400
# Epoch 033 | loss: 0.5030 | val_loss: 0.4860 | val_acc: 0.8425
# Epoch 034 | loss: 0.5029 | val_loss: 0.4858 | val_acc: 0.8425
# Epoch 035 | loss: 0.5028 | val_loss: 0.4856 | val_acc: 0.8425
# Epoch 036 | loss: 0.5026 | val_loss: 0.4855 | val_acc: 0.8400
# Epoch 037 | loss: 0.5024 | val_loss: 0.4854 | val_acc: 0.8400
# Epoch 038 | loss: 0.5024 | val_loss: 0.4853 | val_acc: 0.8400
# Epoch 039 | loss: 0.5022 | val_loss: 0.4851 | val_acc: 0.8425
# Epoch 040 | loss: 0.5022 | val_loss: 0.4851 | val_acc: 0.8400
# [ELU] Acc: 0.8400 | Final train loss: 0.5022
#
# ------------------------------------------------------------
# Training with SOFTPLUS activation...
# Epoch 001 | loss: 0.7671 | val_loss: 0.7567 | val_acc: 0.3775
# Epoch 002 | loss: 0.7482 | val_loss: 0.7418 | val_acc: 0.4075
# Epoch 003 | loss: 0.7350 | val_loss: 0.7299 | val_acc: 0.4200
# Epoch 004 | loss: 0.7241 | val_loss: 0.7192 | val_acc: 0.4575
# Epoch 005 | loss: 0.7138 | val_loss: 0.7089 | val_acc: 0.4925
# Epoch 006 | loss: 0.7039 | val_loss: 0.6989 | val_acc: 0.5050
# Epoch 007 | loss: 0.6944 | val_loss: 0.6888 | val_acc: 0.4975
# Epoch 008 | loss: 0.6841 | val_loss: 0.6783 | val_acc: 0.5250
# Epoch 009 | loss: 0.6741 | val_loss: 0.6675 | val_acc: 0.5925
# Epoch 010 | loss: 0.6631 | val_loss: 0.6560 | val_acc: 0.6650
# Epoch 011 | loss: 0.6518 | val_loss: 0.6440 | val_acc: 0.7075
# Epoch 012 | loss: 0.6399 | val_loss: 0.6313 | val_acc: 0.7575
# Epoch 013 | loss: 0.6276 | val_loss: 0.6183 | val_acc: 0.8025
# Epoch 014 | loss: 0.6149 | val_loss: 0.6046 | val_acc: 0.8200
# Epoch 015 | loss: 0.6021 | val_loss: 0.5913 | val_acc: 0.8325
# Epoch 016 | loss: 0.5897 | val_loss: 0.5782 | val_acc: 0.8475
# Epoch 017 | loss: 0.5778 | val_loss: 0.5660 | val_acc: 0.8475
# Epoch 018 | loss: 0.5669 | val_loss: 0.5542 | val_acc: 0.8550
# Epoch 019 | loss: 0.5566 | val_loss: 0.5440 | val_acc: 0.8475
# Epoch 020 | loss: 0.5475 | val_loss: 0.5350 | val_acc: 0.8500
# Epoch 021 | loss: 0.5397 | val_loss: 0.5269 | val_acc: 0.8450
# Epoch 022 | loss: 0.5330 | val_loss: 0.5199 | val_acc: 0.8475
# Epoch 023 | loss: 0.5273 | val_loss: 0.5140 | val_acc: 0.8500
# Epoch 024 | loss: 0.5227 | val_loss: 0.5092 | val_acc: 0.8500
# Epoch 025 | loss: 0.5190 | val_loss: 0.5052 | val_acc: 0.8500
# Epoch 026 | loss: 0.5160 | val_loss: 0.5019 | val_acc: 0.8425
# Epoch 027 | loss: 0.5135 | val_loss: 0.4994 | val_acc: 0.8400
# Epoch 028 | loss: 0.5119 | val_loss: 0.4972 | val_acc: 0.8450
# Epoch 029 | loss: 0.5103 | val_loss: 0.4956 | val_acc: 0.8375
# Epoch 030 | loss: 0.5091 | val_loss: 0.4941 | val_acc: 0.8450
# Epoch 031 | loss: 0.5083 | val_loss: 0.4929 | val_acc: 0.8450
# Epoch 032 | loss: 0.5075 | val_loss: 0.4924 | val_acc: 0.8375
# Epoch 033 | loss: 0.5070 | val_loss: 0.4915 | val_acc: 0.8450
# Epoch 034 | loss: 0.5068 | val_loss: 0.4910 | val_acc: 0.8475
# Epoch 035 | loss: 0.5065 | val_loss: 0.4905 | val_acc: 0.8400
# Epoch 036 | loss: 0.5062 | val_loss: 0.4903 | val_acc: 0.8400
# Epoch 037 | loss: 0.5059 | val_loss: 0.4900 | val_acc: 0.8375
# Epoch 038 | loss: 0.5059 | val_loss: 0.4898 | val_acc: 0.8400
# Epoch 039 | loss: 0.5057 | val_loss: 0.4895 | val_acc: 0.8450
# Epoch 040 | loss: 0.5056 | val_loss: 0.4894 | val_acc: 0.8400
# [SOFTPLUS] Acc: 0.8400 | Final train loss: 0.5056
#
# ------------------------------------------------------------
# Training with SWISH activation...
# Epoch 001 | loss: 0.7332 | val_loss: 0.7238 | val_acc: 0.4525
# Epoch 002 | loss: 0.7098 | val_loss: 0.7013 | val_acc: 0.4600
# Epoch 003 | loss: 0.6892 | val_loss: 0.6806 | val_acc: 0.5700
# Epoch 004 | loss: 0.6701 | val_loss: 0.6612 | val_acc: 0.6900
# Epoch 005 | loss: 0.6521 | val_loss: 0.6423 | val_acc: 0.7825
# Epoch 006 | loss: 0.6346 | val_loss: 0.6248 | val_acc: 0.8100
# Epoch 007 | loss: 0.6182 | val_loss: 0.6077 | val_acc: 0.8225
# Epoch 008 | loss: 0.6024 | val_loss: 0.5913 | val_acc: 0.8325
# Epoch 009 | loss: 0.5878 | val_loss: 0.5763 | val_acc: 0.8425
# Epoch 010 | loss: 0.5742 | val_loss: 0.5625 | val_acc: 0.8375
# Epoch 011 | loss: 0.5620 | val_loss: 0.5501 | val_acc: 0.8400
# Epoch 012 | loss: 0.5513 | val_loss: 0.5392 | val_acc: 0.8450
# Epoch 013 | loss: 0.5421 | val_loss: 0.5300 | val_acc: 0.8375
# Epoch 014 | loss: 0.5344 | val_loss: 0.5218 | val_acc: 0.8425
# Epoch 015 | loss: 0.5282 | val_loss: 0.5155 | val_acc: 0.8450
# Epoch 016 | loss: 0.5233 | val_loss: 0.5104 | val_acc: 0.8400
# Epoch 017 | loss: 0.5194 | val_loss: 0.5065 | val_acc: 0.8450
# Epoch 018 | loss: 0.5166 | val_loss: 0.5031 | val_acc: 0.8500
# Epoch 019 | loss: 0.5143 | val_loss: 0.5007 | val_acc: 0.8425
# Epoch 020 | loss: 0.5125 | val_loss: 0.4990 | val_acc: 0.8425
# Epoch 021 | loss: 0.5113 | val_loss: 0.4976 | val_acc: 0.8425
# Epoch 022 | loss: 0.5104 | val_loss: 0.4963 | val_acc: 0.8450
# Epoch 023 | loss: 0.5096 | val_loss: 0.4954 | val_acc: 0.8450
# Epoch 024 | loss: 0.5091 | val_loss: 0.4947 | val_acc: 0.8450
# Epoch 025 | loss: 0.5087 | val_loss: 0.4942 | val_acc: 0.8475
# Epoch 026 | loss: 0.5085 | val_loss: 0.4937 | val_acc: 0.8450
# Epoch 027 | loss: 0.5081 | val_loss: 0.4934 | val_acc: 0.8450
# Epoch 028 | loss: 0.5080 | val_loss: 0.4930 | val_acc: 0.8450
# Epoch 029 | loss: 0.5078 | val_loss: 0.4928 | val_acc: 0.8450
# Epoch 030 | loss: 0.5075 | val_loss: 0.4925 | val_acc: 0.8475
# Epoch 031 | loss: 0.5075 | val_loss: 0.4923 | val_acc: 0.8500
# Epoch 032 | loss: 0.5073 | val_loss: 0.4923 | val_acc: 0.8450
# Epoch 033 | loss: 0.5071 | val_loss: 0.4920 | val_acc: 0.8475
# Epoch 034 | loss: 0.5071 | val_loss: 0.4919 | val_acc: 0.8525
# Epoch 035 | loss: 0.5070 | val_loss: 0.4917 | val_acc: 0.8475
# Epoch 036 | loss: 0.5068 | val_loss: 0.4917 | val_acc: 0.8475
# Epoch 037 | loss: 0.5066 | val_loss: 0.4916 | val_acc: 0.8450
# Epoch 038 | loss: 0.5067 | val_loss: 0.4916 | val_acc: 0.8450
# Epoch 039 | loss: 0.5065 | val_loss: 0.4914 | val_acc: 0.8475
# Epoch 040 | loss: 0.5064 | val_loss: 0.4914 | val_acc: 0.8450
# [SWISH] Acc: 0.8450 | Final train loss: 0.5064
#
# ------------------------------------------------------------
# Training with MISH activation...
# Epoch 001 | loss: 0.7111 | val_loss: 0.7005 | val_acc: 0.5825
# Epoch 002 | loss: 0.6848 | val_loss: 0.6747 | val_acc: 0.6375
# Epoch 003 | loss: 0.6612 | val_loss: 0.6508 | val_acc: 0.7725
# Epoch 004 | loss: 0.6396 | val_loss: 0.6291 | val_acc: 0.8100
# Epoch 005 | loss: 0.6196 | val_loss: 0.6082 | val_acc: 0.8100
# Epoch 006 | loss: 0.6008 | val_loss: 0.5896 | val_acc: 0.8250
# Epoch 007 | loss: 0.5838 | val_loss: 0.5724 | val_acc: 0.8250
# Epoch 008 | loss: 0.5681 | val_loss: 0.5567 | val_acc: 0.8325
# Epoch 009 | loss: 0.5547 | val_loss: 0.5432 | val_acc: 0.8425
# Epoch 010 | loss: 0.5429 | val_loss: 0.5319 | val_acc: 0.8450
# Epoch 011 | loss: 0.5333 | val_loss: 0.5226 | val_acc: 0.8525
# Epoch 012 | loss: 0.5256 | val_loss: 0.5150 | val_acc: 0.8525
# Epoch 013 | loss: 0.5196 | val_loss: 0.5095 | val_acc: 0.8600
# Epoch 014 | loss: 0.5152 | val_loss: 0.5047 | val_acc: 0.8650
# Epoch 015 | loss: 0.5119 | val_loss: 0.5014 | val_acc: 0.8675
# Epoch 016 | loss: 0.5098 | val_loss: 0.4990 | val_acc: 0.8650
# Epoch 017 | loss: 0.5082 | val_loss: 0.4974 | val_acc: 0.8650
# Epoch 018 | loss: 0.5071 | val_loss: 0.4959 | val_acc: 0.8700
# Epoch 019 | loss: 0.5064 | val_loss: 0.4951 | val_acc: 0.8675
# Epoch 020 | loss: 0.5058 | val_loss: 0.4945 | val_acc: 0.8675
# Epoch 021 | loss: 0.5055 | val_loss: 0.4942 | val_acc: 0.8675
# Epoch 022 | loss: 0.5053 | val_loss: 0.4936 | val_acc: 0.8675
# Epoch 023 | loss: 0.5051 | val_loss: 0.4933 | val_acc: 0.8675
# Epoch 024 | loss: 0.5050 | val_loss: 0.4931 | val_acc: 0.8675
# Epoch 025 | loss: 0.5050 | val_loss: 0.4929 | val_acc: 0.8675
# Epoch 026 | loss: 0.5050 | val_loss: 0.4928 | val_acc: 0.8675
# Epoch 027 | loss: 0.5049 | val_loss: 0.4927 | val_acc: 0.8675
# Epoch 028 | loss: 0.5049 | val_loss: 0.4926 | val_acc: 0.8675
# Epoch 029 | loss: 0.5049 | val_loss: 0.4925 | val_acc: 0.8675
# Epoch 030 | loss: 0.5047 | val_loss: 0.4924 | val_acc: 0.8675
# Epoch 031 | loss: 0.5049 | val_loss: 0.4923 | val_acc: 0.8675
# Epoch 032 | loss: 0.5048 | val_loss: 0.4924 | val_acc: 0.8675
# Epoch 033 | loss: 0.5047 | val_loss: 0.4923 | val_acc: 0.8675
# Epoch 034 | loss: 0.5048 | val_loss: 0.4923 | val_acc: 0.8675
# Epoch 035 | loss: 0.5048 | val_loss: 0.4922 | val_acc: 0.8675
# Epoch 036 | loss: 0.5047 | val_loss: 0.4922 | val_acc: 0.8675
# Epoch 037 | loss: 0.5046 | val_loss: 0.4922 | val_acc: 0.8650
# Epoch 038 | loss: 0.5047 | val_loss: 0.4922 | val_acc: 0.8675
# Epoch 039 | loss: 0.5046 | val_loss: 0.4921 | val_acc: 0.8675
# Epoch 040 | loss: 0.5046 | val_loss: 0.4921 | val_acc: 0.8675
# [MISH] Acc: 0.8675 | Final train loss: 0.5046
#
# ------------------------------------------------------------
# Training with GELU activation...
# Epoch 001 | loss: 0.7693 | val_loss: 0.7619 | val_acc: 0.4225
# Epoch 002 | loss: 0.7446 | val_loss: 0.7389 | val_acc: 0.4600
# Epoch 003 | loss: 0.7243 | val_loss: 0.7187 | val_acc: 0.5000
# Epoch 004 | loss: 0.7055 | val_loss: 0.6992 | val_acc: 0.5000
# Epoch 005 | loss: 0.6867 | val_loss: 0.6788 | val_acc: 0.5000
# Epoch 006 | loss: 0.6668 | val_loss: 0.6578 | val_acc: 0.5625
# Epoch 007 | loss: 0.6462 | val_loss: 0.6358 | val_acc: 0.6425
# Epoch 008 | loss: 0.6248 | val_loss: 0.6133 | val_acc: 0.7000
# Epoch 009 | loss: 0.6039 | val_loss: 0.5917 | val_acc: 0.7475
# Epoch 010 | loss: 0.5838 | val_loss: 0.5715 | val_acc: 0.8025
# Epoch 011 | loss: 0.5658 | val_loss: 0.5538 | val_acc: 0.8175
# Epoch 012 | loss: 0.5505 | val_loss: 0.5387 | val_acc: 0.8400
# Epoch 013 | loss: 0.5380 | val_loss: 0.5268 | val_acc: 0.8450
# Epoch 014 | loss: 0.5283 | val_loss: 0.5169 | val_acc: 0.8500
# Epoch 015 | loss: 0.5210 | val_loss: 0.5099 | val_acc: 0.8550
# Epoch 016 | loss: 0.5158 | val_loss: 0.5047 | val_acc: 0.8600
# Epoch 017 | loss: 0.5120 | val_loss: 0.5010 | val_acc: 0.8625
# Epoch 018 | loss: 0.5095 | val_loss: 0.4980 | val_acc: 0.8650
# Epoch 019 | loss: 0.5077 | val_loss: 0.4961 | val_acc: 0.8625
# Epoch 020 | loss: 0.5063 | val_loss: 0.4948 | val_acc: 0.8650
# Epoch 021 | loss: 0.5055 | val_loss: 0.4938 | val_acc: 0.8575
# Epoch 022 | loss: 0.5049 | val_loss: 0.4928 | val_acc: 0.8600
# Epoch 023 | loss: 0.5045 | val_loss: 0.4922 | val_acc: 0.8600
# Epoch 024 | loss: 0.5042 | val_loss: 0.4918 | val_acc: 0.8625
# Epoch 025 | loss: 0.5040 | val_loss: 0.4914 | val_acc: 0.8650
# Epoch 026 | loss: 0.5039 | val_loss: 0.4911 | val_acc: 0.8650
# Epoch 027 | loss: 0.5038 | val_loss: 0.4910 | val_acc: 0.8600
# Epoch 028 | loss: 0.5038 | val_loss: 0.4908 | val_acc: 0.8650
# Epoch 029 | loss: 0.5037 | val_loss: 0.4907 | val_acc: 0.8600
# Epoch 030 | loss: 0.5036 | val_loss: 0.4905 | val_acc: 0.8650
# Epoch 031 | loss: 0.5037 | val_loss: 0.4903 | val_acc: 0.8650
# Epoch 032 | loss: 0.5036 | val_loss: 0.4905 | val_acc: 0.8600
# Epoch 033 | loss: 0.5035 | val_loss: 0.4903 | val_acc: 0.8650
# Epoch 034 | loss: 0.5036 | val_loss: 0.4902 | val_acc: 0.8650
# Epoch 035 | loss: 0.5036 | val_loss: 0.4901 | val_acc: 0.8650
# Epoch 036 | loss: 0.5035 | val_loss: 0.4902 | val_acc: 0.8650
# Epoch 037 | loss: 0.5034 | val_loss: 0.4901 | val_acc: 0.8600
# Epoch 038 | loss: 0.5035 | val_loss: 0.4901 | val_acc: 0.8650
# Epoch 039 | loss: 0.5034 | val_loss: 0.4901 | val_acc: 0.8650
# Epoch 040 | loss: 0.5034 | val_loss: 0.4901 | val_acc: 0.8625
# [GELU] Acc: 0.8625 | Final train loss: 0.5034
#
# ------------------------------------------------------------
# Training with SINE activation...
# Epoch 001 | loss: 0.6223 | val_loss: 0.6038 | val_acc: 0.7200
# Epoch 002 | loss: 0.5960 | val_loss: 0.5787 | val_acc: 0.7650
# Epoch 003 | loss: 0.5743 | val_loss: 0.5576 | val_acc: 0.7975
# Epoch 004 | loss: 0.5562 | val_loss: 0.5404 | val_acc: 0.8200
# Epoch 005 | loss: 0.5419 | val_loss: 0.5261 | val_acc: 0.8425
# Epoch 006 | loss: 0.5306 | val_loss: 0.5159 | val_acc: 0.8450
# Epoch 007 | loss: 0.5225 | val_loss: 0.5083 | val_acc: 0.8550
# Epoch 008 | loss: 0.5164 | val_loss: 0.5022 | val_acc: 0.8525
# Epoch 009 | loss: 0.5124 | val_loss: 0.4982 | val_acc: 0.8525
# Epoch 010 | loss: 0.5095 | val_loss: 0.4955 | val_acc: 0.8500
# Epoch 011 | loss: 0.5075 | val_loss: 0.4934 | val_acc: 0.8525
# Epoch 012 | loss: 0.5062 | val_loss: 0.4918 | val_acc: 0.8500
# Epoch 013 | loss: 0.5053 | val_loss: 0.4909 | val_acc: 0.8500
# Epoch 014 | loss: 0.5047 | val_loss: 0.4900 | val_acc: 0.8500
# Epoch 015 | loss: 0.5043 | val_loss: 0.4894 | val_acc: 0.8500
# Epoch 016 | loss: 0.5041 | val_loss: 0.4890 | val_acc: 0.8500
# Epoch 017 | loss: 0.5040 | val_loss: 0.4888 | val_acc: 0.8500
# Epoch 018 | loss: 0.5039 | val_loss: 0.4884 | val_acc: 0.8500
# Epoch 019 | loss: 0.5038 | val_loss: 0.4882 | val_acc: 0.8500
# Epoch 020 | loss: 0.5036 | val_loss: 0.4882 | val_acc: 0.8500
# Epoch 021 | loss: 0.5036 | val_loss: 0.4882 | val_acc: 0.8500
# Epoch 022 | loss: 0.5036 | val_loss: 0.4879 | val_acc: 0.8500
# Epoch 023 | loss: 0.5034 | val_loss: 0.4878 | val_acc: 0.8500
# Epoch 024 | loss: 0.5034 | val_loss: 0.4878 | val_acc: 0.8500
# Epoch 025 | loss: 0.5034 | val_loss: 0.4878 | val_acc: 0.8500
# Epoch 026 | loss: 0.5034 | val_loss: 0.4877 | val_acc: 0.8500
# Epoch 027 | loss: 0.5033 | val_loss: 0.4877 | val_acc: 0.8500
# Epoch 028 | loss: 0.5033 | val_loss: 0.4876 | val_acc: 0.8500
# Epoch 029 | loss: 0.5033 | val_loss: 0.4875 | val_acc: 0.8500
# Epoch 030 | loss: 0.5032 | val_loss: 0.4875 | val_acc: 0.8500
# Epoch 031 | loss: 0.5033 | val_loss: 0.4874 | val_acc: 0.8500
# Epoch 032 | loss: 0.5032 | val_loss: 0.4876 | val_acc: 0.8500
# Epoch 033 | loss: 0.5032 | val_loss: 0.4874 | val_acc: 0.8500
# Epoch 034 | loss: 0.5032 | val_loss: 0.4874 | val_acc: 0.8500
# Epoch 035 | loss: 0.5032 | val_loss: 0.4873 | val_acc: 0.8500
# Epoch 036 | loss: 0.5031 | val_loss: 0.4874 | val_acc: 0.8500
# Epoch 037 | loss: 0.5030 | val_loss: 0.4873 | val_acc: 0.8500
# Epoch 038 | loss: 0.5031 | val_loss: 0.4874 | val_acc: 0.8500
# Epoch 039 | loss: 0.5030 | val_loss: 0.4873 | val_acc: 0.8500
# Epoch 040 | loss: 0.5030 | val_loss: 0.4873 | val_acc: 0.8500
# [SINE] Acc: 0.8500 | Final train loss: 0.5030
#
# ------------------------------------------------------------
# Training with SIGMOID activation...
# Epoch 001 | loss: 0.7384 | val_loss: 0.7295 | val_acc: 0.4925
# Epoch 002 | loss: 0.7214 | val_loss: 0.7172 | val_acc: 0.4350
# Epoch 003 | loss: 0.7119 | val_loss: 0.7089 | val_acc: 0.3550
# Epoch 004 | loss: 0.7055 | val_loss: 0.7030 | val_acc: 0.4050
# Epoch 005 | loss: 0.7001 | val_loss: 0.6978 | val_acc: 0.4675
# Epoch 006 | loss: 0.6953 | val_loss: 0.6929 | val_acc: 0.5025
# Epoch 007 | loss: 0.6909 | val_loss: 0.6882 | val_acc: 0.5625
# Epoch 008 | loss: 0.6862 | val_loss: 0.6835 | val_acc: 0.6025
# Epoch 009 | loss: 0.6818 | val_loss: 0.6789 | val_acc: 0.6550
# Epoch 010 | loss: 0.6772 | val_loss: 0.6742 | val_acc: 0.7175
# Epoch 011 | loss: 0.6727 | val_loss: 0.6694 | val_acc: 0.7625
# Epoch 012 | loss: 0.6679 | val_loss: 0.6645 | val_acc: 0.7825
# Epoch 013 | loss: 0.6630 | val_loss: 0.6594 | val_acc: 0.7825
# Epoch 014 | loss: 0.6579 | val_loss: 0.6539 | val_acc: 0.8075
# Epoch 015 | loss: 0.6527 | val_loss: 0.6483 | val_acc: 0.8175
# Epoch 016 | loss: 0.6472 | val_loss: 0.6425 | val_acc: 0.8200
# Epoch 017 | loss: 0.6415 | val_loss: 0.6365 | val_acc: 0.8300
# Epoch 018 | loss: 0.6357 | val_loss: 0.6302 | val_acc: 0.8425
# Epoch 019 | loss: 0.6296 | val_loss: 0.6238 | val_acc: 0.8350
# Epoch 020 | loss: 0.6233 | val_loss: 0.6173 | val_acc: 0.8350
# Epoch 021 | loss: 0.6170 | val_loss: 0.6106 | val_acc: 0.8325
# Epoch 022 | loss: 0.6106 | val_loss: 0.6040 | val_acc: 0.8325
# Epoch 023 | loss: 0.6042 | val_loss: 0.5972 | val_acc: 0.8425
# Epoch 024 | loss: 0.5978 | val_loss: 0.5906 | val_acc: 0.8450
# Epoch 025 | loss: 0.5916 | val_loss: 0.5839 | val_acc: 0.8450
# Epoch 026 | loss: 0.5854 | val_loss: 0.5775 | val_acc: 0.8425
# Epoch 027 | loss: 0.5793 | val_loss: 0.5711 | val_acc: 0.8400
# Epoch 028 | loss: 0.5736 | val_loss: 0.5651 | val_acc: 0.8450
# Epoch 029 | loss: 0.5679 | val_loss: 0.5592 | val_acc: 0.8450
# Epoch 030 | loss: 0.5625 | val_loss: 0.5536 | val_acc: 0.8450
# Epoch 031 | loss: 0.5574 | val_loss: 0.5481 | val_acc: 0.8450
# Epoch 032 | loss: 0.5525 | val_loss: 0.5433 | val_acc: 0.8450
# Epoch 033 | loss: 0.5480 | val_loss: 0.5384 | val_acc: 0.8450
# Epoch 034 | loss: 0.5437 | val_loss: 0.5340 | val_acc: 0.8450
# Epoch 035 | loss: 0.5398 | val_loss: 0.5296 | val_acc: 0.8450
# Epoch 036 | loss: 0.5360 | val_loss: 0.5259 | val_acc: 0.8450
# Epoch 037 | loss: 0.5326 | val_loss: 0.5222 | val_acc: 0.8450
# Epoch 038 | loss: 0.5294 | val_loss: 0.5189 | val_acc: 0.8450
# Epoch 039 | loss: 0.5265 | val_loss: 0.5158 | val_acc: 0.8475
# Epoch 040 | loss: 0.5238 | val_loss: 0.5130 | val_acc: 0.8475
# [SIGMOID] Acc: 0.8475 | Final train loss: 0.5238
#
# ------------------------------------------------------------
# Training with TANH activation...
# Epoch 001 | loss: 0.6720 | val_loss: 0.6545 | val_acc: 0.7400
# Epoch 002 | loss: 0.6417 | val_loss: 0.6256 | val_acc: 0.8025
# Epoch 003 | loss: 0.6160 | val_loss: 0.6003 | val_acc: 0.8225
# Epoch 004 | loss: 0.5938 | val_loss: 0.5788 | val_acc: 0.8425
# Epoch 005 | loss: 0.5750 | val_loss: 0.5599 | val_acc: 0.8450
# Epoch 006 | loss: 0.5591 | val_loss: 0.5448 | val_acc: 0.8475
# Epoch 007 | loss: 0.5463 | val_loss: 0.5324 | val_acc: 0.8550
# Epoch 008 | loss: 0.5357 | val_loss: 0.5219 | val_acc: 0.8525
# Epoch 009 | loss: 0.5275 | val_loss: 0.5138 | val_acc: 0.8550
# Epoch 010 | loss: 0.5209 | val_loss: 0.5076 | val_acc: 0.8525
# Epoch 011 | loss: 0.5159 | val_loss: 0.5025 | val_acc: 0.8600
# Epoch 012 | loss: 0.5120 | val_loss: 0.4985 | val_acc: 0.8550
# Epoch 013 | loss: 0.5090 | val_loss: 0.4955 | val_acc: 0.8500
# Epoch 014 | loss: 0.5068 | val_loss: 0.4929 | val_acc: 0.8525
# Epoch 015 | loss: 0.5051 | val_loss: 0.4911 | val_acc: 0.8500
# Epoch 016 | loss: 0.5040 | val_loss: 0.4897 | val_acc: 0.8500
# Epoch 017 | loss: 0.5030 | val_loss: 0.4887 | val_acc: 0.8500
# Epoch 018 | loss: 0.5024 | val_loss: 0.4876 | val_acc: 0.8525
# Epoch 019 | loss: 0.5018 | val_loss: 0.4869 | val_acc: 0.8500
# Epoch 020 | loss: 0.5013 | val_loss: 0.4865 | val_acc: 0.8500
# Epoch 021 | loss: 0.5010 | val_loss: 0.4861 | val_acc: 0.8500
# Epoch 022 | loss: 0.5007 | val_loss: 0.4856 | val_acc: 0.8500
# Epoch 023 | loss: 0.5004 | val_loss: 0.4852 | val_acc: 0.8500
# Epoch 024 | loss: 0.5002 | val_loss: 0.4850 | val_acc: 0.8500
# Epoch 025 | loss: 0.5000 | val_loss: 0.4847 | val_acc: 0.8500
# Epoch 026 | loss: 0.4999 | val_loss: 0.4845 | val_acc: 0.8500
# Epoch 027 | loss: 0.4996 | val_loss: 0.4843 | val_acc: 0.8500
# Epoch 028 | loss: 0.4996 | val_loss: 0.4841 | val_acc: 0.8500
# Epoch 029 | loss: 0.4994 | val_loss: 0.4839 | val_acc: 0.8500
# Epoch 030 | loss: 0.4992 | val_loss: 0.4837 | val_acc: 0.8500
# Epoch 031 | loss: 0.4992 | val_loss: 0.4835 | val_acc: 0.8500
# Epoch 032 | loss: 0.4989 | val_loss: 0.4836 | val_acc: 0.8500
# Epoch 033 | loss: 0.4988 | val_loss: 0.4833 | val_acc: 0.8500
# Epoch 034 | loss: 0.4986 | val_loss: 0.4832 | val_acc: 0.8500
# Epoch 035 | loss: 0.4985 | val_loss: 0.4830 | val_acc: 0.8500
# Epoch 036 | loss: 0.4983 | val_loss: 0.4830 | val_acc: 0.8500
# Epoch 037 | loss: 0.4981 | val_loss: 0.4828 | val_acc: 0.8500
# Epoch 038 | loss: 0.4980 | val_loss: 0.4827 | val_acc: 0.8500
# Epoch 039 | loss: 0.4978 | val_loss: 0.4825 | val_acc: 0.8500
# Epoch 040 | loss: 0.4977 | val_loss: 0.4824 | val_acc: 0.8500
# [TANH] Acc: 0.8500 | Final train loss: 0.4977
#
#
# ============================================================
# ACTIVATIONS: lasa, relu, leaky_relu, elu, softplus, swish, mish, gelu, sine, sigmoid, tanh
# ============================================================
#
# ============================================================
# FINAL RESULTS COMPARISON
# ============================================================
# Rank   Activation      Accuracy     Final Train Loss
# ------------------------------------------------------------
# 1      LASA            0.9175       0.2334
# 2      MISH            0.8675       0.5046
# 3      GELU            0.8625       0.5034
# 4      LEAKY_RELU      0.8600       0.4703
# 5      RELU            0.8525       0.4573
# 6      SINE            0.8500       0.5030
# 7      TANH            0.8500       0.4977
# 8      SIGMOID         0.8475       0.5238
# 9      SWISH           0.8450       0.5064
# 10     ELU             0.8400       0.5022
# 11     SOFTPLUS        0.8400       0.5056
# ============================================================
