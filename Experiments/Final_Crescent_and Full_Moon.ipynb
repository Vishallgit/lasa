# %%
pip install mlxtend
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mlxtend
#   Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 3.1 MB/s eta 0:00:00:00:010:01
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/lib/python3/dist-packages (from mlxtend) (3.5.1)
# Requirement already satisfied: pandas>=0.24.2 in ./.local/lib/python3.10/site-packages (from mlxtend) (2.3.2)
# Requirement already satisfied: joblib>=0.13.2 in /usr/lib/python3/dist-packages (from mlxtend) (0.17.0)
# Requirement already satisfied: numpy>=1.16.2 in ./.local/lib/python3.10/site-packages (from mlxtend) (1.24.3)
# Requirement already satisfied: scipy>=1.2.1 in ./.local/lib/python3.10/site-packages (from mlxtend) (1.15.3)
# Collecting scikit-learn>=1.3.1
#   Downloading scikit_learn-1.7.1-cp310-cp310-manylinux_2_27_aarch64.manylinux_2_28_aarch64.whl (9.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 16.3 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.local/lib/python3.10/site-packages (from pandas>=0.24.2->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=0.24.2->mlxtend) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.local/lib/python3.10/site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Collecting joblib>=0.13.2
#   Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.4/308.4 KB 2.2 MB/s eta 0:00:0000:01
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/lib/python3/dist-packages (from scikit-learn>=1.3.1->mlxtend) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas>=0.24.2->mlxtend) (1.16.0)
# Installing collected packages: joblib, scikit-learn, mlxtend
# Successfully installed joblib-1.5.2 mlxtend-0.23.4 scikit-learn-1.7.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import os, math, warnings
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_moons
from mlxtend.plotting import plot_decision_regions

warnings.filterwarnings('ignore')
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from IPython.display import display, HTML
display(HTML("<style>.output_scroll {height:auto !important; max-height:none !important;}</style>"))

SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)

print("="*60)
print("GPU CONFIGURATION")
print("="*60)
gpus = tf.config.list_physical_devices('GPU')
USE_GPU = bool(gpus)
if USE_GPU:
    print(f"GPUs available: {len(gpus)}")
    for gpu in gpus:
        print("  -", gpu)
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU memory growth enabled")
    except RuntimeError as e:
        print(e)
else:
    print("No GPUs available, using CPU")

policy_name = 'mixed_float16' if USE_GPU else 'float32'
tf.keras.mixed_precision.set_global_policy(policy_name)
print(f"Mixed precision policy: {tf.keras.mixed_precision.global_policy().name}")
print("="*60 + "\n")

USE_XLA = USE_GPU

def inv_softplus(y):
    y = np.maximum(float(y), 1e-6)
    return np.log(np.expm1(y))

def make_crescent_and_full_moon(n_samples, noise=0.1):
    np.random.seed(SEED)
    n_crescent = n_samples // 2
    n_moon = n_samples - n_crescent
    crescent, y_crescent = make_moons(n_samples=n_crescent, noise=noise)
    crescent = crescent * [1.2, 1.2] + [-0.5, 0.2]
    angle = np.linspace(0, 2 * np.pi, n_moon)
    moon_x = np.cos(angle) * 1.5
    moon_y = np.sin(angle) * 1.5
    moon = np.vstack([moon_x, moon_y]).T + noise * np.random.randn(n_moon, 2)
    X = np.vstack([crescent, moon])
    y = np.hstack([np.zeros(n_crescent), np.ones(n_moon)])
    return X.astype(np.float32), y.astype(np.int32)

def generate_crescent_moon(n_samples=2000, noise=0.1, random_state=42):
    np.random.seed(random_state)
    X, y = make_crescent_and_full_moon(n_samples, noise=noise)
    return X, y

class LASAActivation(tf.keras.layers.Layer):
    def __init__(self, theta_degrees=45.0, lambda_window=3e-4,
                 penalty_mode='hinge', hybrid_alpha=0.1,
                 enforce_gain_cap=False, gain_cap=1.25,
                 initial_frequency=1.6, name=None, **kwargs):
        super().__init__(name=name, **kwargs)
        self.theta_degrees     = float(theta_degrees)
        self.lambda_window     = float(lambda_window)
        self.penalty_mode      = str(penalty_mode)
        self.hybrid_alpha      = float(hybrid_alpha)
        self.enforce_gain_cap  = bool(enforce_gain_cap)
        self.gain_cap          = float(gain_cap)
        self.initial_frequency = float(initial_frequency)

    def build(self, input_shape):
        self.theta_rad = tf.constant(self.theta_degrees * math.pi/180.0, dtype=tf.float32)
        self.sin_theta = tf.sin(self.theta_rad)

        self.penalty_scale = self.add_weight(
            shape=(), name='penalty_scale', dtype=tf.float32, trainable=False,
            initializer=tf.keras.initializers.Constant(1.0)
        )

        if self.enforce_gain_cap:
            denom   = tf.maximum(self.sin_theta, tf.constant(1e-6, tf.float32))
            k_max_v = float(self.gain_cap) / float(denom.numpy())
            self.k_max = tf.constant(k_max_v, dtype=tf.float32)
            ratio = np.clip(self.initial_frequency / k_max_v, 1e-6, 1.0-1e-6)
            rho0  = np.log(ratio/(1.0 - ratio))
        else:
            self.k_max = None
            rho0 = inv_softplus(self.initial_frequency)

        self.rho = self.add_weight(shape=(), name='rho', dtype=tf.float32, trainable=True,
                                   initializer=tf.keras.initializers.Constant(float(rho0)))

    @property
    def tau_value(self):
        if self.enforce_gain_cap:
            return self.k_max * tf.nn.sigmoid(self.rho)
        return tf.nn.softplus(self.rho)

    def set_penalty_scale(self, scale):
        self.penalty_scale.assign(tf.cast(scale, tf.float32))

    def scale_down_penalty(self, factor=0.8, min_scale=0.05):
        new_scale = tf.maximum(self.penalty_scale * tf.cast(factor, tf.float32),
                               tf.constant(min_scale, tf.float32))
        self.penalty_scale.assign(new_scale)

    def _penalty(self, inputs, tau32):
        if self.lambda_window <= 0.0:
            return None
        x32     = tf.cast(inputs, tf.float32)
        cos_phi = tf.math.cos(tau32 * x32)
        abs_cos = tf.abs(cos_phi)

        if self.penalty_mode == 'hinge':
            margin = self.sin_theta
            viol   = tf.maximum(abs_cos - margin, 0.0)
            pen    = tf.reduce_mean(tf.square(viol))
        elif self.penalty_mode == 'cos2':
            pen    = tf.reduce_mean(tf.square(cos_phi))
        elif self.penalty_mode == 'hybrid':
            margin = self.sin_theta
            viol   = tf.maximum(abs_cos - margin, 0.0)
            hinge  = tf.reduce_mean(tf.square(viol))
            cos2   = tf.reduce_mean(tf.square(cos_phi))
            pen    = self.hybrid_alpha * cos2 + hinge
        else:
            raise ValueError("penalty_mode must be 'hinge', 'cos2', or 'hybrid'.")

        lw32    = tf.cast(self.lambda_window, tf.float32)
        scale32 = tf.cast(self.penalty_scale, tf.float32)
        return lw32 * scale32 * pen

    def call(self, inputs):
        tau32 = tf.cast(self.tau_value, tf.float32)
        pen = self._penalty(inputs, tau32)
        if pen is not None:
            self.add_loss(pen)
        x32 = tf.cast(inputs, tf.float32)
        y32 = tf.math.sin(tau32 * x32)
        return tf.cast(y32, inputs.dtype)

class SwishActivation(tf.keras.layers.Layer):
    def call(self, inputs):
        x = tf.cast(inputs, tf.float32)
        y = x * tf.nn.sigmoid(x)
        return tf.cast(y, inputs.dtype)

class MishActivation(tf.keras.layers.Layer):
    def call(self, inputs):
        x = tf.cast(inputs, tf.float32)
        y = x * tf.math.tanh(tf.math.softplus(x))
        return tf.cast(y, inputs.dtype)

def create_model(activation_type,
                 hidden_units=[6],
                 initial_frequency=1.6,
                 theta_degrees=45.0, lambda_window=3e-4,
                 penalty_mode='hinge', hybrid_alpha=0.1,
                 enforce_gain_cap=False, gain_cap=1.25):
    with tf.device('/GPU:0' if USE_GPU else '/CPU:0'):
        model = tf.keras.Sequential([tf.keras.layers.Input(shape=(2,))])
        for i, units in enumerate(hidden_units):
            model.add(tf.keras.layers.Dense(units, name=f'dense_{i}'))
            a = activation_type.lower()
            if a == 'lasa':
                model.add(LASAActivation(
                    theta_degrees=theta_degrees,
                    lambda_window=lambda_window,
                    penalty_mode=penalty_mode, hybrid_alpha=hybrid_alpha,
                    enforce_gain_cap=enforce_gain_cap, gain_cap=gain_cap,
                    initial_frequency=initial_frequency,
                    name=f'lasa_{i}'
                ))
            elif a == 'relu':
                model.add(tf.keras.layers.ReLU(name=f'relu_{i}'))
            elif a == 'leaky_relu':
                model.add(tf.keras.layers.LeakyReLU(alpha=0.01, name=f'leaky_relu_{i}'))
            elif a == 'elu':
                model.add(tf.keras.layers.ELU(alpha=1.0, name=f'elu_{i}'))
            elif a == 'softplus':
                model.add(tf.keras.layers.Activation('softplus', name=f'softplus_{i}'))
            elif a == 'swish':
                model.add(SwishActivation(name=f'swish_{i}'))
            elif a == 'mish':
                model.add(MishActivation(name=f'mish_{i}'))
            elif a == 'gelu':
                model.add(tf.keras.layers.Lambda(lambda z: tf.nn.gelu(z), name=f'gelu_{i}'))
            elif a == 'sine':
                model.add(tf.keras.layers.Lambda(lambda z: tf.math.sin(z), name=f'sine_{i}'))
            elif a == 'sigmoid':
                model.add(tf.keras.layers.Activation('sigmoid', name=f'sigmoid_{i}'))
            elif a == 'tanh':
                model.add(tf.keras.layers.Activation('tanh', name=f'tanh_{i}'))
            else:
                raise ValueError(f"Unknown activation_type: {activation_type}")

        model.add(tf.keras.layers.Dense(1, activation='sigmoid', dtype='float32', name='output'))
    return model

class LASATrainer:
    def __init__(self, model,
                 lr_main=1e-3, lr_tau=1e-2,
                 clipnorm_main=1.0, clipnorm_tau=0.5,
                 penalty_warmup_epochs=8,
                 acc_eps=2.5e-3, loss_eps=1e-4,
                 reverse_tau_grads=True, revert_rho_to_snapshot=True,
                 shrink_tau_lr=True, tau_lr_decay=0.5, min_tau_lr=1e-5,
                 shrink_penalty=True, penalty_decay=0.8, min_penalty_scale=0.05,
                 stagnation_window=10, improve_threshold=0.05,
                 bump_delta_k=1.0, min_epochs_between_bumps=10,
                 acc_drop_threshold=0.02):
        self.model = model
        self.loss_fn = tf.keras.losses.BinaryCrossentropy()
        self.optimizer_main = tf.keras.optimizers.Adam(learning_rate=lr_main, clipnorm=clipnorm_main)
        self.optimizer_tau  = tf.keras.optimizers.Adam(learning_rate=lr_tau,  clipnorm=clipnorm_tau)
        self.penalty_warmup_epochs = int(penalty_warmup_epochs)

        self.acc_eps = float(acc_eps)
        self.loss_eps = float(loss_eps)
        self.reverse_tau_grads = bool(reverse_tau_grads)
        self.revert_rho_to_snapshot = bool(revert_rho_to_snapshot)
        self.shrink_tau_lr = bool(shrink_tau_lr)
        self.tau_lr_decay = float(tau_lr_decay)
        self.min_tau_lr = float(min_tau_lr)
        self.shrink_penalty = bool(shrink_penalty)
        self.penalty_decay = float(penalty_decay)
        self.min_penalty_scale = float(min_penalty_scale)

        self.stagnation_window = int(stagnation_window)
        self.improve_threshold = float(improve_threshold)
        self.bump_delta_k = float(bump_delta_k)
        self.min_epochs_between_bumps = int(min_epochs_between_bumps)

        self.acc_drop_threshold = float(acc_drop_threshold)

        self._partition_ready = False
        self.tau_idx, self.other_idx = [], []
        self._best_val_acc  = -np.inf
        self._best_val_loss =  np.inf
        self.val_acc_hist   = []
        self._last_bump_epoch = -10**9
        self.tau_grad_dir = tf.Variable(1.0, trainable=False, dtype=tf.float32)

        self.pending_bump = False
        self.bump_pre_val_acc = None
        self.rho_bump_snapshot = None
        self.bump_reverted_once = False
        self.final_bump_to_apply = False
        self.final_bump_applied = False
        self.disable_future_bumps = False
        self.no_revert_mode = False

    def _build_and_partition(self, sample_x):
        _ = self.model(sample_x)
        self.tau_idx, self.other_idx = [], []
        for i, v in enumerate(self.model.trainable_variables):
            if '/rho:' in v.name: self.tau_idx.append(i)
            else: self.other_idx.append(i)
        self._partition_ready = True

    def _set_penalty_scale(self, epoch_idx):
        scale = 1.0 if self.penalty_warmup_epochs <= 0 else min(1.0, (epoch_idx + 1) / self.penalty_warmup_epochs)
        for layer in self.model.layers:
            if isinstance(layer, LASAActivation):
                layer.set_penalty_scale(scale)

    def _decay_penalty_scale(self):
        if not self.shrink_penalty: return
        for layer in self.model.layers:
            if isinstance(layer, LASAActivation):
                layer.scale_down_penalty(self.penalty_decay, self.min_penalty_scale)

    def _snapshot_rho(self):
        return [self.model.trainable_variables[i].numpy().copy() for i in self.tau_idx]

    def _restore_rho(self, snap):
        for val, i in zip(snap, self.tau_idx):
            self.model.trainable_variables[i].assign(val)

    def _reset_tau_optimizer(self, new_lr):
        self.optimizer_tau = tf.keras.optimizers.Adam(learning_rate=new_lr, clipnorm=self.optimizer_tau.clipnorm)

    def _bump_all_k(self, delta):
        for layer in self.model.layers:
            if isinstance(layer, LASAActivation):
                k0 = float(layer.tau_value.numpy())
                if layer.enforce_gain_cap:
                    kmax = float(layer.k_max.numpy())
                    k1 = min(kmax * 0.999, k0 + float(delta))
                    ratio = np.clip(k1 / kmax, 1e-6, 1.0-1e-6)
                    rho_new = np.log(ratio/(1.0 - ratio))
                else:
                    k1 = max(0.0, k0 + float(delta))
                    rho_new = inv_softplus(k1)
                layer.rho.assign(np.float32(rho_new))

    def _current_k_values(self):
        ks = []
        for layer in self.model.layers:
            if isinstance(layer, LASAActivation):
                ks.append(float(layer.tau_value.numpy()))
        return ks

    @tf.function(jit_compile=USE_XLA)
    def _train_step(self, x_batch, y_batch):
        with tf.GradientTape() as tape:
            preds = self.model(x_batch, training=True)
            yb = tf.reshape(y_batch, (-1, 1))
            main_loss = self.loss_fn(yb, preds)
            reg_losses = tf.add_n(self.model.losses) if self.model.losses else tf.constant(0.0, dtype=main_loss.dtype)
            loss = main_loss + reg_losses
        grads = tape.gradient(loss, self.model.trainable_variables)

        tau_pairs = []
        for i in self.tau_idx:
            g = grads[i]; v = self.model.trainable_variables[i]
            if g is not None:
                g = tf.cast(g, tf.float32) * self.tau_grad_dir
                tau_pairs.append((g, v))
        other_pairs = []
        for i in self.other_idx:
            g = grads[i]; v = self.model.trainable_variables[i]
            if g is not None:
                other_pairs.append((g, v))

        if tau_pairs:   self.optimizer_tau.apply_gradients(tau_pairs)
        if other_pairs: self.optimizer_main.apply_gradients(other_pairs)

        return main_loss

    def _val_metrics(self, X_val, y_val):
        preds = self.model(X_val, training=False)
        yb = tf.reshape(y_val, (-1, 1))
        val_loss = float(self.loss_fn(yb, preds).numpy())
        y_pred = (preds.numpy() > 0.5).astype(int).flatten()
        val_acc = float(np.mean(y_pred == y_val.numpy()))
        return val_loss, val_acc

    def train(self, X_train, y_train, X_val, y_val, epochs=40, batch_size=32, verbose=True):
        X_train = tf.constant(X_train, dtype=tf.float32)
        y_train = tf.constant(y_train, dtype=tf.float32)
        X_val   = tf.constant(X_val,   dtype=tf.float32)
        y_val   = tf.constant(y_val,   dtype=tf.float32)

        if not self._partition_ready:
            self._build_and_partition(X_train[:1])

        ds = (tf.data.Dataset.from_tensor_slices((X_train, y_train))
              .shuffle(4096).batch(batch_size).prefetch(tf.data.AUTOTUNE))

        history = {'loss': [], 'val_accuracy': [], 'val_loss': [], 'k': []}

        for epoch in range(epochs):
            self._set_penalty_scale(epoch)

            if self.final_bump_to_apply and not self.final_bump_applied:
                self._bump_all_k(self.bump_delta_k)
                self.final_bump_applied = True
                self.final_bump_to_apply = False
                self.disable_future_bumps = True
                self.no_revert_mode = True

            rho_snap_epoch = self._snapshot_rho()

            total_loss = 0.0
            nb = 0
            for xb, yb in ds:
                main_l = self._train_step(xb, yb)
                total_loss += float(main_l.numpy())
                nb += 1

            avg_loss = total_loss / max(nb, 1)
            val_loss, val_acc = self._val_metrics(X_val, y_val)

            if self.pending_bump and not self.final_bump_applied:
                if self.bump_pre_val_acc is not None:
                    drop = self.bump_pre_val_acc - val_acc
                    if drop > self.acc_drop_threshold and not self.bump_reverted_once:
                        self._restore_rho(self.rho_bump_snapshot)
                        self.bump_reverted_once = True
                        self.pending_bump = False
                        self.final_bump_to_apply = True
                        val_loss, val_acc = self._val_metrics(X_val, y_val)
                if self.pending_bump:
                    self.pending_bump = False

            worse_acc  = (val_acc  < self._best_val_acc  - self.acc_eps)
            worse_loss = (val_loss > self._best_val_loss + self.loss_eps)
            if (worse_acc or worse_loss):
                if self.revert_rho_to_snapshot and not self.no_revert_mode:
                    self._restore_rho(rho_snap_epoch)
                if self.reverse_tau_grads:
                    self.tau_grad_dir.assign(-self.tau_grad_dir)
                if self.shrink_tau_lr:
                    new_lr = max(self.min_tau_lr, float(self.optimizer_tau.learning_rate.numpy()) * self.tau_lr_decay)
                    self._reset_tau_optimizer(new_lr)
                if self.shrink_penalty:
                    self._decay_penalty_scale()
                val_loss, val_acc = self._val_metrics(X_val, y_val)

            ep = epoch + 1
            self.val_acc_hist.append(val_acc)
            can_try_bump = (not self.disable_future_bumps) and (not self.final_bump_applied)
            if can_try_bump and ep >= self.stagnation_window and (ep - self._last_bump_epoch) >= self.min_epochs_between_bumps:
                acc_then = self.val_acc_hist[-self.stagnation_window]
                improve  = val_acc - acc_then
                if improve < self.improve_threshold:
                    self.rho_bump_snapshot = self._snapshot_rho()
                    self.bump_pre_val_acc  = val_acc
                    self._bump_all_k(self.bump_delta_k)
                    self.pending_bump = True
                    self._last_bump_epoch = ep

            self._best_val_acc  = max(self._best_val_acc,  val_acc)
            self._best_val_loss = min(self._best_val_loss, val_loss)

            history['k'].append(self._current_k_values())

            history['loss'].append(avg_loss)
            history['val_accuracy'].append(val_acc)
            history['val_loss'].append(val_loss)

            if verbose:
                print(f"Epoch {epoch+1:03d} | loss: {avg_loss:.4f} | val_loss: {val_loss:.4f} | val_acc: {val_acc:.4f}")
        return history

class RegularTrainer:
    def __init__(self, model, lr=1e-3, clipnorm=1.0):
        self.model = model
        self.loss_fn = tf.keras.losses.BinaryCrossentropy()
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=lr, clipnorm=clipnorm)

    @tf.function(jit_compile=USE_XLA)
    def _train_step(self, x_batch, y_batch):
        with tf.GradientTape() as tape:
            preds = self.model(x_batch, training=True)
            yb = tf.reshape(y_batch, (-1, 1))
            loss = self.loss_fn(yb, preds)
        grads = tape.gradient(loss, self.model.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.model.trainable_variables))
        return loss

    def _val_metrics(self, X_val, y_val):
        preds = self.model(X_val, training=False)
        yb = tf.reshape(y_val, (-1, 1))
        val_loss = float(self.loss_fn(yb, preds).numpy())
        y_pred = (preds.numpy() > 0.5).astype(int).flatten()
        val_acc = float(np.mean(y_pred == y_val.numpy()))
        return val_loss, val_acc

    def train(self, X_train, y_train, X_val, y_val, epochs=40, batch_size=32, verbose=True):
        X_train = tf.constant(X_train, dtype=tf.float32)
        y_train = tf.constant(y_train, dtype=tf.float32)
        X_val   = tf.constant(X_val,   dtype=tf.float32)
        y_val   = tf.constant(y_val,   dtype=tf.float32)

        ds = (tf.data.Dataset.from_tensor_slices((X_train, y_train))
              .shuffle(4096).batch(batch_size).prefetch(tf.data.AUTOTUNE))

        history = {'loss': [], 'val_accuracy': [], 'val_loss': []}

        for epoch in range(epochs):
            total_loss = 0.0; nb = 0
            for xb, yb in ds:
                main_l = self._train_step(xb, yb)
                total_loss += float(main_l.numpy()); nb += 1

            avg_loss = total_loss / max(nb, 1)
            val_loss, val_acc = self._val_metrics(X_val, y_val)

            history['loss'].append(avg_loss)
            history['val_accuracy'].append(val_acc)
            history['val_loss'].append(val_loss)

            if verbose:
                print(f"Epoch {epoch+1:03d} | loss: {avg_loss:.4f} | val_loss: {val_loss:.4f} | val_acc: {val_acc:.4f}")
        return history

def plot_all_decision_boundaries(models, results, X_test, y_test):
    class Wrapper:
        def __init__(self, model): self.model = model
        def predict(self, X):
            X_tensor = tf.constant(X, dtype=tf.float32)
            preds = self.model(X_tensor)
            return (preds.numpy() > 0.5).astype(int).flatten()

    names = list(models.keys())
    n = len(names); cols = 4; rows = int(np.ceil(n / cols))
    fig, axes = plt.subplots(rows, cols, figsize=(4.6*cols, 4.2*rows))
    axes = np.array(axes).reshape(rows, cols)

    for idx, name in enumerate(names):
        r, c = divmod(idx, cols); ax = axes[r, c]
        wrapper = Wrapper(models[name])
        plot_decision_regions(X=X_test, y=y_test, clf=wrapper, ax=ax, legend=0)
        acc = results[name]['accuracy']
        ax.set_title(f"{name.upper()}  Acc: {acc:.4f}", fontsize=11, fontweight='bold')
        ax.set_xlabel('x1'); ax.set_ylabel('x2'); ax.grid(True, alpha=0.3)

    for idx in range(n, rows*cols):
        r, c = divmod(idx, cols)
        fig.delaxes(axes[r, c])

    plt.suptitle('Decision Boundaries Comparison (Crescent and Full Moon)', fontsize=15, fontweight='bold')
    plt.tight_layout(); plt.show()

def plot_training_curves_comparison(results):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
    for name, data in results.items():
        ax1.plot(data['history']['loss'], label=f"{name}")
        ax1.plot(data['history']['val_loss'], linestyle='--', alpha=0.7, label=f"{name} (val)")
        ax2.plot(data['history']['val_accuracy'], label=f"{name}")
    ax1.set_title('Training & Validation Loss'); ax1.set_xlabel('Epoch'); ax1.set_ylabel('Loss'); ax1.grid(True); ax1.legend(ncol=2, fontsize=8)
    ax2.set_title('Validation Accuracy'); ax2.set_xlabel('Epoch'); ax2.set_ylabel('Accuracy'); ax2.grid(True); ax2.legend(ncol=2, fontsize=8)
    plt.tight_layout(); plt.show()

def print_comparison_table(results):
    print("\n" + "="*60)
    print("FINAL RESULTS COMPARISON")
    print("="*60)
    print(f"{'Rank':<6} {'Activation':<15} {'Accuracy':<12} {'Final Train Loss':<18}")
    print("-"*60)
    sorted_items = sorted(results.items(), key=lambda kv: kv[1]['accuracy'], reverse=True)
    for rank, (name, data) in enumerate(sorted_items, 1):
        print(f"{rank:<6} {name.upper():<15} {data['accuracy']:<12.4f} {data['final_loss']:<18.4f}")
    print("="*60)

def plot_k_evolution(results, model_key='lasa', title_suffix="Crescent and Full Moon"):
    if model_key not in results:
        print(f"[plot_k_evolution] '{model_key}' not in results."); return
    hist = results[model_key]['history']
    if 'k' not in hist or len(hist['k']) == 0:
        print("[plot_k_evolution] No k history found."); return

    K = np.array([np.array(ks, dtype=float) for ks in hist['k']], dtype=object)
    try:
        K = np.stack(K).astype(float)
    except Exception:
        print("[plot_k_evolution] Ragged k history; cannot plot."); return

    plt.figure(figsize=(7, 4))
    for j in range(K.shape[1]):
        plt.plot(K[:, j], label=f'k[{j}]')
    plt.title(f'k evolution per LASA layer ({title_suffix})')
    plt.xlabel('Epoch'); plt.ylabel('k'); plt.grid(True, alpha=0.3)
    plt.legend(ncol=2)
    plt.tight_layout(); plt.show()

def run_all_activations_comparison_crescent_moon(hidden_units=[6],
                                                 n_samples=2000, noise=0.1,
                                                 test_size=0.2, random_state=42,
                                                 epochs=40, batch_size=32,
                                                 lr_main=1e-3,
                                                 lr_tau=1e-2,
                                                 initial_frequency=1.6,
                                                 theta_degrees=45.0, lambda_window=3e-4,
                                                 penalty_mode='hinge', hybrid_alpha=0.1,
                                                 enforce_gain_cap=False, gain_cap=1.25,
                                                 penalty_warmup_epochs=8,
                                                 acc_eps=2.5e-3, loss_eps=1e-4,
                                                 reverse_tau_grads=True, revert_rho_to_snapshot=True,
                                                 shrink_tau_lr=True, tau_lr_decay=0.5, min_tau_lr=1e-5,
                                                 shrink_penalty=True, penalty_decay=0.8, min_penalty_scale=0.05,
                                                 stagnation_window=10, improve_threshold=0.05,
                                                 bump_delta_k=1.0, min_epochs_between_bumps=10,
                                                 acc_drop_threshold=0.02,
                                                 verbose=True):
    activation_types = [
        'lasa', 'relu', 'leaky_relu', 'elu', 'softplus',
        'swish', 'mish', 'gelu', 'sine', 'sigmoid', 'tanh'
    ]

    print("="*60)
    print("ACTIVATION FUNCTIONS COMPARISON - Crescent and Full Moon")
    print("="*60)
    print("Config:",
          f"\n  hidden_units={hidden_units}",
          f"\n  epochs={epochs}  batch_size={batch_size}",
          f"\n  lr_main={lr_main}  (lr_tau={lr_tau} for LASA only)",
          f"\n  dataset: n_samples={n_samples}, noise={noise}, random_state={random_state}",
          f"\n  LASA: theta={theta_degrees}°, lambda_window={lambda_window}, penalty_mode={penalty_mode}, "
          f"enforce_gain_cap={enforce_gain_cap}, gain_cap={gain_cap}",
          f"\n  Rule: if post-bump drop > {acc_drop_threshold:.2f}, revert-once, then one final +1 bump and disable scheduler"
          )

    X, y = generate_crescent_moon(n_samples=n_samples, noise=noise, random_state=random_state)
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, random_state=random_state, stratify=y
    )
    print(f"\nDataset: total={n_samples} | train={len(X_train)} | test={len(X_test)}")
    print(f"Class counts: 0->{np.sum(y==0)}  1->{np.sum(y==1)}")

    results = {}
    models  = {}

    for act in activation_types:
        print("\n" + "-"*60)
        print(f"Training with {act.upper()} activation...")
        tf.keras.backend.clear_session()
        np.random.seed(random_state); tf.random.set_seed(random_state)

        model = create_model(
            activation_type=act,
            hidden_units=hidden_units,
            initial_frequency=initial_frequency,
            theta_degrees=theta_degrees, lambda_window=lambda_window,
            penalty_mode=penalty_mode, hybrid_alpha=hybrid_alpha,
            enforce_gain_cap=enforce_gain_cap, gain_cap=gain_cap
        )

        if act.lower() == 'lasa':
            trainer = LASATrainer(
                model,
                lr_main=lr_main, lr_tau=lr_tau,
                clipnorm_main=1.0, clipnorm_tau=0.5,
                penalty_warmup_epochs=penalty_warmup_epochs,
                acc_eps=acc_eps, loss_eps=loss_eps,
                reverse_tau_grads=reverse_tau_grads, revert_rho_to_snapshot=revert_rho_to_snapshot,
                shrink_tau_lr=shrink_tau_lr, tau_lr_decay=tau_lr_decay, min_tau_lr=min_tau_lr,
                shrink_penalty=shrink_penalty, penalty_decay=penalty_decay, min_penalty_scale=min_penalty_scale,
                stagnation_window=stagnation_window, improve_threshold=improve_threshold,
                bump_delta_k=bump_delta_k, min_epochs_between_bumps=min_epochs_between_bumps,
                acc_drop_threshold=acc_drop_threshold
            )
            hist = trainer.train(
                tf.constant(X_train), tf.constant(y_train, np.float32),
                tf.constant(X_test),  tf.constant(y_test,  np.float32),
                epochs=epochs, batch_size=batch_size, verbose=verbose
            )
        else:
            trainer = RegularTrainer(model, lr=lr_main, clipnorm=1.0)
            hist = trainer.train(
                tf.constant(X_train), tf.constant(y_train, np.float32),
                tf.constant(X_test),  tf.constant(y_test,  np.float32),
                epochs=epochs, batch_size=batch_size, verbose=verbose
            )

        preds = model(tf.constant(X_test, tf.float32))
        y_true = tf.constant(y_test, np.float32)
        y_true = tf.reshape(y_true, (-1, 1))
        final_loss = float(tf.keras.losses.BinaryCrossentropy()(y_true, preds).numpy())
        y_pred = (preds.numpy() > 0.5).astype(int).flatten()
        final_acc  = float(np.mean(y_pred == y_test))

        results[act] = {'accuracy': final_acc, 'history': hist, 'final_loss': hist['loss'][-1]}
        models[act]  = model

        print(f"[{act.upper()}] Acc: {final_acc:.4f} | Final train loss: {hist['loss'][-1]:.4f}")

    return models, results, X, y, X_test, y_test

if __name__ == "__main__":
    models, results, X, y, X_test, y_test = run_all_activations_comparison_crescent_moon(
        hidden_units=[12],
        n_samples=2000, noise=0.1,
        test_size=0.2, random_state=42,
        epochs=80, batch_size=32,
        lr_main=1e-4, lr_tau=1e-2,
        initial_frequency=1.6,
        theta_degrees=45.0, lambda_window=3e-4,
        penalty_mode='hinge', hybrid_alpha=0.1,
        enforce_gain_cap=False, gain_cap=1.25,
        penalty_warmup_epochs=8,
        acc_eps=2.5e-3, loss_eps=1e-4,
        reverse_tau_grads=True, revert_rho_to_snapshot=True,
        shrink_tau_lr=True, tau_lr_decay=0.5, min_tau_lr=1e-5,
        shrink_penalty=True, penalty_decay=0.8, min_penalty_scale=0.05,
        stagnation_window=10, improve_threshold=0.05,
        bump_delta_k=1.0, min_epochs_between_bumps=10,
        acc_drop_threshold=0.02,
        verbose=True
    )

    print("\n")
    print("="*60)
    print("ACTIVATIONS: lasa, relu, leaky_relu, elu, softplus, swish, mish, gelu, sine, sigmoid, tanh")
    print("="*60)
    print_comparison_table(results)
    plot_all_decision_boundaries(models, results, X_test, y_test)
    plot_training_curves_comparison(results)

    plot_k_evolution(results, model_key='lasa', title_suffix="Crescent and Full Moon")
# Out:
# <style>.output_scroll {height:auto !important; max-height:none !important;}</style>
# ============================================================
# GPU CONFIGURATION
# ============================================================
# No GPUs available, using CPU
# Mixed precision policy: float32
# ============================================================
#
# ============================================================
# ACTIVATION FUNCTIONS COMPARISON - Crescent and Full Moon
# ============================================================
# Config:
#   hidden_units=[12]
#   epochs=80  batch_size=32
#   lr_main=0.0001  (lr_tau=0.01 for LASA only)
#   dataset: n_samples=2000, noise=0.1, random_state=42
#   LASA: theta=45.0°, lambda_window=0.0003, penalty_mode=hinge, enforce_gain_cap=False, gain_cap=1.25
#   Rule: if post-bump drop > 0.02, revert-once, then one final +1 bump and disable scheduler
#
# Dataset: total=2000 | train=1600 | test=400
# Class counts: 0->1000  1->1000
#
# ------------------------------------------------------------
# Training with LASA activation...
# Epoch 001 | loss: 0.7081 | val_loss: 0.7095 | val_acc: 0.4900
# Epoch 002 | loss: 0.7011 | val_loss: 0.7042 | val_acc: 0.4975
# Epoch 003 | loss: 0.6960 | val_loss: 0.7004 | val_acc: 0.4800
# Epoch 004 | loss: 0.6925 | val_loss: 0.6968 | val_acc: 0.4850
# Epoch 005 | loss: 0.6888 | val_loss: 0.6935 | val_acc: 0.4950
# Epoch 006 | loss: 0.6855 | val_loss: 0.6904 | val_acc: 0.5075
# Epoch 007 | loss: 0.6824 | val_loss: 0.6876 | val_acc: 0.5100
# Epoch 008 | loss: 0.6794 | val_loss: 0.6849 | val_acc: 0.5200
# Epoch 009 | loss: 0.6765 | val_loss: 0.6820 | val_acc: 0.5250
# Epoch 010 | loss: 0.6737 | val_loss: 0.6793 | val_acc: 0.5350
# Epoch 011 | loss: 0.6767 | val_loss: 0.6748 | val_acc: 0.5825
# Epoch 012 | loss: 0.6685 | val_loss: 0.6727 | val_acc: 0.6125
# Epoch 013 | loss: 0.6658 | val_loss: 0.6706 | val_acc: 0.6575
# Epoch 014 | loss: 0.6635 | val_loss: 0.6688 | val_acc: 0.6700
# Epoch 015 | loss: 0.6616 | val_loss: 0.6673 | val_acc: 0.6650
# Epoch 016 | loss: 0.6598 | val_loss: 0.6656 | val_acc: 0.6700
# Epoch 017 | loss: 0.6583 | val_loss: 0.6638 | val_acc: 0.6700
# Epoch 018 | loss: 0.6567 | val_loss: 0.6624 | val_acc: 0.6700
# Epoch 019 | loss: 0.6553 | val_loss: 0.6607 | val_acc: 0.6775
# Epoch 020 | loss: 0.6539 | val_loss: 0.6594 | val_acc: 0.6775
# Epoch 021 | loss: 0.6526 | val_loss: 0.6583 | val_acc: 0.6725
# Epoch 022 | loss: 0.6512 | val_loss: 0.6572 | val_acc: 0.6725
# Epoch 023 | loss: 0.6553 | val_loss: 0.6496 | val_acc: 0.6775
# Epoch 024 | loss: 0.6473 | val_loss: 0.6491 | val_acc: 0.6825
# Epoch 025 | loss: 0.6452 | val_loss: 0.6475 | val_acc: 0.6825
# Epoch 026 | loss: 0.6435 | val_loss: 0.6447 | val_acc: 0.6800
# Epoch 027 | loss: 0.6414 | val_loss: 0.6422 | val_acc: 0.6875
# Epoch 028 | loss: 0.6392 | val_loss: 0.6386 | val_acc: 0.6875
# Epoch 029 | loss: 0.6367 | val_loss: 0.6362 | val_acc: 0.6950
# Epoch 030 | loss: 0.6339 | val_loss: 0.6338 | val_acc: 0.6925
# Epoch 031 | loss: 0.6326 | val_loss: 0.6317 | val_acc: 0.7000
# Epoch 032 | loss: 0.6293 | val_loss: 0.6261 | val_acc: 0.6975
# Epoch 033 | loss: 0.6325 | val_loss: 0.6111 | val_acc: 0.7175
# Epoch 034 | loss: 0.6177 | val_loss: 0.6077 | val_acc: 0.7200
# Epoch 035 | loss: 0.6128 | val_loss: 0.6029 | val_acc: 0.7225
# Epoch 036 | loss: 0.6076 | val_loss: 0.5954 | val_acc: 0.7275
# Epoch 037 | loss: 0.6020 | val_loss: 0.5895 | val_acc: 0.7525
# Epoch 038 | loss: 0.5963 | val_loss: 0.5824 | val_acc: 0.7500
# Epoch 039 | loss: 0.5904 | val_loss: 0.5759 | val_acc: 0.7600
# Epoch 040 | loss: 0.5843 | val_loss: 0.5711 | val_acc: 0.7600
# Epoch 041 | loss: 0.5805 | val_loss: 0.5669 | val_acc: 0.7575
# Epoch 042 | loss: 0.5737 | val_loss: 0.5595 | val_acc: 0.7625
# Epoch 043 | loss: 0.5823 | val_loss: 0.5458 | val_acc: 0.7625
# Epoch 044 | loss: 0.5584 | val_loss: 0.5436 | val_acc: 0.7800
# Epoch 045 | loss: 0.5523 | val_loss: 0.5370 | val_acc: 0.7800
# Epoch 046 | loss: 0.5466 | val_loss: 0.5319 | val_acc: 0.7850
# Epoch 047 | loss: 0.5411 | val_loss: 0.5276 | val_acc: 0.7875
# Epoch 048 | loss: 0.5361 | val_loss: 0.5228 | val_acc: 0.7900
# Epoch 049 | loss: 0.5311 | val_loss: 0.5195 | val_acc: 0.7875
# Epoch 050 | loss: 0.5274 | val_loss: 0.5164 | val_acc: 0.7925
# Epoch 051 | loss: 0.5229 | val_loss: 0.5134 | val_acc: 0.7925
# Epoch 052 | loss: 0.5185 | val_loss: 0.5081 | val_acc: 0.7925
# Epoch 053 | loss: 0.5379 | val_loss: 0.5224 | val_acc: 0.7700
# Epoch 054 | loss: 0.5738 | val_loss: 0.5105 | val_acc: 0.7750
# Epoch 055 | loss: 0.5265 | val_loss: 0.5021 | val_acc: 0.7775
# Epoch 056 | loss: 0.5286 | val_loss: 0.4957 | val_acc: 0.7825
# Epoch 057 | loss: 0.5079 | val_loss: 0.4908 | val_acc: 0.7825
# Epoch 058 | loss: 0.5082 | val_loss: 0.4867 | val_acc: 0.7825
# Epoch 059 | loss: 0.4950 | val_loss: 0.4828 | val_acc: 0.7900
# Epoch 060 | loss: 0.4868 | val_loss: 0.4805 | val_acc: 0.7875
# Epoch 061 | loss: 0.4842 | val_loss: 0.4781 | val_acc: 0.7950
# Epoch 062 | loss: 0.4854 | val_loss: 0.4757 | val_acc: 0.7850
# Epoch 063 | loss: 0.5189 | val_loss: 0.5054 | val_acc: 0.7750
# Epoch 064 | loss: 0.5365 | val_loss: 0.4940 | val_acc: 0.7725
# Epoch 065 | loss: 0.4993 | val_loss: 0.4852 | val_acc: 0.7850
# Epoch 066 | loss: 0.5034 | val_loss: 0.4784 | val_acc: 0.7925
# Epoch 067 | loss: 0.4815 | val_loss: 0.4728 | val_acc: 0.8000
# Epoch 068 | loss: 0.4811 | val_loss: 0.4683 | val_acc: 0.7950
# Epoch 069 | loss: 0.4678 | val_loss: 0.4645 | val_acc: 0.7950
# Epoch 070 | loss: 0.4662 | val_loss: 0.4614 | val_acc: 0.8000
# Epoch 071 | loss: 0.4578 | val_loss: 0.4581 | val_acc: 0.8050
# Epoch 072 | loss: 0.4514 | val_loss: 0.4560 | val_acc: 0.8025
# Epoch 073 | loss: 0.5111 | val_loss: 0.4790 | val_acc: 0.7750
# Epoch 074 | loss: 0.5446 | val_loss: 0.4991 | val_acc: 0.7675
# Epoch 075 | loss: 0.5073 | val_loss: 0.5091 | val_acc: 0.7600
# Epoch 076 | loss: 0.4997 | val_loss: 0.4758 | val_acc: 0.7775
# Epoch 077 | loss: 0.4748 | val_loss: 0.4809 | val_acc: 0.7700
# Epoch 078 | loss: 0.4699 | val_loss: 0.4606 | val_acc: 0.8075
# Epoch 079 | loss: 0.4542 | val_loss: 0.4634 | val_acc: 0.7950
# Epoch 080 | loss: 0.4503 | val_loss: 0.4509 | val_acc: 0.8175
# [LASA] Acc: 0.8175 | Final train loss: 0.4503
#
# ------------------------------------------------------------
# Training with RELU activation...
# Epoch 001 | loss: 0.7065 | val_loss: 0.7032 | val_acc: 0.4625
# Epoch 002 | loss: 0.7035 | val_loss: 0.7005 | val_acc: 0.4625
# Epoch 003 | loss: 0.7005 | val_loss: 0.6979 | val_acc: 0.4625
# Epoch 004 | loss: 0.6977 | val_loss: 0.6953 | val_acc: 0.4800
# Epoch 005 | loss: 0.6949 | val_loss: 0.6927 | val_acc: 0.4900
# Epoch 006 | loss: 0.6921 | val_loss: 0.6902 | val_acc: 0.4975
# Epoch 007 | loss: 0.6894 | val_loss: 0.6879 | val_acc: 0.5100
# Epoch 008 | loss: 0.6868 | val_loss: 0.6855 | val_acc: 0.5175
# Epoch 009 | loss: 0.6841 | val_loss: 0.6832 | val_acc: 0.5225
# Epoch 010 | loss: 0.6816 | val_loss: 0.6809 | val_acc: 0.5350
# Epoch 011 | loss: 0.6791 | val_loss: 0.6787 | val_acc: 0.5425
# Epoch 012 | loss: 0.6767 | val_loss: 0.6766 | val_acc: 0.5450
# Epoch 013 | loss: 0.6744 | val_loss: 0.6745 | val_acc: 0.5500
# Epoch 014 | loss: 0.6720 | val_loss: 0.6725 | val_acc: 0.5500
# Epoch 015 | loss: 0.6698 | val_loss: 0.6705 | val_acc: 0.5600
# Epoch 016 | loss: 0.6675 | val_loss: 0.6685 | val_acc: 0.5725
# Epoch 017 | loss: 0.6654 | val_loss: 0.6666 | val_acc: 0.5750
# Epoch 018 | loss: 0.6633 | val_loss: 0.6648 | val_acc: 0.5750
# Epoch 019 | loss: 0.6612 | val_loss: 0.6630 | val_acc: 0.5825
# Epoch 020 | loss: 0.6592 | val_loss: 0.6612 | val_acc: 0.5825
# Epoch 021 | loss: 0.6572 | val_loss: 0.6594 | val_acc: 0.5875
# Epoch 022 | loss: 0.6552 | val_loss: 0.6578 | val_acc: 0.5950
# Epoch 023 | loss: 0.6532 | val_loss: 0.6560 | val_acc: 0.5950
# Epoch 024 | loss: 0.6514 | val_loss: 0.6544 | val_acc: 0.6025
# Epoch 025 | loss: 0.6495 | val_loss: 0.6528 | val_acc: 0.6075
# Epoch 026 | loss: 0.6476 | val_loss: 0.6512 | val_acc: 0.6125
# Epoch 027 | loss: 0.6458 | val_loss: 0.6496 | val_acc: 0.6075
# Epoch 028 | loss: 0.6440 | val_loss: 0.6481 | val_acc: 0.6100
# Epoch 029 | loss: 0.6422 | val_loss: 0.6466 | val_acc: 0.6075
# Epoch 030 | loss: 0.6404 | val_loss: 0.6451 | val_acc: 0.6100
# Epoch 031 | loss: 0.6387 | val_loss: 0.6436 | val_acc: 0.6100
# Epoch 032 | loss: 0.6370 | val_loss: 0.6421 | val_acc: 0.6100
# Epoch 033 | loss: 0.6353 | val_loss: 0.6406 | val_acc: 0.6125
# Epoch 034 | loss: 0.6336 | val_loss: 0.6392 | val_acc: 0.6125
# Epoch 035 | loss: 0.6320 | val_loss: 0.6378 | val_acc: 0.6075
# Epoch 036 | loss: 0.6304 | val_loss: 0.6364 | val_acc: 0.6075
# Epoch 037 | loss: 0.6288 | val_loss: 0.6350 | val_acc: 0.6100
# Epoch 038 | loss: 0.6272 | val_loss: 0.6337 | val_acc: 0.6100
# Epoch 039 | loss: 0.6257 | val_loss: 0.6324 | val_acc: 0.6150
# Epoch 040 | loss: 0.6242 | val_loss: 0.6311 | val_acc: 0.6150
# Epoch 041 | loss: 0.6227 | val_loss: 0.6298 | val_acc: 0.6150
# Epoch 042 | loss: 0.6212 | val_loss: 0.6286 | val_acc: 0.6150
# Epoch 043 | loss: 0.6198 | val_loss: 0.6273 | val_acc: 0.6150
# Epoch 044 | loss: 0.6184 | val_loss: 0.6261 | val_acc: 0.6150
# Epoch 045 | loss: 0.6170 | val_loss: 0.6249 | val_acc: 0.6150
# Epoch 046 | loss: 0.6156 | val_loss: 0.6237 | val_acc: 0.6175
# Epoch 047 | loss: 0.6142 | val_loss: 0.6225 | val_acc: 0.6175
# Epoch 048 | loss: 0.6129 | val_loss: 0.6213 | val_acc: 0.6175
# Epoch 049 | loss: 0.6116 | val_loss: 0.6201 | val_acc: 0.6175
# Epoch 050 | loss: 0.6102 | val_loss: 0.6190 | val_acc: 0.6200
# Epoch 051 | loss: 0.6090 | val_loss: 0.6179 | val_acc: 0.6200
# Epoch 052 | loss: 0.6077 | val_loss: 0.6168 | val_acc: 0.6200
# Epoch 053 | loss: 0.6064 | val_loss: 0.6156 | val_acc: 0.6200
# Epoch 054 | loss: 0.6052 | val_loss: 0.6145 | val_acc: 0.6200
# Epoch 055 | loss: 0.6040 | val_loss: 0.6134 | val_acc: 0.6175
# Epoch 056 | loss: 0.6028 | val_loss: 0.6123 | val_acc: 0.6175
# Epoch 057 | loss: 0.6016 | val_loss: 0.6113 | val_acc: 0.6200
# Epoch 058 | loss: 0.6005 | val_loss: 0.6101 | val_acc: 0.6225
# Epoch 059 | loss: 0.5993 | val_loss: 0.6091 | val_acc: 0.6225
# Epoch 060 | loss: 0.5981 | val_loss: 0.6080 | val_acc: 0.6275
# Epoch 061 | loss: 0.5970 | val_loss: 0.6070 | val_acc: 0.6275
# Epoch 062 | loss: 0.5959 | val_loss: 0.6060 | val_acc: 0.6275
# Epoch 063 | loss: 0.5948 | val_loss: 0.6050 | val_acc: 0.6275
# Epoch 064 | loss: 0.5938 | val_loss: 0.6039 | val_acc: 0.6275
# Epoch 065 | loss: 0.5927 | val_loss: 0.6030 | val_acc: 0.6250
# Epoch 066 | loss: 0.5916 | val_loss: 0.6020 | val_acc: 0.6225
# Epoch 067 | loss: 0.5906 | val_loss: 0.6011 | val_acc: 0.6250
# Epoch 068 | loss: 0.5896 | val_loss: 0.6001 | val_acc: 0.6250
# Epoch 069 | loss: 0.5886 | val_loss: 0.5992 | val_acc: 0.6250
# Epoch 070 | loss: 0.5876 | val_loss: 0.5983 | val_acc: 0.6250
# Epoch 071 | loss: 0.5866 | val_loss: 0.5974 | val_acc: 0.6250
# Epoch 072 | loss: 0.5856 | val_loss: 0.5965 | val_acc: 0.6275
# Epoch 073 | loss: 0.5846 | val_loss: 0.5956 | val_acc: 0.6275
# Epoch 074 | loss: 0.5837 | val_loss: 0.5947 | val_acc: 0.6325
# Epoch 075 | loss: 0.5828 | val_loss: 0.5939 | val_acc: 0.6350
# Epoch 076 | loss: 0.5818 | val_loss: 0.5931 | val_acc: 0.6350
# Epoch 077 | loss: 0.5809 | val_loss: 0.5922 | val_acc: 0.6325
# Epoch 078 | loss: 0.5800 | val_loss: 0.5914 | val_acc: 0.6350
# Epoch 079 | loss: 0.5791 | val_loss: 0.5906 | val_acc: 0.6350
# Epoch 080 | loss: 0.5782 | val_loss: 0.5898 | val_acc: 0.6350
# [RELU] Acc: 0.6350 | Final train loss: 0.5782
#
# ------------------------------------------------------------
# Training with LEAKY_RELU activation...
# Epoch 001 | loss: 0.7325 | val_loss: 0.7166 | val_acc: 0.5650
# Epoch 002 | loss: 0.7253 | val_loss: 0.7106 | val_acc: 0.5700
# Epoch 003 | loss: 0.7187 | val_loss: 0.7047 | val_acc: 0.5700
# Epoch 004 | loss: 0.7123 | val_loss: 0.6994 | val_acc: 0.5725
# Epoch 005 | loss: 0.7063 | val_loss: 0.6944 | val_acc: 0.5775
# Epoch 006 | loss: 0.7006 | val_loss: 0.6895 | val_acc: 0.5775
# Epoch 007 | loss: 0.6952 | val_loss: 0.6849 | val_acc: 0.5825
# Epoch 008 | loss: 0.6899 | val_loss: 0.6807 | val_acc: 0.5825
# Epoch 009 | loss: 0.6851 | val_loss: 0.6766 | val_acc: 0.5875
# Epoch 010 | loss: 0.6804 | val_loss: 0.6727 | val_acc: 0.5875
# Epoch 011 | loss: 0.6760 | val_loss: 0.6690 | val_acc: 0.5875
# Epoch 012 | loss: 0.6718 | val_loss: 0.6656 | val_acc: 0.5875
# Epoch 013 | loss: 0.6679 | val_loss: 0.6622 | val_acc: 0.5900
# Epoch 014 | loss: 0.6640 | val_loss: 0.6590 | val_acc: 0.5900
# Epoch 015 | loss: 0.6604 | val_loss: 0.6560 | val_acc: 0.5950
# Epoch 016 | loss: 0.6569 | val_loss: 0.6532 | val_acc: 0.5975
# Epoch 017 | loss: 0.6536 | val_loss: 0.6505 | val_acc: 0.5925
# Epoch 018 | loss: 0.6504 | val_loss: 0.6479 | val_acc: 0.5900
# Epoch 019 | loss: 0.6474 | val_loss: 0.6454 | val_acc: 0.5900
# Epoch 020 | loss: 0.6444 | val_loss: 0.6430 | val_acc: 0.5925
# Epoch 021 | loss: 0.6416 | val_loss: 0.6408 | val_acc: 0.5925
# Epoch 022 | loss: 0.6390 | val_loss: 0.6385 | val_acc: 0.6000
# Epoch 023 | loss: 0.6363 | val_loss: 0.6365 | val_acc: 0.6000
# Epoch 024 | loss: 0.6339 | val_loss: 0.6345 | val_acc: 0.6000
# Epoch 025 | loss: 0.6315 | val_loss: 0.6326 | val_acc: 0.6050
# Epoch 026 | loss: 0.6291 | val_loss: 0.6308 | val_acc: 0.6050
# Epoch 027 | loss: 0.6270 | val_loss: 0.6289 | val_acc: 0.6200
# Epoch 028 | loss: 0.6248 | val_loss: 0.6273 | val_acc: 0.6300
# Epoch 029 | loss: 0.6227 | val_loss: 0.6257 | val_acc: 0.6400
# Epoch 030 | loss: 0.6207 | val_loss: 0.6241 | val_acc: 0.6575
# Epoch 031 | loss: 0.6189 | val_loss: 0.6226 | val_acc: 0.6625
# Epoch 032 | loss: 0.6170 | val_loss: 0.6211 | val_acc: 0.6675
# Epoch 033 | loss: 0.6152 | val_loss: 0.6197 | val_acc: 0.6750
# Epoch 034 | loss: 0.6135 | val_loss: 0.6183 | val_acc: 0.6750
# Epoch 035 | loss: 0.6119 | val_loss: 0.6169 | val_acc: 0.6800
# Epoch 036 | loss: 0.6102 | val_loss: 0.6157 | val_acc: 0.6825
# Epoch 037 | loss: 0.6086 | val_loss: 0.6144 | val_acc: 0.6800
# Epoch 038 | loss: 0.6071 | val_loss: 0.6132 | val_acc: 0.6775
# Epoch 039 | loss: 0.6056 | val_loss: 0.6120 | val_acc: 0.6800
# Epoch 040 | loss: 0.6042 | val_loss: 0.6109 | val_acc: 0.6750
# Epoch 041 | loss: 0.6028 | val_loss: 0.6097 | val_acc: 0.6650
# Epoch 042 | loss: 0.6014 | val_loss: 0.6086 | val_acc: 0.6550
# Epoch 043 | loss: 0.6001 | val_loss: 0.6076 | val_acc: 0.6450
# Epoch 044 | loss: 0.5988 | val_loss: 0.6065 | val_acc: 0.6425
# Epoch 045 | loss: 0.5975 | val_loss: 0.6056 | val_acc: 0.6350
# Epoch 046 | loss: 0.5963 | val_loss: 0.6046 | val_acc: 0.6375
# Epoch 047 | loss: 0.5951 | val_loss: 0.6036 | val_acc: 0.6250
# Epoch 048 | loss: 0.5939 | val_loss: 0.6027 | val_acc: 0.6275
# Epoch 049 | loss: 0.5927 | val_loss: 0.6018 | val_acc: 0.6275
# Epoch 050 | loss: 0.5916 | val_loss: 0.6009 | val_acc: 0.6325
# Epoch 051 | loss: 0.5905 | val_loss: 0.6000 | val_acc: 0.6375
# Epoch 052 | loss: 0.5894 | val_loss: 0.5991 | val_acc: 0.6425
# Epoch 053 | loss: 0.5883 | val_loss: 0.5982 | val_acc: 0.6500
# Epoch 054 | loss: 0.5872 | val_loss: 0.5973 | val_acc: 0.6525
# Epoch 055 | loss: 0.5862 | val_loss: 0.5965 | val_acc: 0.6500
# Epoch 056 | loss: 0.5852 | val_loss: 0.5956 | val_acc: 0.6550
# Epoch 057 | loss: 0.5842 | val_loss: 0.5948 | val_acc: 0.6625
# Epoch 058 | loss: 0.5832 | val_loss: 0.5939 | val_acc: 0.6625
# Epoch 059 | loss: 0.5822 | val_loss: 0.5931 | val_acc: 0.6600
# Epoch 060 | loss: 0.5812 | val_loss: 0.5923 | val_acc: 0.6600
# Epoch 061 | loss: 0.5803 | val_loss: 0.5915 | val_acc: 0.6550
# Epoch 062 | loss: 0.5794 | val_loss: 0.5907 | val_acc: 0.6550
# Epoch 063 | loss: 0.5784 | val_loss: 0.5899 | val_acc: 0.6550
# Epoch 064 | loss: 0.5776 | val_loss: 0.5891 | val_acc: 0.6550
# Epoch 065 | loss: 0.5766 | val_loss: 0.5884 | val_acc: 0.6550
# Epoch 066 | loss: 0.5758 | val_loss: 0.5876 | val_acc: 0.6550
# Epoch 067 | loss: 0.5749 | val_loss: 0.5869 | val_acc: 0.6575
# Epoch 068 | loss: 0.5740 | val_loss: 0.5861 | val_acc: 0.6575
# Epoch 069 | loss: 0.5732 | val_loss: 0.5854 | val_acc: 0.6575
# Epoch 070 | loss: 0.5723 | val_loss: 0.5846 | val_acc: 0.6550
# Epoch 071 | loss: 0.5715 | val_loss: 0.5839 | val_acc: 0.6575
# Epoch 072 | loss: 0.5707 | val_loss: 0.5831 | val_acc: 0.6575
# Epoch 073 | loss: 0.5698 | val_loss: 0.5824 | val_acc: 0.6575
# Epoch 074 | loss: 0.5690 | val_loss: 0.5816 | val_acc: 0.6525
# Epoch 075 | loss: 0.5682 | val_loss: 0.5809 | val_acc: 0.6525
# Epoch 076 | loss: 0.5674 | val_loss: 0.5802 | val_acc: 0.6525
# Epoch 077 | loss: 0.5666 | val_loss: 0.5794 | val_acc: 0.6525
# Epoch 078 | loss: 0.5658 | val_loss: 0.5788 | val_acc: 0.6550
# Epoch 079 | loss: 0.5650 | val_loss: 0.5781 | val_acc: 0.6550
# Epoch 080 | loss: 0.5643 | val_loss: 0.5774 | val_acc: 0.6550
# [LEAKY_RELU] Acc: 0.6550 | Final train loss: 0.5643
#
# ------------------------------------------------------------
# Training with ELU activation...
# Epoch 001 | loss: 0.7560 | val_loss: 0.7561 | val_acc: 0.4475
# Epoch 002 | loss: 0.7493 | val_loss: 0.7499 | val_acc: 0.4500
# Epoch 003 | loss: 0.7430 | val_loss: 0.7438 | val_acc: 0.4475
# Epoch 004 | loss: 0.7369 | val_loss: 0.7381 | val_acc: 0.4525
# Epoch 005 | loss: 0.7312 | val_loss: 0.7328 | val_acc: 0.4525
# Epoch 006 | loss: 0.7259 | val_loss: 0.7276 | val_acc: 0.4625
# Epoch 007 | loss: 0.7207 | val_loss: 0.7230 | val_acc: 0.4575
# Epoch 008 | loss: 0.7159 | val_loss: 0.7187 | val_acc: 0.4725
# Epoch 009 | loss: 0.7113 | val_loss: 0.7145 | val_acc: 0.4800
# Epoch 010 | loss: 0.7071 | val_loss: 0.7104 | val_acc: 0.4875
# Epoch 011 | loss: 0.7030 | val_loss: 0.7069 | val_acc: 0.4900
# Epoch 012 | loss: 0.6991 | val_loss: 0.7035 | val_acc: 0.4875
# Epoch 013 | loss: 0.6955 | val_loss: 0.7002 | val_acc: 0.4950
# Epoch 014 | loss: 0.6921 | val_loss: 0.6972 | val_acc: 0.4950
# Epoch 015 | loss: 0.6888 | val_loss: 0.6944 | val_acc: 0.5000
# Epoch 016 | loss: 0.6858 | val_loss: 0.6916 | val_acc: 0.5200
# Epoch 017 | loss: 0.6829 | val_loss: 0.6891 | val_acc: 0.5400
# Epoch 018 | loss: 0.6801 | val_loss: 0.6867 | val_acc: 0.5475
# Epoch 019 | loss: 0.6776 | val_loss: 0.6845 | val_acc: 0.5525
# Epoch 020 | loss: 0.6751 | val_loss: 0.6825 | val_acc: 0.5625
# Epoch 021 | loss: 0.6728 | val_loss: 0.6806 | val_acc: 0.5575
# Epoch 022 | loss: 0.6707 | val_loss: 0.6789 | val_acc: 0.5525
# Epoch 023 | loss: 0.6686 | val_loss: 0.6770 | val_acc: 0.5500
# Epoch 024 | loss: 0.6667 | val_loss: 0.6754 | val_acc: 0.5550
# Epoch 025 | loss: 0.6649 | val_loss: 0.6740 | val_acc: 0.5600
# Epoch 026 | loss: 0.6632 | val_loss: 0.6725 | val_acc: 0.5575
# Epoch 027 | loss: 0.6616 | val_loss: 0.6712 | val_acc: 0.5600
# Epoch 028 | loss: 0.6600 | val_loss: 0.6701 | val_acc: 0.5600
# Epoch 029 | loss: 0.6586 | val_loss: 0.6690 | val_acc: 0.5600
# Epoch 030 | loss: 0.6573 | val_loss: 0.6678 | val_acc: 0.5625
# Epoch 031 | loss: 0.6560 | val_loss: 0.6669 | val_acc: 0.5600
# Epoch 032 | loss: 0.6548 | val_loss: 0.6660 | val_acc: 0.5600
# Epoch 033 | loss: 0.6536 | val_loss: 0.6651 | val_acc: 0.5550
# Epoch 034 | loss: 0.6526 | val_loss: 0.6643 | val_acc: 0.5500
# Epoch 035 | loss: 0.6516 | val_loss: 0.6636 | val_acc: 0.5525
# Epoch 036 | loss: 0.6506 | val_loss: 0.6629 | val_acc: 0.5600
# Epoch 037 | loss: 0.6498 | val_loss: 0.6623 | val_acc: 0.5600
# Epoch 038 | loss: 0.6490 | val_loss: 0.6616 | val_acc: 0.5575
# Epoch 039 | loss: 0.6482 | val_loss: 0.6611 | val_acc: 0.5600
# Epoch 040 | loss: 0.6474 | val_loss: 0.6606 | val_acc: 0.5600
# Epoch 041 | loss: 0.6467 | val_loss: 0.6601 | val_acc: 0.5650
# Epoch 042 | loss: 0.6461 | val_loss: 0.6596 | val_acc: 0.5675
# Epoch 043 | loss: 0.6454 | val_loss: 0.6592 | val_acc: 0.5675
# Epoch 044 | loss: 0.6449 | val_loss: 0.6589 | val_acc: 0.5725
# Epoch 045 | loss: 0.6443 | val_loss: 0.6585 | val_acc: 0.5675
# Epoch 046 | loss: 0.6438 | val_loss: 0.6581 | val_acc: 0.5675
# Epoch 047 | loss: 0.6433 | val_loss: 0.6578 | val_acc: 0.5675
# Epoch 048 | loss: 0.6428 | val_loss: 0.6574 | val_acc: 0.5675
# Epoch 049 | loss: 0.6423 | val_loss: 0.6572 | val_acc: 0.5725
# Epoch 050 | loss: 0.6419 | val_loss: 0.6569 | val_acc: 0.5750
# Epoch 051 | loss: 0.6415 | val_loss: 0.6567 | val_acc: 0.5750
# Epoch 052 | loss: 0.6411 | val_loss: 0.6564 | val_acc: 0.5750
# Epoch 053 | loss: 0.6408 | val_loss: 0.6562 | val_acc: 0.5775
# Epoch 054 | loss: 0.6404 | val_loss: 0.6559 | val_acc: 0.5750
# Epoch 055 | loss: 0.6401 | val_loss: 0.6557 | val_acc: 0.5750
# Epoch 056 | loss: 0.6397 | val_loss: 0.6556 | val_acc: 0.5750
# Epoch 057 | loss: 0.6394 | val_loss: 0.6554 | val_acc: 0.5750
# Epoch 058 | loss: 0.6392 | val_loss: 0.6551 | val_acc: 0.5750
# Epoch 059 | loss: 0.6388 | val_loss: 0.6550 | val_acc: 0.5725
# Epoch 060 | loss: 0.6385 | val_loss: 0.6548 | val_acc: 0.5725
# Epoch 061 | loss: 0.6383 | val_loss: 0.6546 | val_acc: 0.5750
# Epoch 062 | loss: 0.6380 | val_loss: 0.6545 | val_acc: 0.5725
# Epoch 063 | loss: 0.6377 | val_loss: 0.6543 | val_acc: 0.5750
# Epoch 064 | loss: 0.6375 | val_loss: 0.6540 | val_acc: 0.5750
# Epoch 065 | loss: 0.6372 | val_loss: 0.6539 | val_acc: 0.5750
# Epoch 066 | loss: 0.6370 | val_loss: 0.6537 | val_acc: 0.5750
# Epoch 067 | loss: 0.6367 | val_loss: 0.6536 | val_acc: 0.5750
# Epoch 068 | loss: 0.6365 | val_loss: 0.6534 | val_acc: 0.5750
# Epoch 069 | loss: 0.6363 | val_loss: 0.6533 | val_acc: 0.5750
# Epoch 070 | loss: 0.6360 | val_loss: 0.6531 | val_acc: 0.5750
# Epoch 071 | loss: 0.6358 | val_loss: 0.6530 | val_acc: 0.5750
# Epoch 072 | loss: 0.6356 | val_loss: 0.6528 | val_acc: 0.5750
# Epoch 073 | loss: 0.6353 | val_loss: 0.6526 | val_acc: 0.5750
# Epoch 074 | loss: 0.6351 | val_loss: 0.6525 | val_acc: 0.5750
# Epoch 075 | loss: 0.6349 | val_loss: 0.6523 | val_acc: 0.5750
# Epoch 076 | loss: 0.6346 | val_loss: 0.6522 | val_acc: 0.5750
# Epoch 077 | loss: 0.6344 | val_loss: 0.6519 | val_acc: 0.5750
# Epoch 078 | loss: 0.6342 | val_loss: 0.6519 | val_acc: 0.5750
# Epoch 079 | loss: 0.6340 | val_loss: 0.6517 | val_acc: 0.5750
# Epoch 080 | loss: 0.6338 | val_loss: 0.6515 | val_acc: 0.5775
# [ELU] Acc: 0.5775 | Final train loss: 0.6338
#
# ------------------------------------------------------------
# Training with SOFTPLUS activation...
# Epoch 001 | loss: 0.8867 | val_loss: 0.8780 | val_acc: 0.5000
# Epoch 002 | loss: 0.8702 | val_loss: 0.8630 | val_acc: 0.5000
# Epoch 003 | loss: 0.8551 | val_loss: 0.8481 | val_acc: 0.5000
# Epoch 004 | loss: 0.8404 | val_loss: 0.8346 | val_acc: 0.5000
# Epoch 005 | loss: 0.8267 | val_loss: 0.8219 | val_acc: 0.5000
# Epoch 006 | loss: 0.8139 | val_loss: 0.8098 | val_acc: 0.5000
# Epoch 007 | loss: 0.8019 | val_loss: 0.7984 | val_acc: 0.5000
# Epoch 008 | loss: 0.7906 | val_loss: 0.7884 | val_acc: 0.5000
# Epoch 009 | loss: 0.7802 | val_loss: 0.7785 | val_acc: 0.5000
# Epoch 010 | loss: 0.7706 | val_loss: 0.7696 | val_acc: 0.5000
# Epoch 011 | loss: 0.7616 | val_loss: 0.7614 | val_acc: 0.5000
# Epoch 012 | loss: 0.7534 | val_loss: 0.7538 | val_acc: 0.5000
# Epoch 013 | loss: 0.7458 | val_loss: 0.7468 | val_acc: 0.5000
# Epoch 014 | loss: 0.7389 | val_loss: 0.7402 | val_acc: 0.5000
# Epoch 015 | loss: 0.7325 | val_loss: 0.7347 | val_acc: 0.5000
# Epoch 016 | loss: 0.7268 | val_loss: 0.7293 | val_acc: 0.5025
# Epoch 017 | loss: 0.7215 | val_loss: 0.7244 | val_acc: 0.5100
# Epoch 018 | loss: 0.7167 | val_loss: 0.7201 | val_acc: 0.5250
# Epoch 019 | loss: 0.7124 | val_loss: 0.7160 | val_acc: 0.5325
# Epoch 020 | loss: 0.7085 | val_loss: 0.7126 | val_acc: 0.5425
# Epoch 021 | loss: 0.7049 | val_loss: 0.7093 | val_acc: 0.5425
# Epoch 022 | loss: 0.7017 | val_loss: 0.7063 | val_acc: 0.5325
# Epoch 023 | loss: 0.6987 | val_loss: 0.7037 | val_acc: 0.5225
# Epoch 024 | loss: 0.6961 | val_loss: 0.7011 | val_acc: 0.5000
# Epoch 025 | loss: 0.6936 | val_loss: 0.6992 | val_acc: 0.4825
# Epoch 026 | loss: 0.6915 | val_loss: 0.6971 | val_acc: 0.4750
# Epoch 027 | loss: 0.6895 | val_loss: 0.6952 | val_acc: 0.4675
# Epoch 028 | loss: 0.6876 | val_loss: 0.6938 | val_acc: 0.4575
# Epoch 029 | loss: 0.6860 | val_loss: 0.6921 | val_acc: 0.4600
# Epoch 030 | loss: 0.6844 | val_loss: 0.6907 | val_acc: 0.4675
# Epoch 031 | loss: 0.6830 | val_loss: 0.6895 | val_acc: 0.4700
# Epoch 032 | loss: 0.6817 | val_loss: 0.6883 | val_acc: 0.4825
# Epoch 033 | loss: 0.6804 | val_loss: 0.6872 | val_acc: 0.4875
# Epoch 034 | loss: 0.6793 | val_loss: 0.6861 | val_acc: 0.5150
# Epoch 035 | loss: 0.6782 | val_loss: 0.6851 | val_acc: 0.5225
# Epoch 036 | loss: 0.6771 | val_loss: 0.6842 | val_acc: 0.5225
# Epoch 037 | loss: 0.6762 | val_loss: 0.6833 | val_acc: 0.5200
# Epoch 038 | loss: 0.6752 | val_loss: 0.6825 | val_acc: 0.5150
# Epoch 039 | loss: 0.6743 | val_loss: 0.6816 | val_acc: 0.5150
# Epoch 040 | loss: 0.6735 | val_loss: 0.6809 | val_acc: 0.5150
# Epoch 041 | loss: 0.6726 | val_loss: 0.6801 | val_acc: 0.5200
# Epoch 042 | loss: 0.6718 | val_loss: 0.6794 | val_acc: 0.5200
# Epoch 043 | loss: 0.6710 | val_loss: 0.6787 | val_acc: 0.5175
# Epoch 044 | loss: 0.6703 | val_loss: 0.6780 | val_acc: 0.5250
# Epoch 045 | loss: 0.6695 | val_loss: 0.6774 | val_acc: 0.5250
# Epoch 046 | loss: 0.6688 | val_loss: 0.6767 | val_acc: 0.5225
# Epoch 047 | loss: 0.6681 | val_loss: 0.6761 | val_acc: 0.5300
# Epoch 048 | loss: 0.6674 | val_loss: 0.6754 | val_acc: 0.5325
# Epoch 049 | loss: 0.6667 | val_loss: 0.6749 | val_acc: 0.5350
# Epoch 050 | loss: 0.6660 | val_loss: 0.6743 | val_acc: 0.5350
# Epoch 051 | loss: 0.6653 | val_loss: 0.6737 | val_acc: 0.5300
# Epoch 052 | loss: 0.6647 | val_loss: 0.6731 | val_acc: 0.5325
# Epoch 053 | loss: 0.6640 | val_loss: 0.6726 | val_acc: 0.5375
# Epoch 054 | loss: 0.6634 | val_loss: 0.6720 | val_acc: 0.5425
# Epoch 055 | loss: 0.6628 | val_loss: 0.6715 | val_acc: 0.5475
# Epoch 056 | loss: 0.6622 | val_loss: 0.6710 | val_acc: 0.5525
# Epoch 057 | loss: 0.6616 | val_loss: 0.6705 | val_acc: 0.5550
# Epoch 058 | loss: 0.6610 | val_loss: 0.6699 | val_acc: 0.5525
# Epoch 059 | loss: 0.6604 | val_loss: 0.6695 | val_acc: 0.5550
# Epoch 060 | loss: 0.6598 | val_loss: 0.6690 | val_acc: 0.5500
# Epoch 061 | loss: 0.6593 | val_loss: 0.6685 | val_acc: 0.5525
# Epoch 062 | loss: 0.6587 | val_loss: 0.6681 | val_acc: 0.5525
# Epoch 063 | loss: 0.6581 | val_loss: 0.6676 | val_acc: 0.5525
# Epoch 064 | loss: 0.6576 | val_loss: 0.6672 | val_acc: 0.5650
# Epoch 065 | loss: 0.6571 | val_loss: 0.6667 | val_acc: 0.5650
# Epoch 066 | loss: 0.6566 | val_loss: 0.6663 | val_acc: 0.5650
# Epoch 067 | loss: 0.6560 | val_loss: 0.6659 | val_acc: 0.5650
# Epoch 068 | loss: 0.6556 | val_loss: 0.6655 | val_acc: 0.5650
# Epoch 069 | loss: 0.6551 | val_loss: 0.6651 | val_acc: 0.5650
# Epoch 070 | loss: 0.6546 | val_loss: 0.6647 | val_acc: 0.5650
# Epoch 071 | loss: 0.6541 | val_loss: 0.6643 | val_acc: 0.5675
# Epoch 072 | loss: 0.6537 | val_loss: 0.6640 | val_acc: 0.5725
# Epoch 073 | loss: 0.6532 | val_loss: 0.6636 | val_acc: 0.5725
# Epoch 074 | loss: 0.6527 | val_loss: 0.6633 | val_acc: 0.5775
# Epoch 075 | loss: 0.6523 | val_loss: 0.6629 | val_acc: 0.5775
# Epoch 076 | loss: 0.6518 | val_loss: 0.6626 | val_acc: 0.5775
# Epoch 077 | loss: 0.6514 | val_loss: 0.6622 | val_acc: 0.5775
# Epoch 078 | loss: 0.6510 | val_loss: 0.6619 | val_acc: 0.5775
# Epoch 079 | loss: 0.6506 | val_loss: 0.6616 | val_acc: 0.5775
# Epoch 080 | loss: 0.6502 | val_loss: 0.6612 | val_acc: 0.5775
# [SOFTPLUS] Acc: 0.5775 | Final train loss: 0.6502
#
# ------------------------------------------------------------
# Training with SWISH activation...
# Epoch 001 | loss: 0.6969 | val_loss: 0.7017 | val_acc: 0.5500
# Epoch 002 | loss: 0.6947 | val_loss: 0.6994 | val_acc: 0.5650
# Epoch 003 | loss: 0.6925 | val_loss: 0.6972 | val_acc: 0.5825
# Epoch 004 | loss: 0.6905 | val_loss: 0.6950 | val_acc: 0.5525
# Epoch 005 | loss: 0.6886 | val_loss: 0.6930 | val_acc: 0.5475
# Epoch 006 | loss: 0.6867 | val_loss: 0.6911 | val_acc: 0.5475
# Epoch 007 | loss: 0.6850 | val_loss: 0.6893 | val_acc: 0.5500
# Epoch 008 | loss: 0.6833 | val_loss: 0.6876 | val_acc: 0.5550
# Epoch 009 | loss: 0.6817 | val_loss: 0.6860 | val_acc: 0.5525
# Epoch 010 | loss: 0.6802 | val_loss: 0.6843 | val_acc: 0.5475
# Epoch 011 | loss: 0.6787 | val_loss: 0.6829 | val_acc: 0.5525
# Epoch 012 | loss: 0.6773 | val_loss: 0.6815 | val_acc: 0.5600
# Epoch 013 | loss: 0.6760 | val_loss: 0.6802 | val_acc: 0.5600
# Epoch 014 | loss: 0.6747 | val_loss: 0.6789 | val_acc: 0.5650
# Epoch 015 | loss: 0.6734 | val_loss: 0.6777 | val_acc: 0.5650
# Epoch 016 | loss: 0.6722 | val_loss: 0.6765 | val_acc: 0.5625
# Epoch 017 | loss: 0.6711 | val_loss: 0.6754 | val_acc: 0.5550
# Epoch 018 | loss: 0.6700 | val_loss: 0.6743 | val_acc: 0.5675
# Epoch 019 | loss: 0.6690 | val_loss: 0.6733 | val_acc: 0.5700
# Epoch 020 | loss: 0.6679 | val_loss: 0.6724 | val_acc: 0.5700
# Epoch 021 | loss: 0.6670 | val_loss: 0.6715 | val_acc: 0.5750
# Epoch 022 | loss: 0.6660 | val_loss: 0.6706 | val_acc: 0.5775
# Epoch 023 | loss: 0.6651 | val_loss: 0.6697 | val_acc: 0.5775
# Epoch 024 | loss: 0.6642 | val_loss: 0.6689 | val_acc: 0.5775
# Epoch 025 | loss: 0.6634 | val_loss: 0.6681 | val_acc: 0.5850
# Epoch 026 | loss: 0.6626 | val_loss: 0.6673 | val_acc: 0.5875
# Epoch 027 | loss: 0.6618 | val_loss: 0.6665 | val_acc: 0.5875
# Epoch 028 | loss: 0.6610 | val_loss: 0.6659 | val_acc: 0.5875
# Epoch 029 | loss: 0.6602 | val_loss: 0.6652 | val_acc: 0.5875
# Epoch 030 | loss: 0.6595 | val_loss: 0.6645 | val_acc: 0.5900
# Epoch 031 | loss: 0.6588 | val_loss: 0.6639 | val_acc: 0.5900
# Epoch 032 | loss: 0.6581 | val_loss: 0.6633 | val_acc: 0.5900
# Epoch 033 | loss: 0.6574 | val_loss: 0.6627 | val_acc: 0.5950
# Epoch 034 | loss: 0.6568 | val_loss: 0.6621 | val_acc: 0.5950
# Epoch 035 | loss: 0.6562 | val_loss: 0.6615 | val_acc: 0.6000
# Epoch 036 | loss: 0.6555 | val_loss: 0.6610 | val_acc: 0.6000
# Epoch 037 | loss: 0.6549 | val_loss: 0.6605 | val_acc: 0.6000
# Epoch 038 | loss: 0.6543 | val_loss: 0.6599 | val_acc: 0.6025
# Epoch 039 | loss: 0.6538 | val_loss: 0.6594 | val_acc: 0.6050
# Epoch 040 | loss: 0.6532 | val_loss: 0.6590 | val_acc: 0.6050
# Epoch 041 | loss: 0.6526 | val_loss: 0.6585 | val_acc: 0.6075
# Epoch 042 | loss: 0.6521 | val_loss: 0.6580 | val_acc: 0.6050
# Epoch 043 | loss: 0.6516 | val_loss: 0.6575 | val_acc: 0.6050
# Epoch 044 | loss: 0.6510 | val_loss: 0.6571 | val_acc: 0.6050
# Epoch 045 | loss: 0.6505 | val_loss: 0.6566 | val_acc: 0.6050
# Epoch 046 | loss: 0.6500 | val_loss: 0.6562 | val_acc: 0.6050
# Epoch 047 | loss: 0.6495 | val_loss: 0.6558 | val_acc: 0.6050
# Epoch 048 | loss: 0.6490 | val_loss: 0.6553 | val_acc: 0.6050
# Epoch 049 | loss: 0.6485 | val_loss: 0.6549 | val_acc: 0.6050
# Epoch 050 | loss: 0.6480 | val_loss: 0.6546 | val_acc: 0.6075
# Epoch 051 | loss: 0.6475 | val_loss: 0.6541 | val_acc: 0.6075
# Epoch 052 | loss: 0.6471 | val_loss: 0.6537 | val_acc: 0.6075
# Epoch 053 | loss: 0.6466 | val_loss: 0.6533 | val_acc: 0.6100
# Epoch 054 | loss: 0.6461 | val_loss: 0.6529 | val_acc: 0.6100
# Epoch 055 | loss: 0.6457 | val_loss: 0.6526 | val_acc: 0.6100
# Epoch 056 | loss: 0.6452 | val_loss: 0.6522 | val_acc: 0.6100
# Epoch 057 | loss: 0.6447 | val_loss: 0.6518 | val_acc: 0.6100
# Epoch 058 | loss: 0.6443 | val_loss: 0.6514 | val_acc: 0.6100
# Epoch 059 | loss: 0.6438 | val_loss: 0.6511 | val_acc: 0.6100
# Epoch 060 | loss: 0.6434 | val_loss: 0.6507 | val_acc: 0.6100
# Epoch 061 | loss: 0.6429 | val_loss: 0.6503 | val_acc: 0.6100
# Epoch 062 | loss: 0.6425 | val_loss: 0.6499 | val_acc: 0.6100
# Epoch 063 | loss: 0.6420 | val_loss: 0.6495 | val_acc: 0.6100
# Epoch 064 | loss: 0.6416 | val_loss: 0.6491 | val_acc: 0.6100
# Epoch 065 | loss: 0.6411 | val_loss: 0.6488 | val_acc: 0.6050
# Epoch 066 | loss: 0.6407 | val_loss: 0.6484 | val_acc: 0.6075
# Epoch 067 | loss: 0.6402 | val_loss: 0.6480 | val_acc: 0.6100
# Epoch 068 | loss: 0.6398 | val_loss: 0.6477 | val_acc: 0.6050
# Epoch 069 | loss: 0.6394 | val_loss: 0.6473 | val_acc: 0.6050
# Epoch 070 | loss: 0.6389 | val_loss: 0.6469 | val_acc: 0.6075
# Epoch 071 | loss: 0.6385 | val_loss: 0.6466 | val_acc: 0.6075
# Epoch 072 | loss: 0.6380 | val_loss: 0.6462 | val_acc: 0.6050
# Epoch 073 | loss: 0.6376 | val_loss: 0.6458 | val_acc: 0.6050
# Epoch 074 | loss: 0.6371 | val_loss: 0.6455 | val_acc: 0.6075
# Epoch 075 | loss: 0.6367 | val_loss: 0.6451 | val_acc: 0.6075
# Epoch 076 | loss: 0.6362 | val_loss: 0.6447 | val_acc: 0.6075
# Epoch 077 | loss: 0.6358 | val_loss: 0.6443 | val_acc: 0.6075
# Epoch 078 | loss: 0.6354 | val_loss: 0.6440 | val_acc: 0.6075
# Epoch 079 | loss: 0.6349 | val_loss: 0.6436 | val_acc: 0.6075
# Epoch 080 | loss: 0.6345 | val_loss: 0.6432 | val_acc: 0.6075
# [SWISH] Acc: 0.6075 | Final train loss: 0.6345
#
# ------------------------------------------------------------
# Training with MISH activation...
# Epoch 001 | loss: 0.7335 | val_loss: 0.7230 | val_acc: 0.4725
# Epoch 002 | loss: 0.7306 | val_loss: 0.7208 | val_acc: 0.4575
# Epoch 003 | loss: 0.7279 | val_loss: 0.7187 | val_acc: 0.4575
# Epoch 004 | loss: 0.7253 | val_loss: 0.7166 | val_acc: 0.4575
# Epoch 005 | loss: 0.7228 | val_loss: 0.7147 | val_acc: 0.4575
# Epoch 006 | loss: 0.7204 | val_loss: 0.7127 | val_acc: 0.4625
# Epoch 007 | loss: 0.7181 | val_loss: 0.7109 | val_acc: 0.4600
# Epoch 008 | loss: 0.7158 | val_loss: 0.7091 | val_acc: 0.4625
# Epoch 009 | loss: 0.7136 | val_loss: 0.7074 | val_acc: 0.4625
# Epoch 010 | loss: 0.7115 | val_loss: 0.7057 | val_acc: 0.4625
# Epoch 011 | loss: 0.7094 | val_loss: 0.7041 | val_acc: 0.4600
# Epoch 012 | loss: 0.7075 | val_loss: 0.7026 | val_acc: 0.4625
# Epoch 013 | loss: 0.7056 | val_loss: 0.7011 | val_acc: 0.4650
# Epoch 014 | loss: 0.7037 | val_loss: 0.6996 | val_acc: 0.4675
# Epoch 015 | loss: 0.7019 | val_loss: 0.6983 | val_acc: 0.4675
# Epoch 016 | loss: 0.7001 | val_loss: 0.6969 | val_acc: 0.4700
# Epoch 017 | loss: 0.6985 | val_loss: 0.6955 | val_acc: 0.4725
# Epoch 018 | loss: 0.6968 | val_loss: 0.6942 | val_acc: 0.4775
# Epoch 019 | loss: 0.6952 | val_loss: 0.6930 | val_acc: 0.4775
# Epoch 020 | loss: 0.6936 | val_loss: 0.6918 | val_acc: 0.4850
# Epoch 021 | loss: 0.6921 | val_loss: 0.6906 | val_acc: 0.4900
# Epoch 022 | loss: 0.6906 | val_loss: 0.6895 | val_acc: 0.5000
# Epoch 023 | loss: 0.6892 | val_loss: 0.6883 | val_acc: 0.5075
# Epoch 024 | loss: 0.6878 | val_loss: 0.6872 | val_acc: 0.5125
# Epoch 025 | loss: 0.6864 | val_loss: 0.6862 | val_acc: 0.5125
# Epoch 026 | loss: 0.6850 | val_loss: 0.6851 | val_acc: 0.5200
# Epoch 027 | loss: 0.6837 | val_loss: 0.6841 | val_acc: 0.5275
# Epoch 028 | loss: 0.6824 | val_loss: 0.6831 | val_acc: 0.5300
# Epoch 029 | loss: 0.6812 | val_loss: 0.6822 | val_acc: 0.5350
# Epoch 030 | loss: 0.6799 | val_loss: 0.6811 | val_acc: 0.5350
# Epoch 031 | loss: 0.6787 | val_loss: 0.6802 | val_acc: 0.5425
# Epoch 032 | loss: 0.6775 | val_loss: 0.6793 | val_acc: 0.5425
# Epoch 033 | loss: 0.6764 | val_loss: 0.6784 | val_acc: 0.5425
# Epoch 034 | loss: 0.6752 | val_loss: 0.6775 | val_acc: 0.5425
# Epoch 035 | loss: 0.6741 | val_loss: 0.6767 | val_acc: 0.5425
# Epoch 036 | loss: 0.6730 | val_loss: 0.6758 | val_acc: 0.5475
# Epoch 037 | loss: 0.6719 | val_loss: 0.6749 | val_acc: 0.5475
# Epoch 038 | loss: 0.6709 | val_loss: 0.6741 | val_acc: 0.5500
# Epoch 039 | loss: 0.6698 | val_loss: 0.6733 | val_acc: 0.5450
# Epoch 040 | loss: 0.6688 | val_loss: 0.6725 | val_acc: 0.5400
# Epoch 041 | loss: 0.6678 | val_loss: 0.6717 | val_acc: 0.5425
# Epoch 042 | loss: 0.6668 | val_loss: 0.6709 | val_acc: 0.5450
# Epoch 043 | loss: 0.6658 | val_loss: 0.6701 | val_acc: 0.5475
# Epoch 044 | loss: 0.6648 | val_loss: 0.6693 | val_acc: 0.5475
# Epoch 045 | loss: 0.6639 | val_loss: 0.6686 | val_acc: 0.5500
# Epoch 046 | loss: 0.6629 | val_loss: 0.6678 | val_acc: 0.5525
# Epoch 047 | loss: 0.6620 | val_loss: 0.6671 | val_acc: 0.5550
# Epoch 048 | loss: 0.6610 | val_loss: 0.6663 | val_acc: 0.5575
# Epoch 049 | loss: 0.6601 | val_loss: 0.6656 | val_acc: 0.5525
# Epoch 050 | loss: 0.6592 | val_loss: 0.6649 | val_acc: 0.5600
# Epoch 051 | loss: 0.6583 | val_loss: 0.6642 | val_acc: 0.5600
# Epoch 052 | loss: 0.6574 | val_loss: 0.6635 | val_acc: 0.5650
# Epoch 053 | loss: 0.6566 | val_loss: 0.6627 | val_acc: 0.5650
# Epoch 054 | loss: 0.6557 | val_loss: 0.6620 | val_acc: 0.5700
# Epoch 055 | loss: 0.6548 | val_loss: 0.6613 | val_acc: 0.5700
# Epoch 056 | loss: 0.6540 | val_loss: 0.6606 | val_acc: 0.5700
# Epoch 057 | loss: 0.6531 | val_loss: 0.6599 | val_acc: 0.5750
# Epoch 058 | loss: 0.6523 | val_loss: 0.6592 | val_acc: 0.5825
# Epoch 059 | loss: 0.6515 | val_loss: 0.6586 | val_acc: 0.5825
# Epoch 060 | loss: 0.6506 | val_loss: 0.6579 | val_acc: 0.5825
# Epoch 061 | loss: 0.6498 | val_loss: 0.6572 | val_acc: 0.5800
# Epoch 062 | loss: 0.6490 | val_loss: 0.6565 | val_acc: 0.5800
# Epoch 063 | loss: 0.6482 | val_loss: 0.6558 | val_acc: 0.5775
# Epoch 064 | loss: 0.6474 | val_loss: 0.6551 | val_acc: 0.5800
# Epoch 065 | loss: 0.6466 | val_loss: 0.6545 | val_acc: 0.5775
# Epoch 066 | loss: 0.6458 | val_loss: 0.6538 | val_acc: 0.5800
# Epoch 067 | loss: 0.6450 | val_loss: 0.6531 | val_acc: 0.5775
# Epoch 068 | loss: 0.6442 | val_loss: 0.6524 | val_acc: 0.5800
# Epoch 069 | loss: 0.6434 | val_loss: 0.6518 | val_acc: 0.5775
# Epoch 070 | loss: 0.6427 | val_loss: 0.6511 | val_acc: 0.5800
# Epoch 071 | loss: 0.6418 | val_loss: 0.6504 | val_acc: 0.5800
# Epoch 072 | loss: 0.6411 | val_loss: 0.6497 | val_acc: 0.5800
# Epoch 073 | loss: 0.6403 | val_loss: 0.6491 | val_acc: 0.5800
# Epoch 074 | loss: 0.6395 | val_loss: 0.6484 | val_acc: 0.5800
# Epoch 075 | loss: 0.6388 | val_loss: 0.6477 | val_acc: 0.5850
# Epoch 076 | loss: 0.6379 | val_loss: 0.6470 | val_acc: 0.5850
# Epoch 077 | loss: 0.6372 | val_loss: 0.6463 | val_acc: 0.5850
# Epoch 078 | loss: 0.6364 | val_loss: 0.6457 | val_acc: 0.5875
# Epoch 079 | loss: 0.6356 | val_loss: 0.6450 | val_acc: 0.5875
# Epoch 080 | loss: 0.6349 | val_loss: 0.6444 | val_acc: 0.5875
# [MISH] Acc: 0.5875 | Final train loss: 0.6349
#
# ------------------------------------------------------------
# Training with GELU activation...
# Epoch 001 | loss: 0.7339 | val_loss: 0.7442 | val_acc: 0.5850
# Epoch 002 | loss: 0.7286 | val_loss: 0.7389 | val_acc: 0.5850
# Epoch 003 | loss: 0.7235 | val_loss: 0.7342 | val_acc: 0.5875
# Epoch 004 | loss: 0.7189 | val_loss: 0.7296 | val_acc: 0.5925
# Epoch 005 | loss: 0.7145 | val_loss: 0.7252 | val_acc: 0.5875
# Epoch 006 | loss: 0.7103 | val_loss: 0.7213 | val_acc: 0.5875
# Epoch 007 | loss: 0.7064 | val_loss: 0.7176 | val_acc: 0.5825
# Epoch 008 | loss: 0.7028 | val_loss: 0.7138 | val_acc: 0.5825
# Epoch 009 | loss: 0.6993 | val_loss: 0.7106 | val_acc: 0.5825
# Epoch 010 | loss: 0.6960 | val_loss: 0.7073 | val_acc: 0.5825
# Epoch 011 | loss: 0.6929 | val_loss: 0.7044 | val_acc: 0.5800
# Epoch 012 | loss: 0.6900 | val_loss: 0.7015 | val_acc: 0.5850
# Epoch 013 | loss: 0.6872 | val_loss: 0.6989 | val_acc: 0.5825
# Epoch 014 | loss: 0.6846 | val_loss: 0.6965 | val_acc: 0.5825
# Epoch 015 | loss: 0.6821 | val_loss: 0.6940 | val_acc: 0.5825
# Epoch 016 | loss: 0.6797 | val_loss: 0.6917 | val_acc: 0.5750
# Epoch 017 | loss: 0.6775 | val_loss: 0.6896 | val_acc: 0.5750
# Epoch 018 | loss: 0.6754 | val_loss: 0.6875 | val_acc: 0.5800
# Epoch 019 | loss: 0.6733 | val_loss: 0.6856 | val_acc: 0.5825
# Epoch 020 | loss: 0.6714 | val_loss: 0.6838 | val_acc: 0.5850
# Epoch 021 | loss: 0.6696 | val_loss: 0.6819 | val_acc: 0.5850
# Epoch 022 | loss: 0.6677 | val_loss: 0.6803 | val_acc: 0.5850
# Epoch 023 | loss: 0.6660 | val_loss: 0.6786 | val_acc: 0.5825
# Epoch 024 | loss: 0.6644 | val_loss: 0.6771 | val_acc: 0.5825
# Epoch 025 | loss: 0.6628 | val_loss: 0.6755 | val_acc: 0.5800
# Epoch 026 | loss: 0.6612 | val_loss: 0.6740 | val_acc: 0.5775
# Epoch 027 | loss: 0.6598 | val_loss: 0.6727 | val_acc: 0.5775
# Epoch 028 | loss: 0.6583 | val_loss: 0.6712 | val_acc: 0.5750
# Epoch 029 | loss: 0.6569 | val_loss: 0.6700 | val_acc: 0.5775
# Epoch 030 | loss: 0.6556 | val_loss: 0.6686 | val_acc: 0.5800
# Epoch 031 | loss: 0.6542 | val_loss: 0.6674 | val_acc: 0.5800
# Epoch 032 | loss: 0.6529 | val_loss: 0.6662 | val_acc: 0.5800
# Epoch 033 | loss: 0.6516 | val_loss: 0.6649 | val_acc: 0.5800
# Epoch 034 | loss: 0.6504 | val_loss: 0.6637 | val_acc: 0.5800
# Epoch 035 | loss: 0.6491 | val_loss: 0.6626 | val_acc: 0.5775
# Epoch 036 | loss: 0.6479 | val_loss: 0.6614 | val_acc: 0.5750
# Epoch 037 | loss: 0.6467 | val_loss: 0.6603 | val_acc: 0.5750
# Epoch 038 | loss: 0.6456 | val_loss: 0.6592 | val_acc: 0.5775
# Epoch 039 | loss: 0.6444 | val_loss: 0.6581 | val_acc: 0.5775
# Epoch 040 | loss: 0.6433 | val_loss: 0.6570 | val_acc: 0.5775
# Epoch 041 | loss: 0.6421 | val_loss: 0.6559 | val_acc: 0.5775
# Epoch 042 | loss: 0.6410 | val_loss: 0.6549 | val_acc: 0.5800
# Epoch 043 | loss: 0.6398 | val_loss: 0.6538 | val_acc: 0.5775
# Epoch 044 | loss: 0.6388 | val_loss: 0.6528 | val_acc: 0.5800
# Epoch 045 | loss: 0.6377 | val_loss: 0.6517 | val_acc: 0.5800
# Epoch 046 | loss: 0.6365 | val_loss: 0.6506 | val_acc: 0.5800
# Epoch 047 | loss: 0.6354 | val_loss: 0.6496 | val_acc: 0.5800
# Epoch 048 | loss: 0.6343 | val_loss: 0.6485 | val_acc: 0.5800
# Epoch 049 | loss: 0.6332 | val_loss: 0.6475 | val_acc: 0.5800
# Epoch 050 | loss: 0.6321 | val_loss: 0.6465 | val_acc: 0.5800
# Epoch 051 | loss: 0.6311 | val_loss: 0.6454 | val_acc: 0.5800
# Epoch 052 | loss: 0.6300 | val_loss: 0.6444 | val_acc: 0.5800
# Epoch 053 | loss: 0.6289 | val_loss: 0.6433 | val_acc: 0.5800
# Epoch 054 | loss: 0.6278 | val_loss: 0.6422 | val_acc: 0.5800
# Epoch 055 | loss: 0.6267 | val_loss: 0.6412 | val_acc: 0.5825
# Epoch 056 | loss: 0.6257 | val_loss: 0.6402 | val_acc: 0.5825
# Epoch 057 | loss: 0.6246 | val_loss: 0.6392 | val_acc: 0.5825
# Epoch 058 | loss: 0.6236 | val_loss: 0.6381 | val_acc: 0.5850
# Epoch 059 | loss: 0.6225 | val_loss: 0.6371 | val_acc: 0.5825
# Epoch 060 | loss: 0.6214 | val_loss: 0.6361 | val_acc: 0.5900
# Epoch 061 | loss: 0.6203 | val_loss: 0.6350 | val_acc: 0.5925
# Epoch 062 | loss: 0.6193 | val_loss: 0.6340 | val_acc: 0.5925
# Epoch 063 | loss: 0.6182 | val_loss: 0.6329 | val_acc: 0.5925
# Epoch 064 | loss: 0.6172 | val_loss: 0.6319 | val_acc: 0.5925
# Epoch 065 | loss: 0.6161 | val_loss: 0.6309 | val_acc: 0.5925
# Epoch 066 | loss: 0.6150 | val_loss: 0.6298 | val_acc: 0.5925
# Epoch 067 | loss: 0.6140 | val_loss: 0.6288 | val_acc: 0.5950
# Epoch 068 | loss: 0.6129 | val_loss: 0.6278 | val_acc: 0.5975
# Epoch 069 | loss: 0.6119 | val_loss: 0.6268 | val_acc: 0.5975
# Epoch 070 | loss: 0.6108 | val_loss: 0.6257 | val_acc: 0.5975
# Epoch 071 | loss: 0.6097 | val_loss: 0.6247 | val_acc: 0.6000
# Epoch 072 | loss: 0.6087 | val_loss: 0.6237 | val_acc: 0.5975
# Epoch 073 | loss: 0.6077 | val_loss: 0.6227 | val_acc: 0.5975
# Epoch 074 | loss: 0.6066 | val_loss: 0.6216 | val_acc: 0.5975
# Epoch 075 | loss: 0.6056 | val_loss: 0.6206 | val_acc: 0.6000
# Epoch 076 | loss: 0.6045 | val_loss: 0.6196 | val_acc: 0.6000
# Epoch 077 | loss: 0.6035 | val_loss: 0.6185 | val_acc: 0.6000
# Epoch 078 | loss: 0.6025 | val_loss: 0.6176 | val_acc: 0.6000
# Epoch 079 | loss: 0.6014 | val_loss: 0.6166 | val_acc: 0.6000
# Epoch 080 | loss: 0.6004 | val_loss: 0.6156 | val_acc: 0.6025
# [GELU] Acc: 0.6025 | Final train loss: 0.6004
#
# ------------------------------------------------------------
# Training with SINE activation...
# Epoch 001 | loss: 0.6819 | val_loss: 0.6985 | val_acc: 0.5300
# Epoch 002 | loss: 0.6785 | val_loss: 0.6949 | val_acc: 0.5325
# Epoch 003 | loss: 0.6753 | val_loss: 0.6914 | val_acc: 0.5375
# Epoch 004 | loss: 0.6723 | val_loss: 0.6882 | val_acc: 0.5375
# Epoch 005 | loss: 0.6696 | val_loss: 0.6853 | val_acc: 0.5425
# Epoch 006 | loss: 0.6672 | val_loss: 0.6826 | val_acc: 0.5500
# Epoch 007 | loss: 0.6649 | val_loss: 0.6802 | val_acc: 0.5525
# Epoch 008 | loss: 0.6629 | val_loss: 0.6780 | val_acc: 0.5600
# Epoch 009 | loss: 0.6610 | val_loss: 0.6760 | val_acc: 0.5625
# Epoch 010 | loss: 0.6594 | val_loss: 0.6741 | val_acc: 0.5525
# Epoch 011 | loss: 0.6578 | val_loss: 0.6725 | val_acc: 0.5525
# Epoch 012 | loss: 0.6565 | val_loss: 0.6710 | val_acc: 0.5625
# Epoch 013 | loss: 0.6553 | val_loss: 0.6697 | val_acc: 0.5600
# Epoch 014 | loss: 0.6541 | val_loss: 0.6685 | val_acc: 0.5650
# Epoch 015 | loss: 0.6531 | val_loss: 0.6675 | val_acc: 0.5700
# Epoch 016 | loss: 0.6522 | val_loss: 0.6663 | val_acc: 0.5775
# Epoch 017 | loss: 0.6514 | val_loss: 0.6655 | val_acc: 0.5725
# Epoch 018 | loss: 0.6507 | val_loss: 0.6646 | val_acc: 0.5775
# Epoch 019 | loss: 0.6500 | val_loss: 0.6639 | val_acc: 0.5725
# Epoch 020 | loss: 0.6494 | val_loss: 0.6634 | val_acc: 0.5775
# Epoch 021 | loss: 0.6489 | val_loss: 0.6628 | val_acc: 0.5750
# Epoch 022 | loss: 0.6485 | val_loss: 0.6624 | val_acc: 0.5750
# Epoch 023 | loss: 0.6480 | val_loss: 0.6618 | val_acc: 0.5825
# Epoch 024 | loss: 0.6477 | val_loss: 0.6614 | val_acc: 0.5825
# Epoch 025 | loss: 0.6473 | val_loss: 0.6611 | val_acc: 0.5850
# Epoch 026 | loss: 0.6470 | val_loss: 0.6606 | val_acc: 0.5825
# Epoch 027 | loss: 0.6467 | val_loss: 0.6604 | val_acc: 0.5825
# Epoch 028 | loss: 0.6464 | val_loss: 0.6602 | val_acc: 0.5825
# Epoch 029 | loss: 0.6462 | val_loss: 0.6599 | val_acc: 0.5825
# Epoch 030 | loss: 0.6460 | val_loss: 0.6596 | val_acc: 0.5850
# Epoch 031 | loss: 0.6457 | val_loss: 0.6595 | val_acc: 0.5825
# Epoch 032 | loss: 0.6456 | val_loss: 0.6593 | val_acc: 0.5875
# Epoch 033 | loss: 0.6454 | val_loss: 0.6591 | val_acc: 0.5875
# Epoch 034 | loss: 0.6453 | val_loss: 0.6589 | val_acc: 0.5850
# Epoch 035 | loss: 0.6451 | val_loss: 0.6588 | val_acc: 0.5850
# Epoch 036 | loss: 0.6449 | val_loss: 0.6587 | val_acc: 0.5900
# Epoch 037 | loss: 0.6448 | val_loss: 0.6586 | val_acc: 0.5900
# Epoch 038 | loss: 0.6447 | val_loss: 0.6584 | val_acc: 0.5900
# Epoch 039 | loss: 0.6446 | val_loss: 0.6583 | val_acc: 0.5900
# Epoch 040 | loss: 0.6445 | val_loss: 0.6582 | val_acc: 0.5900
# Epoch 041 | loss: 0.6443 | val_loss: 0.6581 | val_acc: 0.5925
# Epoch 042 | loss: 0.6442 | val_loss: 0.6580 | val_acc: 0.5925
# Epoch 043 | loss: 0.6441 | val_loss: 0.6580 | val_acc: 0.5925
# Epoch 044 | loss: 0.6440 | val_loss: 0.6579 | val_acc: 0.5900
# Epoch 045 | loss: 0.6439 | val_loss: 0.6577 | val_acc: 0.5900
# Epoch 046 | loss: 0.6438 | val_loss: 0.6577 | val_acc: 0.5900
# Epoch 047 | loss: 0.6437 | val_loss: 0.6576 | val_acc: 0.5900
# Epoch 048 | loss: 0.6436 | val_loss: 0.6575 | val_acc: 0.5900
# Epoch 049 | loss: 0.6435 | val_loss: 0.6574 | val_acc: 0.5900
# Epoch 050 | loss: 0.6434 | val_loss: 0.6574 | val_acc: 0.5900
# Epoch 051 | loss: 0.6433 | val_loss: 0.6573 | val_acc: 0.5900
# Epoch 052 | loss: 0.6432 | val_loss: 0.6572 | val_acc: 0.5900
# Epoch 053 | loss: 0.6431 | val_loss: 0.6571 | val_acc: 0.5900
# Epoch 054 | loss: 0.6431 | val_loss: 0.6570 | val_acc: 0.5900
# Epoch 055 | loss: 0.6429 | val_loss: 0.6570 | val_acc: 0.5900
# Epoch 056 | loss: 0.6428 | val_loss: 0.6569 | val_acc: 0.5900
# Epoch 057 | loss: 0.6427 | val_loss: 0.6568 | val_acc: 0.5900
# Epoch 058 | loss: 0.6427 | val_loss: 0.6567 | val_acc: 0.5925
# Epoch 059 | loss: 0.6426 | val_loss: 0.6567 | val_acc: 0.5900
# Epoch 060 | loss: 0.6424 | val_loss: 0.6566 | val_acc: 0.5900
# Epoch 061 | loss: 0.6424 | val_loss: 0.6565 | val_acc: 0.5925
# Epoch 062 | loss: 0.6423 | val_loss: 0.6564 | val_acc: 0.5900
# Epoch 063 | loss: 0.6421 | val_loss: 0.6563 | val_acc: 0.5925
# Epoch 064 | loss: 0.6420 | val_loss: 0.6562 | val_acc: 0.5925
# Epoch 065 | loss: 0.6419 | val_loss: 0.6561 | val_acc: 0.5925
# Epoch 066 | loss: 0.6418 | val_loss: 0.6560 | val_acc: 0.5950
# Epoch 067 | loss: 0.6417 | val_loss: 0.6559 | val_acc: 0.5950
# Epoch 068 | loss: 0.6416 | val_loss: 0.6558 | val_acc: 0.5950
# Epoch 069 | loss: 0.6415 | val_loss: 0.6557 | val_acc: 0.5925
# Epoch 070 | loss: 0.6414 | val_loss: 0.6556 | val_acc: 0.5925
# Epoch 071 | loss: 0.6412 | val_loss: 0.6556 | val_acc: 0.5950
# Epoch 072 | loss: 0.6411 | val_loss: 0.6554 | val_acc: 0.5950
# Epoch 073 | loss: 0.6410 | val_loss: 0.6553 | val_acc: 0.5950
# Epoch 074 | loss: 0.6409 | val_loss: 0.6552 | val_acc: 0.5925
# Epoch 075 | loss: 0.6408 | val_loss: 0.6551 | val_acc: 0.5950
# Epoch 076 | loss: 0.6406 | val_loss: 0.6550 | val_acc: 0.5950
# Epoch 077 | loss: 0.6405 | val_loss: 0.6549 | val_acc: 0.5950
# Epoch 078 | loss: 0.6404 | val_loss: 0.6548 | val_acc: 0.5950
# Epoch 079 | loss: 0.6403 | val_loss: 0.6547 | val_acc: 0.5950
# Epoch 080 | loss: 0.6402 | val_loss: 0.6546 | val_acc: 0.5950
# [SINE] Acc: 0.5950 | Final train loss: 0.6402
#
# ------------------------------------------------------------
# Training with SIGMOID activation...
# Epoch 001 | loss: 0.7299 | val_loss: 0.7391 | val_acc: 0.5000
# Epoch 002 | loss: 0.7248 | val_loss: 0.7339 | val_acc: 0.5000
# Epoch 003 | loss: 0.7200 | val_loss: 0.7296 | val_acc: 0.5000
# Epoch 004 | loss: 0.7158 | val_loss: 0.7253 | val_acc: 0.5000
# Epoch 005 | loss: 0.7119 | val_loss: 0.7213 | val_acc: 0.5000
# Epoch 006 | loss: 0.7082 | val_loss: 0.7177 | val_acc: 0.5000
# Epoch 007 | loss: 0.7049 | val_loss: 0.7145 | val_acc: 0.5100
# Epoch 008 | loss: 0.7019 | val_loss: 0.7113 | val_acc: 0.5175
# Epoch 009 | loss: 0.6990 | val_loss: 0.7086 | val_acc: 0.5350
# Epoch 010 | loss: 0.6964 | val_loss: 0.7060 | val_acc: 0.5600
# Epoch 011 | loss: 0.6941 | val_loss: 0.7037 | val_acc: 0.5625
# Epoch 012 | loss: 0.6919 | val_loss: 0.7015 | val_acc: 0.5650
# Epoch 013 | loss: 0.6900 | val_loss: 0.6996 | val_acc: 0.5675
# Epoch 014 | loss: 0.6881 | val_loss: 0.6979 | val_acc: 0.5700
# Epoch 015 | loss: 0.6865 | val_loss: 0.6961 | val_acc: 0.5700
# Epoch 016 | loss: 0.6849 | val_loss: 0.6946 | val_acc: 0.5700
# Epoch 017 | loss: 0.6835 | val_loss: 0.6933 | val_acc: 0.5675
# Epoch 018 | loss: 0.6823 | val_loss: 0.6919 | val_acc: 0.5675
# Epoch 019 | loss: 0.6811 | val_loss: 0.6908 | val_acc: 0.5775
# Epoch 020 | loss: 0.6800 | val_loss: 0.6897 | val_acc: 0.5775
# Epoch 021 | loss: 0.6789 | val_loss: 0.6887 | val_acc: 0.5800
# Epoch 022 | loss: 0.6780 | val_loss: 0.6879 | val_acc: 0.5875
# Epoch 023 | loss: 0.6771 | val_loss: 0.6869 | val_acc: 0.5950
# Epoch 024 | loss: 0.6763 | val_loss: 0.6861 | val_acc: 0.5950
# Epoch 025 | loss: 0.6755 | val_loss: 0.6853 | val_acc: 0.5950
# Epoch 026 | loss: 0.6747 | val_loss: 0.6845 | val_acc: 0.5900
# Epoch 027 | loss: 0.6740 | val_loss: 0.6839 | val_acc: 0.5750
# Epoch 028 | loss: 0.6733 | val_loss: 0.6832 | val_acc: 0.5800
# Epoch 029 | loss: 0.6727 | val_loss: 0.6826 | val_acc: 0.5825
# Epoch 030 | loss: 0.6721 | val_loss: 0.6820 | val_acc: 0.5800
# Epoch 031 | loss: 0.6714 | val_loss: 0.6814 | val_acc: 0.5750
# Epoch 032 | loss: 0.6709 | val_loss: 0.6809 | val_acc: 0.5725
# Epoch 033 | loss: 0.6703 | val_loss: 0.6803 | val_acc: 0.5725
# Epoch 034 | loss: 0.6698 | val_loss: 0.6798 | val_acc: 0.5725
# Epoch 035 | loss: 0.6693 | val_loss: 0.6793 | val_acc: 0.5575
# Epoch 036 | loss: 0.6687 | val_loss: 0.6788 | val_acc: 0.5450
# Epoch 037 | loss: 0.6682 | val_loss: 0.6784 | val_acc: 0.5400
# Epoch 038 | loss: 0.6678 | val_loss: 0.6779 | val_acc: 0.5450
# Epoch 039 | loss: 0.6673 | val_loss: 0.6775 | val_acc: 0.5425
# Epoch 040 | loss: 0.6668 | val_loss: 0.6771 | val_acc: 0.5375
# Epoch 041 | loss: 0.6664 | val_loss: 0.6766 | val_acc: 0.5425
# Epoch 042 | loss: 0.6659 | val_loss: 0.6762 | val_acc: 0.5450
# Epoch 043 | loss: 0.6655 | val_loss: 0.6758 | val_acc: 0.5400
# Epoch 044 | loss: 0.6651 | val_loss: 0.6754 | val_acc: 0.5450
# Epoch 045 | loss: 0.6647 | val_loss: 0.6750 | val_acc: 0.5475
# Epoch 046 | loss: 0.6643 | val_loss: 0.6747 | val_acc: 0.5475
# Epoch 047 | loss: 0.6639 | val_loss: 0.6743 | val_acc: 0.5500
# Epoch 048 | loss: 0.6635 | val_loss: 0.6739 | val_acc: 0.5500
# Epoch 049 | loss: 0.6631 | val_loss: 0.6736 | val_acc: 0.5525
# Epoch 050 | loss: 0.6627 | val_loss: 0.6733 | val_acc: 0.5475
# Epoch 051 | loss: 0.6623 | val_loss: 0.6729 | val_acc: 0.5475
# Epoch 052 | loss: 0.6620 | val_loss: 0.6726 | val_acc: 0.5500
# Epoch 053 | loss: 0.6616 | val_loss: 0.6723 | val_acc: 0.5475
# Epoch 054 | loss: 0.6613 | val_loss: 0.6720 | val_acc: 0.5475
# Epoch 055 | loss: 0.6609 | val_loss: 0.6717 | val_acc: 0.5500
# Epoch 056 | loss: 0.6606 | val_loss: 0.6714 | val_acc: 0.5500
# Epoch 057 | loss: 0.6603 | val_loss: 0.6711 | val_acc: 0.5525
# Epoch 058 | loss: 0.6600 | val_loss: 0.6708 | val_acc: 0.5500
# Epoch 059 | loss: 0.6596 | val_loss: 0.6705 | val_acc: 0.5500
# Epoch 060 | loss: 0.6593 | val_loss: 0.6702 | val_acc: 0.5525
# Epoch 061 | loss: 0.6590 | val_loss: 0.6700 | val_acc: 0.5450
# Epoch 062 | loss: 0.6587 | val_loss: 0.6697 | val_acc: 0.5450
# Epoch 063 | loss: 0.6584 | val_loss: 0.6695 | val_acc: 0.5450
# Epoch 064 | loss: 0.6581 | val_loss: 0.6692 | val_acc: 0.5475
# Epoch 065 | loss: 0.6578 | val_loss: 0.6689 | val_acc: 0.5500
# Epoch 066 | loss: 0.6575 | val_loss: 0.6687 | val_acc: 0.5525
# Epoch 067 | loss: 0.6573 | val_loss: 0.6685 | val_acc: 0.5525
# Epoch 068 | loss: 0.6570 | val_loss: 0.6682 | val_acc: 0.5525
# Epoch 069 | loss: 0.6567 | val_loss: 0.6680 | val_acc: 0.5550
# Epoch 070 | loss: 0.6565 | val_loss: 0.6678 | val_acc: 0.5575
# Epoch 071 | loss: 0.6562 | val_loss: 0.6676 | val_acc: 0.5600
# Epoch 072 | loss: 0.6560 | val_loss: 0.6674 | val_acc: 0.5650
# Epoch 073 | loss: 0.6557 | val_loss: 0.6672 | val_acc: 0.5650
# Epoch 074 | loss: 0.6555 | val_loss: 0.6670 | val_acc: 0.5675
# Epoch 075 | loss: 0.6553 | val_loss: 0.6667 | val_acc: 0.5650
# Epoch 076 | loss: 0.6550 | val_loss: 0.6666 | val_acc: 0.5650
# Epoch 077 | loss: 0.6548 | val_loss: 0.6664 | val_acc: 0.5675
# Epoch 078 | loss: 0.6546 | val_loss: 0.6662 | val_acc: 0.5750
# Epoch 079 | loss: 0.6543 | val_loss: 0.6660 | val_acc: 0.5750
# Epoch 080 | loss: 0.6541 | val_loss: 0.6658 | val_acc: 0.5750
# [SIGMOID] Acc: 0.5750 | Final train loss: 0.6541
#
# ------------------------------------------------------------
# Training with TANH activation...
# Epoch 001 | loss: 0.7532 | val_loss: 0.7363 | val_acc: 0.4275
# Epoch 002 | loss: 0.7468 | val_loss: 0.7312 | val_acc: 0.4300
# Epoch 003 | loss: 0.7407 | val_loss: 0.7263 | val_acc: 0.4425
# Epoch 004 | loss: 0.7350 | val_loss: 0.7217 | val_acc: 0.4525
# Epoch 005 | loss: 0.7295 | val_loss: 0.7175 | val_acc: 0.4575
# Epoch 006 | loss: 0.7244 | val_loss: 0.7134 | val_acc: 0.4650
# Epoch 007 | loss: 0.7195 | val_loss: 0.7096 | val_acc: 0.4700
# Epoch 008 | loss: 0.7149 | val_loss: 0.7061 | val_acc: 0.4900
# Epoch 009 | loss: 0.7106 | val_loss: 0.7027 | val_acc: 0.5000
# Epoch 010 | loss: 0.7066 | val_loss: 0.6996 | val_acc: 0.5000
# Epoch 011 | loss: 0.7028 | val_loss: 0.6966 | val_acc: 0.4975
# Epoch 012 | loss: 0.6992 | val_loss: 0.6940 | val_acc: 0.5300
# Epoch 013 | loss: 0.6958 | val_loss: 0.6913 | val_acc: 0.5250
# Epoch 014 | loss: 0.6926 | val_loss: 0.6889 | val_acc: 0.5525
# Epoch 015 | loss: 0.6896 | val_loss: 0.6868 | val_acc: 0.5975
# Epoch 016 | loss: 0.6868 | val_loss: 0.6847 | val_acc: 0.6250
# Epoch 017 | loss: 0.6842 | val_loss: 0.6827 | val_acc: 0.6475
# Epoch 018 | loss: 0.6817 | val_loss: 0.6809 | val_acc: 0.6350
# Epoch 019 | loss: 0.6794 | val_loss: 0.6792 | val_acc: 0.6375
# Epoch 020 | loss: 0.6772 | val_loss: 0.6776 | val_acc: 0.6575
# Epoch 021 | loss: 0.6751 | val_loss: 0.6762 | val_acc: 0.6575
# Epoch 022 | loss: 0.6732 | val_loss: 0.6748 | val_acc: 0.6650
# Epoch 023 | loss: 0.6713 | val_loss: 0.6735 | val_acc: 0.6575
# Epoch 024 | loss: 0.6697 | val_loss: 0.6723 | val_acc: 0.6575
# Epoch 025 | loss: 0.6681 | val_loss: 0.6713 | val_acc: 0.6500
# Epoch 026 | loss: 0.6665 | val_loss: 0.6702 | val_acc: 0.6425
# Epoch 027 | loss: 0.6652 | val_loss: 0.6692 | val_acc: 0.6425
# Epoch 028 | loss: 0.6638 | val_loss: 0.6684 | val_acc: 0.6325
# Epoch 029 | loss: 0.6626 | val_loss: 0.6676 | val_acc: 0.6300
# Epoch 030 | loss: 0.6614 | val_loss: 0.6668 | val_acc: 0.6300
# Epoch 031 | loss: 0.6603 | val_loss: 0.6661 | val_acc: 0.6275
# Epoch 032 | loss: 0.6593 | val_loss: 0.6655 | val_acc: 0.6275
# Epoch 033 | loss: 0.6583 | val_loss: 0.6649 | val_acc: 0.6250
# Epoch 034 | loss: 0.6574 | val_loss: 0.6643 | val_acc: 0.6250
# Epoch 035 | loss: 0.6566 | val_loss: 0.6638 | val_acc: 0.6225
# Epoch 036 | loss: 0.6558 | val_loss: 0.6634 | val_acc: 0.6200
# Epoch 037 | loss: 0.6551 | val_loss: 0.6629 | val_acc: 0.6200
# Epoch 038 | loss: 0.6544 | val_loss: 0.6625 | val_acc: 0.6200
# Epoch 039 | loss: 0.6538 | val_loss: 0.6621 | val_acc: 0.6200
# Epoch 040 | loss: 0.6532 | val_loss: 0.6619 | val_acc: 0.6175
# Epoch 041 | loss: 0.6526 | val_loss: 0.6615 | val_acc: 0.6150
# Epoch 042 | loss: 0.6521 | val_loss: 0.6612 | val_acc: 0.6125
# Epoch 043 | loss: 0.6516 | val_loss: 0.6610 | val_acc: 0.6075
# Epoch 044 | loss: 0.6511 | val_loss: 0.6607 | val_acc: 0.6050
# Epoch 045 | loss: 0.6507 | val_loss: 0.6605 | val_acc: 0.6100
# Epoch 046 | loss: 0.6503 | val_loss: 0.6603 | val_acc: 0.6050
# Epoch 047 | loss: 0.6499 | val_loss: 0.6601 | val_acc: 0.6050
# Epoch 048 | loss: 0.6495 | val_loss: 0.6599 | val_acc: 0.6075
# Epoch 049 | loss: 0.6491 | val_loss: 0.6598 | val_acc: 0.6075
# Epoch 050 | loss: 0.6488 | val_loss: 0.6596 | val_acc: 0.6050
# Epoch 051 | loss: 0.6485 | val_loss: 0.6595 | val_acc: 0.6100
# Epoch 052 | loss: 0.6482 | val_loss: 0.6593 | val_acc: 0.6075
# Epoch 053 | loss: 0.6480 | val_loss: 0.6592 | val_acc: 0.6100
# Epoch 054 | loss: 0.6477 | val_loss: 0.6591 | val_acc: 0.6100
# Epoch 055 | loss: 0.6474 | val_loss: 0.6590 | val_acc: 0.6100
# Epoch 056 | loss: 0.6472 | val_loss: 0.6589 | val_acc: 0.6100
# Epoch 057 | loss: 0.6470 | val_loss: 0.6588 | val_acc: 0.6075
# Epoch 058 | loss: 0.6468 | val_loss: 0.6586 | val_acc: 0.6100
# Epoch 059 | loss: 0.6466 | val_loss: 0.6586 | val_acc: 0.6075
# Epoch 060 | loss: 0.6463 | val_loss: 0.6585 | val_acc: 0.6100
# Epoch 061 | loss: 0.6462 | val_loss: 0.6584 | val_acc: 0.6100
# Epoch 062 | loss: 0.6460 | val_loss: 0.6583 | val_acc: 0.6100
# Epoch 063 | loss: 0.6457 | val_loss: 0.6582 | val_acc: 0.6100
# Epoch 064 | loss: 0.6456 | val_loss: 0.6581 | val_acc: 0.6100
# Epoch 065 | loss: 0.6454 | val_loss: 0.6580 | val_acc: 0.6100
# Epoch 066 | loss: 0.6453 | val_loss: 0.6579 | val_acc: 0.6100
# Epoch 067 | loss: 0.6451 | val_loss: 0.6578 | val_acc: 0.6100
# Epoch 068 | loss: 0.6449 | val_loss: 0.6577 | val_acc: 0.6100
# Epoch 069 | loss: 0.6448 | val_loss: 0.6576 | val_acc: 0.6075
# Epoch 070 | loss: 0.6446 | val_loss: 0.6575 | val_acc: 0.6075
# Epoch 071 | loss: 0.6444 | val_loss: 0.6575 | val_acc: 0.6050
# Epoch 072 | loss: 0.6443 | val_loss: 0.6573 | val_acc: 0.6075
# Epoch 073 | loss: 0.6441 | val_loss: 0.6572 | val_acc: 0.6025
# Epoch 074 | loss: 0.6440 | val_loss: 0.6572 | val_acc: 0.6025
# Epoch 075 | loss: 0.6439 | val_loss: 0.6571 | val_acc: 0.6075
# Epoch 076 | loss: 0.6437 | val_loss: 0.6570 | val_acc: 0.6025
# Epoch 077 | loss: 0.6435 | val_loss: 0.6568 | val_acc: 0.6025
# Epoch 078 | loss: 0.6434 | val_loss: 0.6568 | val_acc: 0.6025
# Epoch 079 | loss: 0.6433 | val_loss: 0.6567 | val_acc: 0.6025
# Epoch 080 | loss: 0.6431 | val_loss: 0.6566 | val_acc: 0.6025
# [TANH] Acc: 0.6025 | Final train loss: 0.6431
#
#
# ============================================================
# ACTIVATIONS: lasa, relu, leaky_relu, elu, softplus, swish, mish, gelu, sine, sigmoid, tanh
# ============================================================
#
# ============================================================
# FINAL RESULTS COMPARISON
# ============================================================
# Rank   Activation      Accuracy     Final Train Loss
# ------------------------------------------------------------
# 1      LASA            0.8175       0.4503
# 2      LEAKY_RELU      0.6550       0.5643
# 3      RELU            0.6350       0.5782
# 4      SWISH           0.6075       0.6345
# 5      GELU            0.6025       0.6004
# 6      TANH            0.6025       0.6431
# 7      SINE            0.5950       0.6402
# 8      MISH            0.5875       0.6349
# 9      ELU             0.5775       0.6338
# 10     SOFTPLUS        0.5775       0.6502
# 11     SIGMOID         0.5750       0.6541
# ============================================================
