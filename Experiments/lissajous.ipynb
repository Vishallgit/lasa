# %%
pip install mlxtend
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mlxtend
#   Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 11.7 MB/s eta 0:00:00a 0:00:01
# Collecting scikit-learn>=1.3.1
#   Downloading scikit_learn-1.7.1-cp310-cp310-manylinux_2_27_aarch64.manylinux_2_28_aarch64.whl (9.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 42.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: scipy>=1.2.1 in ./.local/lib/python3.10/site-packages (from mlxtend) (1.15.3)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/lib/python3/dist-packages (from mlxtend) (3.5.1)
# Requirement already satisfied: joblib>=0.13.2 in /usr/lib/python3/dist-packages (from mlxtend) (0.17.0)
# Requirement already satisfied: pandas>=0.24.2 in ./.local/lib/python3.10/site-packages (from mlxtend) (2.3.2)
# Requirement already satisfied: numpy>=1.16.2 in ./.local/lib/python3.10/site-packages (from mlxtend) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.local/lib/python3.10/site-packages (from pandas>=0.24.2->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=0.24.2->mlxtend) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.local/lib/python3.10/site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Collecting joblib>=0.13.2
#   Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.4/308.4 KB 83.8 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/lib/python3/dist-packages (from scikit-learn>=1.3.1->mlxtend) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas>=0.24.2->mlxtend) (1.16.0)
# Installing collected packages: joblib, scikit-learn, mlxtend
# Successfully installed joblib-1.5.2 mlxtend-0.23.4 scikit-learn-1.7.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import os, math, warnings
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from mlxtend.plotting import plot_decision_regions

warnings.filterwarnings('ignore')

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from IPython.display import display, HTML
display(HTML("<style>.output_scroll {height:auto !important; max-height:none !important;}</style>"))

SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)

print("="*60)
print("GPU CONFIGURATION")
print("="*60)
gpus = tf.config.list_physical_devices('GPU')
USE_GPU = bool(gpus)
if USE_GPU:
    print(f"GPUs available: {len(gpus)}")
    for gpu in gpus:
        print("  -", gpu)
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU memory growth enabled")
    except RuntimeError as e:
        print(e)
else:
    print("No GPUs available, using CPU")

policy_name = 'mixed_float16' if USE_GPU else 'float32'
policy = tf.keras.mixed_precision.Policy(policy_name)
tf.keras.mixed_precision.set_global_policy(policy)
print(f"Mixed precision policy: {policy.name}")
print("="*60 + "\n")

USE_XLA = USE_GPU

def inv_softplus(y):
    y = np.maximum(float(y), 1e-6)
    return np.log(np.expm1(y))

def generate_lissajous(n_samples=2000, seed=42):
    rng = np.random.default_rng(seed)
    t = rng.uniform(0, 2*np.pi, n_samples)
    X = np.column_stack((np.sin(3*t), np.sin(2*t))).astype(np.float32)
    y = (np.sin(5*t) <= 0).astype(np.int32)
    return X, y

class LASAActivation(tf.keras.layers.Layer):
    def __init__(self, theta_degrees=45.0, lambda_window=3e-4,
                 penalty_mode='hinge', hybrid_alpha=0.1,
                 enforce_gain_cap=False, gain_cap=1.25,
                 initial_frequency=1.6, name=None, **kwargs):
        super().__init__(name=name, **kwargs)
        self.theta_degrees     = float(theta_degrees)
        self.lambda_window     = float(lambda_window)
        self.penalty_mode      = str(penalty_mode)
        self.hybrid_alpha      = float(hybrid_alpha)
        self.enforce_gain_cap  = bool(enforce_gain_cap)
        self.gain_cap          = float(gain_cap)
        self.initial_frequency = float(initial_frequency)

    def build(self, input_shape):
        self.theta_rad = tf.constant(self.theta_degrees * math.pi/180.0, dtype=tf.float32)
        self.sin_theta = tf.sin(self.theta_rad)

        self.penalty_scale = self.add_weight(shape=(), name='penalty_scale', dtype=tf.float32,
                                             trainable=False,
                                             initializer=tf.keras.initializers.Constant(1.0))

        if self.enforce_gain_cap:
            denom   = tf.maximum(self.sin_theta, tf.constant(1e-6, tf.float32))
            k_max_v = float(self.gain_cap) / float(denom.numpy())
            self.k_max = tf.constant(k_max_v, dtype=tf.float32)
            ratio = np.clip(self.initial_frequency / k_max_v, 1e-6, 1.0-1e-6)
            rho0  = np.log(ratio/(1.0 - ratio))
        else:
            self.k_max = None
            rho0 = inv_softplus(self.initial_frequency)

        self.rho = self.add_weight(shape=(), name='rho', dtype=tf.float32, trainable=True,
                                   initializer=tf.keras.initializers.Constant(float(rho0)))

    @property
    def tau_value(self):
        if self.enforce_gain_cap:
            return self.k_max * tf.nn.sigmoid(self.rho)
        return tf.nn.softplus(self.rho)

    def set_penalty_scale(self, scale):
        self.penalty_scale.assign(tf.cast(scale, tf.float32))

    def scale_down_penalty(self, factor=0.8, min_scale=0.05):
        new_scale = tf.maximum(self.penalty_scale * tf.cast(factor, tf.float32),
                               tf.constant(min_scale, tf.float32))
        self.penalty_scale.assign(new_scale)

    def _penalty(self, inputs, tau32):
        if self.lambda_window <= 0.0:
            return None
        x32     = tf.cast(inputs, tf.float32)
        cos_phi = tf.math.cos(tau32 * x32)
        abs_cos = tf.abs(cos_phi)

        if self.penalty_mode == 'hinge':
            margin = self.sin_theta
            viol   = tf.maximum(abs_cos - margin, 0.0)
            pen    = tf.reduce_mean(tf.square(viol))
        elif self.penalty_mode == 'cos2':
            pen    = tf.reduce_mean(tf.square(cos_phi))
        elif self.penalty_mode == 'hybrid':
            margin = self.sin_theta
            viol   = tf.maximum(abs_cos - margin, 0.0)
            hinge  = tf.reduce_mean(tf.square(viol))
            cos2   = tf.reduce_mean(tf.square(cos_phi))
            pen    = self.hybrid_alpha * cos2 + hinge
        else:
            raise ValueError("penalty_mode must be 'hinge', 'cos2', or 'hybrid'.")

        lw32    = tf.cast(self.lambda_window, tf.float32)
        scale32 = tf.cast(self.penalty_scale, tf.float32)
        return lw32 * scale32 * pen

    def call(self, inputs):
        tau32 = tf.cast(self.tau_value, tf.float32)
        pen = self._penalty(inputs, tau32)
        if pen is not None:
            self.add_loss(pen)
        x32 = tf.cast(inputs, tf.float32)
        y32 = tf.math.sin(tau32 * x32)
        return tf.cast(y32, inputs.dtype)

class SwishActivation(tf.keras.layers.Layer):
    def call(self, inputs):
        x = tf.cast(inputs, tf.float32)
        y = x * tf.nn.sigmoid(x)
        return tf.cast(y, inputs.dtype)

class MishActivation(tf.keras.layers.Layer):
    def call(self, inputs):
        x = tf.cast(inputs, tf.float32)
        y = x * tf.math.tanh(tf.math.softplus(x))
        return tf.cast(y, inputs.dtype)

def create_model(activation_type,
                 hidden_units=[6],
                 initial_frequency=1.6,
                 theta_degrees=45.0, lambda_window=3e-4,
                 penalty_mode='hinge', hybrid_alpha=0.1,
                 enforce_gain_cap=False, gain_cap=1.25):
    with tf.device('/GPU:0' if USE_GPU else '/CPU:0'):
        model = tf.keras.Sequential([tf.keras.layers.Input(shape=(2,))])
        for i, units in enumerate(hidden_units):
            model.add(tf.keras.layers.Dense(units, name=f'dense_{i}'))
            act_name = activation_type.lower()
            if act_name == 'lasa':
                model.add(LASAActivation(
                    theta_degrees=theta_degrees,
                    lambda_window=lambda_window,
                    penalty_mode=penalty_mode, hybrid_alpha=hybrid_alpha,
                    enforce_gain_cap=enforce_gain_cap, gain_cap=gain_cap,
                    initial_frequency=initial_frequency,
                    name=f'lasa_{i}'
                ))
            elif act_name == 'relu':
                model.add(tf.keras.layers.ReLU(name=f'relu_{i}'))
            elif act_name == 'leaky_relu':
                model.add(tf.keras.layers.LeakyReLU(alpha=0.01, name=f'leaky_relu_{i}'))
            elif act_name == 'elu':
                model.add(tf.keras.layers.ELU(alpha=1.0, name=f'elu_{i}'))
            elif act_name == 'softplus':
                model.add(tf.keras.layers.Activation('softplus', name=f'softplus_{i}'))
            elif act_name == 'swish':
                model.add(SwishActivation(name=f'swish_{i}'))
            elif act_name == 'mish':
                model.add(MishActivation(name=f'mish_{i}'))
            elif act_name == 'gelu':
                model.add(tf.keras.layers.Lambda(lambda z: tf.nn.gelu(z), name=f'gelu_{i}'))
            elif act_name == 'sine':
                model.add(tf.keras.layers.Lambda(lambda z: tf.math.sin(z), name=f'sine_{i}'))
            elif act_name == 'sigmoid':
                model.add(tf.keras.layers.Activation('sigmoid', name=f'sigmoid_{i}'))
            elif act_name == 'tanh':
                model.add(tf.keras.layers.Activation('tanh', name=f'tanh_{i}'))
            else:
                raise ValueError(f"Unknown activation_type: {activation_type}")

        model.add(tf.keras.layers.Dense(1, activation='sigmoid', dtype='float32', name='output'))
    return model

class LASATrainer:
    def __init__(self, model,
                 lr_main=1e-3, lr_tau=1e-2,
                 clipnorm_main=1.0, clipnorm_tau=0.5,
                 penalty_warmup_epochs=8,
                 guard_use_acc=True, guard_use_loss=True,
                 acc_eps=2.5e-3, loss_eps=1e-4,
                 reverse_tau_grads=True, revert_rho_to_snapshot=True,
                 shrink_tau_lr=True, tau_lr_decay=0.5, min_tau_lr=1e-5,
                 shrink_penalty=True, penalty_decay=0.8, min_penalty_scale=0.05,
                 stagnation_window=10, improve_threshold=0.05,
                 bump_delta_k=1.0, min_epochs_between_bumps=10,
                 acc_drop_threshold=0.20):
        self.model = model
        self.loss_fn = tf.keras.losses.BinaryCrossentropy()
        self.optimizer_main = tf.keras.optimizers.Adam(learning_rate=lr_main, clipnorm=clipnorm_main)
        self.optimizer_tau  = tf.keras.optimizers.Adam(learning_rate=lr_tau,  clipnorm=clipnorm_tau)
        self.penalty_warmup_epochs = int(penalty_warmup_epochs)

        self.guard_use_acc  = bool(guard_use_acc)
        self.guard_use_loss = bool(guard_use_loss)
        self.acc_eps        = float(acc_eps)
        self.loss_eps       = float(loss_eps)

        self.reverse_tau_grads       = bool(reverse_tau_grads)
        self.revert_rho_to_snapshot  = bool(revert_rho_to_snapshot)
        self.shrink_tau_lr           = bool(shrink_tau_lr)
        self.tau_lr_decay            = float(tau_lr_decay)
        self.min_tau_lr              = float(min_tau_lr)
        self.shrink_penalty          = bool(shrink_penalty)
        self.penalty_decay           = float(penalty_decay)
        self.min_penalty_scale       = float(min_penalty_scale)

        self.stagnation_window       = int(stagnation_window)
        self.improve_threshold       = float(improve_threshold)
        self.bump_delta_k            = float(bump_delta_k)
        self.min_epochs_between_bumps= int(min_epochs_between_bumps)

        self.acc_drop_threshold      = float(acc_drop_threshold)

        self._partition_ready = False
        self.tau_idx, self.other_idx = [], []
        self._best_val_acc  = -np.inf
        self._best_val_loss =  np.inf
        self.val_acc_hist   = []
        self._last_bump_epoch = -10**9
        self.tau_grad_dir = tf.Variable(1.0, trainable=False, dtype=tf.float32)

        self.pending_bump = False
        self.bump_pre_val_acc = None
        self.rho_bump_snapshot = None
        self.bump_reverted_once = False
        self.final_bump_to_apply = False
        self.final_bump_applied  = False
        self.disable_future_bumps = False
        self.no_revert_mode = False

    def _build_and_partition(self, sample_x):
        _ = self.model(sample_x)
        self.tau_idx, self.other_idx = [], []
        for i, v in enumerate(self.model.trainable_variables):
            if '/rho:' in v.name: self.tau_idx.append(i)
            else: self.other_idx.append(i)
        self._partition_ready = True

    def _set_penalty_scale(self, epoch_idx):
        scale = 1.0 if self.penalty_warmup_epochs <= 0 else min(1.0, (epoch_idx + 1) / self.penalty_warmup_epochs)
        for layer in self.model.layers:
            if isinstance(layer, LASAActivation):
                layer.set_penalty_scale(scale)

    def _decay_penalty_scale(self):
        if not self.shrink_penalty: return
        for layer in self.model.layers:
            if isinstance(layer, LASAActivation):
                layer.scale_down_penalty(self.penalty_decay, self.min_penalty_scale)

    def _snapshot_rho(self):
        return [self.model.trainable_variables[i].numpy().copy() for i in self.tau_idx]

    def _restore_rho(self, snap):
        for val, i in zip(snap, self.tau_idx):
            self.model.trainable_variables[i].assign(val)

    def _reset_tau_optimizer(self, new_lr):
        self.optimizer_tau = tf.keras.optimizers.Adam(learning_rate=new_lr, clipnorm=self.optimizer_tau.clipnorm)

    def _bump_all_k(self, delta):
        for layer in self.model.layers:
            if isinstance(layer, LASAActivation):
                k0 = float(layer.tau_value.numpy())
                if layer.enforce_gain_cap:
                    kmax = float(layer.k_max.numpy())
                    k1 = min(kmax * 0.999, k0 + float(delta))
                    ratio = np.clip(k1 / kmax, 1e-6, 1.0-1e-6)
                    rho_new = np.log(ratio/(1.0 - ratio))
                else:
                    k1 = max(0.0, k0 + float(delta))
                    rho_new = inv_softplus(k1)
                layer.rho.assign(np.float32(rho_new))

    @tf.function(jit_compile=USE_XLA)
    def _train_step(self, x_batch, y_batch):
        with tf.GradientTape() as tape:
            preds = self.model(x_batch, training=True)
            yb = tf.reshape(y_batch, (-1, 1))
            main_loss = self.loss_fn(yb, preds)
            reg_losses = tf.add_n(self.model.losses) if self.model.losses else tf.constant(0.0, dtype=main_loss.dtype)
            loss = main_loss + reg_losses
        grads = tape.gradient(loss, self.model.trainable_variables)

        tau_pairs = []
        for i in self.tau_idx:
            g = grads[i]; v = self.model.trainable_variables[i]
            if g is not None:
                g = tf.cast(g, tf.float32) * self.tau_grad_dir
                tau_pairs.append((g, v))
        other_pairs = []
        for i in self.other_idx:
            g = grads[i]; v = self.model.trainable_variables[i]
            if g is not None:
                other_pairs.append((g, v))

        if tau_pairs:   self.optimizer_tau.apply_gradients(tau_pairs)
        if other_pairs: self.optimizer_main.apply_gradients(other_pairs)

        return main_loss, reg_losses

    def _val_metrics(self, X_val, y_val):
        preds = self.model(X_val, training=False)
        yb = tf.reshape(y_val, (-1, 1))
        val_loss = float(self.loss_fn(yb, preds).numpy())
        y_pred = (preds.numpy() > 0.5).astype(int).flatten()
        val_acc = float(np.mean(y_pred == y_val.numpy()))
        return val_loss, val_acc

    def train(self, X_train, y_train, X_val, y_val, epochs=40, batch_size=32, verbose=True):
        X_train = tf.constant(X_train, dtype=tf.float32)
        y_train = tf.constant(y_train, dtype=tf.float32)
        X_val   = tf.constant(X_val,   dtype=tf.float32)
        y_val   = tf.constant(y_val,   dtype=tf.float32)

        if not self._partition_ready:
            self._build_and_partition(X_train[:1])

        ds = (tf.data.Dataset.from_tensor_slices((X_train, y_train))
              .shuffle(4096).batch(batch_size).prefetch(tf.data.AUTOTUNE))

        history = {'loss': [], 'val_accuracy': [], 'val_loss': []}

        for epoch in range(epochs):
            self._set_penalty_scale(epoch)

            if self.final_bump_to_apply and not self.final_bump_applied:
                self._bump_all_k(self.bump_delta_k)
                self.final_bump_applied = True
                self.final_bump_to_apply = False
                self.disable_future_bumps = True
                self.no_revert_mode = True

            rho_snap = self._snapshot_rho()

            total_loss = 0.0
            nb = 0
            for xb, yb in ds:
                main_l, _ = self._train_step(xb, yb)
                total_loss += float(main_l.numpy()); nb += 1

            avg_loss = total_loss / max(nb, 1)
            val_loss, val_acc = self._val_metrics(X_val, y_val)

            if self.pending_bump and not self.final_bump_applied:
                if self.bump_pre_val_acc is not None:
                    drop = self.bump_pre_val_acc - val_acc
                    if (drop > self.acc_drop_threshold) and (not self.bump_reverted_once):
                        self._restore_rho(self.rho_bump_snapshot)
                        self.bump_reverted_once = True
                        self.pending_bump = False
                        self.final_bump_to_apply = True
                        val_loss, val_acc = self._val_metrics(X_val, y_val)
                if self.pending_bump:
                    self.pending_bump = False

            worse_acc  = self.guard_use_acc  and (val_acc  < self._best_val_acc  - self.acc_eps)
            worse_loss = self.guard_use_loss and (val_loss > self._best_val_loss + self.loss_eps)
            if worse_acc or worse_loss:
                if self.revert_rho_to_snapshot and (not self.no_revert_mode):
                    self._restore_rho(rho_snap)
                if self.reverse_tau_grads:
                    self.tau_grad_dir.assign(-self.tau_grad_dir)
                if self.shrink_tau_lr:
                    new_lr = max(self.min_tau_lr, float(self.optimizer_tau.learning_rate.numpy()) * self.tau_lr_decay)
                    self._reset_tau_optimizer(new_lr)
                if self.shrink_penalty:
                    self._decay_penalty_scale()
                val_loss, val_acc = self._val_metrics(X_val, y_val)

            ep = epoch + 1
            self.val_acc_hist.append(val_acc)
            can_try_bump = (not self.disable_future_bumps) and (not self.final_bump_applied)
            if can_try_bump and ep >= self.stagnation_window and (ep - self._last_bump_epoch) >= self.min_epochs_between_bumps:
                acc_then = self.val_acc_hist[-self.stagnation_window]
                improve  = val_acc - acc_then
                if improve < self.improve_threshold:
                    self.rho_bump_snapshot = self._snapshot_rho()
                    self.bump_pre_val_acc  = val_acc
                    self._bump_all_k(self.bump_delta_k)
                    self.pending_bump = True
                    self._last_bump_epoch = ep

            self._best_val_acc  = max(self._best_val_acc,  val_acc)
            self._best_val_loss = min(self._best_val_loss, val_loss)

            history['loss'].append(avg_loss)
            history['val_accuracy'].append(val_acc)
            history['val_loss'].append(val_loss)

            if verbose:
                print(f"Epoch {epoch+1:03d} | loss: {avg_loss:.4f} | val_loss: {val_loss:.4f} | val_acc: {val_acc:.4f}")
        return history

class RegularTrainer:
    def __init__(self, model, lr=1e-3, clipnorm=1.0):
        self.model = model
        self.loss_fn = tf.keras.losses.BinaryCrossentropy()
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=lr, clipnorm=clipnorm)

    @tf.function(jit_compile=USE_XLA)
    def _train_step(self, x_batch, y_batch):
        with tf.GradientTape() as tape:
            preds = self.model(x_batch, training=True)
            yb = tf.reshape(y_batch, (-1, 1))
            loss = self.loss_fn(yb, preds)
        grads = tape.gradient(loss, self.model.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.model.trainable_variables))
        return loss

    def _val_metrics(self, X_val, y_val):
        preds = self.model(X_val, training=False)
        yb = tf.reshape(y_val, (-1, 1))
        val_loss = float(self.loss_fn(yb, preds).numpy())
        y_pred = (preds.numpy() > 0.5).astype(int).flatten()
        val_acc = float(np.mean(y_pred == y_val.numpy()))
        return val_loss, val_acc

    def train(self, X_train, y_train, X_val, y_val, epochs=40, batch_size=32, verbose=True):
        X_train = tf.constant(X_train, dtype=tf.float32)
        y_train = tf.constant(y_train, dtype=tf.float32)
        X_val   = tf.constant(X_val,   dtype=tf.float32)
        y_val   = tf.constant(y_val,   dtype=tf.float32)

        ds = (tf.data.Dataset.from_tensor_slices((X_train, y_train))
              .shuffle(4096).batch(batch_size).prefetch(tf.data.AUTOTUNE))

        history = {'loss': [], 'val_accuracy': [], 'val_loss': []}

        for epoch in range(epochs):
            total_loss = 0.0; nb = 0
            for xb, yb in ds:
                main_l = self._train_step(xb, yb)
                total_loss += float(main_l.numpy()); nb += 1

            avg_loss = total_loss / max(nb, 1)
            val_loss, val_acc = self._val_metrics(X_val, y_val)

            history['loss'].append(avg_loss)
            history['val_accuracy'].append(val_acc)
            history['val_loss'].append(val_loss)

            if verbose:
                print(f"Epoch {epoch+1:03d} | loss: {avg_loss:.4f} | val_loss: {val_loss:.4f} | val_acc: {val_acc:.4f}")
        return history

def plot_all_decision_boundaries(models, results, X_test, y_test):
    class Wrapper:
        def __init__(self, model): self.model = model
        def predict(self, X):
            X_tensor = tf.constant(X, dtype=tf.float32)
            preds = self.model(X_tensor)
            return (preds.numpy() > 0.5).astype(int).flatten()

    names = list(models.keys())
    n = len(names)
    cols = 4
    rows = int(np.ceil(n / cols))
    fig, axes = plt.subplots(rows, cols, figsize=(4.6*cols, 4.2*rows))
    axes = np.array(axes).reshape(rows, cols)

    for idx, name in enumerate(names):
        r, c = divmod(idx, cols)
        ax = axes[r, c]
        wrapper = Wrapper(models[name])
        plot_decision_regions(X=X_test, y=y_test, clf=wrapper, ax=ax, legend=0)
        acc = results[name]['accuracy']
        ax.set_title(f"{name.upper()}  Acc: {acc:.4f}", fontsize=11, fontweight='bold')
        ax.set_xlabel('sin(3t)'); ax.set_ylabel('sin(2t)'); ax.grid(True, alpha=0.3)

    for idx in range(n, rows*cols):
        r, c = divmod(idx, cols)
        fig.delaxes(axes[r, c])

    plt.suptitle('Decision Boundaries Comparison', fontsize=15, fontweight='bold')
    plt.tight_layout(); plt.show()

def plot_training_curves_comparison(results):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
    for name, data in results.items():
        ax1.plot(data['history']['loss'], label=f"{name}")
        ax1.plot(data['history']['val_loss'], linestyle='--', alpha=0.7, label=f"{name} (val)")
        ax2.plot(data['history']['val_accuracy'], label=f"{name}")
    ax1.set_title('Training & Validation Loss'); ax1.set_xlabel('Epoch'); ax1.set_ylabel('Loss'); ax1.grid(True); ax1.legend(ncol=2, fontsize=8)
    ax2.set_title('Validation Accuracy'); ax2.set_xlabel('Epoch'); ax2.set_ylabel('Accuracy'); ax2.grid(True); ax2.legend(ncol=2, fontsize=8)
    plt.tight_layout(); plt.show()

def print_comparison_table(results):
    print("\n" + "="*60)
    print("FINAL RESULTS COMPARISON")
    print("="*60)
    print(f"{'Rank':<6} {'Activation':<15} {'Accuracy':<12} {'Final Train Loss':<18}")
    print("-"*60)
    sorted_items = sorted(results.items(), key=lambda kv: kv[1]['accuracy'], reverse=True)
    for rank, (name, data) in enumerate(sorted_items, 1):
        print(f"{rank:<6} {name.upper():<15} {data['accuracy']:<12.4f} {data['final_loss']:<18.4f}")
    print("="*60)

def run_all_activations_comparison(hidden_units=[6],
                                   n_samples=2000, test_size=0.2, random_state=42,
                                   epochs=40, batch_size=32,
                                   lr_main=1e-3,
                                   lr_tau=1e-2,
                                   initial_frequency=1.6,
                                   theta_degrees=45.0, lambda_window=3e-4,
                                   penalty_mode='hinge', hybrid_alpha=0.1,
                                   enforce_gain_cap=False, gain_cap=1.25,
                                   penalty_warmup_epochs=8,
                                   acc_eps=2.5e-3, loss_eps=1e-4,
                                   reverse_tau_grads=True, revert_rho_to_snapshot=True,
                                   shrink_tau_lr=True, tau_lr_decay=0.5, min_tau_lr=1e-5,
                                   shrink_penalty=True, penalty_decay=0.8, min_penalty_scale=0.05,
                                   stagnation_window=10, improve_threshold=0.05,
                                   bump_delta_k=1.0, min_epochs_between_bumps=10,
                                   acc_drop_threshold=0.20,
                                   verbose=True):
    activation_types = [
        'lasa', 'relu', 'leaky_relu', 'elu', 'softplus',
        'swish', 'mish', 'gelu', 'sine', 'sigmoid', 'tanh'
    ]

    print("="*60)
    print("ACTIVATION FUNCTIONS COMPARISON - Lissajous")
    print("="*60)
    print("Config:",
          f"\n  hidden_units={hidden_units}",
          f"\n  epochs={epochs}  batch_size={batch_size}",
          f"\n  lr_main={lr_main}  (lr_tau={lr_tau} for LASA only)",
          f"\n  LASA: theta={theta_degrees}°, lambda_window={lambda_window}, penalty_mode={penalty_mode}, "
          f"enforce_gain_cap={enforce_gain_cap}, gain_cap={gain_cap}",
          f"\n  Rule: if post-bump val_acc drop > {acc_drop_threshold:.2f}, revert once, then one final +1 bump and disable further bumps"
          )

    X, y = generate_lissajous(n_samples=n_samples, seed=random_state)
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, random_state=random_state, stratify=y
    )
    print(f"\nDataset: total={n_samples} | train={len(X_train)} | test={len(X_test)}")
    print(f"Class counts: 0->{np.sum(y==0)}  1->{np.sum(y==1)}")

    results = {}
    models  = {}

    for act in activation_types:
        print("\n" + "-"*60)
        print(f"Training with {act.upper()} activation...")
        tf.keras.backend.clear_session()
        np.random.seed(random_state); tf.random.set_seed(random_state)

        model = create_model(
            activation_type=act,
            hidden_units=hidden_units,
            initial_frequency=initial_frequency,
            theta_degrees=theta_degrees, lambda_window=lambda_window,
            penalty_mode=penalty_mode, hybrid_alpha=hybrid_alpha,
            enforce_gain_cap=enforce_gain_cap, gain_cap=gain_cap
        )

        if act.lower() == 'lasa':
            trainer = LASATrainer(
                model,
                lr_main=lr_main, lr_tau=lr_tau,
                clipnorm_main=1.0, clipnorm_tau=0.5,
                penalty_warmup_epochs=penalty_warmup_epochs,
                guard_use_acc=True, guard_use_loss=True,
                acc_eps=acc_eps, loss_eps=loss_eps,
                reverse_tau_grads=reverse_tau_grads, revert_rho_to_snapshot=revert_rho_to_snapshot,
                shrink_tau_lr=shrink_tau_lr, tau_lr_decay=tau_lr_decay, min_tau_lr=min_tau_lr,
                shrink_penalty=shrink_penalty, penalty_decay=penalty_decay, min_penalty_scale=min_penalty_scale,
                stagnation_window=stagnation_window, improve_threshold=improve_threshold,
                bump_delta_k=bump_delta_k, min_epochs_between_bumps=min_epochs_between_bumps,
                acc_drop_threshold=acc_drop_threshold
            )
            hist = trainer.train(
                tf.constant(X_train), tf.constant(y_train, np.float32),
                tf.constant(X_test),  tf.constant(y_test,  np.float32),
                epochs=epochs, batch_size=batch_size, verbose=verbose
            )
        else:
            trainer = RegularTrainer(model, lr=lr_main, clipnorm=1.0)
            hist = trainer.train(
                tf.constant(X_train), tf.constant(y_train, np.float32),
                tf.constant(X_test),  tf.constant(y_test,  np.float32),
                epochs=epochs, batch_size=batch_size, verbose=verbose
            )

        preds = model(tf.constant(X_test, tf.float32))
        y_true = tf.constant(y_test, np.float32)
        y_true = tf.reshape(y_true, (-1, 1))
        final_loss = float(tf.keras.losses.BinaryCrossentropy()(y_true, preds).numpy())
        y_pred = (preds.numpy() > 0.5).astype(int).flatten()
        final_acc  = float(np.mean(y_pred == y_test))

        results[act] = {'accuracy': final_acc, 'history': hist, 'final_loss': hist['loss'][-1]}
        models[act]  = model

        print(f"[{act.upper()}] Acc: {final_acc:.4f} | Final train loss: {hist['loss'][-1]:.4f}")

    return models, results, X, y, X_test, y_test

if __name__ == "__main__":
    models, results, X, y, X_test, y_test = run_all_activations_comparison(
        hidden_units=[6],
        n_samples=2000, test_size=0.2, random_state=42,
        epochs=60, batch_size=32,
        lr_main=1e-3, lr_tau=1e-2,
        initial_frequency=1.6,
        theta_degrees=45.0, lambda_window=3e-4,
        penalty_mode='hinge', hybrid_alpha=0.1,
        enforce_gain_cap=False, gain_cap=1.25,
        penalty_warmup_epochs=8,
        acc_eps=2.5e-3, loss_eps=1e-4,
        reverse_tau_grads=True, revert_rho_to_snapshot=True,
        shrink_tau_lr=True, tau_lr_decay=0.5, min_tau_lr=1e-5,
        shrink_penalty=True, penalty_decay=0.8, min_penalty_scale=0.05,
        stagnation_window=10, improve_threshold=0.05, bump_delta_k=1.0, min_epochs_between_bumps=10,
        acc_drop_threshold=0.20,
        verbose=True
    )

    print_comparison_table(results)
    plot_all_decision_boundaries(models, results, X_test, y_test)
    plot_training_curves_comparison(results)
# Out:
# <style>.output_scroll {height:auto !important; max-height:none !important;}</style>
# ============================================================
# GPU CONFIGURATION
# ============================================================
# No GPUs available, using CPU
# Mixed precision policy: float32
# ============================================================
#
# ============================================================
# ACTIVATION FUNCTIONS COMPARISON - Lissajous
# ============================================================
# Config:
#   hidden_units=[6]
#   epochs=60  batch_size=32
#   lr_main=0.001  (lr_tau=0.01 for LASA only)
#   LASA: theta=45.0°, lambda_window=0.0003, penalty_mode=hinge, enforce_gain_cap=False, gain_cap=1.25
#   Rule: if post-bump val_acc drop > 0.20, revert once, then one final +1 bump and disable further bumps
#
# Dataset: total=2000 | train=1600 | test=400
# Class counts: 0->988  1->1012
#
# ------------------------------------------------------------
# Training with LASA activation...
# Epoch 001 | loss: 0.7181 | val_loss: 0.7128 | val_acc: 0.5150
# Epoch 002 | loss: 0.7023 | val_loss: 0.7025 | val_acc: 0.5225
# Epoch 003 | loss: 0.6967 | val_loss: 0.6995 | val_acc: 0.5050
# Epoch 004 | loss: 0.6953 | val_loss: 0.6974 | val_acc: 0.4925
# Epoch 005 | loss: 0.6939 | val_loss: 0.6959 | val_acc: 0.4800
# Epoch 006 | loss: 0.6934 | val_loss: 0.6951 | val_acc: 0.4775
# Epoch 007 | loss: 0.6931 | val_loss: 0.6948 | val_acc: 0.4625
# Epoch 008 | loss: 0.6928 | val_loss: 0.6944 | val_acc: 0.4750
# Epoch 009 | loss: 0.6929 | val_loss: 0.6945 | val_acc: 0.4675
# Epoch 010 | loss: 0.6926 | val_loss: 0.6944 | val_acc: 0.4750
# Epoch 011 | loss: 0.6919 | val_loss: 0.6935 | val_acc: 0.5000
# Epoch 012 | loss: 0.6906 | val_loss: 0.6925 | val_acc: 0.5200
# Epoch 013 | loss: 0.6902 | val_loss: 0.6919 | val_acc: 0.5150
# Epoch 014 | loss: 0.6882 | val_loss: 0.6902 | val_acc: 0.5100
# Epoch 015 | loss: 0.6879 | val_loss: 0.6888 | val_acc: 0.5150
# Epoch 016 | loss: 0.6841 | val_loss: 0.6871 | val_acc: 0.5050
# Epoch 017 | loss: 0.6848 | val_loss: 0.6847 | val_acc: 0.5150
# Epoch 018 | loss: 0.6777 | val_loss: 0.6703 | val_acc: 0.6375
# Epoch 019 | loss: 0.6526 | val_loss: 0.6484 | val_acc: 0.6800
# Epoch 020 | loss: 0.6338 | val_loss: 0.6323 | val_acc: 0.6925
# Epoch 021 | loss: 0.6292 | val_loss: 0.6202 | val_acc: 0.6850
# Epoch 022 | loss: 0.6077 | val_loss: 0.6089 | val_acc: 0.7000
# Epoch 023 | loss: 0.5963 | val_loss: 0.5991 | val_acc: 0.6975
# Epoch 024 | loss: 0.5861 | val_loss: 0.5891 | val_acc: 0.7125
# Epoch 025 | loss: 0.5782 | val_loss: 0.5808 | val_acc: 0.7125
# Epoch 026 | loss: 0.5705 | val_loss: 0.5745 | val_acc: 0.7050
# Epoch 027 | loss: 0.5630 | val_loss: 0.5678 | val_acc: 0.7150
# Epoch 028 | loss: 0.5608 | val_loss: 0.5636 | val_acc: 0.6975
# Epoch 029 | loss: 0.5891 | val_loss: 0.6485 | val_acc: 0.6825
# Epoch 030 | loss: 0.6489 | val_loss: 0.6053 | val_acc: 0.6800
# Epoch 031 | loss: 0.5772 | val_loss: 0.5629 | val_acc: 0.7125
# Epoch 032 | loss: 0.5528 | val_loss: 0.5532 | val_acc: 0.7200
# Epoch 033 | loss: 0.5456 | val_loss: 0.5487 | val_acc: 0.7000
# Epoch 034 | loss: 0.5412 | val_loss: 0.5441 | val_acc: 0.7075
# Epoch 035 | loss: 0.5359 | val_loss: 0.5401 | val_acc: 0.7150
# Epoch 036 | loss: 0.5314 | val_loss: 0.5369 | val_acc: 0.7200
# Epoch 037 | loss: 0.5283 | val_loss: 0.5332 | val_acc: 0.7225
# Epoch 038 | loss: 0.5321 | val_loss: 0.5308 | val_acc: 0.7225
# Epoch 039 | loss: 0.5656 | val_loss: 0.6150 | val_acc: 0.6950
# Epoch 040 | loss: 0.6010 | val_loss: 0.5667 | val_acc: 0.7100
# Epoch 041 | loss: 0.5412 | val_loss: 0.5420 | val_acc: 0.7150
# Epoch 042 | loss: 0.5364 | val_loss: 0.5279 | val_acc: 0.7150
# Epoch 043 | loss: 0.5188 | val_loss: 0.5218 | val_acc: 0.7150
# Epoch 044 | loss: 0.5144 | val_loss: 0.5216 | val_acc: 0.7225
# Epoch 045 | loss: 0.5126 | val_loss: 0.5211 | val_acc: 0.7225
# Epoch 046 | loss: 0.5139 | val_loss: 0.5130 | val_acc: 0.7275
# Epoch 047 | loss: 0.5067 | val_loss: 0.5108 | val_acc: 0.7325
# Epoch 048 | loss: 0.5045 | val_loss: 0.5089 | val_acc: 0.7250
# Epoch 049 | loss: 0.5858 | val_loss: 0.5382 | val_acc: 0.6950
# Epoch 050 | loss: 0.5154 | val_loss: 0.5141 | val_acc: 0.7225
# Epoch 051 | loss: 0.5055 | val_loss: 0.5059 | val_acc: 0.7250
# Epoch 052 | loss: 0.4987 | val_loss: 0.5027 | val_acc: 0.7275
# Epoch 053 | loss: 0.4955 | val_loss: 0.5007 | val_acc: 0.7300
# Epoch 054 | loss: 0.4935 | val_loss: 0.4984 | val_acc: 0.7375
# Epoch 055 | loss: 0.4908 | val_loss: 0.4963 | val_acc: 0.7375
# Epoch 056 | loss: 0.4883 | val_loss: 0.4943 | val_acc: 0.7275
# Epoch 057 | loss: 0.4862 | val_loss: 0.4915 | val_acc: 0.7325
# Epoch 058 | loss: 0.4844 | val_loss: 0.4902 | val_acc: 0.7425
# Epoch 059 | loss: 0.5624 | val_loss: 0.5083 | val_acc: 0.7050
# Epoch 060 | loss: 0.4896 | val_loss: 0.4921 | val_acc: 0.7100
# [LASA] Acc: 0.7100 | Final train loss: 0.4896
#
# ------------------------------------------------------------
# Training with RELU activation...
# Epoch 001 | loss: 0.6950 | val_loss: 0.6936 | val_acc: 0.4950
# Epoch 002 | loss: 0.6923 | val_loss: 0.6931 | val_acc: 0.4875
# Epoch 003 | loss: 0.6908 | val_loss: 0.6925 | val_acc: 0.5175
# Epoch 004 | loss: 0.6899 | val_loss: 0.6921 | val_acc: 0.5450
# Epoch 005 | loss: 0.6891 | val_loss: 0.6916 | val_acc: 0.5650
# Epoch 006 | loss: 0.6887 | val_loss: 0.6911 | val_acc: 0.5100
# Epoch 007 | loss: 0.6880 | val_loss: 0.6907 | val_acc: 0.5075
# Epoch 008 | loss: 0.6872 | val_loss: 0.6901 | val_acc: 0.5025
# Epoch 009 | loss: 0.6867 | val_loss: 0.6896 | val_acc: 0.5050
# Epoch 010 | loss: 0.6858 | val_loss: 0.6891 | val_acc: 0.5075
# Epoch 011 | loss: 0.6853 | val_loss: 0.6882 | val_acc: 0.5400
# Epoch 012 | loss: 0.6847 | val_loss: 0.6876 | val_acc: 0.5275
# Epoch 013 | loss: 0.6840 | val_loss: 0.6874 | val_acc: 0.4900
# Epoch 014 | loss: 0.6837 | val_loss: 0.6868 | val_acc: 0.4975
# Epoch 015 | loss: 0.6833 | val_loss: 0.6864 | val_acc: 0.5200
# Epoch 016 | loss: 0.6830 | val_loss: 0.6862 | val_acc: 0.5125
# Epoch 017 | loss: 0.6828 | val_loss: 0.6860 | val_acc: 0.5125
# Epoch 018 | loss: 0.6826 | val_loss: 0.6858 | val_acc: 0.5350
# Epoch 019 | loss: 0.6822 | val_loss: 0.6853 | val_acc: 0.5350
# Epoch 020 | loss: 0.6821 | val_loss: 0.6855 | val_acc: 0.5050
# Epoch 021 | loss: 0.6816 | val_loss: 0.6850 | val_acc: 0.5275
# Epoch 022 | loss: 0.6813 | val_loss: 0.6847 | val_acc: 0.5225
# Epoch 023 | loss: 0.6812 | val_loss: 0.6846 | val_acc: 0.5175
# Epoch 024 | loss: 0.6809 | val_loss: 0.6841 | val_acc: 0.5550
# Epoch 025 | loss: 0.6807 | val_loss: 0.6838 | val_acc: 0.5525
# Epoch 026 | loss: 0.6803 | val_loss: 0.6836 | val_acc: 0.5200
# Epoch 027 | loss: 0.6799 | val_loss: 0.6834 | val_acc: 0.5200
# Epoch 028 | loss: 0.6798 | val_loss: 0.6832 | val_acc: 0.5500
# Epoch 029 | loss: 0.6793 | val_loss: 0.6827 | val_acc: 0.5300
# Epoch 030 | loss: 0.6791 | val_loss: 0.6826 | val_acc: 0.5325
# Epoch 031 | loss: 0.6788 | val_loss: 0.6822 | val_acc: 0.5450
# Epoch 032 | loss: 0.6785 | val_loss: 0.6820 | val_acc: 0.5250
# Epoch 033 | loss: 0.6781 | val_loss: 0.6816 | val_acc: 0.5375
# Epoch 034 | loss: 0.6778 | val_loss: 0.6813 | val_acc: 0.5250
# Epoch 035 | loss: 0.6774 | val_loss: 0.6811 | val_acc: 0.5400
# Epoch 036 | loss: 0.6773 | val_loss: 0.6808 | val_acc: 0.5250
# Epoch 037 | loss: 0.6769 | val_loss: 0.6805 | val_acc: 0.5650
# Epoch 038 | loss: 0.6766 | val_loss: 0.6799 | val_acc: 0.5725
# Epoch 039 | loss: 0.6764 | val_loss: 0.6801 | val_acc: 0.5300
# Epoch 040 | loss: 0.6760 | val_loss: 0.6795 | val_acc: 0.5475
# Epoch 041 | loss: 0.6756 | val_loss: 0.6793 | val_acc: 0.5775
# Epoch 042 | loss: 0.6752 | val_loss: 0.6790 | val_acc: 0.5575
# Epoch 043 | loss: 0.6749 | val_loss: 0.6785 | val_acc: 0.5675
# Epoch 044 | loss: 0.6746 | val_loss: 0.6786 | val_acc: 0.5675
# Epoch 045 | loss: 0.6743 | val_loss: 0.6781 | val_acc: 0.5650
# Epoch 046 | loss: 0.6739 | val_loss: 0.6778 | val_acc: 0.5700
# Epoch 047 | loss: 0.6737 | val_loss: 0.6777 | val_acc: 0.5450
# Epoch 048 | loss: 0.6733 | val_loss: 0.6771 | val_acc: 0.5925
# Epoch 049 | loss: 0.6728 | val_loss: 0.6771 | val_acc: 0.5775
# Epoch 050 | loss: 0.6725 | val_loss: 0.6766 | val_acc: 0.5725
# Epoch 051 | loss: 0.6721 | val_loss: 0.6764 | val_acc: 0.5800
# Epoch 052 | loss: 0.6718 | val_loss: 0.6758 | val_acc: 0.5825
# Epoch 053 | loss: 0.6714 | val_loss: 0.6757 | val_acc: 0.5850
# Epoch 054 | loss: 0.6709 | val_loss: 0.6754 | val_acc: 0.5825
# Epoch 055 | loss: 0.6705 | val_loss: 0.6751 | val_acc: 0.5900
# Epoch 056 | loss: 0.6701 | val_loss: 0.6745 | val_acc: 0.5800
# Epoch 057 | loss: 0.6700 | val_loss: 0.6739 | val_acc: 0.6175
# Epoch 058 | loss: 0.6696 | val_loss: 0.6738 | val_acc: 0.5900
# Epoch 059 | loss: 0.6692 | val_loss: 0.6734 | val_acc: 0.6275
# Epoch 060 | loss: 0.6688 | val_loss: 0.6730 | val_acc: 0.6325
# [RELU] Acc: 0.6325 | Final train loss: 0.6688
#
# ------------------------------------------------------------
# Training with LEAKY_RELU activation...
# Epoch 001 | loss: 0.7192 | val_loss: 0.7140 | val_acc: 0.4925
# Epoch 002 | loss: 0.7142 | val_loss: 0.7097 | val_acc: 0.4950
# Epoch 003 | loss: 0.7099 | val_loss: 0.7068 | val_acc: 0.4900
# Epoch 004 | loss: 0.7067 | val_loss: 0.7040 | val_acc: 0.4825
# Epoch 005 | loss: 0.7040 | val_loss: 0.7020 | val_acc: 0.4850
# Epoch 006 | loss: 0.7020 | val_loss: 0.7005 | val_acc: 0.4800
# Epoch 007 | loss: 0.7006 | val_loss: 0.6994 | val_acc: 0.4725
# Epoch 008 | loss: 0.6992 | val_loss: 0.6985 | val_acc: 0.4700
# Epoch 009 | loss: 0.6983 | val_loss: 0.6976 | val_acc: 0.4700
# Epoch 010 | loss: 0.6973 | val_loss: 0.6969 | val_acc: 0.4650
# Epoch 011 | loss: 0.6966 | val_loss: 0.6962 | val_acc: 0.4625
# Epoch 012 | loss: 0.6959 | val_loss: 0.6957 | val_acc: 0.4625
# Epoch 013 | loss: 0.6953 | val_loss: 0.6952 | val_acc: 0.4625
# Epoch 014 | loss: 0.6948 | val_loss: 0.6947 | val_acc: 0.4675
# Epoch 015 | loss: 0.6943 | val_loss: 0.6941 | val_acc: 0.4725
# Epoch 016 | loss: 0.6937 | val_loss: 0.6938 | val_acc: 0.4725
# Epoch 017 | loss: 0.6933 | val_loss: 0.6935 | val_acc: 0.4850
# Epoch 018 | loss: 0.6928 | val_loss: 0.6930 | val_acc: 0.4775
# Epoch 019 | loss: 0.6922 | val_loss: 0.6925 | val_acc: 0.4775
# Epoch 020 | loss: 0.6918 | val_loss: 0.6923 | val_acc: 0.4800
# Epoch 021 | loss: 0.6912 | val_loss: 0.6917 | val_acc: 0.4800
# Epoch 022 | loss: 0.6907 | val_loss: 0.6912 | val_acc: 0.4825
# Epoch 023 | loss: 0.6903 | val_loss: 0.6910 | val_acc: 0.4975
# Epoch 024 | loss: 0.6899 | val_loss: 0.6905 | val_acc: 0.5925
# Epoch 025 | loss: 0.6896 | val_loss: 0.6901 | val_acc: 0.6025
# Epoch 026 | loss: 0.6891 | val_loss: 0.6899 | val_acc: 0.5800
# Epoch 027 | loss: 0.6888 | val_loss: 0.6896 | val_acc: 0.5850
# Epoch 028 | loss: 0.6886 | val_loss: 0.6895 | val_acc: 0.5750
# Epoch 029 | loss: 0.6881 | val_loss: 0.6890 | val_acc: 0.5825
# Epoch 030 | loss: 0.6878 | val_loss: 0.6890 | val_acc: 0.5900
# Epoch 031 | loss: 0.6876 | val_loss: 0.6887 | val_acc: 0.5875
# Epoch 032 | loss: 0.6873 | val_loss: 0.6883 | val_acc: 0.5950
# Epoch 033 | loss: 0.6869 | val_loss: 0.6881 | val_acc: 0.5900
# Epoch 034 | loss: 0.6867 | val_loss: 0.6879 | val_acc: 0.5900
# Epoch 035 | loss: 0.6863 | val_loss: 0.6877 | val_acc: 0.6000
# Epoch 036 | loss: 0.6862 | val_loss: 0.6874 | val_acc: 0.5975
# Epoch 037 | loss: 0.6859 | val_loss: 0.6871 | val_acc: 0.5650
# Epoch 038 | loss: 0.6857 | val_loss: 0.6868 | val_acc: 0.5800
# Epoch 039 | loss: 0.6855 | val_loss: 0.6867 | val_acc: 0.5525
# Epoch 040 | loss: 0.6853 | val_loss: 0.6864 | val_acc: 0.5675
# Epoch 041 | loss: 0.6849 | val_loss: 0.6862 | val_acc: 0.5575
# Epoch 042 | loss: 0.6846 | val_loss: 0.6860 | val_acc: 0.5525
# Epoch 043 | loss: 0.6843 | val_loss: 0.6857 | val_acc: 0.5325
# Epoch 044 | loss: 0.6841 | val_loss: 0.6857 | val_acc: 0.5375
# Epoch 045 | loss: 0.6839 | val_loss: 0.6853 | val_acc: 0.5325
# Epoch 046 | loss: 0.6835 | val_loss: 0.6851 | val_acc: 0.5325
# Epoch 047 | loss: 0.6833 | val_loss: 0.6849 | val_acc: 0.5425
# Epoch 048 | loss: 0.6830 | val_loss: 0.6846 | val_acc: 0.5600
# Epoch 049 | loss: 0.6827 | val_loss: 0.6844 | val_acc: 0.5425
# Epoch 050 | loss: 0.6825 | val_loss: 0.6843 | val_acc: 0.5525
# Epoch 051 | loss: 0.6822 | val_loss: 0.6840 | val_acc: 0.5525
# Epoch 052 | loss: 0.6820 | val_loss: 0.6836 | val_acc: 0.5400
# Epoch 053 | loss: 0.6818 | val_loss: 0.6835 | val_acc: 0.5375
# Epoch 054 | loss: 0.6814 | val_loss: 0.6833 | val_acc: 0.5375
# Epoch 055 | loss: 0.6810 | val_loss: 0.6831 | val_acc: 0.5200
# Epoch 056 | loss: 0.6807 | val_loss: 0.6828 | val_acc: 0.5275
# Epoch 057 | loss: 0.6806 | val_loss: 0.6823 | val_acc: 0.5225
# Epoch 058 | loss: 0.6802 | val_loss: 0.6822 | val_acc: 0.5275
# Epoch 059 | loss: 0.6800 | val_loss: 0.6817 | val_acc: 0.5350
# Epoch 060 | loss: 0.6797 | val_loss: 0.6814 | val_acc: 0.5275
# [LEAKY_RELU] Acc: 0.5275 | Final train loss: 0.6797
#
# ------------------------------------------------------------
# Training with ELU activation...
# Epoch 001 | loss: 0.7167 | val_loss: 0.7060 | val_acc: 0.4350
# Epoch 002 | loss: 0.7055 | val_loss: 0.6993 | val_acc: 0.4375
# Epoch 003 | loss: 0.6997 | val_loss: 0.6958 | val_acc: 0.4375
# Epoch 004 | loss: 0.6966 | val_loss: 0.6942 | val_acc: 0.4300
# Epoch 005 | loss: 0.6948 | val_loss: 0.6933 | val_acc: 0.4450
# Epoch 006 | loss: 0.6937 | val_loss: 0.6931 | val_acc: 0.4500
# Epoch 007 | loss: 0.6932 | val_loss: 0.6932 | val_acc: 0.4975
# Epoch 008 | loss: 0.6927 | val_loss: 0.6932 | val_acc: 0.5625
# Epoch 009 | loss: 0.6927 | val_loss: 0.6936 | val_acc: 0.5175
# Epoch 010 | loss: 0.6923 | val_loss: 0.6937 | val_acc: 0.4950
# Epoch 011 | loss: 0.6923 | val_loss: 0.6937 | val_acc: 0.5600
# Epoch 012 | loss: 0.6923 | val_loss: 0.6938 | val_acc: 0.5450
# Epoch 013 | loss: 0.6922 | val_loss: 0.6941 | val_acc: 0.4950
# Epoch 014 | loss: 0.6921 | val_loss: 0.6939 | val_acc: 0.5300
# Epoch 015 | loss: 0.6921 | val_loss: 0.6940 | val_acc: 0.5300
# Epoch 016 | loss: 0.6921 | val_loss: 0.6940 | val_acc: 0.5250
# Epoch 017 | loss: 0.6921 | val_loss: 0.6941 | val_acc: 0.5150
# Epoch 018 | loss: 0.6921 | val_loss: 0.6942 | val_acc: 0.5250
# Epoch 019 | loss: 0.6919 | val_loss: 0.6940 | val_acc: 0.5225
# Epoch 020 | loss: 0.6921 | val_loss: 0.6943 | val_acc: 0.5075
# Epoch 021 | loss: 0.6918 | val_loss: 0.6942 | val_acc: 0.5175
# Epoch 022 | loss: 0.6918 | val_loss: 0.6941 | val_acc: 0.5200
# Epoch 023 | loss: 0.6919 | val_loss: 0.6941 | val_acc: 0.5125
# Epoch 024 | loss: 0.6919 | val_loss: 0.6940 | val_acc: 0.5300
# Epoch 025 | loss: 0.6920 | val_loss: 0.6937 | val_acc: 0.5300
# Epoch 026 | loss: 0.6919 | val_loss: 0.6940 | val_acc: 0.5175
# Epoch 027 | loss: 0.6918 | val_loss: 0.6939 | val_acc: 0.5150
# Epoch 028 | loss: 0.6919 | val_loss: 0.6941 | val_acc: 0.5225
# Epoch 029 | loss: 0.6917 | val_loss: 0.6938 | val_acc: 0.5250
# Epoch 030 | loss: 0.6917 | val_loss: 0.6940 | val_acc: 0.5100
# Epoch 031 | loss: 0.6917 | val_loss: 0.6940 | val_acc: 0.5200
# Epoch 032 | loss: 0.6917 | val_loss: 0.6939 | val_acc: 0.5300
# Epoch 033 | loss: 0.6916 | val_loss: 0.6938 | val_acc: 0.5225
# Epoch 034 | loss: 0.6917 | val_loss: 0.6938 | val_acc: 0.5125
# Epoch 035 | loss: 0.6914 | val_loss: 0.6938 | val_acc: 0.5200
# Epoch 036 | loss: 0.6917 | val_loss: 0.6938 | val_acc: 0.5275
# Epoch 037 | loss: 0.6916 | val_loss: 0.6938 | val_acc: 0.5125
# Epoch 038 | loss: 0.6915 | val_loss: 0.6936 | val_acc: 0.5275
# Epoch 039 | loss: 0.6916 | val_loss: 0.6939 | val_acc: 0.5250
# Epoch 040 | loss: 0.6916 | val_loss: 0.6936 | val_acc: 0.5275
# Epoch 041 | loss: 0.6914 | val_loss: 0.6937 | val_acc: 0.5050
# Epoch 042 | loss: 0.6914 | val_loss: 0.6938 | val_acc: 0.5150
# Epoch 043 | loss: 0.6914 | val_loss: 0.6936 | val_acc: 0.5250
# Epoch 044 | loss: 0.6914 | val_loss: 0.6939 | val_acc: 0.5225
# Epoch 045 | loss: 0.6914 | val_loss: 0.6936 | val_acc: 0.5275
# Epoch 046 | loss: 0.6913 | val_loss: 0.6937 | val_acc: 0.5225
# Epoch 047 | loss: 0.6914 | val_loss: 0.6938 | val_acc: 0.5300
# Epoch 048 | loss: 0.6913 | val_loss: 0.6936 | val_acc: 0.5125
# Epoch 049 | loss: 0.6912 | val_loss: 0.6937 | val_acc: 0.5225
# Epoch 050 | loss: 0.6913 | val_loss: 0.6937 | val_acc: 0.5150
# Epoch 051 | loss: 0.6912 | val_loss: 0.6938 | val_acc: 0.5150
# Epoch 052 | loss: 0.6912 | val_loss: 0.6936 | val_acc: 0.5275
# Epoch 053 | loss: 0.6912 | val_loss: 0.6937 | val_acc: 0.5125
# Epoch 054 | loss: 0.6912 | val_loss: 0.6937 | val_acc: 0.5125
# Epoch 055 | loss: 0.6911 | val_loss: 0.6937 | val_acc: 0.5125
# Epoch 056 | loss: 0.6911 | val_loss: 0.6937 | val_acc: 0.5225
# Epoch 057 | loss: 0.6913 | val_loss: 0.6934 | val_acc: 0.5225
# Epoch 058 | loss: 0.6912 | val_loss: 0.6936 | val_acc: 0.5125
# Epoch 059 | loss: 0.6912 | val_loss: 0.6935 | val_acc: 0.5225
# Epoch 060 | loss: 0.6912 | val_loss: 0.6935 | val_acc: 0.5200
# [ELU] Acc: 0.5200 | Final train loss: 0.6912
#
# ------------------------------------------------------------
# Training with SOFTPLUS activation...
# Epoch 001 | loss: 0.7211 | val_loss: 0.7119 | val_acc: 0.5050
# Epoch 002 | loss: 0.7024 | val_loss: 0.7019 | val_acc: 0.5175
# Epoch 003 | loss: 0.6969 | val_loss: 0.6985 | val_acc: 0.4650
# Epoch 004 | loss: 0.6955 | val_loss: 0.6973 | val_acc: 0.4550
# Epoch 005 | loss: 0.6945 | val_loss: 0.6966 | val_acc: 0.4600
# Epoch 006 | loss: 0.6941 | val_loss: 0.6959 | val_acc: 0.4650
# Epoch 007 | loss: 0.6940 | val_loss: 0.6955 | val_acc: 0.4825
# Epoch 008 | loss: 0.6935 | val_loss: 0.6952 | val_acc: 0.5000
# Epoch 009 | loss: 0.6936 | val_loss: 0.6950 | val_acc: 0.5200
# Epoch 010 | loss: 0.6930 | val_loss: 0.6949 | val_acc: 0.4650
# Epoch 011 | loss: 0.6931 | val_loss: 0.6947 | val_acc: 0.4750
# Epoch 012 | loss: 0.6929 | val_loss: 0.6945 | val_acc: 0.4775
# Epoch 013 | loss: 0.6928 | val_loss: 0.6945 | val_acc: 0.4925
# Epoch 014 | loss: 0.6928 | val_loss: 0.6944 | val_acc: 0.5025
# Epoch 015 | loss: 0.6927 | val_loss: 0.6943 | val_acc: 0.5300
# Epoch 016 | loss: 0.6927 | val_loss: 0.6943 | val_acc: 0.5200
# Epoch 017 | loss: 0.6927 | val_loss: 0.6943 | val_acc: 0.5250
# Epoch 018 | loss: 0.6929 | val_loss: 0.6943 | val_acc: 0.5350
# Epoch 019 | loss: 0.6926 | val_loss: 0.6941 | val_acc: 0.5450
# Epoch 020 | loss: 0.6927 | val_loss: 0.6942 | val_acc: 0.5400
# Epoch 021 | loss: 0.6925 | val_loss: 0.6941 | val_acc: 0.5450
# Epoch 022 | loss: 0.6926 | val_loss: 0.6941 | val_acc: 0.4700
# Epoch 023 | loss: 0.6925 | val_loss: 0.6941 | val_acc: 0.5475
# Epoch 024 | loss: 0.6927 | val_loss: 0.6941 | val_acc: 0.5450
# Epoch 025 | loss: 0.6929 | val_loss: 0.6940 | val_acc: 0.5475
# Epoch 026 | loss: 0.6928 | val_loss: 0.6940 | val_acc: 0.4725
# Epoch 027 | loss: 0.6926 | val_loss: 0.6939 | val_acc: 0.4700
# Epoch 028 | loss: 0.6928 | val_loss: 0.6941 | val_acc: 0.5425
# Epoch 029 | loss: 0.6925 | val_loss: 0.6939 | val_acc: 0.4825
# Epoch 030 | loss: 0.6926 | val_loss: 0.6941 | val_acc: 0.5550
# Epoch 031 | loss: 0.6927 | val_loss: 0.6942 | val_acc: 0.5525
# Epoch 032 | loss: 0.6925 | val_loss: 0.6939 | val_acc: 0.4875
# Epoch 033 | loss: 0.6925 | val_loss: 0.6939 | val_acc: 0.4975
# Epoch 034 | loss: 0.6926 | val_loss: 0.6940 | val_acc: 0.5425
# Epoch 035 | loss: 0.6925 | val_loss: 0.6939 | val_acc: 0.4975
# Epoch 036 | loss: 0.6926 | val_loss: 0.6939 | val_acc: 0.4975
# Epoch 037 | loss: 0.6926 | val_loss: 0.6939 | val_acc: 0.4700
# Epoch 038 | loss: 0.6927 | val_loss: 0.6939 | val_acc: 0.5050
# Epoch 039 | loss: 0.6926 | val_loss: 0.6940 | val_acc: 0.5000
# Epoch 040 | loss: 0.6928 | val_loss: 0.6939 | val_acc: 0.4900
# Epoch 041 | loss: 0.6926 | val_loss: 0.6939 | val_acc: 0.4750
# Epoch 042 | loss: 0.6925 | val_loss: 0.6940 | val_acc: 0.5050
# Epoch 043 | loss: 0.6925 | val_loss: 0.6939 | val_acc: 0.4675
# Epoch 044 | loss: 0.6925 | val_loss: 0.6940 | val_acc: 0.4850
# Epoch 045 | loss: 0.6926 | val_loss: 0.6939 | val_acc: 0.4900
# Epoch 046 | loss: 0.6925 | val_loss: 0.6939 | val_acc: 0.4950
# Epoch 047 | loss: 0.6926 | val_loss: 0.6940 | val_acc: 0.4975
# Epoch 048 | loss: 0.6925 | val_loss: 0.6940 | val_acc: 0.5500
# Epoch 049 | loss: 0.6925 | val_loss: 0.6940 | val_acc: 0.4900
# Epoch 050 | loss: 0.6926 | val_loss: 0.6940 | val_acc: 0.4850
# Epoch 051 | loss: 0.6926 | val_loss: 0.6940 | val_acc: 0.4800
# Epoch 052 | loss: 0.6926 | val_loss: 0.6940 | val_acc: 0.4975
# Epoch 053 | loss: 0.6926 | val_loss: 0.6940 | val_acc: 0.4800
# Epoch 054 | loss: 0.6925 | val_loss: 0.6940 | val_acc: 0.4675
# Epoch 055 | loss: 0.6925 | val_loss: 0.6939 | val_acc: 0.4650
# Epoch 056 | loss: 0.6925 | val_loss: 0.6940 | val_acc: 0.4950
# Epoch 057 | loss: 0.6927 | val_loss: 0.6939 | val_acc: 0.5600
# Epoch 058 | loss: 0.6925 | val_loss: 0.6939 | val_acc: 0.4650
# Epoch 059 | loss: 0.6927 | val_loss: 0.6939 | val_acc: 0.4725
# Epoch 060 | loss: 0.6927 | val_loss: 0.6939 | val_acc: 0.4700
# [SOFTPLUS] Acc: 0.4700 | Final train loss: 0.6927
#
# ------------------------------------------------------------
# Training with SWISH activation...
# Epoch 001 | loss: 0.6955 | val_loss: 0.6953 | val_acc: 0.5000
# Epoch 002 | loss: 0.6938 | val_loss: 0.6943 | val_acc: 0.4550
# Epoch 003 | loss: 0.6930 | val_loss: 0.6942 | val_acc: 0.4850
# Epoch 004 | loss: 0.6928 | val_loss: 0.6940 | val_acc: 0.5300
# Epoch 005 | loss: 0.6926 | val_loss: 0.6939 | val_acc: 0.5500
# Epoch 006 | loss: 0.6926 | val_loss: 0.6939 | val_acc: 0.5475
# Epoch 007 | loss: 0.6926 | val_loss: 0.6940 | val_acc: 0.5450
# Epoch 008 | loss: 0.6925 | val_loss: 0.6940 | val_acc: 0.5475
# Epoch 009 | loss: 0.6925 | val_loss: 0.6942 | val_acc: 0.5475
# Epoch 010 | loss: 0.6924 | val_loss: 0.6942 | val_acc: 0.5500
# Epoch 011 | loss: 0.6924 | val_loss: 0.6941 | val_acc: 0.5525
# Epoch 012 | loss: 0.6925 | val_loss: 0.6941 | val_acc: 0.5525
# Epoch 013 | loss: 0.6924 | val_loss: 0.6943 | val_acc: 0.5475
# Epoch 014 | loss: 0.6924 | val_loss: 0.6942 | val_acc: 0.5500
# Epoch 015 | loss: 0.6924 | val_loss: 0.6942 | val_acc: 0.5500
# Epoch 016 | loss: 0.6924 | val_loss: 0.6942 | val_acc: 0.5550
# Epoch 017 | loss: 0.6924 | val_loss: 0.6943 | val_acc: 0.5550
# Epoch 018 | loss: 0.6924 | val_loss: 0.6943 | val_acc: 0.5550
# Epoch 019 | loss: 0.6923 | val_loss: 0.6941 | val_acc: 0.5550
# Epoch 020 | loss: 0.6924 | val_loss: 0.6944 | val_acc: 0.5575
# Epoch 021 | loss: 0.6923 | val_loss: 0.6943 | val_acc: 0.5475
# Epoch 022 | loss: 0.6923 | val_loss: 0.6942 | val_acc: 0.5475
# Epoch 023 | loss: 0.6924 | val_loss: 0.6943 | val_acc: 0.5600
# Epoch 024 | loss: 0.6924 | val_loss: 0.6942 | val_acc: 0.5525
# Epoch 025 | loss: 0.6924 | val_loss: 0.6940 | val_acc: 0.5600
# Epoch 026 | loss: 0.6923 | val_loss: 0.6942 | val_acc: 0.5525
# Epoch 027 | loss: 0.6923 | val_loss: 0.6941 | val_acc: 0.5475
# Epoch 028 | loss: 0.6924 | val_loss: 0.6943 | val_acc: 0.5575
# Epoch 029 | loss: 0.6923 | val_loss: 0.6941 | val_acc: 0.5525
# Epoch 030 | loss: 0.6923 | val_loss: 0.6943 | val_acc: 0.5650
# Epoch 031 | loss: 0.6923 | val_loss: 0.6943 | val_acc: 0.5675
# Epoch 032 | loss: 0.6923 | val_loss: 0.6942 | val_acc: 0.5525
# Epoch 033 | loss: 0.6923 | val_loss: 0.6941 | val_acc: 0.5600
# Epoch 034 | loss: 0.6923 | val_loss: 0.6941 | val_acc: 0.5675
# Epoch 035 | loss: 0.6922 | val_loss: 0.6942 | val_acc: 0.5625
# Epoch 036 | loss: 0.6923 | val_loss: 0.6941 | val_acc: 0.5600
# Epoch 037 | loss: 0.6923 | val_loss: 0.6941 | val_acc: 0.5400
# Epoch 038 | loss: 0.6923 | val_loss: 0.6941 | val_acc: 0.5625
# Epoch 039 | loss: 0.6923 | val_loss: 0.6942 | val_acc: 0.5550
# Epoch 040 | loss: 0.6923 | val_loss: 0.6941 | val_acc: 0.5650
# Epoch 041 | loss: 0.6922 | val_loss: 0.6941 | val_acc: 0.5675
# Epoch 042 | loss: 0.6922 | val_loss: 0.6942 | val_acc: 0.5675
# Epoch 043 | loss: 0.6922 | val_loss: 0.6941 | val_acc: 0.5475
# Epoch 044 | loss: 0.6922 | val_loss: 0.6943 | val_acc: 0.5550
# Epoch 045 | loss: 0.6922 | val_loss: 0.6941 | val_acc: 0.5600
# Epoch 046 | loss: 0.6922 | val_loss: 0.6941 | val_acc: 0.5500
# Epoch 047 | loss: 0.6923 | val_loss: 0.6942 | val_acc: 0.5550
# Epoch 048 | loss: 0.6922 | val_loss: 0.6941 | val_acc: 0.5700
# Epoch 049 | loss: 0.6922 | val_loss: 0.6942 | val_acc: 0.5550
# Epoch 050 | loss: 0.6922 | val_loss: 0.6942 | val_acc: 0.5675
# Epoch 051 | loss: 0.6922 | val_loss: 0.6943 | val_acc: 0.5625
# Epoch 052 | loss: 0.6922 | val_loss: 0.6942 | val_acc: 0.5650
# Epoch 053 | loss: 0.6923 | val_loss: 0.6942 | val_acc: 0.5625
# Epoch 054 | loss: 0.6922 | val_loss: 0.6942 | val_acc: 0.5650
# Epoch 055 | loss: 0.6922 | val_loss: 0.6942 | val_acc: 0.5525
# Epoch 056 | loss: 0.6922 | val_loss: 0.6942 | val_acc: 0.5625
# Epoch 057 | loss: 0.6923 | val_loss: 0.6941 | val_acc: 0.5725
# Epoch 058 | loss: 0.6922 | val_loss: 0.6942 | val_acc: 0.5675
# Epoch 059 | loss: 0.6923 | val_loss: 0.6941 | val_acc: 0.5500
# Epoch 060 | loss: 0.6922 | val_loss: 0.6941 | val_acc: 0.5500
# [SWISH] Acc: 0.5500 | Final train loss: 0.6922
#
# ------------------------------------------------------------
# Training with MISH activation...
# Epoch 001 | loss: 0.7034 | val_loss: 0.6993 | val_acc: 0.4750
# Epoch 002 | loss: 0.7014 | val_loss: 0.6984 | val_acc: 0.4875
# Epoch 003 | loss: 0.7000 | val_loss: 0.6976 | val_acc: 0.4900
# Epoch 004 | loss: 0.6992 | val_loss: 0.6972 | val_acc: 0.4875
# Epoch 005 | loss: 0.6985 | val_loss: 0.6968 | val_acc: 0.4875
# Epoch 006 | loss: 0.6979 | val_loss: 0.6965 | val_acc: 0.4925
# Epoch 007 | loss: 0.6976 | val_loss: 0.6963 | val_acc: 0.4875
# Epoch 008 | loss: 0.6970 | val_loss: 0.6962 | val_acc: 0.4875
# Epoch 009 | loss: 0.6968 | val_loss: 0.6961 | val_acc: 0.4975
# Epoch 010 | loss: 0.6963 | val_loss: 0.6959 | val_acc: 0.5000
# Epoch 011 | loss: 0.6961 | val_loss: 0.6956 | val_acc: 0.4975
# Epoch 012 | loss: 0.6958 | val_loss: 0.6954 | val_acc: 0.5050
# Epoch 013 | loss: 0.6955 | val_loss: 0.6953 | val_acc: 0.5125
# Epoch 014 | loss: 0.6953 | val_loss: 0.6950 | val_acc: 0.5125
# Epoch 015 | loss: 0.6951 | val_loss: 0.6949 | val_acc: 0.5050
# Epoch 016 | loss: 0.6949 | val_loss: 0.6948 | val_acc: 0.5175
# Epoch 017 | loss: 0.6947 | val_loss: 0.6949 | val_acc: 0.4975
# Epoch 018 | loss: 0.6947 | val_loss: 0.6947 | val_acc: 0.5350
# Epoch 019 | loss: 0.6943 | val_loss: 0.6943 | val_acc: 0.5300
# Epoch 020 | loss: 0.6944 | val_loss: 0.6947 | val_acc: 0.5450
# Epoch 021 | loss: 0.6940 | val_loss: 0.6943 | val_acc: 0.5250
# Epoch 022 | loss: 0.6939 | val_loss: 0.6941 | val_acc: 0.5225
# Epoch 023 | loss: 0.6939 | val_loss: 0.6942 | val_acc: 0.5150
# Epoch 024 | loss: 0.6937 | val_loss: 0.6941 | val_acc: 0.5075
# Epoch 025 | loss: 0.6938 | val_loss: 0.6938 | val_acc: 0.5100
# Epoch 026 | loss: 0.6936 | val_loss: 0.6939 | val_acc: 0.5025
# Epoch 027 | loss: 0.6935 | val_loss: 0.6937 | val_acc: 0.5025
# Epoch 028 | loss: 0.6935 | val_loss: 0.6941 | val_acc: 0.5250
# Epoch 029 | loss: 0.6932 | val_loss: 0.6936 | val_acc: 0.5025
# Epoch 030 | loss: 0.6932 | val_loss: 0.6940 | val_acc: 0.5375
# Epoch 031 | loss: 0.6932 | val_loss: 0.6940 | val_acc: 0.5250
# Epoch 032 | loss: 0.6930 | val_loss: 0.6935 | val_acc: 0.4875
# Epoch 033 | loss: 0.6929 | val_loss: 0.6936 | val_acc: 0.5150
# Epoch 034 | loss: 0.6929 | val_loss: 0.6936 | val_acc: 0.5075
# Epoch 035 | loss: 0.6927 | val_loss: 0.6935 | val_acc: 0.5100
# Epoch 036 | loss: 0.6928 | val_loss: 0.6934 | val_acc: 0.5075
# Epoch 037 | loss: 0.6927 | val_loss: 0.6934 | val_acc: 0.4875
# Epoch 038 | loss: 0.6927 | val_loss: 0.6934 | val_acc: 0.5050
# Epoch 039 | loss: 0.6926 | val_loss: 0.6936 | val_acc: 0.4975
# Epoch 040 | loss: 0.6926 | val_loss: 0.6934 | val_acc: 0.4825
# Epoch 041 | loss: 0.6925 | val_loss: 0.6935 | val_acc: 0.4975
# Epoch 042 | loss: 0.6925 | val_loss: 0.6935 | val_acc: 0.5225
# Epoch 043 | loss: 0.6923 | val_loss: 0.6932 | val_acc: 0.5150
# Epoch 044 | loss: 0.6923 | val_loss: 0.6934 | val_acc: 0.5150
# Epoch 045 | loss: 0.6923 | val_loss: 0.6933 | val_acc: 0.5100
# Epoch 046 | loss: 0.6922 | val_loss: 0.6934 | val_acc: 0.5200
# Epoch 047 | loss: 0.6923 | val_loss: 0.6935 | val_acc: 0.5275
# Epoch 048 | loss: 0.6922 | val_loss: 0.6936 | val_acc: 0.5500
# Epoch 049 | loss: 0.6921 | val_loss: 0.6934 | val_acc: 0.5150
# Epoch 050 | loss: 0.6922 | val_loss: 0.6935 | val_acc: 0.5450
# Epoch 051 | loss: 0.6922 | val_loss: 0.6935 | val_acc: 0.5450
# Epoch 052 | loss: 0.6921 | val_loss: 0.6933 | val_acc: 0.5500
# Epoch 053 | loss: 0.6921 | val_loss: 0.6934 | val_acc: 0.5475
# Epoch 054 | loss: 0.6920 | val_loss: 0.6934 | val_acc: 0.5450
# Epoch 055 | loss: 0.6920 | val_loss: 0.6933 | val_acc: 0.5100
# Epoch 056 | loss: 0.6921 | val_loss: 0.6933 | val_acc: 0.5475
# Epoch 057 | loss: 0.6921 | val_loss: 0.6932 | val_acc: 0.5475
# Epoch 058 | loss: 0.6920 | val_loss: 0.6933 | val_acc: 0.5450
# Epoch 059 | loss: 0.6920 | val_loss: 0.6932 | val_acc: 0.5450
# Epoch 060 | loss: 0.6922 | val_loss: 0.6933 | val_acc: 0.5475
# [MISH] Acc: 0.5475 | Final train loss: 0.6922
#
# ------------------------------------------------------------
# Training with GELU activation...
# Epoch 001 | loss: 0.7299 | val_loss: 0.7112 | val_acc: 0.5550
# Epoch 002 | loss: 0.7155 | val_loss: 0.7034 | val_acc: 0.5550
# Epoch 003 | loss: 0.7077 | val_loss: 0.6996 | val_acc: 0.5350
# Epoch 004 | loss: 0.7032 | val_loss: 0.6973 | val_acc: 0.5375
# Epoch 005 | loss: 0.7001 | val_loss: 0.6961 | val_acc: 0.5200
# Epoch 006 | loss: 0.6981 | val_loss: 0.6951 | val_acc: 0.5100
# Epoch 007 | loss: 0.6967 | val_loss: 0.6947 | val_acc: 0.4975
# Epoch 008 | loss: 0.6955 | val_loss: 0.6943 | val_acc: 0.4600
# Epoch 009 | loss: 0.6948 | val_loss: 0.6941 | val_acc: 0.4675
# Epoch 010 | loss: 0.6941 | val_loss: 0.6940 | val_acc: 0.4875
# Epoch 011 | loss: 0.6937 | val_loss: 0.6940 | val_acc: 0.4875
# Epoch 012 | loss: 0.6934 | val_loss: 0.6940 | val_acc: 0.4550
# Epoch 013 | loss: 0.6931 | val_loss: 0.6940 | val_acc: 0.4625
# Epoch 014 | loss: 0.6928 | val_loss: 0.6940 | val_acc: 0.4500
# Epoch 015 | loss: 0.6927 | val_loss: 0.6940 | val_acc: 0.4525
# Epoch 016 | loss: 0.6926 | val_loss: 0.6941 | val_acc: 0.4575
# Epoch 017 | loss: 0.6926 | val_loss: 0.6942 | val_acc: 0.4650
# Epoch 018 | loss: 0.6925 | val_loss: 0.6942 | val_acc: 0.4600
# Epoch 019 | loss: 0.6924 | val_loss: 0.6941 | val_acc: 0.4600
# Epoch 020 | loss: 0.6925 | val_loss: 0.6944 | val_acc: 0.4750
# Epoch 021 | loss: 0.6923 | val_loss: 0.6943 | val_acc: 0.4775
# Epoch 022 | loss: 0.6923 | val_loss: 0.6942 | val_acc: 0.4825
# Epoch 023 | loss: 0.6923 | val_loss: 0.6944 | val_acc: 0.4800
# Epoch 024 | loss: 0.6923 | val_loss: 0.6942 | val_acc: 0.4850
# Epoch 025 | loss: 0.6924 | val_loss: 0.6941 | val_acc: 0.4875
# Epoch 026 | loss: 0.6923 | val_loss: 0.6943 | val_acc: 0.5050
# Epoch 027 | loss: 0.6923 | val_loss: 0.6942 | val_acc: 0.5075
# Epoch 028 | loss: 0.6923 | val_loss: 0.6944 | val_acc: 0.5025
# Epoch 029 | loss: 0.6922 | val_loss: 0.6942 | val_acc: 0.5100
# Epoch 030 | loss: 0.6922 | val_loss: 0.6945 | val_acc: 0.5000
# Epoch 031 | loss: 0.6922 | val_loss: 0.6945 | val_acc: 0.5150
# Epoch 032 | loss: 0.6922 | val_loss: 0.6942 | val_acc: 0.5250
# Epoch 033 | loss: 0.6922 | val_loss: 0.6942 | val_acc: 0.5250
# Epoch 034 | loss: 0.6922 | val_loss: 0.6943 | val_acc: 0.5100
# Epoch 035 | loss: 0.6921 | val_loss: 0.6943 | val_acc: 0.5150
# Epoch 036 | loss: 0.6922 | val_loss: 0.6942 | val_acc: 0.5275
# Epoch 037 | loss: 0.6921 | val_loss: 0.6943 | val_acc: 0.5275
# Epoch 038 | loss: 0.6922 | val_loss: 0.6942 | val_acc: 0.5275
# Epoch 039 | loss: 0.6922 | val_loss: 0.6943 | val_acc: 0.5300
# Epoch 040 | loss: 0.6921 | val_loss: 0.6942 | val_acc: 0.5250
# Epoch 041 | loss: 0.6921 | val_loss: 0.6943 | val_acc: 0.5200
# Epoch 042 | loss: 0.6921 | val_loss: 0.6943 | val_acc: 0.5175
# Epoch 043 | loss: 0.6921 | val_loss: 0.6942 | val_acc: 0.5300
# Epoch 044 | loss: 0.6921 | val_loss: 0.6943 | val_acc: 0.5250
# Epoch 045 | loss: 0.6921 | val_loss: 0.6942 | val_acc: 0.5300
# Epoch 046 | loss: 0.6921 | val_loss: 0.6943 | val_acc: 0.5250
# Epoch 047 | loss: 0.6921 | val_loss: 0.6943 | val_acc: 0.5350
# Epoch 048 | loss: 0.6921 | val_loss: 0.6943 | val_acc: 0.5325
# Epoch 049 | loss: 0.6921 | val_loss: 0.6943 | val_acc: 0.5250
# Epoch 050 | loss: 0.6921 | val_loss: 0.6944 | val_acc: 0.5300
# Epoch 051 | loss: 0.6921 | val_loss: 0.6944 | val_acc: 0.5375
# Epoch 052 | loss: 0.6921 | val_loss: 0.6942 | val_acc: 0.5325
# Epoch 053 | loss: 0.6921 | val_loss: 0.6943 | val_acc: 0.5350
# Epoch 054 | loss: 0.6920 | val_loss: 0.6943 | val_acc: 0.5325
# Epoch 055 | loss: 0.6920 | val_loss: 0.6942 | val_acc: 0.5350
# Epoch 056 | loss: 0.6921 | val_loss: 0.6943 | val_acc: 0.5275
# Epoch 057 | loss: 0.6922 | val_loss: 0.6941 | val_acc: 0.5300
# Epoch 058 | loss: 0.6921 | val_loss: 0.6943 | val_acc: 0.5250
# Epoch 059 | loss: 0.6921 | val_loss: 0.6941 | val_acc: 0.5275
# Epoch 060 | loss: 0.6922 | val_loss: 0.6942 | val_acc: 0.5325
# [GELU] Acc: 0.5325 | Final train loss: 0.6922
#
# ------------------------------------------------------------
# Training with SINE activation...
# Epoch 001 | loss: 0.7223 | val_loss: 0.7024 | val_acc: 0.4800
# Epoch 002 | loss: 0.7089 | val_loss: 0.6967 | val_acc: 0.4925
# Epoch 003 | loss: 0.7016 | val_loss: 0.6940 | val_acc: 0.4925
# Epoch 004 | loss: 0.6977 | val_loss: 0.6932 | val_acc: 0.4850
# Epoch 005 | loss: 0.6953 | val_loss: 0.6932 | val_acc: 0.4375
# Epoch 006 | loss: 0.6941 | val_loss: 0.6935 | val_acc: 0.4225
# Epoch 007 | loss: 0.6936 | val_loss: 0.6939 | val_acc: 0.4825
# Epoch 008 | loss: 0.6931 | val_loss: 0.6942 | val_acc: 0.5025
# Epoch 009 | loss: 0.6931 | val_loss: 0.6948 | val_acc: 0.5075
# Epoch 010 | loss: 0.6929 | val_loss: 0.6950 | val_acc: 0.5125
# Epoch 011 | loss: 0.6929 | val_loss: 0.6950 | val_acc: 0.5000
# Epoch 012 | loss: 0.6929 | val_loss: 0.6952 | val_acc: 0.5025
# Epoch 013 | loss: 0.6928 | val_loss: 0.6954 | val_acc: 0.5075
# Epoch 014 | loss: 0.6928 | val_loss: 0.6953 | val_acc: 0.5000
# Epoch 015 | loss: 0.6927 | val_loss: 0.6953 | val_acc: 0.5075
# Epoch 016 | loss: 0.6928 | val_loss: 0.6954 | val_acc: 0.5000
# Epoch 017 | loss: 0.6928 | val_loss: 0.6955 | val_acc: 0.5050
# Epoch 018 | loss: 0.6928 | val_loss: 0.6955 | val_acc: 0.5100
# Epoch 019 | loss: 0.6927 | val_loss: 0.6953 | val_acc: 0.5075
# Epoch 020 | loss: 0.6929 | val_loss: 0.6957 | val_acc: 0.5050
# Epoch 021 | loss: 0.6926 | val_loss: 0.6955 | val_acc: 0.5050
# Epoch 022 | loss: 0.6926 | val_loss: 0.6954 | val_acc: 0.5125
# Epoch 023 | loss: 0.6927 | val_loss: 0.6955 | val_acc: 0.5125
# Epoch 024 | loss: 0.6927 | val_loss: 0.6953 | val_acc: 0.5175
# Epoch 025 | loss: 0.6928 | val_loss: 0.6951 | val_acc: 0.5125
# Epoch 026 | loss: 0.6926 | val_loss: 0.6954 | val_acc: 0.5075
# Epoch 027 | loss: 0.6926 | val_loss: 0.6953 | val_acc: 0.5125
# Epoch 028 | loss: 0.6927 | val_loss: 0.6956 | val_acc: 0.5150
# Epoch 029 | loss: 0.6925 | val_loss: 0.6953 | val_acc: 0.5100
# Epoch 030 | loss: 0.6926 | val_loss: 0.6955 | val_acc: 0.5550
# Epoch 031 | loss: 0.6926 | val_loss: 0.6955 | val_acc: 0.5425
# Epoch 032 | loss: 0.6925 | val_loss: 0.6953 | val_acc: 0.5150
# Epoch 033 | loss: 0.6925 | val_loss: 0.6953 | val_acc: 0.5175
# Epoch 034 | loss: 0.6926 | val_loss: 0.6953 | val_acc: 0.5425
# Epoch 035 | loss: 0.6923 | val_loss: 0.6953 | val_acc: 0.5250
# Epoch 036 | loss: 0.6926 | val_loss: 0.6953 | val_acc: 0.5150
# Epoch 037 | loss: 0.6924 | val_loss: 0.6953 | val_acc: 0.5200
# Epoch 038 | loss: 0.6924 | val_loss: 0.6952 | val_acc: 0.5200
# Epoch 039 | loss: 0.6925 | val_loss: 0.6955 | val_acc: 0.5250
# Epoch 040 | loss: 0.6925 | val_loss: 0.6952 | val_acc: 0.5300
# Epoch 041 | loss: 0.6924 | val_loss: 0.6953 | val_acc: 0.5500
# Epoch 042 | loss: 0.6924 | val_loss: 0.6954 | val_acc: 0.5325
# Epoch 043 | loss: 0.6923 | val_loss: 0.6952 | val_acc: 0.5225
# Epoch 044 | loss: 0.6923 | val_loss: 0.6955 | val_acc: 0.5325
# Epoch 045 | loss: 0.6924 | val_loss: 0.6953 | val_acc: 0.5250
# Epoch 046 | loss: 0.6923 | val_loss: 0.6954 | val_acc: 0.5300
# Epoch 047 | loss: 0.6924 | val_loss: 0.6955 | val_acc: 0.5300
# Epoch 048 | loss: 0.6923 | val_loss: 0.6954 | val_acc: 0.5575
# Epoch 049 | loss: 0.6922 | val_loss: 0.6954 | val_acc: 0.5325
# Epoch 050 | loss: 0.6923 | val_loss: 0.6955 | val_acc: 0.5375
# Epoch 051 | loss: 0.6922 | val_loss: 0.6955 | val_acc: 0.5350
# Epoch 052 | loss: 0.6923 | val_loss: 0.6953 | val_acc: 0.5375
# Epoch 053 | loss: 0.6923 | val_loss: 0.6954 | val_acc: 0.5400
# Epoch 054 | loss: 0.6922 | val_loss: 0.6955 | val_acc: 0.5425
# Epoch 055 | loss: 0.6922 | val_loss: 0.6955 | val_acc: 0.5275
# Epoch 056 | loss: 0.6922 | val_loss: 0.6955 | val_acc: 0.5425
# Epoch 057 | loss: 0.6923 | val_loss: 0.6951 | val_acc: 0.5475
# Epoch 058 | loss: 0.6922 | val_loss: 0.6954 | val_acc: 0.5425
# Epoch 059 | loss: 0.6923 | val_loss: 0.6953 | val_acc: 0.5375
# Epoch 060 | loss: 0.6923 | val_loss: 0.6953 | val_acc: 0.5400
# [SINE] Acc: 0.5400 | Final train loss: 0.6923
#
# ------------------------------------------------------------
# Training with SIGMOID activation...
# Epoch 001 | loss: 0.6979 | val_loss: 0.6925 | val_acc: 0.5125
# Epoch 002 | loss: 0.6958 | val_loss: 0.6920 | val_acc: 0.5100
# Epoch 003 | loss: 0.6950 | val_loss: 0.6920 | val_acc: 0.4925
# Epoch 004 | loss: 0.6947 | val_loss: 0.6920 | val_acc: 0.5025
# Epoch 005 | loss: 0.6943 | val_loss: 0.6921 | val_acc: 0.5100
# Epoch 006 | loss: 0.6940 | val_loss: 0.6921 | val_acc: 0.4975
# Epoch 007 | loss: 0.6940 | val_loss: 0.6922 | val_acc: 0.4950
# Epoch 008 | loss: 0.6935 | val_loss: 0.6923 | val_acc: 0.4900
# Epoch 009 | loss: 0.6935 | val_loss: 0.6925 | val_acc: 0.5025
# Epoch 010 | loss: 0.6932 | val_loss: 0.6926 | val_acc: 0.5225
# Epoch 011 | loss: 0.6931 | val_loss: 0.6927 | val_acc: 0.5175
# Epoch 012 | loss: 0.6931 | val_loss: 0.6928 | val_acc: 0.5000
# Epoch 013 | loss: 0.6930 | val_loss: 0.6929 | val_acc: 0.5175
# Epoch 014 | loss: 0.6928 | val_loss: 0.6930 | val_acc: 0.5000
# Epoch 015 | loss: 0.6928 | val_loss: 0.6931 | val_acc: 0.4875
# Epoch 016 | loss: 0.6928 | val_loss: 0.6932 | val_acc: 0.5075
# Epoch 017 | loss: 0.6927 | val_loss: 0.6933 | val_acc: 0.5075
# Epoch 018 | loss: 0.6928 | val_loss: 0.6934 | val_acc: 0.5100
# Epoch 019 | loss: 0.6927 | val_loss: 0.6934 | val_acc: 0.5125
# Epoch 020 | loss: 0.6927 | val_loss: 0.6936 | val_acc: 0.5050
# Epoch 021 | loss: 0.6926 | val_loss: 0.6936 | val_acc: 0.5050
# Epoch 022 | loss: 0.6926 | val_loss: 0.6937 | val_acc: 0.5025
# Epoch 023 | loss: 0.6926 | val_loss: 0.6937 | val_acc: 0.5100
# Epoch 024 | loss: 0.6927 | val_loss: 0.6937 | val_acc: 0.5150
# Epoch 025 | loss: 0.6928 | val_loss: 0.6937 | val_acc: 0.5150
# Epoch 026 | loss: 0.6927 | val_loss: 0.6938 | val_acc: 0.5025
# Epoch 027 | loss: 0.6926 | val_loss: 0.6938 | val_acc: 0.4950
# Epoch 028 | loss: 0.6927 | val_loss: 0.6939 | val_acc: 0.5075
# Epoch 029 | loss: 0.6926 | val_loss: 0.6939 | val_acc: 0.5000
# Epoch 030 | loss: 0.6926 | val_loss: 0.6940 | val_acc: 0.5100
# Epoch 031 | loss: 0.6926 | val_loss: 0.6941 | val_acc: 0.5125
# Epoch 032 | loss: 0.6925 | val_loss: 0.6940 | val_acc: 0.4950
# Epoch 033 | loss: 0.6925 | val_loss: 0.6940 | val_acc: 0.4950
# Epoch 034 | loss: 0.6926 | val_loss: 0.6940 | val_acc: 0.4975
# Epoch 035 | loss: 0.6925 | val_loss: 0.6940 | val_acc: 0.4975
# Epoch 036 | loss: 0.6926 | val_loss: 0.6940 | val_acc: 0.5025
# Epoch 037 | loss: 0.6926 | val_loss: 0.6941 | val_acc: 0.4725
# Epoch 038 | loss: 0.6926 | val_loss: 0.6941 | val_acc: 0.5000
# Epoch 039 | loss: 0.6926 | val_loss: 0.6941 | val_acc: 0.5000
# Epoch 040 | loss: 0.6927 | val_loss: 0.6941 | val_acc: 0.4975
# Epoch 041 | loss: 0.6925 | val_loss: 0.6941 | val_acc: 0.4900
# Epoch 042 | loss: 0.6925 | val_loss: 0.6941 | val_acc: 0.4950
# Epoch 043 | loss: 0.6925 | val_loss: 0.6941 | val_acc: 0.4775
# Epoch 044 | loss: 0.6925 | val_loss: 0.6942 | val_acc: 0.4800
# Epoch 045 | loss: 0.6926 | val_loss: 0.6941 | val_acc: 0.4925
# Epoch 046 | loss: 0.6925 | val_loss: 0.6941 | val_acc: 0.4900
# Epoch 047 | loss: 0.6925 | val_loss: 0.6942 | val_acc: 0.4975
# Epoch 048 | loss: 0.6925 | val_loss: 0.6942 | val_acc: 0.4975
# Epoch 049 | loss: 0.6925 | val_loss: 0.6942 | val_acc: 0.4850
# Epoch 050 | loss: 0.6925 | val_loss: 0.6942 | val_acc: 0.4875
# Epoch 051 | loss: 0.6925 | val_loss: 0.6942 | val_acc: 0.4900
# Epoch 052 | loss: 0.6926 | val_loss: 0.6942 | val_acc: 0.4925
# Epoch 053 | loss: 0.6926 | val_loss: 0.6942 | val_acc: 0.4925
# Epoch 054 | loss: 0.6925 | val_loss: 0.6942 | val_acc: 0.4825
# Epoch 055 | loss: 0.6925 | val_loss: 0.6942 | val_acc: 0.4675
# Epoch 056 | loss: 0.6926 | val_loss: 0.6942 | val_acc: 0.4875
# Epoch 057 | loss: 0.6927 | val_loss: 0.6942 | val_acc: 0.5050
# Epoch 058 | loss: 0.6925 | val_loss: 0.6942 | val_acc: 0.4825
# Epoch 059 | loss: 0.6926 | val_loss: 0.6942 | val_acc: 0.4775
# Epoch 060 | loss: 0.6926 | val_loss: 0.6942 | val_acc: 0.4800
# [SIGMOID] Acc: 0.4800 | Final train loss: 0.6926
#
# ------------------------------------------------------------
# Training with TANH activation...
# Epoch 001 | loss: 0.6946 | val_loss: 0.6939 | val_acc: 0.6150
# Epoch 002 | loss: 0.6928 | val_loss: 0.6926 | val_acc: 0.5800
# Epoch 003 | loss: 0.6917 | val_loss: 0.6923 | val_acc: 0.5900
# Epoch 004 | loss: 0.6914 | val_loss: 0.6919 | val_acc: 0.5725
# Epoch 005 | loss: 0.6910 | val_loss: 0.6918 | val_acc: 0.5425
# Epoch 006 | loss: 0.6910 | val_loss: 0.6917 | val_acc: 0.5125
# Epoch 007 | loss: 0.6909 | val_loss: 0.6919 | val_acc: 0.5200
# Epoch 008 | loss: 0.6907 | val_loss: 0.6918 | val_acc: 0.5150
# Epoch 009 | loss: 0.6907 | val_loss: 0.6920 | val_acc: 0.5050
# Epoch 010 | loss: 0.6905 | val_loss: 0.6921 | val_acc: 0.5125
# Epoch 011 | loss: 0.6904 | val_loss: 0.6918 | val_acc: 0.5025
# Epoch 012 | loss: 0.6904 | val_loss: 0.6918 | val_acc: 0.5175
# Epoch 013 | loss: 0.6902 | val_loss: 0.6919 | val_acc: 0.5125
# Epoch 014 | loss: 0.6901 | val_loss: 0.6916 | val_acc: 0.5175
# Epoch 015 | loss: 0.6900 | val_loss: 0.6915 | val_acc: 0.5025
# Epoch 016 | loss: 0.6900 | val_loss: 0.6915 | val_acc: 0.5225
# Epoch 017 | loss: 0.6899 | val_loss: 0.6916 | val_acc: 0.5250
# Epoch 018 | loss: 0.6898 | val_loss: 0.6915 | val_acc: 0.5050
# Epoch 019 | loss: 0.6896 | val_loss: 0.6912 | val_acc: 0.5050
# Epoch 020 | loss: 0.6897 | val_loss: 0.6915 | val_acc: 0.5300
# Epoch 021 | loss: 0.6894 | val_loss: 0.6913 | val_acc: 0.5200
# Epoch 022 | loss: 0.6893 | val_loss: 0.6911 | val_acc: 0.5225
# Epoch 023 | loss: 0.6894 | val_loss: 0.6912 | val_acc: 0.5325
# Epoch 024 | loss: 0.6892 | val_loss: 0.6908 | val_acc: 0.5100
# Epoch 025 | loss: 0.6892 | val_loss: 0.6906 | val_acc: 0.5125
# Epoch 026 | loss: 0.6889 | val_loss: 0.6908 | val_acc: 0.5325
# Epoch 027 | loss: 0.6888 | val_loss: 0.6906 | val_acc: 0.5275
# Epoch 028 | loss: 0.6888 | val_loss: 0.6908 | val_acc: 0.5325
# Epoch 029 | loss: 0.6885 | val_loss: 0.6903 | val_acc: 0.5325
# Epoch 030 | loss: 0.6885 | val_loss: 0.6905 | val_acc: 0.5200
# Epoch 031 | loss: 0.6883 | val_loss: 0.6904 | val_acc: 0.5225
# Epoch 032 | loss: 0.6882 | val_loss: 0.6900 | val_acc: 0.5300
# Epoch 033 | loss: 0.6880 | val_loss: 0.6900 | val_acc: 0.5375
# Epoch 034 | loss: 0.6879 | val_loss: 0.6899 | val_acc: 0.5225
# Epoch 035 | loss: 0.6876 | val_loss: 0.6898 | val_acc: 0.5275
# Epoch 036 | loss: 0.6877 | val_loss: 0.6895 | val_acc: 0.5375
# Epoch 037 | loss: 0.6874 | val_loss: 0.6895 | val_acc: 0.5375
# Epoch 038 | loss: 0.6873 | val_loss: 0.6892 | val_acc: 0.5325
# Epoch 039 | loss: 0.6872 | val_loss: 0.6893 | val_acc: 0.5400
# Epoch 040 | loss: 0.6871 | val_loss: 0.6890 | val_acc: 0.5250
# Epoch 041 | loss: 0.6868 | val_loss: 0.6890 | val_acc: 0.5375
# Epoch 042 | loss: 0.6866 | val_loss: 0.6889 | val_acc: 0.5275
# Epoch 043 | loss: 0.6864 | val_loss: 0.6885 | val_acc: 0.5425
# Epoch 044 | loss: 0.6862 | val_loss: 0.6887 | val_acc: 0.5325
# Epoch 045 | loss: 0.6861 | val_loss: 0.6883 | val_acc: 0.5275
# Epoch 046 | loss: 0.6858 | val_loss: 0.6883 | val_acc: 0.5425
# Epoch 047 | loss: 0.6858 | val_loss: 0.6881 | val_acc: 0.5300
# Epoch 048 | loss: 0.6855 | val_loss: 0.6880 | val_acc: 0.5325
# Epoch 049 | loss: 0.6853 | val_loss: 0.6878 | val_acc: 0.5425
# Epoch 050 | loss: 0.6852 | val_loss: 0.6876 | val_acc: 0.5425
# Epoch 051 | loss: 0.6849 | val_loss: 0.6875 | val_acc: 0.5375
# Epoch 052 | loss: 0.6847 | val_loss: 0.6870 | val_acc: 0.5225
# Epoch 053 | loss: 0.6846 | val_loss: 0.6871 | val_acc: 0.5450
# Epoch 054 | loss: 0.6842 | val_loss: 0.6869 | val_acc: 0.5550
# Epoch 055 | loss: 0.6840 | val_loss: 0.6867 | val_acc: 0.5525
# Epoch 056 | loss: 0.6838 | val_loss: 0.6864 | val_acc: 0.5450
# Epoch 057 | loss: 0.6837 | val_loss: 0.6859 | val_acc: 0.5150
# Epoch 058 | loss: 0.6834 | val_loss: 0.6860 | val_acc: 0.5475
# Epoch 059 | loss: 0.6833 | val_loss: 0.6855 | val_acc: 0.5350
# Epoch 060 | loss: 0.6830 | val_loss: 0.6854 | val_acc: 0.5350
# [TANH] Acc: 0.5350 | Final train loss: 0.6830
#
# ============================================================
# FINAL RESULTS COMPARISON
# ============================================================
# Rank   Activation      Accuracy     Final Train Loss
# ------------------------------------------------------------
# 1      LASA            0.7100       0.4896
# 2      RELU            0.6325       0.6688
# 3      SWISH           0.5500       0.6922
# 4      MISH            0.5475       0.6922
# 5      SINE            0.5400       0.6923
# 6      TANH            0.5350       0.6830
# 7      GELU            0.5325       0.6922
# 8      LEAKY_RELU      0.5275       0.6797
# 9      ELU             0.5200       0.6912
# 10     SIGMOID         0.4800       0.6926
# 11     SOFTPLUS        0.4700       0.6927
# ============================================================
