# %%
pip install mlxtend
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mlxtend
#   Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 12.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pandas>=0.24.2 in /usr/lib/python3/dist-packages (from mlxtend) (1.3.5)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/lib/python3/dist-packages (from mlxtend) (3.5.1)
# Collecting scikit-learn>=1.3.1
#   Downloading scikit_learn-1.7.2-cp310-cp310-manylinux_2_27_aarch64.manylinux_2_28_aarch64.whl (9.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 6.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: scipy>=1.2.1 in /usr/lib/python3/dist-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: numpy>=1.16.2 in /usr/lib/python3/dist-packages (from mlxtend) (1.21.5)
# Requirement already satisfied: joblib>=0.13.2 in /usr/lib/python3/dist-packages (from mlxtend) (0.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/lib/python3/dist-packages (from scikit-learn>=1.3.1->mlxtend) (3.1.0)
# Collecting numpy>=1.16.2
#   Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (14.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 8.9 MB/s eta 0:00:0000:0100:01
# Collecting joblib>=0.13.2
#   Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 308.4/308.4 KB 103.0 MB/s eta 0:00:00
# Installing collected packages: numpy, joblib, scikit-learn, mlxtend
# Successfully installed joblib-1.5.2 mlxtend-0.23.4 numpy-2.2.6 scikit-learn-1.7.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import os, math, warnings
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from mlxtend.plotting import plot_decision_regions


warnings.filterwarnings('ignore')
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from IPython.display import display, HTML
display(HTML("<style>.output_scroll {height:auto !important; max-height:none !important;}</style>"))

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)
os.environ['PYTHONHASHSEED'] = str(RANDOM_SEED)

print("="*60)
print("GPU CONFIGURATION")
print("="*60)
gpus = tf.config.list_physical_devices('GPU')
USE_GPU = bool(gpus)
if USE_GPU:
    print(f"GPUs available: {len(gpus)}")
    for gpu in gpus:
        print("  -", gpu)
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU memory growth enabled")
    except RuntimeError as e:
        print(e)
else:
    print("No GPUs available, using CPU")

policy_name = 'mixed_float16' if USE_GPU else 'float32'
tf.keras.mixed_precision.set_global_policy(policy_name)
print(f"Mixed precision policy: {tf.keras.mixed_precision.global_policy().name}")
print("="*60 + "\n")

USE_XLA = USE_GPU


def inv_softplus(y):
    y = np.maximum(float(y), 1e-6)
    return np.log(np.expm1(y))


def generate_vortex(n_samples=1000, random_state=42):
    np.random.seed(random_state)
    t = np.random.uniform(0, 4*np.pi, n_samples)
    r = np.exp(-0.1 * t)
    X = np.column_stack((r * np.cos(t), r * np.sin(t)))
    y = np.where(np.sin(4*t) > 0, 0, 1)
    return X.astype(np.float32), y.astype(np.int32)


class LASAActivation(tf.keras.layers.Layer):
    def __init__(self, theta_degrees=45.0, lambda_window=3e-4,
                 penalty_mode='hinge', hybrid_alpha=0.1,
                 enforce_gain_cap=False, gain_cap=1.25,
                 initial_frequency=1.6, name=None, **kwargs):
        super().__init__(name=name, **kwargs)
        self.theta_degrees     = float(theta_degrees)
        self.lambda_window     = float(lambda_window)
        self.penalty_mode      = str(penalty_mode)
        self.hybrid_alpha      = float(hybrid_alpha)
        self.enforce_gain_cap  = bool(enforce_gain_cap)
        self.gain_cap          = float(gain_cap)
        self.initial_frequency = float(initial_frequency)

    def build(self, input_shape):
        self.theta_rad = tf.constant(self.theta_degrees * math.pi/180.0, dtype=tf.float32)
        self.sin_theta = tf.sin(self.theta_rad)

        self.penalty_scale = self.add_weight(
            shape=(), name='penalty_scale', dtype=tf.float32, trainable=False,
            initializer=tf.keras.initializers.Constant(1.0)
        )

        if self.enforce_gain_cap:
            denom   = tf.maximum(self.sin_theta, tf.constant(1e-6, tf.float32))
            k_max_v = float(self.gain_cap) / float(denom.numpy())
            self.k_max = tf.constant(k_max_v, dtype=tf.float32)
            ratio = np.clip(self.initial_frequency / k_max_v, 1e-6, 1.0-1e-6)
            rho0  = np.log(ratio/(1.0 - ratio))
        else:
            self.k_max = None
            rho0 = inv_softplus(self.initial_frequency)

        self.rho = self.add_weight(shape=(), name='rho', dtype=tf.float32, trainable=True,
                                   initializer=tf.keras.initializers.Constant(float(rho0)))

    @property
    def tau_value(self):
        if self.enforce_gain_cap:
            return self.k_max * tf.nn.sigmoid(self.rho)
        return tf.nn.softplus(self.rho)

    def set_penalty_scale(self, scale):
        self.penalty_scale.assign(tf.cast(scale, tf.float32))

    def scale_down_penalty(self, factor=0.8, min_scale=0.05):
        new_scale = tf.maximum(self.penalty_scale * tf.cast(factor, tf.float32),
                               tf.constant(min_scale, tf.float32))
        self.penalty_scale.assign(new_scale)

    def _penalty(self, inputs, tau32):
        if self.lambda_window <= 0.0:
            return None
        x32     = tf.cast(inputs, tf.float32)
        cos_phi = tf.math.cos(tau32 * x32)
        abs_cos = tf.abs(cos_phi)

        if self.penalty_mode == 'hinge':
            margin = self.sin_theta
            viol   = tf.maximum(abs_cos - margin, 0.0)
            pen    = tf.reduce_mean(tf.square(viol))
        elif self.penalty_mode == 'cos2':
            pen    = tf.reduce_mean(tf.square(cos_phi))
        elif self.penalty_mode == 'hybrid':
            margin = self.sin_theta
            viol   = tf.maximum(abs_cos - margin, 0.0)
            hinge  = tf.reduce_mean(tf.square(viol))
            cos2   = tf.reduce_mean(tf.square(cos_phi))
            pen    = self.hybrid_alpha * cos2 + hinge
        else:
            raise ValueError("penalty_mode must be 'hinge', 'cos2', or 'hybrid'.")

        lw32    = tf.cast(self.lambda_window, tf.float32)
        scale32 = tf.cast(self.penalty_scale, tf.float32)
        return lw32 * scale32 * pen

    def call(self, inputs):
        tau32 = tf.cast(self.tau_value, tf.float32)
        pen = self._penalty(inputs, tau32)
        if pen is not None:
            self.add_loss(pen)
        x32 = tf.cast(inputs, tf.float32)
        y32 = tf.math.sin(tau32 * x32)
        return tf.cast(y32, inputs.dtype)


class SwishActivation(tf.keras.layers.Layer):
    def call(self, inputs):
        x = tf.cast(inputs, tf.float32)
        y = x * tf.nn.sigmoid(x)
        return tf.cast(y, inputs.dtype)

class MishActivation(tf.keras.layers.Layer):
    def call(self, inputs):
        x = tf.cast(inputs, tf.float32)
        y = x * tf.math.tanh(tf.math.softplus(x))
        return tf.cast(y, inputs.dtype)


def create_model(activation_type,
                 hidden_units=[6],
                 initial_frequency=1.6,
                 theta_degrees=45.0, lambda_window=3e-4,
                 penalty_mode='hinge', hybrid_alpha=0.1,
                 enforce_gain_cap=False, gain_cap=1.25):
    with tf.device('/GPU:0' if USE_GPU else '/CPU:0'):
        model = tf.keras.Sequential([tf.keras.layers.Input(shape=(2,))])
        for i, units in enumerate(hidden_units):
            model.add(tf.keras.layers.Dense(units, name=f'dense_{i}'))
            a = activation_type.lower()
            if a == 'lasa':
                model.add(LASAActivation(
                    theta_degrees=theta_degrees,
                    lambda_window=lambda_window,
                    penalty_mode=penalty_mode, hybrid_alpha=hybrid_alpha,
                    enforce_gain_cap=enforce_gain_cap, gain_cap=gain_cap,
                    initial_frequency=initial_frequency,
                    name=f'lasa_{i}'
                ))
            elif a == 'relu':
                model.add(tf.keras.layers.ReLU(name=f'relu_{i}'))
            elif a == 'leaky_relu':
                model.add(tf.keras.layers.LeakyReLU(alpha=0.01, name=f'leaky_relu_{i}'))
            elif a == 'elu':
                model.add(tf.keras.layers.ELU(alpha=1.0, name=f'elu_{i}'))
            elif a == 'softplus':
                model.add(tf.keras.layers.Activation('softplus', name=f'softplus_{i}'))
            elif a == 'swish':
                model.add(SwishActivation(name=f'swish_{i}'))
            elif a == 'mish':
                model.add(MishActivation(name=f'mish_{i}'))
            elif a == 'gelu':
                model.add(tf.keras.layers.Lambda(lambda z: tf.nn.gelu(z), name=f'gelu_{i}'))
            elif a == 'sine':
                model.add(tf.keras.layers.Lambda(lambda z: tf.math.sin(z), name=f'sine_{i}'))
            elif a == 'sigmoid':
                model.add(tf.keras.layers.Activation('sigmoid', name=f'sigmoid_{i}'))
            elif a == 'tanh':
                model.add(tf.keras.layers.Activation('tanh', name=f'tanh_{i}'))
            else:
                raise ValueError(f"Unknown activation_type: {activation_type}")

        model.add(tf.keras.layers.Dense(1, activation='sigmoid', dtype='float32', name='output'))
    return model


class LASATrainer:
    def __init__(self, model,
                 lr_main=1e-3, lr_tau=1e-2,
                 clipnorm_main=1.0, clipnorm_tau=0.5,
                 penalty_warmup_epochs=8,
                 acc_eps=2.5e-3, loss_eps=1e-4,
                 reverse_tau_grads=True, revert_rho_to_snapshot=True,
                 shrink_tau_lr=True, tau_lr_decay=0.5, min_tau_lr=1e-5,
                 shrink_penalty=True, penalty_decay=0.8, min_penalty_scale=0.05,
                 stagnation_window=10, improve_threshold=0.05,
                 bump_delta_k=1.0, min_epochs_between_bumps=10,
                 acc_drop_threshold=0.02):
        self.model = model
        self.loss_fn = tf.keras.losses.BinaryCrossentropy()
        self.optimizer_main = tf.keras.optimizers.Adam(learning_rate=lr_main, clipnorm=clipnorm_main)
        self.optimizer_tau  = tf.keras.optimizers.Adam(learning_rate=lr_tau,  clipnorm=clipnorm_tau)
        self.penalty_warmup_epochs = int(penalty_warmup_epochs)

        self.acc_eps = float(acc_eps)
        self.loss_eps = float(loss_eps)
        self.reverse_tau_grads = bool(reverse_tau_grads)
        self.revert_rho_to_snapshot = bool(revert_rho_to_snapshot)
        self.shrink_tau_lr = bool(shrink_tau_lr)
        self.tau_lr_decay = float(tau_lr_decay)
        self.min_tau_lr = float(min_tau_lr)
        self.shrink_penalty = bool(shrink_penalty)
        self.penalty_decay = float(penalty_decay)
        self.min_penalty_scale = float(min_penalty_scale)

        self.stagnation_window = int(stagnation_window)
        self.improve_threshold = float(improve_threshold)
        self.bump_delta_k = float(bump_delta_k)
        self.min_epochs_between_bumps = int(min_epochs_between_bumps)

        self.acc_drop_threshold = float(acc_drop_threshold)

        self._partition_ready = False
        self.tau_idx, self.other_idx = [], []
        self._best_val_acc  = -np.inf
        self._best_val_loss =  np.inf
        self.val_acc_hist   = []
        self._last_bump_epoch = -10**9
        self.tau_grad_dir = tf.Variable(1.0, trainable=False, dtype=tf.float32)

        self.pending_bump = False
        self.bump_pre_val_acc = None
        self.rho_bump_snapshot = None
        self.bump_reverted_once = False
        self.final_bump_to_apply = False
        self.final_bump_applied = False
        self.disable_future_bumps = False
        self.no_revert_mode = False

    def _build_and_partition(self, sample_x):
        _ = self.model(sample_x)
        self.tau_idx, self.other_idx = [], []
        for i, v in enumerate(self.model.trainable_variables):
            if '/rho:' in v.name: self.tau_idx.append(i)
            else: self.other_idx.append(i)
        self._partition_ready = True

    def _set_penalty_scale(self, epoch_idx):
        scale = 1.0 if self.penalty_warmup_epochs <= 0 else min(1.0, (epoch_idx + 1) / self.penalty_warmup_epochs)
        for layer in self.model.layers:
            if isinstance(layer, LASAActivation):
                layer.set_penalty_scale(scale)

    def _decay_penalty_scale(self):
        if not self.shrink_penalty: return
        for layer in self.model.layers:
            if isinstance(layer, LASAActivation):
                layer.scale_down_penalty(self.penalty_decay, self.min_penalty_scale)

    def _snapshot_rho(self):
        return [self.model.trainable_variables[i].numpy().copy() for i in self.tau_idx]

    def _restore_rho(self, snap):
        for val, i in zip(snap, self.tau_idx):
            self.model.trainable_variables[i].assign(val)

    def _reset_tau_optimizer(self, new_lr):
        self.optimizer_tau = tf.keras.optimizers.Adam(learning_rate=new_lr, clipnorm=self.optimizer_tau.clipnorm)

    def _bump_all_k(self, delta):
        for layer in self.model.layers:
            if isinstance(layer, LASAActivation):
                k0 = float(layer.tau_value.numpy())
                if layer.enforce_gain_cap:
                    kmax = float(layer.k_max.numpy())
                    k1 = min(kmax * 0.999, k0 + float(delta))
                    ratio = np.clip(k1 / kmax, 1e-6, 1.0-1e-6)
                    rho_new = np.log(ratio/(1.0 - ratio))
                else:
                    k1 = max(0.0, k0 + float(delta))
                    rho_new = inv_softplus(k1)
                layer.rho.assign(np.float32(rho_new))

    def _current_k_values(self):
        ks = []
        for layer in self.model.layers:
            if isinstance(layer, LASAActivation):
                ks.append(float(layer.tau_value.numpy()))
        return ks

    @tf.function(jit_compile=USE_XLA)
    def _train_step(self, x_batch, y_batch):
        with tf.GradientTape() as tape:
            preds = self.model(x_batch, training=True)
            yb = tf.reshape(y_batch, (-1, 1))
            main_loss = self.loss_fn(yb, preds)
            reg_losses = tf.add_n(self.model.losses) if self.model.losses else tf.constant(0.0, dtype=main_loss.dtype)
            loss = main_loss + reg_losses
        grads = tape.gradient(loss, self.model.trainable_variables)

        tau_pairs = []
        for i in self.tau_idx:
            g = grads[i]; v = self.model.trainable_variables[i]
            if g is not None:
                g = tf.cast(g, tf.float32) * self.tau_grad_dir
                tau_pairs.append((g, v))
        other_pairs = []
        for i in self.other_idx:
            g = grads[i]; v = self.model.trainable_variables[i]
            if g is not None:
                other_pairs.append((g, v))

        if tau_pairs:   self.optimizer_tau.apply_gradients(tau_pairs)
        if other_pairs: self.optimizer_main.apply_gradients(other_pairs)

        return main_loss

    def _val_metrics(self, X_val, y_val):
        preds = self.model(X_val, training=False)
        yb = tf.reshape(y_val, (-1, 1))
        val_loss = float(self.loss_fn(yb, preds).numpy())
        y_pred = (preds.numpy() > 0.5).astype(int).flatten()
        val_acc = float(np.mean(y_pred == y_val.numpy()))
        return val_loss, val_acc

    def train(self, X_train, y_train, X_val, y_val, epochs=40, batch_size=32, verbose=True):
        X_train = tf.constant(X_train, dtype=tf.float32)
        y_train = tf.constant(y_train, dtype=tf.float32)
        X_val   = tf.constant(X_val,   dtype=tf.float32)
        y_val   = tf.constant(y_val,   dtype=tf.float32)

        if not self._partition_ready:
            self._build_and_partition(X_train[:1])

        ds = (tf.data.Dataset.from_tensor_slices((X_train, y_train))
              .shuffle(4096).batch(batch_size).prefetch(tf.data.AUTOTUNE))

        history = {'loss': [], 'val_accuracy': [], 'val_loss': [], 'k': []}

        for epoch in range(epochs):
            self._set_penalty_scale(epoch)

            if self.final_bump_to_apply and not self.final_bump_applied:
                self._bump_all_k(self.bump_delta_k)
                self.final_bump_applied = True
                self.final_bump_to_apply = False
                self.disable_future_bumps = True
                self.no_revert_mode = True

            rho_snap_epoch = self._snapshot_rho()

            total_loss = 0.0
            nb = 0
            for xb, yb in ds:
                main_l = self._train_step(xb, yb)
                total_loss += float(main_l.numpy())
                nb += 1

            avg_loss = total_loss / max(nb, 1)
            val_loss, val_acc = self._val_metrics(X_val, y_val)

            if self.pending_bump and not self.final_bump_applied:
                if self.bump_pre_val_acc is not None:
                    drop = self.bump_pre_val_acc - val_acc
                    if drop > self.acc_drop_threshold and not self.bump_reverted_once:
                        self._restore_rho(self.rho_bump_snapshot)
                        self.bump_reverted_once = True
                        self.pending_bump = False
                        self.final_bump_to_apply = True
                        val_loss, val_acc = self._val_metrics(X_val, y_val)
                if self.pending_bump:
                    self.pending_bump = False

            worse_acc  = (val_acc  < self._best_val_acc  - self.acc_eps)
            worse_loss = (val_loss > self._best_val_loss + self.loss_eps)
            if (worse_acc or worse_loss):
                if self.revert_rho_to_snapshot and not self.no_revert_mode:
                    self._restore_rho(rho_snap_epoch)
                if self.reverse_tau_grads:
                    self.tau_grad_dir.assign(-self.tau_grad_dir)
                if self.shrink_tau_lr:
                    new_lr = max(self.min_tau_lr, float(self.optimizer_tau.learning_rate.numpy()) * self.tau_lr_decay)
                    self._reset_tau_optimizer(new_lr)
                if self.shrink_penalty:
                    self._decay_penalty_scale()
                val_loss, val_acc = self._val_metrics(X_val, y_val)

            ep = epoch + 1
            self.val_acc_hist.append(val_acc)
            can_try_bump = (not self.disable_future_bumps) and (not self.final_bump_applied)
            if can_try_bump and ep >= self.stagnation_window and (ep - self._last_bump_epoch) >= self.min_epochs_between_bumps:
                acc_then = self.val_acc_hist[-self.stagnation_window]
                improve  = val_acc - acc_then
                if improve < self.improve_threshold:
                    self.rho_bump_snapshot = self._snapshot_rho()
                    self.bump_pre_val_acc  = val_acc
                    self._bump_all_k(self.bump_delta_k)
                    self.pending_bump = True
                    self._last_bump_epoch = ep

            self._best_val_acc  = max(self._best_val_acc,  val_acc)
            self._best_val_loss = min(self._best_val_loss, val_loss)

            history['k'].append(self._current_k_values())

            history['loss'].append(avg_loss)
            history['val_accuracy'].append(val_acc)
            history['val_loss'].append(val_loss)

            if verbose:
                print(f"Epoch {epoch+1:03d} | loss: {avg_loss:.4f} | val_loss: {val_loss:.4f} | val_acc: {val_acc:.4f}")
        return history


class RegularTrainer:
    def __init__(self, model, lr=1e-3, clipnorm=1.0):
        self.model = model
        self.loss_fn = tf.keras.losses.BinaryCrossentropy()
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=lr, clipnorm=clipnorm)

    @tf.function(jit_compile=USE_XLA)
    def _train_step(self, x_batch, y_batch):
        with tf.GradientTape() as tape:
            preds = self.model(x_batch, training=True)
            yb = tf.reshape(y_batch, (-1, 1))
            loss = self.loss_fn(yb, preds)
        grads = tape.gradient(loss, self.model.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.model.trainable_variables))
        return loss

    def _val_metrics(self, X_val, y_val):
        preds = self.model(X_val, training=False)
        yb = tf.reshape(y_val, (-1, 1))
        val_loss = float(self.loss_fn(yb, preds).numpy())
        y_pred = (preds.numpy() > 0.5).astype(int).flatten()
        val_acc = float(np.mean(y_pred == y_val.numpy()))
        return val_loss, val_acc

    def train(self, X_train, y_train, X_val, y_val, epochs=40, batch_size=32, verbose=True):
        X_train = tf.constant(X_train, dtype=tf.float32)
        y_train = tf.constant(y_train, dtype=tf.float32)
        X_val   = tf.constant(X_val,   dtype=tf.float32)
        y_val   = tf.constant(y_val,   dtype=tf.float32)

        ds = (tf.data.Dataset.from_tensor_slices((X_train, y_train))
              .shuffle(4096).batch(batch_size).prefetch(tf.data.AUTOTUNE))

        history = {'loss': [], 'val_accuracy': [], 'val_loss': []}

        for epoch in range(epochs):
            total_loss = 0.0; nb = 0
            for xb, yb in ds:
                main_l = self._train_step(xb, yb)
                total_loss += float(main_l.numpy()); nb += 1

            avg_loss = total_loss / max(nb, 1)
            val_loss, val_acc = self._val_metrics(X_val, y_val)

            history['loss'].append(avg_loss)
            history['val_accuracy'].append(val_acc)
            history['val_loss'].append(val_loss)

            if verbose:
                print(f"Epoch {epoch+1:03d} | loss: {avg_loss:.4f} | val_loss: {val_loss:.4f} | val_acc: {val_acc:.4f}")
        return history


def plot_all_decision_boundaries(models, results, X_test, y_test):
    class Wrapper:
        def __init__(self, model): self.model = model
        def predict(self, X):
            X_tensor = tf.constant(X, dtype=tf.float32)
            preds = self.model(X_tensor)
            return (preds.numpy() > 0.5).astype(int).flatten()

    names = list(models.keys())
    n = len(names); cols = 4; rows = int(np.ceil(n / cols))
    fig, axes = plt.subplots(rows, cols, figsize=(4.6*cols, 4.2*rows))
    axes = np.array(axes).reshape(rows, cols)

    for idx, name in enumerate(names):
        r, c = divmod(idx, cols); ax = axes[r, c]
        wrapper = Wrapper(models[name])
        plot_decision_regions(X=X_test, y=y_test, clf=wrapper, ax=ax, legend=0)
        acc = results[name]['accuracy']
        ax.set_title(f"{name.upper()}  Acc: {acc:.4f}", fontsize=11, fontweight='bold')
        ax.set_xlabel('x1'); ax.set_ylabel('x2'); ax.grid(True, alpha=0.3)

    for idx in range(n, rows*cols):
        r, c = divmod(idx, cols)
        fig.delaxes(axes[r, c])

    plt.suptitle('Decision Boundaries Comparison (Vortex Dataset)', fontsize=15, fontweight='bold')
    plt.tight_layout(); plt.show()

def plot_training_curves_comparison(results):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
    for name, data in results.items():
        ax1.plot(data['history']['loss'], label=f"{name}")
        ax1.plot(data['history']['val_loss'], linestyle='--', alpha=0.7, label=f"{name} (val)")
        ax2.plot(data['history']['val_accuracy'], label=f"{name}")
    ax1.set_title('Training & Validation Loss'); ax1.set_xlabel('Epoch'); ax1.set_ylabel('Loss'); ax1.grid(True); ax1.legend(ncol=2, fontsize=8)
    ax2.set_title('Validation Accuracy'); ax2.set_xlabel('Epoch'); ax2.set_ylabel('Accuracy'); ax2.grid(True); ax2.legend(ncol=2, fontsize=8)
    plt.tight_layout(); plt.show()

def print_comparison_table(results):
    print("\n" + "="*60)
    print("FINAL RESULTS COMPARISON")
    print("="*60)
    print(f"{'Rank':<6} {'Activation':<15} {'Accuracy':<12} {'Final Train Loss':<18}")
    print("-"*60)
    sorted_items = sorted(results.items(), key=lambda kv: kv[1]['accuracy'], reverse=True)
    for rank, (name, data) in enumerate(sorted_items, 1):
        print(f"{rank:<6} {name.upper():<15} {data['accuracy']:<12.4f} {data['final_loss']:<18.4f}")
    print("="*60)

def plot_k_evolution(results, model_key='lasa', title_suffix="Vortex Dataset"):
    if model_key not in results:
        print(f"[plot_k_evolution] '{model_key}' not in results."); return
    hist = results[model_key]['history']
    if 'k' not in hist or len(hist['k']) == 0:
        print("[plot_k_evolution] No k history found."); return

    K = np.array([np.array(ks, dtype=float) for ks in hist['k']], dtype=object)
    try:
        K = np.stack(K).astype(float)
    except Exception:
        print("[plot_k_evolution] Ragged k history; cannot plot."); return

    plt.figure(figsize=(7, 4))
    for j in range(K.shape[1]):
        plt.plot(K[:, j], label=f'k[{j}]')
    plt.title(f'k evolution per LASA layer ({title_suffix})')
    plt.xlabel('Epoch'); plt.ylabel('k'); plt.grid(True, alpha=0.3)
    plt.legend(ncol=2)
    plt.tight_layout(); plt.show()


def run_all_activations_comparison_vortex(hidden_units=[6],
                                         n_samples=1000,
                                         test_size=0.2, random_state=42,
                                         epochs=40, batch_size=32,
                                         lr_main=1e-3,
                                         lr_tau=1e-2,
                                         initial_frequency=1.6,
                                         theta_degrees=45.0, lambda_window=3e-4,
                                         penalty_mode='hinge', hybrid_alpha=0.1,
                                         enforce_gain_cap=False, gain_cap=1.25,
                                         penalty_warmup_epochs=8,
                                         acc_eps=2.5e-3, loss_eps=1e-4,
                                         reverse_tau_grads=True, revert_rho_to_snapshot=True,
                                         shrink_tau_lr=True, tau_lr_decay=0.5, min_tau_lr=1e-5,
                                         shrink_penalty=True, penalty_decay=0.8, min_penalty_scale=0.05,
                                         stagnation_window=10, improve_threshold=0.05,
                                         bump_delta_k=1.0, min_epochs_between_bumps=10,
                                         acc_drop_threshold=0.02,
                                         verbose=True):
    activation_types = [
        'lasa', 'relu', 'leaky_relu', 'elu', 'softplus',
        'swish', 'mish', 'gelu', 'sine', 'sigmoid', 'tanh'
    ]

    print("="*60)
    print("ACTIVATION FUNCTIONS COMPARISON - Vortex Dataset")
    print("="*60)
    print("Config:",
          f"\n  hidden_units={hidden_units}",
          f"\n  epochs={epochs}  batch_size={batch_size}",
          f"\n  lr_main={lr_main}  (lr_tau={lr_tau} for LASA only)",
          f"\n  dataset: n_samples={n_samples}",
          f"\n  LASA: theta={theta_degrees}°, lambda_window={lambda_window}, penalty_mode={penalty_mode}, "
          f"enforce_gain_cap={enforce_gain_cap}, gain_cap={gain_cap}",
          f"\n  Rule: if post-bump drop > {acc_drop_threshold:.2f}, revert-once, then one final +1 bump and disable scheduler"
          )

    X, y = generate_vortex(n_samples=n_samples, random_state=random_state)
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, random_state=random_state, stratify=y
    )
    print(f"\nDataset: total={n_samples} | train={len(X_train)} | test={len(X_test)}")
    print(f"Class counts: 0->{np.sum(y==0)}  1->{np.sum(y==1)}")

    results = {}
    models  = {}

    for act in activation_types:
        print("\n" + "-"*60)
        print(f"Training with {act.upper()} activation...")
        tf.keras.backend.clear_session()
        np.random.seed(random_state)
        tf.random.set_seed(random_state)

        model = create_model(
            activation_type=act,
            hidden_units=hidden_units,
            initial_frequency=initial_frequency,
            theta_degrees=theta_degrees, lambda_window=lambda_window,
            penalty_mode=penalty_mode, hybrid_alpha=hybrid_alpha,
            enforce_gain_cap=enforce_gain_cap, gain_cap=gain_cap
        )

        if act.lower() == 'lasa':
            trainer = LASATrainer(
                model,
                lr_main=lr_main, lr_tau=lr_tau,
                clipnorm_main=1.0, clipnorm_tau=0.5,
                penalty_warmup_epochs=penalty_warmup_epochs,
                acc_eps=acc_eps, loss_eps=loss_eps,
                reverse_tau_grads=reverse_tau_grads, revert_rho_to_snapshot=revert_rho_to_snapshot,
                shrink_tau_lr=shrink_tau_lr, tau_lr_decay=tau_lr_decay, min_tau_lr=min_tau_lr,
                shrink_penalty=shrink_penalty, penalty_decay=penalty_decay, min_penalty_scale=min_penalty_scale,
                stagnation_window=stagnation_window, improve_threshold=improve_threshold,
                bump_delta_k=bump_delta_k, min_epochs_between_bumps=min_epochs_between_bumps,
                acc_drop_threshold=acc_drop_threshold
            )
            hist = trainer.train(
                tf.constant(X_train), tf.constant(y_train, np.float32),
                tf.constant(X_test),  tf.constant(y_test,  np.float32),
                epochs=epochs, batch_size=batch_size, verbose=verbose
            )
        else:
            trainer = RegularTrainer(model, lr=lr_main, clipnorm=1.0)
            hist = trainer.train(
                tf.constant(X_train), tf.constant(y_train, np.float32),
                tf.constant(X_test),  tf.constant(y_test,  np.float32),
                epochs=epochs, batch_size=batch_size, verbose=verbose
            )

        preds = model(tf.constant(X_test, tf.float32))
        y_true = tf.constant(y_test, np.float32)
        y_true = tf.reshape(y_true, (-1, 1))
        final_loss = float(tf.keras.losses.BinaryCrossentropy()(y_true, preds).numpy())
        y_pred = (preds.numpy() > 0.5).astype(int).flatten()
        final_acc  = float(np.mean(y_pred == y_test))

        results[act] = {'accuracy': final_acc, 'history': hist, 'final_loss': hist['loss'][-1]}
        models[act]  = model

        print(f"[{act.upper()}] Acc: {final_acc:.4f} | Final train loss: {hist['loss'][-1]:.4f}")

    return models, results, X, y, X_test, y_test


if __name__ == "__main__":
    models, results, X, y, X_test, y_test = run_all_activations_comparison_vortex(
        hidden_units=[8],
        n_samples=1000,
        test_size=0.2, random_state=42,
        epochs=80, batch_size=32,
        lr_main=1e-3, lr_tau=1e-2,
        initial_frequency=2.6,
        theta_degrees=45.0, lambda_window=3e-4,
        penalty_mode='hinge', hybrid_alpha=0.1,
        enforce_gain_cap=False, gain_cap=1.25,
        penalty_warmup_epochs=8,
        acc_eps=2.5e-3, loss_eps=1e-4,
        reverse_tau_grads=True, revert_rho_to_snapshot=True,
        shrink_tau_lr=True, tau_lr_decay=0.5, min_tau_lr=1e-5,
        shrink_penalty=True, penalty_decay=0.8, min_penalty_scale=0.05,
        stagnation_window=10, improve_threshold=0.05,
        bump_delta_k=1.0, min_epochs_between_bumps=10,
        acc_drop_threshold=0.02,
        verbose=True
    )

    print("\n")
    print("="*60)
    print("ACTIVATIONS: lasa, relu, leaky_relu, elu, softplus, swish, mish, gelu, sine, sigmoid, tanh")
    print("="*60)
    print_comparison_table(results)
    plot_all_decision_boundaries(models, results, X_test, y_test)
    plot_training_curves_comparison(results)

    plot_k_evolution(results, model_key='lasa', title_suffix="Vortex Dataset")
# Out:
# <style>.output_scroll {height:auto !important; max-height:none !important;}</style>
# ============================================================
# GPU CONFIGURATION
# ============================================================
# No GPUs available, using CPU
# Mixed precision policy: float32
# ============================================================
#
# ============================================================
# ACTIVATION FUNCTIONS COMPARISON - Vortex Dataset
# ============================================================
# Config:
#   hidden_units=[8]
#   epochs=80  batch_size=32
#   lr_main=0.001  (lr_tau=0.01 for LASA only)
#   dataset: n_samples=1000
#   LASA: theta=45.0°, lambda_window=0.0003, penalty_mode=hinge, enforce_gain_cap=False, gain_cap=1.25
#   Rule: if post-bump drop > 0.02, revert-once, then one final +1 bump and disable scheduler
#
# Dataset: total=1000 | train=800 | test=200
# Class counts: 0->511  1->489
#
# ------------------------------------------------------------
# Training with LASA activation...
# Epoch 001 | loss: 0.7251 | val_loss: 0.7095 | val_acc: 0.4800
# Epoch 002 | loss: 0.7117 | val_loss: 0.6991 | val_acc: 0.4900
# Epoch 003 | loss: 0.7001 | val_loss: 0.6903 | val_acc: 0.5650
# Epoch 004 | loss: 0.6903 | val_loss: 0.6824 | val_acc: 0.5700
# Epoch 005 | loss: 0.6817 | val_loss: 0.6762 | val_acc: 0.5700
# Epoch 006 | loss: 0.6741 | val_loss: 0.6735 | val_acc: 0.5300
# Epoch 007 | loss: 0.6720 | val_loss: 0.6716 | val_acc: 0.5450
# Epoch 008 | loss: 0.6690 | val_loss: 0.6692 | val_acc: 0.5700
# Epoch 009 | loss: 0.6646 | val_loss: 0.6664 | val_acc: 0.5950
# Epoch 010 | loss: 0.6613 | val_loss: 0.6650 | val_acc: 0.5850
# Epoch 011 | loss: 0.6604 | val_loss: 0.6645 | val_acc: 0.5900
# Epoch 012 | loss: 0.6588 | val_loss: 0.6635 | val_acc: 0.5900
# Epoch 013 | loss: 0.6554 | val_loss: 0.6596 | val_acc: 0.5500
# Epoch 014 | loss: 0.6628 | val_loss: 0.6616 | val_acc: 0.5650
# Epoch 015 | loss: 0.6505 | val_loss: 0.6570 | val_acc: 0.5750
# Epoch 016 | loss: 0.6459 | val_loss: 0.6537 | val_acc: 0.5900
# Epoch 017 | loss: 0.6418 | val_loss: 0.6505 | val_acc: 0.6000
# Epoch 018 | loss: 0.6386 | val_loss: 0.6473 | val_acc: 0.6000
# Epoch 019 | loss: 0.6348 | val_loss: 0.6442 | val_acc: 0.6000
# Epoch 020 | loss: 0.6316 | val_loss: 0.6410 | val_acc: 0.5950
# Epoch 021 | loss: 0.6277 | val_loss: 0.6374 | val_acc: 0.6100
# Epoch 022 | loss: 0.6221 | val_loss: 0.6304 | val_acc: 0.6000
# Epoch 023 | loss: 0.6154 | val_loss: 0.6254 | val_acc: 0.6150
# Epoch 024 | loss: 0.6118 | val_loss: 0.6224 | val_acc: 0.6200
# Epoch 025 | loss: 0.6090 | val_loss: 0.6205 | val_acc: 0.6200
# Epoch 026 | loss: 0.6096 | val_loss: 0.6223 | val_acc: 0.6250
# Epoch 027 | loss: 0.6080 | val_loss: 0.6137 | val_acc: 0.6100
# Epoch 028 | loss: 0.5995 | val_loss: 0.6113 | val_acc: 0.6150
# Epoch 029 | loss: 0.5960 | val_loss: 0.6009 | val_acc: 0.6050
# Epoch 030 | loss: 0.5859 | val_loss: 0.5997 | val_acc: 0.6300
# Epoch 031 | loss: 0.5885 | val_loss: 0.6057 | val_acc: 0.6250
# Epoch 032 | loss: 0.5885 | val_loss: 0.5949 | val_acc: 0.6400
# Epoch 033 | loss: 0.5714 | val_loss: 0.5758 | val_acc: 0.6550
# Epoch 034 | loss: 0.5536 | val_loss: 0.5645 | val_acc: 0.7100
# Epoch 035 | loss: 0.5405 | val_loss: 0.5565 | val_acc: 0.7000
# Epoch 036 | loss: 0.5289 | val_loss: 0.5512 | val_acc: 0.7100
# Epoch 037 | loss: 0.5240 | val_loss: 0.5493 | val_acc: 0.6950
# Epoch 038 | loss: 0.5180 | val_loss: 0.5397 | val_acc: 0.7000
# Epoch 039 | loss: 0.5062 | val_loss: 0.5344 | val_acc: 0.7050
# Epoch 040 | loss: 0.4990 | val_loss: 0.5234 | val_acc: 0.6800
# Epoch 041 | loss: 0.4856 | val_loss: 0.5182 | val_acc: 0.6900
# Epoch 042 | loss: 0.4787 | val_loss: 0.5084 | val_acc: 0.6850
# Epoch 043 | loss: 0.4652 | val_loss: 0.5020 | val_acc: 0.7150
# Epoch 044 | loss: 0.4632 | val_loss: 0.5059 | val_acc: 0.7400
# Epoch 045 | loss: 0.4617 | val_loss: 0.4930 | val_acc: 0.7100
# Epoch 046 | loss: 0.4478 | val_loss: 0.4887 | val_acc: 0.7100
# Epoch 047 | loss: 0.4415 | val_loss: 0.4795 | val_acc: 0.7400
# Epoch 048 | loss: 0.4280 | val_loss: 0.4711 | val_acc: 0.7800
# Epoch 049 | loss: 0.4171 | val_loss: 0.4650 | val_acc: 0.7850
# Epoch 050 | loss: 0.4089 | val_loss: 0.4577 | val_acc: 0.7850
# Epoch 051 | loss: 0.4005 | val_loss: 0.4522 | val_acc: 0.8200
# Epoch 052 | loss: 0.3931 | val_loss: 0.4456 | val_acc: 0.8250
# Epoch 053 | loss: 0.3851 | val_loss: 0.4374 | val_acc: 0.8500
# Epoch 054 | loss: 0.3769 | val_loss: 0.4290 | val_acc: 0.8700
# Epoch 055 | loss: 0.3675 | val_loss: 0.4192 | val_acc: 0.8800
# Epoch 056 | loss: 0.3581 | val_loss: 0.4075 | val_acc: 0.8950
# Epoch 057 | loss: 0.3465 | val_loss: 0.3935 | val_acc: 0.9150
# Epoch 058 | loss: 0.3351 | val_loss: 0.3786 | val_acc: 0.9300
# Epoch 059 | loss: 0.3237 | val_loss: 0.3654 | val_acc: 0.9400
# Epoch 060 | loss: 0.3134 | val_loss: 0.3528 | val_acc: 0.9350
# Epoch 061 | loss: 0.3046 | val_loss: 0.3438 | val_acc: 0.9450
# Epoch 062 | loss: 0.2983 | val_loss: 0.3363 | val_acc: 0.9400
# Epoch 063 | loss: 0.2931 | val_loss: 0.3284 | val_acc: 0.9400
# Epoch 064 | loss: 0.2862 | val_loss: 0.3223 | val_acc: 0.9450
# Epoch 065 | loss: 0.2829 | val_loss: 0.3207 | val_acc: 0.9350
# Epoch 066 | loss: 0.2797 | val_loss: 0.3115 | val_acc: 0.9400
# Epoch 067 | loss: 0.2736 | val_loss: 0.3079 | val_acc: 0.9450
# Epoch 068 | loss: 0.2719 | val_loss: 0.3096 | val_acc: 0.9350
# Epoch 069 | loss: 0.2702 | val_loss: 0.2998 | val_acc: 0.9450
# Epoch 070 | loss: 0.2624 | val_loss: 0.2925 | val_acc: 0.9450
# Epoch 071 | loss: 0.2584 | val_loss: 0.2875 | val_acc: 0.9500
# Epoch 072 | loss: 0.2545 | val_loss: 0.2827 | val_acc: 0.9450
# Epoch 073 | loss: 0.2507 | val_loss: 0.2800 | val_acc: 0.9450
# Epoch 074 | loss: 0.2475 | val_loss: 0.2765 | val_acc: 0.9450
# Epoch 075 | loss: 0.2442 | val_loss: 0.2729 | val_acc: 0.9500
# Epoch 076 | loss: 0.2415 | val_loss: 0.2734 | val_acc: 0.9500
# Epoch 077 | loss: 0.2393 | val_loss: 0.2686 | val_acc: 0.9550
# Epoch 078 | loss: 0.2359 | val_loss: 0.2640 | val_acc: 0.9500
# Epoch 079 | loss: 0.2326 | val_loss: 0.2619 | val_acc: 0.9550
# Epoch 080 | loss: 0.2298 | val_loss: 0.2590 | val_acc: 0.9550
# [LASA] Acc: 0.9550 | Final train loss: 0.2298
#
# ------------------------------------------------------------
# Training with RELU activation...
# Epoch 001 | loss: 0.6952 | val_loss: 0.6951 | val_acc: 0.5100
# Epoch 002 | loss: 0.6927 | val_loss: 0.6931 | val_acc: 0.4950
# Epoch 003 | loss: 0.6905 | val_loss: 0.6916 | val_acc: 0.4950
# Epoch 004 | loss: 0.6888 | val_loss: 0.6903 | val_acc: 0.4900
# Epoch 005 | loss: 0.6873 | val_loss: 0.6894 | val_acc: 0.4900
# Epoch 006 | loss: 0.6859 | val_loss: 0.6884 | val_acc: 0.4800
# Epoch 007 | loss: 0.6845 | val_loss: 0.6873 | val_acc: 0.4600
# Epoch 008 | loss: 0.6834 | val_loss: 0.6866 | val_acc: 0.4550
# Epoch 009 | loss: 0.6823 | val_loss: 0.6859 | val_acc: 0.4500
# Epoch 010 | loss: 0.6814 | val_loss: 0.6851 | val_acc: 0.4500
# Epoch 011 | loss: 0.6803 | val_loss: 0.6846 | val_acc: 0.4500
# Epoch 012 | loss: 0.6794 | val_loss: 0.6841 | val_acc: 0.4550
# Epoch 013 | loss: 0.6787 | val_loss: 0.6834 | val_acc: 0.4600
# Epoch 014 | loss: 0.6780 | val_loss: 0.6829 | val_acc: 0.4700
# Epoch 015 | loss: 0.6771 | val_loss: 0.6823 | val_acc: 0.4700
# Epoch 016 | loss: 0.6763 | val_loss: 0.6818 | val_acc: 0.4650
# Epoch 017 | loss: 0.6756 | val_loss: 0.6811 | val_acc: 0.4600
# Epoch 018 | loss: 0.6750 | val_loss: 0.6805 | val_acc: 0.4650
# Epoch 019 | loss: 0.6742 | val_loss: 0.6800 | val_acc: 0.4700
# Epoch 020 | loss: 0.6735 | val_loss: 0.6796 | val_acc: 0.4750
# Epoch 021 | loss: 0.6728 | val_loss: 0.6792 | val_acc: 0.4700
# Epoch 022 | loss: 0.6721 | val_loss: 0.6785 | val_acc: 0.4750
# Epoch 023 | loss: 0.6713 | val_loss: 0.6782 | val_acc: 0.4750
# Epoch 024 | loss: 0.6708 | val_loss: 0.6777 | val_acc: 0.4750
# Epoch 025 | loss: 0.6703 | val_loss: 0.6774 | val_acc: 0.4800
# Epoch 026 | loss: 0.6698 | val_loss: 0.6770 | val_acc: 0.4800
# Epoch 027 | loss: 0.6694 | val_loss: 0.6767 | val_acc: 0.4850
# Epoch 028 | loss: 0.6690 | val_loss: 0.6765 | val_acc: 0.4900
# Epoch 029 | loss: 0.6687 | val_loss: 0.6761 | val_acc: 0.4900
# Epoch 030 | loss: 0.6683 | val_loss: 0.6760 | val_acc: 0.5050
# Epoch 031 | loss: 0.6678 | val_loss: 0.6756 | val_acc: 0.5050
# Epoch 032 | loss: 0.6676 | val_loss: 0.6754 | val_acc: 0.5100
# Epoch 033 | loss: 0.6673 | val_loss: 0.6752 | val_acc: 0.5200
# Epoch 034 | loss: 0.6670 | val_loss: 0.6750 | val_acc: 0.5100
# Epoch 035 | loss: 0.6666 | val_loss: 0.6748 | val_acc: 0.5350
# Epoch 036 | loss: 0.6664 | val_loss: 0.6747 | val_acc: 0.5350
# Epoch 037 | loss: 0.6660 | val_loss: 0.6745 | val_acc: 0.5350
# Epoch 038 | loss: 0.6657 | val_loss: 0.6744 | val_acc: 0.5350
# Epoch 039 | loss: 0.6655 | val_loss: 0.6743 | val_acc: 0.5350
# Epoch 040 | loss: 0.6653 | val_loss: 0.6740 | val_acc: 0.5450
# Epoch 041 | loss: 0.6650 | val_loss: 0.6739 | val_acc: 0.5350
# Epoch 042 | loss: 0.6647 | val_loss: 0.6738 | val_acc: 0.5300
# Epoch 043 | loss: 0.6646 | val_loss: 0.6736 | val_acc: 0.5500
# Epoch 044 | loss: 0.6643 | val_loss: 0.6736 | val_acc: 0.5250
# Epoch 045 | loss: 0.6642 | val_loss: 0.6733 | val_acc: 0.5500
# Epoch 046 | loss: 0.6642 | val_loss: 0.6734 | val_acc: 0.5350
# Epoch 047 | loss: 0.6637 | val_loss: 0.6732 | val_acc: 0.5300
# Epoch 048 | loss: 0.6635 | val_loss: 0.6732 | val_acc: 0.5300
# Epoch 049 | loss: 0.6633 | val_loss: 0.6731 | val_acc: 0.5300
# Epoch 050 | loss: 0.6634 | val_loss: 0.6729 | val_acc: 0.5550
# Epoch 051 | loss: 0.6630 | val_loss: 0.6730 | val_acc: 0.5250
# Epoch 052 | loss: 0.6627 | val_loss: 0.6728 | val_acc: 0.5250
# Epoch 053 | loss: 0.6626 | val_loss: 0.6727 | val_acc: 0.5300
# Epoch 054 | loss: 0.6624 | val_loss: 0.6727 | val_acc: 0.5250
# Epoch 055 | loss: 0.6622 | val_loss: 0.6726 | val_acc: 0.5250
# Epoch 056 | loss: 0.6621 | val_loss: 0.6724 | val_acc: 0.5350
# Epoch 057 | loss: 0.6619 | val_loss: 0.6724 | val_acc: 0.5300
# Epoch 058 | loss: 0.6618 | val_loss: 0.6724 | val_acc: 0.5250
# Epoch 059 | loss: 0.6616 | val_loss: 0.6723 | val_acc: 0.5250
# Epoch 060 | loss: 0.6614 | val_loss: 0.6721 | val_acc: 0.5300
# Epoch 061 | loss: 0.6613 | val_loss: 0.6721 | val_acc: 0.5250
# Epoch 062 | loss: 0.6610 | val_loss: 0.6719 | val_acc: 0.5250
# Epoch 063 | loss: 0.6610 | val_loss: 0.6718 | val_acc: 0.5300
# Epoch 064 | loss: 0.6608 | val_loss: 0.6718 | val_acc: 0.5300
# Epoch 065 | loss: 0.6607 | val_loss: 0.6719 | val_acc: 0.5250
# Epoch 066 | loss: 0.6605 | val_loss: 0.6717 | val_acc: 0.5250
# Epoch 067 | loss: 0.6604 | val_loss: 0.6716 | val_acc: 0.5250
# Epoch 068 | loss: 0.6602 | val_loss: 0.6715 | val_acc: 0.5250
# Epoch 069 | loss: 0.6601 | val_loss: 0.6714 | val_acc: 0.5250
# Epoch 070 | loss: 0.6600 | val_loss: 0.6715 | val_acc: 0.5250
# Epoch 071 | loss: 0.6597 | val_loss: 0.6712 | val_acc: 0.5250
# Epoch 072 | loss: 0.6598 | val_loss: 0.6713 | val_acc: 0.5250
# Epoch 073 | loss: 0.6595 | val_loss: 0.6711 | val_acc: 0.5250
# Epoch 074 | loss: 0.6593 | val_loss: 0.6710 | val_acc: 0.5250
# Epoch 075 | loss: 0.6591 | val_loss: 0.6709 | val_acc: 0.5250
# Epoch 076 | loss: 0.6590 | val_loss: 0.6707 | val_acc: 0.5250
# Epoch 077 | loss: 0.6589 | val_loss: 0.6709 | val_acc: 0.5250
# Epoch 078 | loss: 0.6587 | val_loss: 0.6708 | val_acc: 0.5250
# Epoch 079 | loss: 0.6586 | val_loss: 0.6707 | val_acc: 0.5250
# Epoch 080 | loss: 0.6585 | val_loss: 0.6708 | val_acc: 0.5250
# [RELU] Acc: 0.5250 | Final train loss: 0.6585
#
# ------------------------------------------------------------
# Training with LEAKY_RELU activation...
# Epoch 001 | loss: 0.7103 | val_loss: 0.7068 | val_acc: 0.5150
# Epoch 002 | loss: 0.7047 | val_loss: 0.7013 | val_acc: 0.5450
# Epoch 003 | loss: 0.6995 | val_loss: 0.6965 | val_acc: 0.5300
# Epoch 004 | loss: 0.6949 | val_loss: 0.6919 | val_acc: 0.5000
# Epoch 005 | loss: 0.6905 | val_loss: 0.6877 | val_acc: 0.5000
# Epoch 006 | loss: 0.6862 | val_loss: 0.6837 | val_acc: 0.5200
# Epoch 007 | loss: 0.6822 | val_loss: 0.6805 | val_acc: 0.5250
# Epoch 008 | loss: 0.6790 | val_loss: 0.6778 | val_acc: 0.5750
# Epoch 009 | loss: 0.6761 | val_loss: 0.6758 | val_acc: 0.5750
# Epoch 010 | loss: 0.6741 | val_loss: 0.6741 | val_acc: 0.5800
# Epoch 011 | loss: 0.6723 | val_loss: 0.6727 | val_acc: 0.5800
# Epoch 012 | loss: 0.6708 | val_loss: 0.6716 | val_acc: 0.5900
# Epoch 013 | loss: 0.6697 | val_loss: 0.6705 | val_acc: 0.6050
# Epoch 014 | loss: 0.6686 | val_loss: 0.6694 | val_acc: 0.5950
# Epoch 015 | loss: 0.6675 | val_loss: 0.6687 | val_acc: 0.6100
# Epoch 016 | loss: 0.6667 | val_loss: 0.6679 | val_acc: 0.6100
# Epoch 017 | loss: 0.6659 | val_loss: 0.6670 | val_acc: 0.6200
# Epoch 018 | loss: 0.6653 | val_loss: 0.6662 | val_acc: 0.6250
# Epoch 019 | loss: 0.6645 | val_loss: 0.6655 | val_acc: 0.6300
# Epoch 020 | loss: 0.6639 | val_loss: 0.6649 | val_acc: 0.6000
# Epoch 021 | loss: 0.6630 | val_loss: 0.6641 | val_acc: 0.6300
# Epoch 022 | loss: 0.6623 | val_loss: 0.6633 | val_acc: 0.5800
# Epoch 023 | loss: 0.6615 | val_loss: 0.6628 | val_acc: 0.5950
# Epoch 024 | loss: 0.6610 | val_loss: 0.6621 | val_acc: 0.6100
# Epoch 025 | loss: 0.6603 | val_loss: 0.6615 | val_acc: 0.6100
# Epoch 026 | loss: 0.6596 | val_loss: 0.6609 | val_acc: 0.5850
# Epoch 027 | loss: 0.6590 | val_loss: 0.6603 | val_acc: 0.5750
# Epoch 028 | loss: 0.6583 | val_loss: 0.6597 | val_acc: 0.5800
# Epoch 029 | loss: 0.6578 | val_loss: 0.6591 | val_acc: 0.5750
# Epoch 030 | loss: 0.6571 | val_loss: 0.6585 | val_acc: 0.5800
# Epoch 031 | loss: 0.6564 | val_loss: 0.6580 | val_acc: 0.5800
# Epoch 032 | loss: 0.6560 | val_loss: 0.6575 | val_acc: 0.5850
# Epoch 033 | loss: 0.6554 | val_loss: 0.6567 | val_acc: 0.5750
# Epoch 034 | loss: 0.6549 | val_loss: 0.6563 | val_acc: 0.5850
# Epoch 035 | loss: 0.6541 | val_loss: 0.6558 | val_acc: 0.5900
# Epoch 036 | loss: 0.6536 | val_loss: 0.6552 | val_acc: 0.5700
# Epoch 037 | loss: 0.6530 | val_loss: 0.6548 | val_acc: 0.5750
# Epoch 038 | loss: 0.6524 | val_loss: 0.6544 | val_acc: 0.5900
# Epoch 039 | loss: 0.6519 | val_loss: 0.6539 | val_acc: 0.5850
# Epoch 040 | loss: 0.6515 | val_loss: 0.6533 | val_acc: 0.5700
# Epoch 041 | loss: 0.6509 | val_loss: 0.6528 | val_acc: 0.5750
# Epoch 042 | loss: 0.6503 | val_loss: 0.6525 | val_acc: 0.5850
# Epoch 043 | loss: 0.6500 | val_loss: 0.6519 | val_acc: 0.5900
# Epoch 044 | loss: 0.6494 | val_loss: 0.6516 | val_acc: 0.5750
# Epoch 045 | loss: 0.6490 | val_loss: 0.6510 | val_acc: 0.5750
# Epoch 046 | loss: 0.6487 | val_loss: 0.6507 | val_acc: 0.5900
# Epoch 047 | loss: 0.6480 | val_loss: 0.6502 | val_acc: 0.5700
# Epoch 048 | loss: 0.6475 | val_loss: 0.6498 | val_acc: 0.5700
# Epoch 049 | loss: 0.6471 | val_loss: 0.6494 | val_acc: 0.5700
# Epoch 050 | loss: 0.6470 | val_loss: 0.6488 | val_acc: 0.6050
# Epoch 051 | loss: 0.6461 | val_loss: 0.6486 | val_acc: 0.5750
# Epoch 052 | loss: 0.6456 | val_loss: 0.6481 | val_acc: 0.5650
# Epoch 053 | loss: 0.6452 | val_loss: 0.6476 | val_acc: 0.5600
# Epoch 054 | loss: 0.6448 | val_loss: 0.6472 | val_acc: 0.5650
# Epoch 055 | loss: 0.6443 | val_loss: 0.6468 | val_acc: 0.5650
# Epoch 056 | loss: 0.6439 | val_loss: 0.6462 | val_acc: 0.5750
# Epoch 057 | loss: 0.6434 | val_loss: 0.6459 | val_acc: 0.5650
# Epoch 058 | loss: 0.6430 | val_loss: 0.6457 | val_acc: 0.5600
# Epoch 059 | loss: 0.6427 | val_loss: 0.6453 | val_acc: 0.5600
# Epoch 060 | loss: 0.6421 | val_loss: 0.6447 | val_acc: 0.5650
# Epoch 061 | loss: 0.6417 | val_loss: 0.6445 | val_acc: 0.5550
# Epoch 062 | loss: 0.6412 | val_loss: 0.6439 | val_acc: 0.5550
# Epoch 063 | loss: 0.6409 | val_loss: 0.6434 | val_acc: 0.5550
# Epoch 064 | loss: 0.6403 | val_loss: 0.6431 | val_acc: 0.5650
# Epoch 065 | loss: 0.6400 | val_loss: 0.6430 | val_acc: 0.5600
# Epoch 066 | loss: 0.6395 | val_loss: 0.6425 | val_acc: 0.5500
# Epoch 067 | loss: 0.6392 | val_loss: 0.6421 | val_acc: 0.5600
# Epoch 068 | loss: 0.6387 | val_loss: 0.6417 | val_acc: 0.5600
# Epoch 069 | loss: 0.6383 | val_loss: 0.6411 | val_acc: 0.5600
# Epoch 070 | loss: 0.6380 | val_loss: 0.6410 | val_acc: 0.5600
# Epoch 071 | loss: 0.6374 | val_loss: 0.6405 | val_acc: 0.5600
# Epoch 072 | loss: 0.6371 | val_loss: 0.6402 | val_acc: 0.5650
# Epoch 073 | loss: 0.6367 | val_loss: 0.6396 | val_acc: 0.5700
# Epoch 074 | loss: 0.6362 | val_loss: 0.6392 | val_acc: 0.5600
# Epoch 075 | loss: 0.6358 | val_loss: 0.6388 | val_acc: 0.5650
# Epoch 076 | loss: 0.6354 | val_loss: 0.6385 | val_acc: 0.5650
# Epoch 077 | loss: 0.6351 | val_loss: 0.6383 | val_acc: 0.5600
# Epoch 078 | loss: 0.6346 | val_loss: 0.6381 | val_acc: 0.5600
# Epoch 079 | loss: 0.6344 | val_loss: 0.6377 | val_acc: 0.5550
# Epoch 080 | loss: 0.6340 | val_loss: 0.6374 | val_acc: 0.5600
# [LEAKY_RELU] Acc: 0.5600 | Final train loss: 0.6340
#
# ------------------------------------------------------------
# Training with ELU activation...
# Epoch 001 | loss: 0.6956 | val_loss: 0.6922 | val_acc: 0.5400
# Epoch 002 | loss: 0.6950 | val_loss: 0.6921 | val_acc: 0.5350
# Epoch 003 | loss: 0.6944 | val_loss: 0.6919 | val_acc: 0.5200
# Epoch 004 | loss: 0.6940 | val_loss: 0.6918 | val_acc: 0.4950
# Epoch 005 | loss: 0.6937 | val_loss: 0.6918 | val_acc: 0.4800
# Epoch 006 | loss: 0.6934 | val_loss: 0.6918 | val_acc: 0.5300
# Epoch 007 | loss: 0.6932 | val_loss: 0.6917 | val_acc: 0.5200
# Epoch 008 | loss: 0.6931 | val_loss: 0.6919 | val_acc: 0.5150
# Epoch 009 | loss: 0.6928 | val_loss: 0.6919 | val_acc: 0.5350
# Epoch 010 | loss: 0.6930 | val_loss: 0.6916 | val_acc: 0.5700
# Epoch 011 | loss: 0.6925 | val_loss: 0.6919 | val_acc: 0.5500
# Epoch 012 | loss: 0.6925 | val_loss: 0.6919 | val_acc: 0.5150
# Epoch 013 | loss: 0.6925 | val_loss: 0.6919 | val_acc: 0.5200
# Epoch 014 | loss: 0.6923 | val_loss: 0.6919 | val_acc: 0.5000
# Epoch 015 | loss: 0.6922 | val_loss: 0.6920 | val_acc: 0.5050
# Epoch 016 | loss: 0.6922 | val_loss: 0.6920 | val_acc: 0.4950
# Epoch 017 | loss: 0.6921 | val_loss: 0.6920 | val_acc: 0.4750
# Epoch 018 | loss: 0.6924 | val_loss: 0.6918 | val_acc: 0.5150
# Epoch 019 | loss: 0.6921 | val_loss: 0.6919 | val_acc: 0.4650
# Epoch 020 | loss: 0.6921 | val_loss: 0.6920 | val_acc: 0.4700
# Epoch 021 | loss: 0.6921 | val_loss: 0.6922 | val_acc: 0.4600
# Epoch 022 | loss: 0.6920 | val_loss: 0.6920 | val_acc: 0.4650
# Epoch 023 | loss: 0.6918 | val_loss: 0.6920 | val_acc: 0.4600
# Epoch 024 | loss: 0.6919 | val_loss: 0.6920 | val_acc: 0.4600
# Epoch 025 | loss: 0.6918 | val_loss: 0.6921 | val_acc: 0.4600
# Epoch 026 | loss: 0.6918 | val_loss: 0.6921 | val_acc: 0.4600
# Epoch 027 | loss: 0.6918 | val_loss: 0.6921 | val_acc: 0.4600
# Epoch 028 | loss: 0.6918 | val_loss: 0.6922 | val_acc: 0.4600
# Epoch 029 | loss: 0.6919 | val_loss: 0.6921 | val_acc: 0.4600
# Epoch 030 | loss: 0.6918 | val_loss: 0.6923 | val_acc: 0.4550
# Epoch 031 | loss: 0.6917 | val_loss: 0.6922 | val_acc: 0.4600
# Epoch 032 | loss: 0.6917 | val_loss: 0.6921 | val_acc: 0.4550
# Epoch 033 | loss: 0.6918 | val_loss: 0.6923 | val_acc: 0.4450
# Epoch 034 | loss: 0.6917 | val_loss: 0.6921 | val_acc: 0.4600
# Epoch 035 | loss: 0.6917 | val_loss: 0.6922 | val_acc: 0.4500
# Epoch 036 | loss: 0.6917 | val_loss: 0.6922 | val_acc: 0.4500
# Epoch 037 | loss: 0.6916 | val_loss: 0.6921 | val_acc: 0.4500
# Epoch 038 | loss: 0.6916 | val_loss: 0.6922 | val_acc: 0.4500
# Epoch 039 | loss: 0.6916 | val_loss: 0.6923 | val_acc: 0.4500
# Epoch 040 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4550
# Epoch 041 | loss: 0.6916 | val_loss: 0.6921 | val_acc: 0.4500
# Epoch 042 | loss: 0.6916 | val_loss: 0.6921 | val_acc: 0.4600
# Epoch 043 | loss: 0.6916 | val_loss: 0.6921 | val_acc: 0.4450
# Epoch 044 | loss: 0.6915 | val_loss: 0.6921 | val_acc: 0.4600
# Epoch 045 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4600
# Epoch 046 | loss: 0.6917 | val_loss: 0.6921 | val_acc: 0.4550
# Epoch 047 | loss: 0.6915 | val_loss: 0.6919 | val_acc: 0.4550
# Epoch 048 | loss: 0.6915 | val_loss: 0.6921 | val_acc: 0.4450
# Epoch 049 | loss: 0.6915 | val_loss: 0.6921 | val_acc: 0.4500
# Epoch 050 | loss: 0.6917 | val_loss: 0.6920 | val_acc: 0.4500
# Epoch 051 | loss: 0.6915 | val_loss: 0.6922 | val_acc: 0.4500
# Epoch 052 | loss: 0.6914 | val_loss: 0.6920 | val_acc: 0.4450
# Epoch 053 | loss: 0.6914 | val_loss: 0.6920 | val_acc: 0.4550
# Epoch 054 | loss: 0.6914 | val_loss: 0.6920 | val_acc: 0.4500
# Epoch 055 | loss: 0.6914 | val_loss: 0.6921 | val_acc: 0.4500
# Epoch 056 | loss: 0.6914 | val_loss: 0.6920 | val_acc: 0.4400
# Epoch 057 | loss: 0.6914 | val_loss: 0.6919 | val_acc: 0.4400
# Epoch 058 | loss: 0.6913 | val_loss: 0.6919 | val_acc: 0.4550
# Epoch 059 | loss: 0.6914 | val_loss: 0.6919 | val_acc: 0.4600
# Epoch 060 | loss: 0.6913 | val_loss: 0.6919 | val_acc: 0.4550
# Epoch 061 | loss: 0.6913 | val_loss: 0.6919 | val_acc: 0.4500
# Epoch 062 | loss: 0.6912 | val_loss: 0.6919 | val_acc: 0.4500
# Epoch 063 | loss: 0.6913 | val_loss: 0.6918 | val_acc: 0.4400
# Epoch 064 | loss: 0.6913 | val_loss: 0.6919 | val_acc: 0.4400
# Epoch 065 | loss: 0.6912 | val_loss: 0.6919 | val_acc: 0.4500
# Epoch 066 | loss: 0.6912 | val_loss: 0.6919 | val_acc: 0.4500
# Epoch 067 | loss: 0.6913 | val_loss: 0.6919 | val_acc: 0.4450
# Epoch 068 | loss: 0.6912 | val_loss: 0.6918 | val_acc: 0.4550
# Epoch 069 | loss: 0.6912 | val_loss: 0.6919 | val_acc: 0.4450
# Epoch 070 | loss: 0.6913 | val_loss: 0.6919 | val_acc: 0.4400
# Epoch 071 | loss: 0.6912 | val_loss: 0.6916 | val_acc: 0.4550
# Epoch 072 | loss: 0.6913 | val_loss: 0.6917 | val_acc: 0.4600
# Epoch 073 | loss: 0.6911 | val_loss: 0.6918 | val_acc: 0.4300
# Epoch 074 | loss: 0.6911 | val_loss: 0.6918 | val_acc: 0.4400
# Epoch 075 | loss: 0.6910 | val_loss: 0.6916 | val_acc: 0.4300
# Epoch 076 | loss: 0.6911 | val_loss: 0.6915 | val_acc: 0.4500
# Epoch 077 | loss: 0.6911 | val_loss: 0.6917 | val_acc: 0.4450
# Epoch 078 | loss: 0.6910 | val_loss: 0.6917 | val_acc: 0.4400
# Epoch 079 | loss: 0.6910 | val_loss: 0.6916 | val_acc: 0.4400
# Epoch 080 | loss: 0.6911 | val_loss: 0.6918 | val_acc: 0.4600
# [ELU] Acc: 0.4600 | Final train loss: 0.6911
#
# ------------------------------------------------------------
# Training with SOFTPLUS activation...
# Epoch 001 | loss: 0.6949 | val_loss: 0.6921 | val_acc: 0.5100
# Epoch 002 | loss: 0.6935 | val_loss: 0.6910 | val_acc: 0.5450
# Epoch 003 | loss: 0.6927 | val_loss: 0.6907 | val_acc: 0.5300
# Epoch 004 | loss: 0.6924 | val_loss: 0.6907 | val_acc: 0.5600
# Epoch 005 | loss: 0.6923 | val_loss: 0.6907 | val_acc: 0.5500
# Epoch 006 | loss: 0.6922 | val_loss: 0.6907 | val_acc: 0.5750
# Epoch 007 | loss: 0.6921 | val_loss: 0.6907 | val_acc: 0.5850
# Epoch 008 | loss: 0.6921 | val_loss: 0.6907 | val_acc: 0.5950
# Epoch 009 | loss: 0.6920 | val_loss: 0.6907 | val_acc: 0.6000
# Epoch 010 | loss: 0.6922 | val_loss: 0.6908 | val_acc: 0.5600
# Epoch 011 | loss: 0.6918 | val_loss: 0.6907 | val_acc: 0.6150
# Epoch 012 | loss: 0.6918 | val_loss: 0.6908 | val_acc: 0.6450
# Epoch 013 | loss: 0.6919 | val_loss: 0.6908 | val_acc: 0.6300
# Epoch 014 | loss: 0.6918 | val_loss: 0.6908 | val_acc: 0.6100
# Epoch 015 | loss: 0.6916 | val_loss: 0.6908 | val_acc: 0.6300
# Epoch 016 | loss: 0.6916 | val_loss: 0.6908 | val_acc: 0.6300
# Epoch 017 | loss: 0.6915 | val_loss: 0.6908 | val_acc: 0.6050
# Epoch 018 | loss: 0.6921 | val_loss: 0.6908 | val_acc: 0.6000
# Epoch 019 | loss: 0.6917 | val_loss: 0.6908 | val_acc: 0.5950
# Epoch 020 | loss: 0.6918 | val_loss: 0.6909 | val_acc: 0.5850
# Epoch 021 | loss: 0.6916 | val_loss: 0.6909 | val_acc: 0.5700
# Epoch 022 | loss: 0.6914 | val_loss: 0.6909 | val_acc: 0.5800
# Epoch 023 | loss: 0.6912 | val_loss: 0.6909 | val_acc: 0.5700
# Epoch 024 | loss: 0.6913 | val_loss: 0.6908 | val_acc: 0.5700
# Epoch 025 | loss: 0.6912 | val_loss: 0.6909 | val_acc: 0.5450
# Epoch 026 | loss: 0.6911 | val_loss: 0.6909 | val_acc: 0.5550
# Epoch 027 | loss: 0.6912 | val_loss: 0.6909 | val_acc: 0.5500
# Epoch 028 | loss: 0.6910 | val_loss: 0.6909 | val_acc: 0.5250
# Epoch 029 | loss: 0.6912 | val_loss: 0.6909 | val_acc: 0.5400
# Epoch 030 | loss: 0.6910 | val_loss: 0.6910 | val_acc: 0.5050
# Epoch 031 | loss: 0.6910 | val_loss: 0.6909 | val_acc: 0.5100
# Epoch 032 | loss: 0.6909 | val_loss: 0.6910 | val_acc: 0.5150
# Epoch 033 | loss: 0.6911 | val_loss: 0.6909 | val_acc: 0.5200
# Epoch 034 | loss: 0.6911 | val_loss: 0.6910 | val_acc: 0.5000
# Epoch 035 | loss: 0.6908 | val_loss: 0.6909 | val_acc: 0.5050
# Epoch 036 | loss: 0.6909 | val_loss: 0.6909 | val_acc: 0.5000
# Epoch 037 | loss: 0.6908 | val_loss: 0.6909 | val_acc: 0.4950
# Epoch 038 | loss: 0.6907 | val_loss: 0.6910 | val_acc: 0.4950
# Epoch 039 | loss: 0.6907 | val_loss: 0.6910 | val_acc: 0.4850
# Epoch 040 | loss: 0.6907 | val_loss: 0.6909 | val_acc: 0.4900
# Epoch 041 | loss: 0.6907 | val_loss: 0.6909 | val_acc: 0.4900
# Epoch 042 | loss: 0.6907 | val_loss: 0.6910 | val_acc: 0.4800
# Epoch 043 | loss: 0.6909 | val_loss: 0.6909 | val_acc: 0.4900
# Epoch 044 | loss: 0.6906 | val_loss: 0.6910 | val_acc: 0.4800
# Epoch 045 | loss: 0.6907 | val_loss: 0.6909 | val_acc: 0.4750
# Epoch 046 | loss: 0.6912 | val_loss: 0.6910 | val_acc: 0.4650
# Epoch 047 | loss: 0.6904 | val_loss: 0.6909 | val_acc: 0.4700
# Epoch 048 | loss: 0.6906 | val_loss: 0.6909 | val_acc: 0.4700
# Epoch 049 | loss: 0.6904 | val_loss: 0.6909 | val_acc: 0.4700
# Epoch 050 | loss: 0.6911 | val_loss: 0.6909 | val_acc: 0.5000
# Epoch 051 | loss: 0.6904 | val_loss: 0.6910 | val_acc: 0.4650
# Epoch 052 | loss: 0.6903 | val_loss: 0.6909 | val_acc: 0.4650
# Epoch 053 | loss: 0.6902 | val_loss: 0.6909 | val_acc: 0.4650
# Epoch 054 | loss: 0.6903 | val_loss: 0.6909 | val_acc: 0.4600
# Epoch 055 | loss: 0.6902 | val_loss: 0.6909 | val_acc: 0.4600
# Epoch 056 | loss: 0.6903 | val_loss: 0.6908 | val_acc: 0.4650
# Epoch 057 | loss: 0.6903 | val_loss: 0.6908 | val_acc: 0.4600
# Epoch 058 | loss: 0.6902 | val_loss: 0.6909 | val_acc: 0.4550
# Epoch 059 | loss: 0.6903 | val_loss: 0.6909 | val_acc: 0.4400
# Epoch 060 | loss: 0.6900 | val_loss: 0.6908 | val_acc: 0.4550
# Epoch 061 | loss: 0.6901 | val_loss: 0.6908 | val_acc: 0.4600
# Epoch 062 | loss: 0.6900 | val_loss: 0.6908 | val_acc: 0.4500
# Epoch 063 | loss: 0.6900 | val_loss: 0.6907 | val_acc: 0.4550
# Epoch 064 | loss: 0.6902 | val_loss: 0.6907 | val_acc: 0.4750
# Epoch 065 | loss: 0.6900 | val_loss: 0.6908 | val_acc: 0.4450
# Epoch 066 | loss: 0.6898 | val_loss: 0.6907 | val_acc: 0.4550
# Epoch 067 | loss: 0.6901 | val_loss: 0.6907 | val_acc: 0.4500
# Epoch 068 | loss: 0.6899 | val_loss: 0.6907 | val_acc: 0.4600
# Epoch 069 | loss: 0.6899 | val_loss: 0.6907 | val_acc: 0.4700
# Epoch 070 | loss: 0.6900 | val_loss: 0.6907 | val_acc: 0.4550
# Epoch 071 | loss: 0.6897 | val_loss: 0.6906 | val_acc: 0.4550
# Epoch 072 | loss: 0.6900 | val_loss: 0.6907 | val_acc: 0.4350
# Epoch 073 | loss: 0.6896 | val_loss: 0.6906 | val_acc: 0.4750
# Epoch 074 | loss: 0.6896 | val_loss: 0.6906 | val_acc: 0.4600
# Epoch 075 | loss: 0.6895 | val_loss: 0.6905 | val_acc: 0.4500
# Epoch 076 | loss: 0.6895 | val_loss: 0.6904 | val_acc: 0.4500
# Epoch 077 | loss: 0.6895 | val_loss: 0.6905 | val_acc: 0.4450
# Epoch 078 | loss: 0.6894 | val_loss: 0.6905 | val_acc: 0.4500
# Epoch 079 | loss: 0.6894 | val_loss: 0.6904 | val_acc: 0.4500
# Epoch 080 | loss: 0.6894 | val_loss: 0.6905 | val_acc: 0.4550
# [SOFTPLUS] Acc: 0.4550 | Final train loss: 0.6894
#
# ------------------------------------------------------------
# Training with SWISH activation...
# Epoch 001 | loss: 0.6933 | val_loss: 0.6935 | val_acc: 0.5700
# Epoch 002 | loss: 0.6928 | val_loss: 0.6933 | val_acc: 0.5350
# Epoch 003 | loss: 0.6925 | val_loss: 0.6929 | val_acc: 0.5350
# Epoch 004 | loss: 0.6922 | val_loss: 0.6927 | val_acc: 0.5150
# Epoch 005 | loss: 0.6920 | val_loss: 0.6925 | val_acc: 0.4850
# Epoch 006 | loss: 0.6918 | val_loss: 0.6924 | val_acc: 0.4900
# Epoch 007 | loss: 0.6916 | val_loss: 0.6921 | val_acc: 0.5050
# Epoch 008 | loss: 0.6915 | val_loss: 0.6921 | val_acc: 0.5000
# Epoch 009 | loss: 0.6913 | val_loss: 0.6920 | val_acc: 0.4900
# Epoch 010 | loss: 0.6913 | val_loss: 0.6917 | val_acc: 0.5250
# Epoch 011 | loss: 0.6910 | val_loss: 0.6917 | val_acc: 0.4750
# Epoch 012 | loss: 0.6909 | val_loss: 0.6917 | val_acc: 0.4750
# Epoch 013 | loss: 0.6909 | val_loss: 0.6915 | val_acc: 0.4700
# Epoch 014 | loss: 0.6908 | val_loss: 0.6915 | val_acc: 0.4650
# Epoch 015 | loss: 0.6906 | val_loss: 0.6914 | val_acc: 0.4700
# Epoch 016 | loss: 0.6905 | val_loss: 0.6914 | val_acc: 0.4700
# Epoch 017 | loss: 0.6904 | val_loss: 0.6912 | val_acc: 0.4600
# Epoch 018 | loss: 0.6906 | val_loss: 0.6911 | val_acc: 0.4700
# Epoch 019 | loss: 0.6903 | val_loss: 0.6911 | val_acc: 0.4500
# Epoch 020 | loss: 0.6902 | val_loss: 0.6910 | val_acc: 0.4600
# Epoch 021 | loss: 0.6902 | val_loss: 0.6910 | val_acc: 0.4450
# Epoch 022 | loss: 0.6900 | val_loss: 0.6909 | val_acc: 0.4500
# Epoch 023 | loss: 0.6898 | val_loss: 0.6908 | val_acc: 0.4650
# Epoch 024 | loss: 0.6898 | val_loss: 0.6907 | val_acc: 0.4650
# Epoch 025 | loss: 0.6897 | val_loss: 0.6907 | val_acc: 0.4600
# Epoch 026 | loss: 0.6896 | val_loss: 0.6907 | val_acc: 0.4600
# Epoch 027 | loss: 0.6895 | val_loss: 0.6906 | val_acc: 0.4600
# Epoch 028 | loss: 0.6894 | val_loss: 0.6906 | val_acc: 0.4600
# Epoch 029 | loss: 0.6894 | val_loss: 0.6905 | val_acc: 0.4600
# Epoch 030 | loss: 0.6893 | val_loss: 0.6905 | val_acc: 0.4700
# Epoch 031 | loss: 0.6892 | val_loss: 0.6904 | val_acc: 0.4650
# Epoch 032 | loss: 0.6891 | val_loss: 0.6903 | val_acc: 0.4650
# Epoch 033 | loss: 0.6891 | val_loss: 0.6903 | val_acc: 0.4900
# Epoch 034 | loss: 0.6890 | val_loss: 0.6901 | val_acc: 0.4750
# Epoch 035 | loss: 0.6888 | val_loss: 0.6901 | val_acc: 0.4900
# Epoch 036 | loss: 0.6887 | val_loss: 0.6900 | val_acc: 0.4950
# Epoch 037 | loss: 0.6886 | val_loss: 0.6899 | val_acc: 0.4850
# Epoch 038 | loss: 0.6885 | val_loss: 0.6899 | val_acc: 0.4950
# Epoch 039 | loss: 0.6884 | val_loss: 0.6898 | val_acc: 0.4950
# Epoch 040 | loss: 0.6883 | val_loss: 0.6897 | val_acc: 0.5000
# Epoch 041 | loss: 0.6882 | val_loss: 0.6896 | val_acc: 0.5000
# Epoch 042 | loss: 0.6881 | val_loss: 0.6895 | val_acc: 0.4950
# Epoch 043 | loss: 0.6881 | val_loss: 0.6894 | val_acc: 0.5200
# Epoch 044 | loss: 0.6879 | val_loss: 0.6893 | val_acc: 0.5000
# Epoch 045 | loss: 0.6878 | val_loss: 0.6892 | val_acc: 0.5100
# Epoch 046 | loss: 0.6878 | val_loss: 0.6891 | val_acc: 0.4950
# Epoch 047 | loss: 0.6875 | val_loss: 0.6889 | val_acc: 0.5200
# Epoch 048 | loss: 0.6874 | val_loss: 0.6889 | val_acc: 0.5300
# Epoch 049 | loss: 0.6872 | val_loss: 0.6887 | val_acc: 0.5250
# Epoch 050 | loss: 0.6873 | val_loss: 0.6886 | val_acc: 0.5450
# Epoch 051 | loss: 0.6869 | val_loss: 0.6885 | val_acc: 0.5350
# Epoch 052 | loss: 0.6867 | val_loss: 0.6883 | val_acc: 0.5300
# Epoch 053 | loss: 0.6866 | val_loss: 0.6882 | val_acc: 0.5350
# Epoch 054 | loss: 0.6865 | val_loss: 0.6881 | val_acc: 0.5450
# Epoch 055 | loss: 0.6862 | val_loss: 0.6879 | val_acc: 0.5450
# Epoch 056 | loss: 0.6861 | val_loss: 0.6877 | val_acc: 0.5450
# Epoch 057 | loss: 0.6859 | val_loss: 0.6875 | val_acc: 0.5450
# Epoch 058 | loss: 0.6857 | val_loss: 0.6874 | val_acc: 0.5450
# Epoch 059 | loss: 0.6856 | val_loss: 0.6872 | val_acc: 0.5450
# Epoch 060 | loss: 0.6853 | val_loss: 0.6869 | val_acc: 0.5500
# Epoch 061 | loss: 0.6851 | val_loss: 0.6868 | val_acc: 0.5500
# Epoch 062 | loss: 0.6848 | val_loss: 0.6866 | val_acc: 0.5600
# Epoch 063 | loss: 0.6847 | val_loss: 0.6863 | val_acc: 0.5600
# Epoch 064 | loss: 0.6844 | val_loss: 0.6861 | val_acc: 0.5700
# Epoch 065 | loss: 0.6841 | val_loss: 0.6859 | val_acc: 0.5650
# Epoch 066 | loss: 0.6838 | val_loss: 0.6857 | val_acc: 0.5700
# Epoch 067 | loss: 0.6837 | val_loss: 0.6855 | val_acc: 0.5700
# Epoch 068 | loss: 0.6834 | val_loss: 0.6851 | val_acc: 0.5700
# Epoch 069 | loss: 0.6831 | val_loss: 0.6849 | val_acc: 0.5750
# Epoch 070 | loss: 0.6828 | val_loss: 0.6847 | val_acc: 0.5450
# Epoch 071 | loss: 0.6825 | val_loss: 0.6842 | val_acc: 0.5600
# Epoch 072 | loss: 0.6823 | val_loss: 0.6840 | val_acc: 0.5600
# Epoch 073 | loss: 0.6818 | val_loss: 0.6838 | val_acc: 0.5800
# Epoch 074 | loss: 0.6815 | val_loss: 0.6835 | val_acc: 0.5800
# Epoch 075 | loss: 0.6812 | val_loss: 0.6831 | val_acc: 0.5700
# Epoch 076 | loss: 0.6809 | val_loss: 0.6827 | val_acc: 0.5750
# Epoch 077 | loss: 0.6805 | val_loss: 0.6825 | val_acc: 0.5850
# Epoch 078 | loss: 0.6801 | val_loss: 0.6822 | val_acc: 0.5950
# Epoch 079 | loss: 0.6799 | val_loss: 0.6818 | val_acc: 0.5950
# Epoch 080 | loss: 0.6795 | val_loss: 0.6816 | val_acc: 0.5950
# [SWISH] Acc: 0.5950 | Final train loss: 0.6795
#
# ------------------------------------------------------------
# Training with MISH activation...
# Epoch 001 | loss: 0.6931 | val_loss: 0.6898 | val_acc: 0.5200
# Epoch 002 | loss: 0.6927 | val_loss: 0.6898 | val_acc: 0.5100
# Epoch 003 | loss: 0.6923 | val_loss: 0.6895 | val_acc: 0.4950
# Epoch 004 | loss: 0.6920 | val_loss: 0.6894 | val_acc: 0.5000
# Epoch 005 | loss: 0.6918 | val_loss: 0.6894 | val_acc: 0.5350
# Epoch 006 | loss: 0.6916 | val_loss: 0.6893 | val_acc: 0.5350
# Epoch 007 | loss: 0.6914 | val_loss: 0.6891 | val_acc: 0.5350
# Epoch 008 | loss: 0.6913 | val_loss: 0.6892 | val_acc: 0.5650
# Epoch 009 | loss: 0.6911 | val_loss: 0.6892 | val_acc: 0.5750
# Epoch 010 | loss: 0.6913 | val_loss: 0.6889 | val_acc: 0.5450
# Epoch 011 | loss: 0.6908 | val_loss: 0.6891 | val_acc: 0.5800
# Epoch 012 | loss: 0.6907 | val_loss: 0.6891 | val_acc: 0.5800
# Epoch 013 | loss: 0.6908 | val_loss: 0.6890 | val_acc: 0.5800
# Epoch 014 | loss: 0.6906 | val_loss: 0.6890 | val_acc: 0.5400
# Epoch 015 | loss: 0.6904 | val_loss: 0.6890 | val_acc: 0.5500
# Epoch 016 | loss: 0.6904 | val_loss: 0.6890 | val_acc: 0.5400
# Epoch 017 | loss: 0.6903 | val_loss: 0.6889 | val_acc: 0.5450
# Epoch 018 | loss: 0.6905 | val_loss: 0.6887 | val_acc: 0.5450
# Epoch 019 | loss: 0.6902 | val_loss: 0.6887 | val_acc: 0.5400
# Epoch 020 | loss: 0.6902 | val_loss: 0.6888 | val_acc: 0.5250
# Epoch 021 | loss: 0.6901 | val_loss: 0.6889 | val_acc: 0.5400
# Epoch 022 | loss: 0.6899 | val_loss: 0.6887 | val_acc: 0.5450
# Epoch 023 | loss: 0.6897 | val_loss: 0.6886 | val_acc: 0.5450
# Epoch 024 | loss: 0.6897 | val_loss: 0.6885 | val_acc: 0.5450
# Epoch 025 | loss: 0.6896 | val_loss: 0.6886 | val_acc: 0.5450
# Epoch 026 | loss: 0.6895 | val_loss: 0.6885 | val_acc: 0.5350
# Epoch 027 | loss: 0.6895 | val_loss: 0.6884 | val_acc: 0.5350
# Epoch 028 | loss: 0.6893 | val_loss: 0.6885 | val_acc: 0.5350
# Epoch 029 | loss: 0.6894 | val_loss: 0.6883 | val_acc: 0.5350
# Epoch 030 | loss: 0.6892 | val_loss: 0.6885 | val_acc: 0.5400
# Epoch 031 | loss: 0.6891 | val_loss: 0.6883 | val_acc: 0.5350
# Epoch 032 | loss: 0.6890 | val_loss: 0.6882 | val_acc: 0.5350
# Epoch 033 | loss: 0.6890 | val_loss: 0.6882 | val_acc: 0.5350
# Epoch 034 | loss: 0.6889 | val_loss: 0.6880 | val_acc: 0.5350
# Epoch 035 | loss: 0.6887 | val_loss: 0.6880 | val_acc: 0.4900
# Epoch 036 | loss: 0.6887 | val_loss: 0.6880 | val_acc: 0.5200
# Epoch 037 | loss: 0.6886 | val_loss: 0.6878 | val_acc: 0.5000
# Epoch 038 | loss: 0.6884 | val_loss: 0.6878 | val_acc: 0.4950
# Epoch 039 | loss: 0.6883 | val_loss: 0.6878 | val_acc: 0.4950
# Epoch 040 | loss: 0.6882 | val_loss: 0.6875 | val_acc: 0.5000
# Epoch 041 | loss: 0.6882 | val_loss: 0.6875 | val_acc: 0.5100
# Epoch 042 | loss: 0.6881 | val_loss: 0.6875 | val_acc: 0.5450
# Epoch 043 | loss: 0.6881 | val_loss: 0.6874 | val_acc: 0.5550
# Epoch 044 | loss: 0.6878 | val_loss: 0.6873 | val_acc: 0.5250
# Epoch 045 | loss: 0.6878 | val_loss: 0.6870 | val_acc: 0.5500
# Epoch 046 | loss: 0.6879 | val_loss: 0.6871 | val_acc: 0.5100
# Epoch 047 | loss: 0.6875 | val_loss: 0.6868 | val_acc: 0.5100
# Epoch 048 | loss: 0.6874 | val_loss: 0.6869 | val_acc: 0.5450
# Epoch 049 | loss: 0.6872 | val_loss: 0.6867 | val_acc: 0.5000
# Epoch 050 | loss: 0.6874 | val_loss: 0.6866 | val_acc: 0.5550
# Epoch 051 | loss: 0.6870 | val_loss: 0.6866 | val_acc: 0.5050
# Epoch 052 | loss: 0.6868 | val_loss: 0.6864 | val_acc: 0.4900
# Epoch 053 | loss: 0.6867 | val_loss: 0.6862 | val_acc: 0.5250
# Epoch 054 | loss: 0.6866 | val_loss: 0.6862 | val_acc: 0.4450
# Epoch 055 | loss: 0.6864 | val_loss: 0.6861 | val_acc: 0.4500
# Epoch 056 | loss: 0.6863 | val_loss: 0.6859 | val_acc: 0.5200
# Epoch 057 | loss: 0.6862 | val_loss: 0.6858 | val_acc: 0.4750
# Epoch 058 | loss: 0.6860 | val_loss: 0.6856 | val_acc: 0.4800
# Epoch 059 | loss: 0.6859 | val_loss: 0.6855 | val_acc: 0.5350
# Epoch 060 | loss: 0.6856 | val_loss: 0.6853 | val_acc: 0.4750
# Epoch 061 | loss: 0.6855 | val_loss: 0.6852 | val_acc: 0.4900
# Epoch 062 | loss: 0.6853 | val_loss: 0.6851 | val_acc: 0.4700
# Epoch 063 | loss: 0.6852 | val_loss: 0.6848 | val_acc: 0.5350
# Epoch 064 | loss: 0.6851 | val_loss: 0.6848 | val_acc: 0.5700
# Epoch 065 | loss: 0.6849 | val_loss: 0.6846 | val_acc: 0.5150
# Epoch 066 | loss: 0.6846 | val_loss: 0.6845 | val_acc: 0.4950
# Epoch 067 | loss: 0.6846 | val_loss: 0.6844 | val_acc: 0.5050
# Epoch 068 | loss: 0.6843 | val_loss: 0.6841 | val_acc: 0.5050
# Epoch 069 | loss: 0.6842 | val_loss: 0.6840 | val_acc: 0.5050
# Epoch 070 | loss: 0.6840 | val_loss: 0.6839 | val_acc: 0.5300
# Epoch 071 | loss: 0.6837 | val_loss: 0.6834 | val_acc: 0.5500
# Epoch 072 | loss: 0.6837 | val_loss: 0.6834 | val_acc: 0.5650
# Epoch 073 | loss: 0.6833 | val_loss: 0.6833 | val_acc: 0.5100
# Epoch 074 | loss: 0.6831 | val_loss: 0.6830 | val_acc: 0.5200
# Epoch 075 | loss: 0.6828 | val_loss: 0.6828 | val_acc: 0.5300
# Epoch 076 | loss: 0.6827 | val_loss: 0.6824 | val_acc: 0.5350
# Epoch 077 | loss: 0.6825 | val_loss: 0.6825 | val_acc: 0.5300
# Epoch 078 | loss: 0.6822 | val_loss: 0.6822 | val_acc: 0.5350
# Epoch 079 | loss: 0.6820 | val_loss: 0.6819 | val_acc: 0.5550
# Epoch 080 | loss: 0.6819 | val_loss: 0.6820 | val_acc: 0.5450
# [MISH] Acc: 0.5450 | Final train loss: 0.6819
#
# ------------------------------------------------------------
# Training with GELU activation...
# Epoch 001 | loss: 0.7007 | val_loss: 0.7011 | val_acc: 0.5550
# Epoch 002 | loss: 0.6995 | val_loss: 0.7002 | val_acc: 0.5750
# Epoch 003 | loss: 0.6986 | val_loss: 0.6992 | val_acc: 0.5900
# Epoch 004 | loss: 0.6978 | val_loss: 0.6984 | val_acc: 0.6100
# Epoch 005 | loss: 0.6972 | val_loss: 0.6978 | val_acc: 0.6000
# Epoch 006 | loss: 0.6966 | val_loss: 0.6973 | val_acc: 0.5700
# Epoch 007 | loss: 0.6961 | val_loss: 0.6966 | val_acc: 0.5400
# Epoch 008 | loss: 0.6956 | val_loss: 0.6963 | val_acc: 0.5500
# Epoch 009 | loss: 0.6952 | val_loss: 0.6959 | val_acc: 0.5250
# Epoch 010 | loss: 0.6951 | val_loss: 0.6953 | val_acc: 0.4500
# Epoch 011 | loss: 0.6945 | val_loss: 0.6950 | val_acc: 0.4700
# Epoch 012 | loss: 0.6943 | val_loss: 0.6948 | val_acc: 0.4650
# Epoch 013 | loss: 0.6941 | val_loss: 0.6944 | val_acc: 0.4550
# Epoch 014 | loss: 0.6938 | val_loss: 0.6941 | val_acc: 0.4700
# Epoch 015 | loss: 0.6935 | val_loss: 0.6938 | val_acc: 0.5050
# Epoch 016 | loss: 0.6933 | val_loss: 0.6936 | val_acc: 0.5100
# Epoch 017 | loss: 0.6931 | val_loss: 0.6933 | val_acc: 0.5250
# Epoch 018 | loss: 0.6932 | val_loss: 0.6929 | val_acc: 0.5100
# Epoch 019 | loss: 0.6928 | val_loss: 0.6928 | val_acc: 0.5100
# Epoch 020 | loss: 0.6927 | val_loss: 0.6926 | val_acc: 0.5100
# Epoch 021 | loss: 0.6926 | val_loss: 0.6925 | val_acc: 0.5100
# Epoch 022 | loss: 0.6923 | val_loss: 0.6922 | val_acc: 0.5100
# Epoch 023 | loss: 0.6920 | val_loss: 0.6920 | val_acc: 0.5100
# Epoch 024 | loss: 0.6920 | val_loss: 0.6917 | val_acc: 0.5100
# Epoch 025 | loss: 0.6918 | val_loss: 0.6916 | val_acc: 0.5100
# Epoch 026 | loss: 0.6916 | val_loss: 0.6914 | val_acc: 0.5100
# Epoch 027 | loss: 0.6915 | val_loss: 0.6912 | val_acc: 0.5100
# Epoch 028 | loss: 0.6913 | val_loss: 0.6911 | val_acc: 0.5100
# Epoch 029 | loss: 0.6912 | val_loss: 0.6908 | val_acc: 0.5100
# Epoch 030 | loss: 0.6910 | val_loss: 0.6908 | val_acc: 0.5100
# Epoch 031 | loss: 0.6908 | val_loss: 0.6905 | val_acc: 0.5100
# Epoch 032 | loss: 0.6907 | val_loss: 0.6903 | val_acc: 0.5100
# Epoch 033 | loss: 0.6906 | val_loss: 0.6901 | val_acc: 0.5250
# Epoch 034 | loss: 0.6905 | val_loss: 0.6899 | val_acc: 0.5100
# Epoch 035 | loss: 0.6902 | val_loss: 0.6897 | val_acc: 0.5300
# Epoch 036 | loss: 0.6901 | val_loss: 0.6895 | val_acc: 0.5350
# Epoch 037 | loss: 0.6899 | val_loss: 0.6892 | val_acc: 0.5300
# Epoch 038 | loss: 0.6897 | val_loss: 0.6892 | val_acc: 0.5700
# Epoch 039 | loss: 0.6895 | val_loss: 0.6890 | val_acc: 0.5700
# Epoch 040 | loss: 0.6893 | val_loss: 0.6886 | val_acc: 0.5550
# Epoch 041 | loss: 0.6891 | val_loss: 0.6884 | val_acc: 0.5750
# Epoch 042 | loss: 0.6890 | val_loss: 0.6883 | val_acc: 0.5750
# Epoch 043 | loss: 0.6889 | val_loss: 0.6880 | val_acc: 0.5500
# Epoch 044 | loss: 0.6885 | val_loss: 0.6878 | val_acc: 0.5800
# Epoch 045 | loss: 0.6884 | val_loss: 0.6874 | val_acc: 0.5600
# Epoch 046 | loss: 0.6884 | val_loss: 0.6873 | val_acc: 0.5750
# Epoch 047 | loss: 0.6879 | val_loss: 0.6870 | val_acc: 0.5900
# Epoch 048 | loss: 0.6877 | val_loss: 0.6868 | val_acc: 0.5800
# Epoch 049 | loss: 0.6874 | val_loss: 0.6865 | val_acc: 0.6200
# Epoch 050 | loss: 0.6875 | val_loss: 0.6862 | val_acc: 0.5850
# Epoch 051 | loss: 0.6870 | val_loss: 0.6861 | val_acc: 0.6100
# Epoch 052 | loss: 0.6867 | val_loss: 0.6857 | val_acc: 0.6200
# Epoch 053 | loss: 0.6864 | val_loss: 0.6853 | val_acc: 0.6250
# Epoch 054 | loss: 0.6862 | val_loss: 0.6851 | val_acc: 0.6050
# Epoch 055 | loss: 0.6859 | val_loss: 0.6849 | val_acc: 0.6000
# Epoch 056 | loss: 0.6856 | val_loss: 0.6845 | val_acc: 0.5850
# Epoch 057 | loss: 0.6853 | val_loss: 0.6842 | val_acc: 0.5850
# Epoch 058 | loss: 0.6850 | val_loss: 0.6839 | val_acc: 0.6100
# Epoch 059 | loss: 0.6848 | val_loss: 0.6835 | val_acc: 0.6200
# Epoch 060 | loss: 0.6843 | val_loss: 0.6831 | val_acc: 0.6000
# Epoch 061 | loss: 0.6840 | val_loss: 0.6828 | val_acc: 0.6050
# Epoch 062 | loss: 0.6836 | val_loss: 0.6824 | val_acc: 0.5900
# Epoch 063 | loss: 0.6834 | val_loss: 0.6819 | val_acc: 0.6000
# Epoch 064 | loss: 0.6830 | val_loss: 0.6816 | val_acc: 0.5950
# Epoch 065 | loss: 0.6826 | val_loss: 0.6813 | val_acc: 0.6100
# Epoch 066 | loss: 0.6822 | val_loss: 0.6808 | val_acc: 0.6000
# Epoch 067 | loss: 0.6819 | val_loss: 0.6805 | val_acc: 0.6000
# Epoch 068 | loss: 0.6815 | val_loss: 0.6800 | val_acc: 0.6000
# Epoch 069 | loss: 0.6811 | val_loss: 0.6796 | val_acc: 0.6000
# Epoch 070 | loss: 0.6807 | val_loss: 0.6792 | val_acc: 0.5850
# Epoch 071 | loss: 0.6802 | val_loss: 0.6785 | val_acc: 0.6100
# Epoch 072 | loss: 0.6799 | val_loss: 0.6782 | val_acc: 0.6100
# Epoch 073 | loss: 0.6793 | val_loss: 0.6778 | val_acc: 0.6300
# Epoch 074 | loss: 0.6789 | val_loss: 0.6773 | val_acc: 0.6100
# Epoch 075 | loss: 0.6784 | val_loss: 0.6767 | val_acc: 0.6050
# Epoch 076 | loss: 0.6780 | val_loss: 0.6761 | val_acc: 0.6000
# Epoch 077 | loss: 0.6775 | val_loss: 0.6759 | val_acc: 0.5950
# Epoch 078 | loss: 0.6770 | val_loss: 0.6754 | val_acc: 0.5950
# Epoch 079 | loss: 0.6766 | val_loss: 0.6748 | val_acc: 0.5850
# Epoch 080 | loss: 0.6762 | val_loss: 0.6745 | val_acc: 0.6100
# [GELU] Acc: 0.6100 | Final train loss: 0.6762
#
# ------------------------------------------------------------
# Training with SINE activation...
# Epoch 001 | loss: 0.6954 | val_loss: 0.6964 | val_acc: 0.3900
# Epoch 002 | loss: 0.6941 | val_loss: 0.6956 | val_acc: 0.4350
# Epoch 003 | loss: 0.6935 | val_loss: 0.6946 | val_acc: 0.5850
# Epoch 004 | loss: 0.6930 | val_loss: 0.6941 | val_acc: 0.5550
# Epoch 005 | loss: 0.6928 | val_loss: 0.6939 | val_acc: 0.5350
# Epoch 006 | loss: 0.6926 | val_loss: 0.6937 | val_acc: 0.5050
# Epoch 007 | loss: 0.6925 | val_loss: 0.6932 | val_acc: 0.4550
# Epoch 008 | loss: 0.6924 | val_loss: 0.6933 | val_acc: 0.4550
# Epoch 009 | loss: 0.6924 | val_loss: 0.6932 | val_acc: 0.4550
# Epoch 010 | loss: 0.6926 | val_loss: 0.6928 | val_acc: 0.4400
# Epoch 011 | loss: 0.6922 | val_loss: 0.6929 | val_acc: 0.4400
# Epoch 012 | loss: 0.6922 | val_loss: 0.6929 | val_acc: 0.4400
# Epoch 013 | loss: 0.6924 | val_loss: 0.6928 | val_acc: 0.4250
# Epoch 014 | loss: 0.6923 | val_loss: 0.6927 | val_acc: 0.4400
# Epoch 015 | loss: 0.6921 | val_loss: 0.6927 | val_acc: 0.4400
# Epoch 016 | loss: 0.6921 | val_loss: 0.6927 | val_acc: 0.4300
# Epoch 017 | loss: 0.6921 | val_loss: 0.6926 | val_acc: 0.4250
# Epoch 018 | loss: 0.6925 | val_loss: 0.6924 | val_acc: 0.4500
# Epoch 019 | loss: 0.6922 | val_loss: 0.6925 | val_acc: 0.4350
# Epoch 020 | loss: 0.6922 | val_loss: 0.6925 | val_acc: 0.4450
# Epoch 021 | loss: 0.6922 | val_loss: 0.6926 | val_acc: 0.4600
# Epoch 022 | loss: 0.6921 | val_loss: 0.6924 | val_acc: 0.4250
# Epoch 023 | loss: 0.6919 | val_loss: 0.6924 | val_acc: 0.4250
# Epoch 024 | loss: 0.6920 | val_loss: 0.6923 | val_acc: 0.4400
# Epoch 025 | loss: 0.6919 | val_loss: 0.6924 | val_acc: 0.4300
# Epoch 026 | loss: 0.6919 | val_loss: 0.6924 | val_acc: 0.4350
# Epoch 027 | loss: 0.6919 | val_loss: 0.6923 | val_acc: 0.4250
# Epoch 028 | loss: 0.6919 | val_loss: 0.6924 | val_acc: 0.4300
# Epoch 029 | loss: 0.6920 | val_loss: 0.6923 | val_acc: 0.4400
# Epoch 030 | loss: 0.6919 | val_loss: 0.6924 | val_acc: 0.4250
# Epoch 031 | loss: 0.6918 | val_loss: 0.6923 | val_acc: 0.4300
# Epoch 032 | loss: 0.6919 | val_loss: 0.6923 | val_acc: 0.4400
# Epoch 033 | loss: 0.6919 | val_loss: 0.6923 | val_acc: 0.4650
# Epoch 034 | loss: 0.6919 | val_loss: 0.6922 | val_acc: 0.4450
# Epoch 035 | loss: 0.6918 | val_loss: 0.6923 | val_acc: 0.4400
# Epoch 036 | loss: 0.6918 | val_loss: 0.6923 | val_acc: 0.4600
# Epoch 037 | loss: 0.6918 | val_loss: 0.6921 | val_acc: 0.4400
# Epoch 038 | loss: 0.6917 | val_loss: 0.6923 | val_acc: 0.4300
# Epoch 039 | loss: 0.6917 | val_loss: 0.6923 | val_acc: 0.4400
# Epoch 040 | loss: 0.6917 | val_loss: 0.6921 | val_acc: 0.4450
# Epoch 041 | loss: 0.6917 | val_loss: 0.6922 | val_acc: 0.4350
# Epoch 042 | loss: 0.6917 | val_loss: 0.6922 | val_acc: 0.4400
# Epoch 043 | loss: 0.6918 | val_loss: 0.6922 | val_acc: 0.4700
# Epoch 044 | loss: 0.6916 | val_loss: 0.6921 | val_acc: 0.4250
# Epoch 045 | loss: 0.6917 | val_loss: 0.6920 | val_acc: 0.4500
# Epoch 046 | loss: 0.6919 | val_loss: 0.6921 | val_acc: 0.4400
# Epoch 047 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4400
# Epoch 048 | loss: 0.6916 | val_loss: 0.6921 | val_acc: 0.4650
# Epoch 049 | loss: 0.6915 | val_loss: 0.6921 | val_acc: 0.4250
# Epoch 050 | loss: 0.6918 | val_loss: 0.6920 | val_acc: 0.4750
# Epoch 051 | loss: 0.6916 | val_loss: 0.6922 | val_acc: 0.4300
# Epoch 052 | loss: 0.6914 | val_loss: 0.6920 | val_acc: 0.4250
# Epoch 053 | loss: 0.6914 | val_loss: 0.6920 | val_acc: 0.4350
# Epoch 054 | loss: 0.6915 | val_loss: 0.6920 | val_acc: 0.4300
# Epoch 055 | loss: 0.6914 | val_loss: 0.6920 | val_acc: 0.4550
# Epoch 056 | loss: 0.6914 | val_loss: 0.6920 | val_acc: 0.4700
# Epoch 057 | loss: 0.6914 | val_loss: 0.6919 | val_acc: 0.4600
# Epoch 058 | loss: 0.6914 | val_loss: 0.6919 | val_acc: 0.4400
# Epoch 059 | loss: 0.6914 | val_loss: 0.6919 | val_acc: 0.4450
# Epoch 060 | loss: 0.6913 | val_loss: 0.6918 | val_acc: 0.4400
# Epoch 061 | loss: 0.6913 | val_loss: 0.6919 | val_acc: 0.4300
# Epoch 062 | loss: 0.6912 | val_loss: 0.6919 | val_acc: 0.4400
# Epoch 063 | loss: 0.6914 | val_loss: 0.6917 | val_acc: 0.4600
# Epoch 064 | loss: 0.6913 | val_loss: 0.6919 | val_acc: 0.4700
# Epoch 065 | loss: 0.6912 | val_loss: 0.6919 | val_acc: 0.4350
# Epoch 066 | loss: 0.6912 | val_loss: 0.6918 | val_acc: 0.4300
# Epoch 067 | loss: 0.6913 | val_loss: 0.6919 | val_acc: 0.4600
# Epoch 068 | loss: 0.6913 | val_loss: 0.6918 | val_acc: 0.4450
# Epoch 069 | loss: 0.6912 | val_loss: 0.6918 | val_acc: 0.4600
# Epoch 070 | loss: 0.6912 | val_loss: 0.6918 | val_acc: 0.4350
# Epoch 071 | loss: 0.6911 | val_loss: 0.6916 | val_acc: 0.4450
# Epoch 072 | loss: 0.6912 | val_loss: 0.6917 | val_acc: 0.4450
# Epoch 073 | loss: 0.6911 | val_loss: 0.6917 | val_acc: 0.4650
# Epoch 074 | loss: 0.6910 | val_loss: 0.6917 | val_acc: 0.4600
# Epoch 075 | loss: 0.6910 | val_loss: 0.6916 | val_acc: 0.4600
# Epoch 076 | loss: 0.6910 | val_loss: 0.6915 | val_acc: 0.4500
# Epoch 077 | loss: 0.6909 | val_loss: 0.6917 | val_acc: 0.4400
# Epoch 078 | loss: 0.6909 | val_loss: 0.6916 | val_acc: 0.4250
# Epoch 079 | loss: 0.6909 | val_loss: 0.6915 | val_acc: 0.4250
# Epoch 080 | loss: 0.6909 | val_loss: 0.6917 | val_acc: 0.4450
# [SINE] Acc: 0.4450 | Final train loss: 0.6909
#
# ------------------------------------------------------------
# Training with SIGMOID activation...
# Epoch 001 | loss: 0.8792 | val_loss: 0.8597 | val_acc: 0.5100
# Epoch 002 | loss: 0.8438 | val_loss: 0.8263 | val_acc: 0.5100
# Epoch 003 | loss: 0.8130 | val_loss: 0.7985 | val_acc: 0.5100
# Epoch 004 | loss: 0.7873 | val_loss: 0.7754 | val_acc: 0.5100
# Epoch 005 | loss: 0.7659 | val_loss: 0.7568 | val_acc: 0.5100
# Epoch 006 | loss: 0.7487 | val_loss: 0.7414 | val_acc: 0.5100
# Epoch 007 | loss: 0.7348 | val_loss: 0.7292 | val_acc: 0.5100
# Epoch 008 | loss: 0.7240 | val_loss: 0.7194 | val_acc: 0.5100
# Epoch 009 | loss: 0.7154 | val_loss: 0.7120 | val_acc: 0.5100
# Epoch 010 | loss: 0.7086 | val_loss: 0.7071 | val_acc: 0.5100
# Epoch 011 | loss: 0.7041 | val_loss: 0.7024 | val_acc: 0.5100
# Epoch 012 | loss: 0.7002 | val_loss: 0.6994 | val_acc: 0.5100
# Epoch 013 | loss: 0.6976 | val_loss: 0.6973 | val_acc: 0.5100
# Epoch 014 | loss: 0.6960 | val_loss: 0.6954 | val_acc: 0.5100
# Epoch 015 | loss: 0.6944 | val_loss: 0.6944 | val_acc: 0.5100
# Epoch 016 | loss: 0.6935 | val_loss: 0.6937 | val_acc: 0.5100
# Epoch 017 | loss: 0.6929 | val_loss: 0.6931 | val_acc: 0.5100
# Epoch 018 | loss: 0.6926 | val_loss: 0.6929 | val_acc: 0.5500
# Epoch 019 | loss: 0.6923 | val_loss: 0.6925 | val_acc: 0.4800
# Epoch 020 | loss: 0.6920 | val_loss: 0.6924 | val_acc: 0.4750
# Epoch 021 | loss: 0.6920 | val_loss: 0.6922 | val_acc: 0.4400
# Epoch 022 | loss: 0.6918 | val_loss: 0.6922 | val_acc: 0.4400
# Epoch 023 | loss: 0.6917 | val_loss: 0.6921 | val_acc: 0.5150
# Epoch 024 | loss: 0.6917 | val_loss: 0.6921 | val_acc: 0.4750
# Epoch 025 | loss: 0.6916 | val_loss: 0.6921 | val_acc: 0.4500
# Epoch 026 | loss: 0.6916 | val_loss: 0.6921 | val_acc: 0.4450
# Epoch 027 | loss: 0.6916 | val_loss: 0.6921 | val_acc: 0.4400
# Epoch 028 | loss: 0.6916 | val_loss: 0.6921 | val_acc: 0.4350
# Epoch 029 | loss: 0.6917 | val_loss: 0.6921 | val_acc: 0.4400
# Epoch 030 | loss: 0.6916 | val_loss: 0.6921 | val_acc: 0.4450
# Epoch 031 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4450
# Epoch 032 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4400
# Epoch 033 | loss: 0.6917 | val_loss: 0.6920 | val_acc: 0.4550
# Epoch 034 | loss: 0.6917 | val_loss: 0.6920 | val_acc: 0.4450
# Epoch 035 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4500
# Epoch 036 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4550
# Epoch 037 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4500
# Epoch 038 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4550
# Epoch 039 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4550
# Epoch 040 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4550
# Epoch 041 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4500
# Epoch 042 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4550
# Epoch 043 | loss: 0.6917 | val_loss: 0.6920 | val_acc: 0.4350
# Epoch 044 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4500
# Epoch 045 | loss: 0.6917 | val_loss: 0.6920 | val_acc: 0.4550
# Epoch 046 | loss: 0.6919 | val_loss: 0.6920 | val_acc: 0.4400
# Epoch 047 | loss: 0.6915 | val_loss: 0.6920 | val_acc: 0.4550
# Epoch 048 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4400
# Epoch 049 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4550
# Epoch 050 | loss: 0.6919 | val_loss: 0.6920 | val_acc: 0.4500
# Epoch 051 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4500
# Epoch 052 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4550
# Epoch 053 | loss: 0.6915 | val_loss: 0.6920 | val_acc: 0.4500
# Epoch 054 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4500
# Epoch 055 | loss: 0.6915 | val_loss: 0.6920 | val_acc: 0.4350
# Epoch 056 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4450
# Epoch 057 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4450
# Epoch 058 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4500
# Epoch 059 | loss: 0.6917 | val_loss: 0.6920 | val_acc: 0.4450
# Epoch 060 | loss: 0.6915 | val_loss: 0.6920 | val_acc: 0.4500
# Epoch 061 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4550
# Epoch 062 | loss: 0.6915 | val_loss: 0.6920 | val_acc: 0.4450
# Epoch 063 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4450
# Epoch 064 | loss: 0.6917 | val_loss: 0.6920 | val_acc: 0.4450
# Epoch 065 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4500
# Epoch 066 | loss: 0.6915 | val_loss: 0.6920 | val_acc: 0.4550
# Epoch 067 | loss: 0.6917 | val_loss: 0.6920 | val_acc: 0.4350
# Epoch 068 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4550
# Epoch 069 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4450
# Epoch 070 | loss: 0.6917 | val_loss: 0.6920 | val_acc: 0.4550
# Epoch 071 | loss: 0.6915 | val_loss: 0.6920 | val_acc: 0.4550
# Epoch 072 | loss: 0.6917 | val_loss: 0.6920 | val_acc: 0.4450
# Epoch 073 | loss: 0.6915 | val_loss: 0.6920 | val_acc: 0.4450
# Epoch 074 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4450
# Epoch 075 | loss: 0.6915 | val_loss: 0.6920 | val_acc: 0.4350
# Epoch 076 | loss: 0.6915 | val_loss: 0.6920 | val_acc: 0.4400
# Epoch 077 | loss: 0.6915 | val_loss: 0.6920 | val_acc: 0.4450
# Epoch 078 | loss: 0.6915 | val_loss: 0.6920 | val_acc: 0.4500
# Epoch 079 | loss: 0.6915 | val_loss: 0.6920 | val_acc: 0.4450
# Epoch 080 | loss: 0.6916 | val_loss: 0.6920 | val_acc: 0.4400
# [SIGMOID] Acc: 0.4400 | Final train loss: 0.6916
#
# ------------------------------------------------------------
# Training with TANH activation...
# Epoch 001 | loss: 0.7250 | val_loss: 0.7066 | val_acc: 0.5300
# Epoch 002 | loss: 0.7203 | val_loss: 0.7035 | val_acc: 0.5250
# Epoch 003 | loss: 0.7159 | val_loss: 0.7012 | val_acc: 0.5150
# Epoch 004 | loss: 0.7126 | val_loss: 0.6991 | val_acc: 0.5100
# Epoch 005 | loss: 0.7097 | val_loss: 0.6974 | val_acc: 0.5200
# Epoch 006 | loss: 0.7071 | val_loss: 0.6960 | val_acc: 0.5100
# Epoch 007 | loss: 0.7048 | val_loss: 0.6951 | val_acc: 0.5100
# Epoch 008 | loss: 0.7033 | val_loss: 0.6941 | val_acc: 0.5100
# Epoch 009 | loss: 0.7015 | val_loss: 0.6934 | val_acc: 0.5100
# Epoch 010 | loss: 0.7002 | val_loss: 0.6927 | val_acc: 0.5200
# Epoch 011 | loss: 0.6990 | val_loss: 0.6922 | val_acc: 0.5200
# Epoch 012 | loss: 0.6979 | val_loss: 0.6918 | val_acc: 0.5150
# Epoch 013 | loss: 0.6972 | val_loss: 0.6914 | val_acc: 0.5100
# Epoch 014 | loss: 0.6964 | val_loss: 0.6913 | val_acc: 0.5300
# Epoch 015 | loss: 0.6956 | val_loss: 0.6911 | val_acc: 0.5250
# Epoch 016 | loss: 0.6951 | val_loss: 0.6911 | val_acc: 0.5200
# Epoch 017 | loss: 0.6946 | val_loss: 0.6910 | val_acc: 0.5350
# Epoch 018 | loss: 0.6946 | val_loss: 0.6909 | val_acc: 0.4600
# Epoch 019 | loss: 0.6940 | val_loss: 0.6910 | val_acc: 0.4800
# Epoch 020 | loss: 0.6938 | val_loss: 0.6910 | val_acc: 0.5000
# Epoch 021 | loss: 0.6936 | val_loss: 0.6912 | val_acc: 0.5300
# Epoch 022 | loss: 0.6933 | val_loss: 0.6911 | val_acc: 0.5650
# Epoch 023 | loss: 0.6930 | val_loss: 0.6912 | val_acc: 0.5950
# Epoch 024 | loss: 0.6929 | val_loss: 0.6912 | val_acc: 0.5950
# Epoch 025 | loss: 0.6928 | val_loss: 0.6914 | val_acc: 0.6100
# Epoch 026 | loss: 0.6927 | val_loss: 0.6914 | val_acc: 0.6050
# Epoch 027 | loss: 0.6926 | val_loss: 0.6915 | val_acc: 0.6000
# Epoch 028 | loss: 0.6925 | val_loss: 0.6916 | val_acc: 0.5650
# Epoch 029 | loss: 0.6926 | val_loss: 0.6915 | val_acc: 0.5500
# Epoch 030 | loss: 0.6925 | val_loss: 0.6918 | val_acc: 0.5150
# Epoch 031 | loss: 0.6923 | val_loss: 0.6917 | val_acc: 0.5200
# Epoch 032 | loss: 0.6923 | val_loss: 0.6918 | val_acc: 0.5150
# Epoch 033 | loss: 0.6924 | val_loss: 0.6919 | val_acc: 0.4950
# Epoch 034 | loss: 0.6923 | val_loss: 0.6918 | val_acc: 0.4950
# Epoch 035 | loss: 0.6922 | val_loss: 0.6919 | val_acc: 0.4850
# Epoch 036 | loss: 0.6922 | val_loss: 0.6919 | val_acc: 0.4800
# Epoch 037 | loss: 0.6921 | val_loss: 0.6918 | val_acc: 0.4800
# Epoch 038 | loss: 0.6921 | val_loss: 0.6919 | val_acc: 0.4700
# Epoch 039 | loss: 0.6921 | val_loss: 0.6920 | val_acc: 0.4700
# Epoch 040 | loss: 0.6921 | val_loss: 0.6918 | val_acc: 0.4700
# Epoch 041 | loss: 0.6921 | val_loss: 0.6919 | val_acc: 0.4700
# Epoch 042 | loss: 0.6920 | val_loss: 0.6919 | val_acc: 0.4650
# Epoch 043 | loss: 0.6921 | val_loss: 0.6919 | val_acc: 0.4750
# Epoch 044 | loss: 0.6919 | val_loss: 0.6919 | val_acc: 0.4650
# Epoch 045 | loss: 0.6920 | val_loss: 0.6917 | val_acc: 0.4750
# Epoch 046 | loss: 0.6922 | val_loss: 0.6919 | val_acc: 0.4450
# Epoch 047 | loss: 0.6919 | val_loss: 0.6917 | val_acc: 0.4700
# Epoch 048 | loss: 0.6919 | val_loss: 0.6918 | val_acc: 0.4650
# Epoch 049 | loss: 0.6918 | val_loss: 0.6918 | val_acc: 0.4650
# Epoch 050 | loss: 0.6921 | val_loss: 0.6918 | val_acc: 0.4650
# Epoch 051 | loss: 0.6918 | val_loss: 0.6919 | val_acc: 0.4450
# Epoch 052 | loss: 0.6917 | val_loss: 0.6918 | val_acc: 0.4650
# Epoch 053 | loss: 0.6917 | val_loss: 0.6917 | val_acc: 0.4650
# Epoch 054 | loss: 0.6917 | val_loss: 0.6917 | val_acc: 0.4600
# Epoch 055 | loss: 0.6916 | val_loss: 0.6917 | val_acc: 0.4600
# Epoch 056 | loss: 0.6917 | val_loss: 0.6917 | val_acc: 0.4600
# Epoch 057 | loss: 0.6916 | val_loss: 0.6916 | val_acc: 0.4600
# Epoch 058 | loss: 0.6916 | val_loss: 0.6916 | val_acc: 0.4600
# Epoch 059 | loss: 0.6916 | val_loss: 0.6916 | val_acc: 0.4500
# Epoch 060 | loss: 0.6915 | val_loss: 0.6915 | val_acc: 0.4650
# Epoch 061 | loss: 0.6915 | val_loss: 0.6915 | val_acc: 0.4650
# Epoch 062 | loss: 0.6914 | val_loss: 0.6915 | val_acc: 0.4600
# Epoch 063 | loss: 0.6915 | val_loss: 0.6913 | val_acc: 0.4700
# Epoch 064 | loss: 0.6914 | val_loss: 0.6914 | val_acc: 0.4600
# Epoch 065 | loss: 0.6914 | val_loss: 0.6914 | val_acc: 0.4450
# Epoch 066 | loss: 0.6913 | val_loss: 0.6914 | val_acc: 0.4650
# Epoch 067 | loss: 0.6914 | val_loss: 0.6914 | val_acc: 0.4550
# Epoch 068 | loss: 0.6913 | val_loss: 0.6913 | val_acc: 0.4550
# Epoch 069 | loss: 0.6913 | val_loss: 0.6913 | val_acc: 0.4550
# Epoch 070 | loss: 0.6913 | val_loss: 0.6913 | val_acc: 0.4500
# Epoch 071 | loss: 0.6912 | val_loss: 0.6910 | val_acc: 0.4650
# Epoch 072 | loss: 0.6913 | val_loss: 0.6912 | val_acc: 0.4600
# Epoch 073 | loss: 0.6911 | val_loss: 0.6911 | val_acc: 0.4550
# Epoch 074 | loss: 0.6910 | val_loss: 0.6911 | val_acc: 0.4600
# Epoch 075 | loss: 0.6910 | val_loss: 0.6910 | val_acc: 0.4600
# Epoch 076 | loss: 0.6910 | val_loss: 0.6908 | val_acc: 0.4750
# Epoch 077 | loss: 0.6910 | val_loss: 0.6910 | val_acc: 0.4600
# Epoch 078 | loss: 0.6909 | val_loss: 0.6909 | val_acc: 0.4600
# Epoch 079 | loss: 0.6909 | val_loss: 0.6908 | val_acc: 0.4650
# Epoch 080 | loss: 0.6909 | val_loss: 0.6910 | val_acc: 0.4600
# [TANH] Acc: 0.4600 | Final train loss: 0.6909
#
#
# ============================================================
# ACTIVATIONS: lasa, relu, leaky_relu, elu, softplus, swish, mish, gelu, sine, sigmoid, tanh
# ============================================================
#
# ============================================================
# FINAL RESULTS COMPARISON
# ============================================================
# Rank   Activation      Accuracy     Final Train Loss
# ------------------------------------------------------------
# 1      LASA            0.9550       0.2298
# 2      GELU            0.6100       0.6762
# 3      SWISH           0.5950       0.6795
# 4      LEAKY_RELU      0.5600       0.6340
# 5      MISH            0.5450       0.6819
# 6      RELU            0.5250       0.6585
# 7      ELU             0.4600       0.6911
# 8      TANH            0.4600       0.6909
# 9      SOFTPLUS        0.4550       0.6894
# 10     SINE            0.4450       0.6909
# 11     SIGMOID         0.4400       0.6916
# ============================================================
