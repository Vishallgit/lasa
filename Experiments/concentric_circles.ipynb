# %%
pip install mlxtend
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mlxtend in ./.local/lib/python3.10/site-packages (0.23.4)
# Requirement already satisfied: scipy>=1.2.1 in ./.local/lib/python3.10/site-packages (from mlxtend) (1.15.3)
# Requirement already satisfied: numpy>=1.16.2 in ./.local/lib/python3.10/site-packages (from mlxtend) (1.24.3)
# Requirement already satisfied: pandas>=0.24.2 in ./.local/lib/python3.10/site-packages (from mlxtend) (2.3.2)
# Requirement already satisfied: scikit-learn>=1.3.1 in ./.local/lib/python3.10/site-packages (from mlxtend) (1.7.1)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/lib/python3/dist-packages (from mlxtend) (3.5.1)
# Requirement already satisfied: joblib>=0.13.2 in ./.local/lib/python3.10/site-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=0.24.2->mlxtend) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.local/lib/python3.10/site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.local/lib/python3.10/site-packages (from pandas>=0.24.2->mlxtend) (2.9.0.post0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/lib/python3/dist-packages (from scikit-learn>=1.3.1->mlxtend) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas>=0.24.2->mlxtend) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os, math, warnings
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles
from mlxtend.plotting import plot_decision_regions

warnings.filterwarnings('ignore')
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from IPython.display import display, HTML
display(HTML("<style>.output_scroll {height:auto !important; max-height:none !important;}</style>"))

SEED = 42
np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)

print("="*60)
print("GPU CONFIGURATION")
print("="*60)
gpus = tf.config.list_physical_devices('GPU')
USE_GPU = bool(gpus)
if USE_GPU:
    print(f"GPUs available: {len(gpus)}")
    for gpu in gpus:
        print("  -", gpu)
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU memory growth enabled")
    except RuntimeError as e:
        print(e)
else:
    print("No GPUs available, using CPU")

policy_name = 'mixed_float16' if USE_GPU else 'float32'
tf.keras.mixed_precision.set_global_policy(policy_name)
print(f"Mixed precision policy: {tf.keras.mixed_precision.global_policy().name}")
print("="*60 + "\n")

USE_XLA = USE_GPU

def inv_softplus(y):
    y = np.maximum(float(y), 1e-6)
    return np.log(np.expm1(y))

def generate_circles(n_samples=2000, noise=0.1, factor=0.5, random_state=42):
    X, y = make_circles(n_samples=n_samples, noise=noise, factor=factor, random_state=random_state)
    return X.astype(np.float32), y.astype(np.int32)

class LASAActivation(tf.keras.layers.Layer):
    def __init__(self, theta_degrees=45.0, lambda_window=3e-4,
                 penalty_mode='hinge', hybrid_alpha=0.1,
                 enforce_gain_cap=False, gain_cap=1.25,
                 initial_frequency=1.6, name=None, **kwargs):
        super().__init__(name=name, **kwargs)
        self.theta_degrees     = float(theta_degrees)
        self.lambda_window     = float(lambda_window)
        self.penalty_mode      = str(penalty_mode)
        self.hybrid_alpha      = float(hybrid_alpha)
        self.enforce_gain_cap  = bool(enforce_gain_cap)
        self.gain_cap          = float(gain_cap)
        self.initial_frequency = float(initial_frequency)

    def build(self, input_shape):
        self.theta_rad = tf.constant(self.theta_degrees * math.pi/180.0, dtype=tf.float32)
        self.sin_theta = tf.sin(self.theta_rad)

        self.penalty_scale = self.add_weight(
            shape=(), name='penalty_scale', dtype=tf.float32, trainable=False,
            initializer=tf.keras.initializers.Constant(1.0)
        )

        if self.enforce_gain_cap:
            denom   = tf.maximum(self.sin_theta, tf.constant(1e-6, tf.float32))
            k_max_v = float(self.gain_cap) / float(denom.numpy())
            self.k_max = tf.constant(k_max_v, dtype=tf.float32)
            ratio = np.clip(self.initial_frequency / k_max_v, 1e-6, 1.0-1e-6)
            rho0  = np.log(ratio/(1.0 - ratio))
        else:
            self.k_max = None
            rho0 = inv_softplus(self.initial_frequency)

        self.rho = self.add_weight(shape=(), name='rho', dtype=tf.float32, trainable=True,
                                   initializer=tf.keras.initializers.Constant(float(rho0)))

    @property
    def tau_value(self):
        if self.enforce_gain_cap:
            return self.k_max * tf.nn.sigmoid(self.rho)
        return tf.nn.softplus(self.rho)

    def set_penalty_scale(self, scale):
        self.penalty_scale.assign(tf.cast(scale, tf.float32))

    def scale_down_penalty(self, factor=0.8, min_scale=0.05):
        new_scale = tf.maximum(self.penalty_scale * tf.cast(factor, tf.float32),
                               tf.constant(min_scale, tf.float32))
        self.penalty_scale.assign(new_scale)

    def _penalty(self, inputs, tau32):
        if self.lambda_window <= 0.0:
            return None
        x32     = tf.cast(inputs, tf.float32)
        cos_phi = tf.math.cos(tau32 * x32)
        abs_cos = tf.abs(cos_phi)

        if self.penalty_mode == 'hinge':
            margin = self.sin_theta
            viol   = tf.maximum(abs_cos - margin, 0.0)
            pen    = tf.reduce_mean(tf.square(viol))
        elif self.penalty_mode == 'cos2':
            pen    = tf.reduce_mean(tf.square(cos_phi))
        elif self.penalty_mode == 'hybrid':
            margin = self.sin_theta
            viol   = tf.maximum(abs_cos - margin, 0.0)
            hinge  = tf.reduce_mean(tf.square(viol))
            cos2   = tf.reduce_mean(tf.square(cos_phi))
            pen    = self.hybrid_alpha * cos2 + hinge
        else:
            raise ValueError("penalty_mode must be 'hinge', 'cos2', or 'hybrid'.")

        lw32    = tf.cast(self.lambda_window, tf.float32)
        scale32 = tf.cast(self.penalty_scale, tf.float32)
        return lw32 * scale32 * pen

    def call(self, inputs):
        tau32 = tf.cast(self.tau_value, tf.float32)
        pen = self._penalty(inputs, tau32)
        if pen is not None:
            self.add_loss(pen)
        x32 = tf.cast(inputs, tf.float32)
        y32 = tf.math.sin(tau32 * x32)
        return tf.cast(y32, inputs.dtype)

class SwishActivation(tf.keras.layers.Layer):
    def call(self, inputs):
        x = tf.cast(inputs, tf.float32)
        y = x * tf.nn.sigmoid(x)
        return tf.cast(y, inputs.dtype)

class MishActivation(tf.keras.layers.Layer):
    def call(self, inputs):
        x = tf.cast(inputs, tf.float32)
        y = x * tf.math.tanh(tf.math.softplus(x))
        return tf.cast(y, inputs.dtype)

def create_model(activation_type,
                 hidden_units=[6],
                 initial_frequency=1.6,
                 theta_degrees=45.0, lambda_window=3e-4,
                 penalty_mode='hinge', hybrid_alpha=0.1,
                 enforce_gain_cap=False, gain_cap=1.25):
    with tf.device('/GPU:0' if USE_GPU else '/CPU:0'):
        model = tf.keras.Sequential([tf.keras.layers.Input(shape=(2,))])
        for i, units in enumerate(hidden_units):
            model.add(tf.keras.layers.Dense(units, name=f'dense_{i}'))
            a = activation_type.lower()
            if a == 'lasa':
                model.add(LASAActivation(
                    theta_degrees=theta_degrees,
                    lambda_window=lambda_window,
                    penalty_mode=penalty_mode, hybrid_alpha=hybrid_alpha,
                    enforce_gain_cap=enforce_gain_cap, gain_cap=gain_cap,
                    initial_frequency=initial_frequency,
                    name=f'lasa_{i}'
                ))
            elif a == 'relu':
                model.add(tf.keras.layers.ReLU(name=f'relu_{i}'))
            elif a == 'leaky_relu':
                model.add(tf.keras.layers.LeakyReLU(alpha=0.01, name=f'leaky_relu_{i}'))
            elif a == 'elu':
                model.add(tf.keras.layers.ELU(alpha=1.0, name=f'elu_{i}'))
            elif a == 'softplus':
                model.add(tf.keras.layers.Activation('softplus', name=f'softplus_{i}'))
            elif a == 'swish':
                model.add(SwishActivation(name=f'swish_{i}'))
            elif a == 'mish':
                model.add(MishActivation(name=f'mish_{i}'))
            elif a == 'gelu':
                model.add(tf.keras.layers.Lambda(lambda z: tf.nn.gelu(z), name=f'gelu_{i}'))
            elif a == 'sine':
                model.add(tf.keras.layers.Lambda(lambda z: tf.math.sin(z), name=f'sine_{i}'))
            elif a == 'sigmoid':
                model.add(tf.keras.layers.Activation('sigmoid', name=f'sigmoid_{i}'))
            elif a == 'tanh':
                model.add(tf.keras.layers.Activation('tanh', name=f'tanh_{i}'))
            else:
                raise ValueError(f"Unknown activation_type: {activation_type}")

        model.add(tf.keras.layers.Dense(1, activation='sigmoid', dtype='float32', name='output'))
    return model

class LASATrainer:
    def __init__(self, model,
                 lr_main=1e-3, lr_tau=1e-2,
                 clipnorm_main=1.0, clipnorm_tau=0.5,
                 penalty_warmup_epochs=8,
                 acc_eps=2.5e-3, loss_eps=1e-4,
                 reverse_tau_grads=True, revert_rho_to_snapshot=True,
                 shrink_tau_lr=True, tau_lr_decay=0.5, min_tau_lr=1e-5,
                 shrink_penalty=True, penalty_decay=0.8, min_penalty_scale=0.05,
                 stagnation_window=10, improve_threshold=0.05,
                 bump_delta_k=1.0, min_epochs_between_bumps=10,
                 acc_drop_threshold=0.20):
        self.model = model
        self.loss_fn = tf.keras.losses.BinaryCrossentropy()
        self.optimizer_main = tf.keras.optimizers.Adam(learning_rate=lr_main, clipnorm=clipnorm_main)
        self.optimizer_tau  = tf.keras.optimizers.Adam(learning_rate=lr_tau,  clipnorm=clipnorm_tau)
        self.penalty_warmup_epochs = int(penalty_warmup_epochs)

        self.acc_eps = float(acc_eps)
        self.loss_eps = float(loss_eps)
        self.reverse_tau_grads = bool(reverse_tau_grads)
        self.revert_rho_to_snapshot = bool(revert_rho_to_snapshot)
        self.shrink_tau_lr = bool(shrink_tau_lr)
        self.tau_lr_decay = float(tau_lr_decay)
        self.min_tau_lr = float(min_tau_lr)
        self.shrink_penalty = bool(shrink_penalty)
        self.penalty_decay = float(penalty_decay)
        self.min_penalty_scale = float(min_penalty_scale)

        self.stagnation_window = int(stagnation_window)
        self.improve_threshold = float(improve_threshold)
        self.bump_delta_k = float(bump_delta_k)
        self.min_epochs_between_bumps = int(min_epochs_between_bumps)

        self.acc_drop_threshold = float(acc_drop_threshold)

        self._partition_ready = False
        self.tau_idx, self.other_idx = [], []
        self._best_val_acc  = -np.inf
        self._best_val_loss =  np.inf
        self.val_acc_hist   = []
        self._last_bump_epoch = -10**9
        self.tau_grad_dir = tf.Variable(1.0, trainable=False, dtype=tf.float32)

        self.pending_bump = False
        self.bump_pre_val_acc = None
        self.rho_bump_snapshot = None
        self.bump_reverted_once = False
        self.final_bump_to_apply = False
        self.final_bump_applied = False
        self.disable_future_bumps = False

        self.no_revert_mode = False

    def _build_and_partition(self, sample_x):
        _ = self.model(sample_x)
        self.tau_idx, self.other_idx = [], []
        for i, v in enumerate(self.model.trainable_variables):
            if '/rho:' in v.name: self.tau_idx.append(i)
            else: self.other_idx.append(i)
        self._partition_ready = True

    def _set_penalty_scale(self, epoch_idx):
        scale = 1.0 if self.penalty_warmup_epochs <= 0 else min(1.0, (epoch_idx + 1) / self.penalty_warmup_epochs)
        for layer in self.model.layers:
            if isinstance(layer, LASAActivation):
                layer.set_penalty_scale(scale)

    def _decay_penalty_scale(self):
        if not self.shrink_penalty: return
        for layer in self.model.layers:
            if isinstance(layer, LASAActivation):
                layer.scale_down_penalty(self.penalty_decay, self.min_penalty_scale)

    def _snapshot_rho(self):
        return [self.model.trainable_variables[i].numpy().copy() for i in self.tau_idx]

    def _restore_rho(self, snap):
        for val, i in zip(snap, self.tau_idx):
            self.model.trainable_variables[i].assign(val)

    def _reset_tau_optimizer(self, new_lr):
        self.optimizer_tau = tf.keras.optimizers.Adam(learning_rate=new_lr, clipnorm=self.optimizer_tau.clipnorm)

    def _bump_all_k(self, delta):
        for layer in self.model.layers:
            if isinstance(layer, LASAActivation):
                k0 = float(layer.tau_value.numpy())
                if layer.enforce_gain_cap:
                    kmax = float(layer.k_max.numpy())
                    k1 = min(kmax * 0.999, k0 + float(delta))
                    ratio = np.clip(k1 / kmax, 1e-6, 1.0-1e-6)
                    rho_new = np.log(ratio/(1.0 - ratio))
                else:
                    k1 = max(0.0, k0 + float(delta))
                    rho_new = inv_softplus(k1)
                layer.rho.assign(np.float32(rho_new))

    @tf.function(jit_compile=USE_XLA)
    def _train_step(self, x_batch, y_batch):
        with tf.GradientTape() as tape:
            preds = self.model(x_batch, training=True)
            yb = tf.reshape(y_batch, (-1, 1))
            main_loss = self.loss_fn(yb, preds)
            reg_losses = tf.add_n(self.model.losses) if self.model.losses else tf.constant(0.0, dtype=main_loss.dtype)
            loss = main_loss + reg_losses
        grads = tape.gradient(loss, self.model.trainable_variables)

        tau_pairs = []
        for i in self.tau_idx:
            g = grads[i]; v = self.model.trainable_variables[i]
            if g is not None:
                g = tf.cast(g, tf.float32) * self.tau_grad_dir
                tau_pairs.append((g, v))
        other_pairs = []
        for i in self.other_idx:
            g = grads[i]; v = self.model.trainable_variables[i]
            if g is not None:
                other_pairs.append((g, v))

        if tau_pairs:   self.optimizer_tau.apply_gradients(tau_pairs)
        if other_pairs: self.optimizer_main.apply_gradients(other_pairs)

        return main_loss

    def _val_metrics(self, X_val, y_val):
        preds = self.model(X_val, training=False)
        yb = tf.reshape(y_val, (-1, 1))
        val_loss = float(self.loss_fn(yb, preds).numpy())
        y_pred = (preds.numpy() > 0.5).astype(int).flatten()
        val_acc = float(np.mean(y_pred == y_val.numpy()))
        return val_loss, val_acc

    def train(self, X_train, y_train, X_val, y_val, epochs=40, batch_size=32, verbose=True):
        X_train = tf.constant(X_train, dtype=tf.float32)
        y_train = tf.constant(y_train, dtype=tf.float32)
        X_val   = tf.constant(X_val,   dtype=tf.float32)
        y_val   = tf.constant(y_val,   dtype=tf.float32)

        if not self._partition_ready:
            self._build_and_partition(X_train[:1])

        ds = (tf.data.Dataset.from_tensor_slices((X_train, y_train))
              .shuffle(4096).batch(batch_size).prefetch(tf.data.AUTOTUNE))

        history = {'loss': [], 'val_accuracy': [], 'val_loss': []}

        for epoch in range(epochs):
            self._set_penalty_scale(epoch)

            if self.final_bump_to_apply and not self.final_bump_applied:
                self._bump_all_k(self.bump_delta_k)
                self.final_bump_applied = True
                self.final_bump_to_apply = False
                self.disable_future_bumps = True
                self.no_revert_mode = True

            rho_snap_epoch = self._snapshot_rho()

            total_loss = 0.0
            nb = 0
            for xb, yb in ds:
                main_l = self._train_step(xb, yb)
                total_loss += float(main_l.numpy())
                nb += 1

            avg_loss = total_loss / max(nb, 1)
            val_loss, val_acc = self._val_metrics(X_val, y_val)

            if self.pending_bump and not self.final_bump_applied:
                if self.bump_pre_val_acc is not None:
                    drop = self.bump_pre_val_acc - val_acc
                    if drop > self.acc_drop_threshold and not self.bump_reverted_once:
                        self._restore_rho(self.rho_bump_snapshot)
                        self.bump_reverted_once = True
                        self.pending_bump = False
                        self.final_bump_to_apply = True
                        val_loss, val_acc = self._val_metrics(X_val, y_val)
                if self.pending_bump:
                    self.pending_bump = False

            worse_acc  = (val_acc  < getattr(self, "_best_val_acc", -np.inf)  - self.acc_eps)
            worse_loss = (val_loss > getattr(self, "_best_val_loss", np.inf) + self.loss_eps)
            if (worse_acc or worse_loss):
                if self.revert_rho_to_snapshot and not self.no_revert_mode:
                    self._restore_rho(rho_snap_epoch)
                if self.reverse_tau_grads:
                    self.tau_grad_dir.assign(-self.tau_grad_dir)
                if self.shrink_tau_lr:
                    new_lr = max(self.min_tau_lr, float(self.optimizer_tau.learning_rate.numpy()) * self.tau_lr_decay)
                    self._reset_tau_optimizer(new_lr)
                if self.shrink_penalty:
                    self._decay_penalty_scale()
                val_loss, val_acc = self._val_metrics(X_val, y_val)

            ep = epoch + 1
            self.val_acc_hist.append(val_acc)
            can_try_bump = (not self.disable_future_bumps) and (not self.final_bump_applied)
            if can_try_bump and ep >= self.stagnation_window and (ep - self._last_bump_epoch) >= self.min_epochs_between_bumps:
                acc_then = self.val_acc_hist[-self.stagnation_window]
                improve  = val_acc - acc_then
                if improve < self.improve_threshold:
                    self.rho_bump_snapshot = self._snapshot_rho()
                    self.bump_pre_val_acc  = val_acc
                    self._bump_all_k(self.bump_delta_k)
                    self.pending_bump = True
                    self._last_bump_epoch = ep

            self._best_val_acc  = max(getattr(self, "_best_val_acc", -np.inf),  val_acc)
            self._best_val_loss = min(getattr(self, "_best_val_loss", np.inf), val_loss)

            history['loss'].append(avg_loss)
            history['val_accuracy'].append(val_acc)
            history['val_loss'].append(val_loss)

            if verbose:
                print(f"Epoch {epoch+1:03d} | loss: {avg_loss:.4f} | val_loss: {val_loss:.4f} | val_acc: {val_acc:.4f}")
        return history

class RegularTrainer:
    def __init__(self, model, lr=1e-3, clipnorm=1.0):
        self.model = model
        self.loss_fn = tf.keras.losses.BinaryCrossentropy()
        self.optimizer = tf.keras.optimizers.Adam(learning_rate=lr, clipnorm=clipnorm)

    @tf.function(jit_compile=USE_XLA)
    def _train_step(self, x_batch, y_batch):
        with tf.GradientTape() as tape:
            preds = self.model(x_batch, training=True)
            yb = tf.reshape(y_batch, (-1, 1))
            loss = self.loss_fn(yb, preds)
        grads = tape.gradient(loss, self.model.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.model.trainable_variables))
        return loss

    def _val_metrics(self, X_val, y_val):
        preds = self.model(X_val, training=False)
        yb = tf.reshape(y_val, (-1, 1))
        val_loss = float(self.loss_fn(yb, preds).numpy())
        y_pred = (preds.numpy() > 0.5).astype(int).flatten()
        val_acc = float(np.mean(y_pred == y_val.numpy()))
        return val_loss, val_acc

    def train(self, X_train, y_train, X_val, y_val, epochs=40, batch_size=32, verbose=True):
        X_train = tf.constant(X_train, dtype=tf.float32)
        y_train = tf.constant(y_train, dtype=tf.float32)
        X_val   = tf.constant(X_val,   dtype=tf.float32)
        y_val   = tf.constant(y_val,   dtype=tf.float32)

        ds = (tf.data.Dataset.from_tensor_slices((X_train, y_train))
              .shuffle(4096).batch(batch_size).prefetch(tf.data.AUTOTUNE))

        history = {'loss': [], 'val_accuracy': [], 'val_loss': []}

        for epoch in range(epochs):
            total_loss = 0.0; nb = 0
            for xb, yb in ds:
                main_l = self._train_step(xb, yb)
                total_loss += float(main_l.numpy()); nb += 1

            avg_loss = total_loss / max(nb, 1)
            val_loss, val_acc = self._val_metrics(X_val, y_val)

            history['loss'].append(avg_loss)
            history['val_accuracy'].append(val_acc)
            history['val_loss'].append(val_loss)

            if verbose:
                print(f"Epoch {epoch+1:03d} | loss: {avg_loss:.4f} | val_loss: {val_loss:.4f} | val_acc: {val_acc:.4f}")
        return history

def plot_all_decision_boundaries(models, results, X_test, y_test):
    class Wrapper:
        def __init__(self, model): self.model = model
        def predict(self, X):
            X_tensor = tf.constant(X, dtype=tf.float32)
            preds = self.model(X_tensor)
            return (preds.numpy() > 0.5).astype(int).flatten()

    names = list(models.keys())
    n = len(names); cols = 4; rows = int(np.ceil(n / cols))
    fig, axes = plt.subplots(rows, cols, figsize=(4.6*cols, 4.2*rows))
    axes = np.array(axes).reshape(rows, cols)

    for idx, name in enumerate(names):
        r, c = divmod(idx, cols); ax = axes[r, c]
        wrapper = Wrapper(models[name])
        plot_decision_regions(X=X_test, y=y_test, clf=wrapper, ax=ax, legend=0)
        acc = results[name]['accuracy']
        ax.set_title(f"{name.upper()}  Acc: {acc:.4f}", fontsize=11, fontweight='bold')
        ax.set_xlabel('x1'); ax.set_ylabel('x2'); ax.grid(True, alpha=0.3)

    for idx in range(n, rows*cols):
        r, c = divmod(idx, cols)
        fig.delaxes(axes[r, c])

    plt.suptitle('Decision Boundaries Comparison (Concentric Circles)', fontsize=15, fontweight='bold')
    plt.tight_layout(); plt.show()

def plot_training_curves_comparison(results):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
    for name, data in results.items():
        ax1.plot(data['history']['loss'], label=f"{name}")
        ax1.plot(data['history']['val_loss'], linestyle='--', alpha=0.7, label=f"{name} (val)")
        ax2.plot(data['history']['val_accuracy'], label=f"{name}")
    ax1.set_title('Training & Validation Loss'); ax1.set_xlabel('Epoch'); ax1.set_ylabel('Loss'); ax1.grid(True); ax1.legend(ncol=2, fontsize=8)
    ax2.set_title('Validation Accuracy'); ax2.set_xlabel('Epoch'); ax2.set_ylabel('Accuracy'); ax2.grid(True); ax2.legend(ncol=2, fontsize=8)
    plt.tight_layout(); plt.show()

def print_comparison_table(results):
    print("\n" + "="*60)
    print("FINAL RESULTS COMPARISON")
    print("="*60)
    print(f"{'Rank':<6} {'Activation':<15} {'Accuracy':<12} {'Final Train Loss':<18}")
    print("-"*60)
    sorted_items = sorted(results.items(), key=lambda kv: kv[1]['accuracy'], reverse=True)
    for rank, (name, data) in enumerate(sorted_items, 1):
        print(f"{rank:<6} {name.upper():<15} {data['accuracy']:<12.4f} {data['final_loss']:<18.4f}")
    print("="*60)

def run_all_activations_comparison_circles(hidden_units=[6],
                                           n_samples=2000, noise=0.1, factor=0.5,
                                           test_size=0.2, random_state=42,
                                           epochs=40, batch_size=32,
                                           lr_main=1e-3,
                                           lr_tau=1e-2,
                                           initial_frequency=1.6,
                                           theta_degrees=45.0, lambda_window=3e-4,
                                           penalty_mode='hinge', hybrid_alpha=0.1,
                                           enforce_gain_cap=False, gain_cap=1.25,
                                           penalty_warmup_epochs=8,
                                           acc_eps=2.5e-3, loss_eps=1e-4,
                                           reverse_tau_grads=True, revert_rho_to_snapshot=True,
                                           shrink_tau_lr=True, tau_lr_decay=0.5, min_tau_lr=1e-5,
                                           shrink_penalty=True, penalty_decay=0.8, min_penalty_scale=0.05,
                                           stagnation_window=10, improve_threshold=0.05,
                                           bump_delta_k=1.0, min_epochs_between_bumps=10,
                                           acc_drop_threshold=0.20,
                                           verbose=True):
    activation_types = [
        'lasa', 'relu', 'leaky_relu', 'elu', 'softplus',
        'swish', 'mish', 'gelu', 'sine', 'sigmoid', 'tanh'
    ]

    print("="*60)
    print("ACTIVATION FUNCTIONS COMPARISON - Concentric Circles")
    print("="*60)
    print("Config:",
          f"\n  hidden_units={hidden_units}",
          f"\n  epochs={epochs}  batch_size={batch_size}",
          f"\n  lr_main={lr_main}  (lr_tau={lr_tau} for LASA only)",
          f"\n  dataset: n_samples={n_samples}, noise={noise}, factor={factor}, random_state={random_state}",
          f"\n  LASA: theta={theta_degrees}°, lambda_window={lambda_window}, penalty_mode={penalty_mode}, "
          f"enforce_gain_cap={enforce_gain_cap}, gain_cap={gain_cap}",
          f"\n  Rule: revert-if-drop>{acc_drop_threshold}, then apply one final +1 bump and disable further bumps"
          )

    X, y = generate_circles(n_samples=n_samples, noise=noise, factor=factor, random_state=random_state)
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, random_state=random_state, stratify=y
    )
    print(f"\nDataset: total={n_samples} | train={len(X_train)} | test={len(X_test)}")
    print(f"Class counts: 0->{np.sum(y==0)}  1->{np.sum(y==1)}")

    results = {}
    models  = {}

    for act in activation_types:
        print("\n" + "-"*60)
        print(f"Training with {act.upper()} activation...")
        tf.keras.backend.clear_session()
        np.random.seed(random_state); tf.random.set_seed(random_state)

        model = create_model(
            activation_type=act,
            hidden_units=hidden_units,
            initial_frequency=initial_frequency,
            theta_degrees=theta_degrees, lambda_window=lambda_window,
            penalty_mode=penalty_mode, hybrid_alpha=hybrid_alpha,
            enforce_gain_cap=enforce_gain_cap, gain_cap=gain_cap
        )

        if act.lower() == 'lasa':
            trainer = LASATrainer(
                model,
                lr_main=lr_main, lr_tau=lr_tau,
                clipnorm_main=1.0, clipnorm_tau=0.5,
                penalty_warmup_epochs=penalty_warmup_epochs,
                acc_eps=acc_eps, loss_eps=loss_eps,
                reverse_tau_grads=reverse_tau_grads, revert_rho_to_snapshot=revert_rho_to_snapshot,
                shrink_tau_lr=shrink_tau_lr, tau_lr_decay=tau_lr_decay, min_tau_lr=min_tau_lr,
                shrink_penalty=shrink_penalty, penalty_decay=penalty_decay, min_penalty_scale=min_penalty_scale,
                stagnation_window=stagnation_window, improve_threshold=improve_threshold,
                bump_delta_k=bump_delta_k, min_epochs_between_bumps=min_epochs_between_bumps,
                acc_drop_threshold=acc_drop_threshold
            )
            hist = trainer.train(
                tf.constant(X_train), tf.constant(y_train, np.float32),
                tf.constant(X_test),  tf.constant(y_test,  np.float32),
                epochs=epochs, batch_size=batch_size, verbose=verbose
            )
        else:
            trainer = RegularTrainer(model, lr=lr_main, clipnorm=1.0)
            hist = trainer.train(
                tf.constant(X_train), tf.constant(y_train, np.float32),
                tf.constant(X_test),  tf.constant(y_test,  np.float32),
                epochs=epochs, batch_size=batch_size, verbose=verbose
            )

        preds = model(tf.constant(X_test, tf.float32))
        y_true = tf.constant(y_test, np.float32)
        y_true = tf.reshape(y_true, (-1, 1))
        final_loss = float(tf.keras.losses.BinaryCrossentropy()(y_true, preds).numpy())
        y_pred = (preds.numpy() > 0.5).astype(int).flatten()
        final_acc  = float(np.mean(y_pred == y_test))

        results[act] = {'accuracy': final_acc, 'history': hist, 'final_loss': hist['loss'][-1]}
        models[act]  = model

        print(f"[{act.upper()}] Acc: {final_acc:.4f} | Final train loss: {hist['loss'][-1]:.4f}")

    return models, results, X, y, X_test, y_test

if __name__ == "__main__":
    models, results, X, y, X_test, y_test = run_all_activations_comparison_circles(
        hidden_units=[2],
        n_samples=2000, noise=0.1, factor=0.5,
        test_size=0.2, random_state=42,
        epochs=40, batch_size=32,
        lr_main=1e-3, lr_tau=1e-2,
        initial_frequency=1.6,
        theta_degrees=45.0, lambda_window=3e-4,
        penalty_mode='hinge', hybrid_alpha=0.1,
        enforce_gain_cap=False, gain_cap=1.25,
        penalty_warmup_epochs=8,
        acc_eps=2.5e-3, loss_eps=1e-4,
        reverse_tau_grads=True, revert_rho_to_snapshot=True,
        shrink_tau_lr=True, tau_lr_decay=0.5, min_tau_lr=1e-5,
        shrink_penalty=True, penalty_decay=0.8, min_penalty_scale=0.05,
        stagnation_window=10, improve_threshold=0.05,
        bump_delta_k=1.0, min_epochs_between_bumps=10,
        acc_drop_threshold=0.20,
        verbose=True
    )

    print("\n")
    print("="*60)
    print("ACTIVATIONS: lasa, relu, leaky_relu, elu, softplus, swish, mish, gelu, sine, sigmoid, tanh")
    print("="*60)
    print_comparison_table(results)

    plot_all_decision_boundaries(models, results, X_test, y_test)
    plot_training_curves_comparison(results)
# Out:
# <style>.output_scroll {height:auto !important; max-height:none !important;}</style>
# ============================================================
# GPU CONFIGURATION
# ============================================================
# No GPUs available, using CPU
# Mixed precision policy: float32
# ============================================================
#
# ============================================================
# ACTIVATION FUNCTIONS COMPARISON - Concentric Circles
# ============================================================
# Config:
#   hidden_units=[2]
#   epochs=40  batch_size=32
#   lr_main=0.001  (lr_tau=0.01 for LASA only)
#   dataset: n_samples=2000, noise=0.1, factor=0.5, random_state=42
#   LASA: theta=45.0°, lambda_window=0.0003, penalty_mode=hinge, enforce_gain_cap=False, gain_cap=1.25
#   Rule: revert-if-drop>0.2, then apply one final +1 bump and disable further bumps
#
# Dataset: total=2000 | train=1600 | test=400
# Class counts: 0->1000  1->1000
#
# ------------------------------------------------------------
# Training with LASA activation...
# Epoch 001 | loss: 0.7077 | val_loss: 0.7222 | val_acc: 0.4625
# Epoch 002 | loss: 0.7009 | val_loss: 0.7137 | val_acc: 0.4775
# Epoch 003 | loss: 0.6976 | val_loss: 0.7083 | val_acc: 0.4750
# Epoch 004 | loss: 0.6957 | val_loss: 0.7054 | val_acc: 0.4800
# Epoch 005 | loss: 0.6948 | val_loss: 0.7035 | val_acc: 0.4850
# Epoch 006 | loss: 0.6942 | val_loss: 0.7026 | val_acc: 0.4800
# Epoch 007 | loss: 0.6940 | val_loss: 0.7021 | val_acc: 0.4825
# Epoch 008 | loss: 0.6938 | val_loss: 0.7015 | val_acc: 0.4950
# Epoch 009 | loss: 0.6936 | val_loss: 0.7007 | val_acc: 0.4850
# Epoch 010 | loss: 0.6932 | val_loss: 0.6998 | val_acc: 0.5000
# Epoch 011 | loss: 0.6893 | val_loss: 0.6978 | val_acc: 0.5625
# Epoch 012 | loss: 0.6784 | val_loss: 0.6758 | val_acc: 0.6800
# Epoch 013 | loss: 0.6377 | val_loss: 0.6121 | val_acc: 0.7550
# Epoch 014 | loss: 0.5898 | val_loss: 0.5919 | val_acc: 0.7500
# Epoch 015 | loss: 0.5883 | val_loss: 0.5744 | val_acc: 0.7450
# Epoch 016 | loss: 0.5616 | val_loss: 0.5609 | val_acc: 0.7550
# Epoch 017 | loss: 0.5441 | val_loss: 0.5465 | val_acc: 0.7625
# Epoch 018 | loss: 0.5247 | val_loss: 0.5326 | val_acc: 0.7475
# Epoch 019 | loss: 0.5087 | val_loss: 0.5288 | val_acc: 0.7775
# Epoch 020 | loss: 0.5318 | val_loss: 0.4984 | val_acc: 0.7725
# Epoch 021 | loss: 0.4673 | val_loss: 0.4649 | val_acc: 0.7825
# Epoch 022 | loss: 0.4328 | val_loss: 0.4293 | val_acc: 0.8400
# Epoch 023 | loss: 0.4033 | val_loss: 0.4011 | val_acc: 0.9175
# Epoch 024 | loss: 0.3803 | val_loss: 0.3779 | val_acc: 0.9525
# Epoch 025 | loss: 0.3621 | val_loss: 0.3592 | val_acc: 0.9675
# Epoch 026 | loss: 0.3473 | val_loss: 0.3443 | val_acc: 0.9750
# Epoch 027 | loss: 0.3352 | val_loss: 0.3317 | val_acc: 0.9800
# Epoch 028 | loss: 0.3246 | val_loss: 0.3213 | val_acc: 0.9825
# Epoch 029 | loss: 0.3153 | val_loss: 0.3131 | val_acc: 0.9850
# Epoch 030 | loss: 0.3076 | val_loss: 0.3039 | val_acc: 0.9875
# Epoch 031 | loss: 0.2998 | val_loss: 0.2974 | val_acc: 0.9925
# Epoch 032 | loss: 0.2930 | val_loss: 0.2896 | val_acc: 0.9925
# Epoch 033 | loss: 0.2862 | val_loss: 0.2838 | val_acc: 0.9925
# Epoch 034 | loss: 0.3102 | val_loss: 0.3381 | val_acc: 0.9000
# Epoch 035 | loss: 0.3497 | val_loss: 0.2942 | val_acc: 0.9725
# Epoch 036 | loss: 0.2759 | val_loss: 0.2692 | val_acc: 0.9925
# Epoch 037 | loss: 0.2667 | val_loss: 0.2639 | val_acc: 0.9975
# Epoch 038 | loss: 0.2610 | val_loss: 0.2584 | val_acc: 0.9975
# Epoch 039 | loss: 0.2561 | val_loss: 0.2537 | val_acc: 0.9975
# Epoch 040 | loss: 0.2514 | val_loss: 0.2482 | val_acc: 0.9975
# [LASA] Acc: 0.9975 | Final train loss: 0.2514
#
# ------------------------------------------------------------
# Training with RELU activation...
# Epoch 001 | loss: 0.8670 | val_loss: 0.8798 | val_acc: 0.4600
# Epoch 002 | loss: 0.8350 | val_loss: 0.8478 | val_acc: 0.4300
# Epoch 003 | loss: 0.8118 | val_loss: 0.8222 | val_acc: 0.4100
# Epoch 004 | loss: 0.7932 | val_loss: 0.8030 | val_acc: 0.4100
# Epoch 005 | loss: 0.7787 | val_loss: 0.7861 | val_acc: 0.4200
# Epoch 006 | loss: 0.7653 | val_loss: 0.7699 | val_acc: 0.4350
# Epoch 007 | loss: 0.7542 | val_loss: 0.7585 | val_acc: 0.4200
# Epoch 008 | loss: 0.7468 | val_loss: 0.7513 | val_acc: 0.4100
# Epoch 009 | loss: 0.7416 | val_loss: 0.7462 | val_acc: 0.4050
# Epoch 010 | loss: 0.7373 | val_loss: 0.7416 | val_acc: 0.3900
# Epoch 011 | loss: 0.7336 | val_loss: 0.7377 | val_acc: 0.3750
# Epoch 012 | loss: 0.7303 | val_loss: 0.7338 | val_acc: 0.3650
# Epoch 013 | loss: 0.7272 | val_loss: 0.7304 | val_acc: 0.3575
# Epoch 014 | loss: 0.7242 | val_loss: 0.7269 | val_acc: 0.3525
# Epoch 015 | loss: 0.7213 | val_loss: 0.7239 | val_acc: 0.3475
# Epoch 016 | loss: 0.7187 | val_loss: 0.7208 | val_acc: 0.3525
# Epoch 017 | loss: 0.7162 | val_loss: 0.7177 | val_acc: 0.3500
# Epoch 018 | loss: 0.7137 | val_loss: 0.7146 | val_acc: 0.3450
# Epoch 019 | loss: 0.7112 | val_loss: 0.7116 | val_acc: 0.3500
# Epoch 020 | loss: 0.7086 | val_loss: 0.7083 | val_acc: 0.3650
# Epoch 021 | loss: 0.7059 | val_loss: 0.7051 | val_acc: 0.3750
# Epoch 022 | loss: 0.7031 | val_loss: 0.7021 | val_acc: 0.3850
# Epoch 023 | loss: 0.7006 | val_loss: 0.6995 | val_acc: 0.4200
# Epoch 024 | loss: 0.6986 | val_loss: 0.6975 | val_acc: 0.4550
# Epoch 025 | loss: 0.6970 | val_loss: 0.6958 | val_acc: 0.4650
# Epoch 026 | loss: 0.6957 | val_loss: 0.6947 | val_acc: 0.4800
# Epoch 027 | loss: 0.6948 | val_loss: 0.6941 | val_acc: 0.4850
# Epoch 028 | loss: 0.6942 | val_loss: 0.6937 | val_acc: 0.4875
# Epoch 029 | loss: 0.6938 | val_loss: 0.6935 | val_acc: 0.4975
# Epoch 030 | loss: 0.6936 | val_loss: 0.6934 | val_acc: 0.4975
# Epoch 031 | loss: 0.6934 | val_loss: 0.6933 | val_acc: 0.4975
# Epoch 032 | loss: 0.6933 | val_loss: 0.6933 | val_acc: 0.4975
# Epoch 033 | loss: 0.6933 | val_loss: 0.6932 | val_acc: 0.4975
# Epoch 034 | loss: 0.6933 | val_loss: 0.6932 | val_acc: 0.4975
# Epoch 035 | loss: 0.6932 | val_loss: 0.6932 | val_acc: 0.4975
# Epoch 036 | loss: 0.6932 | val_loss: 0.6932 | val_acc: 0.4975
# Epoch 037 | loss: 0.6932 | val_loss: 0.6932 | val_acc: 0.4950
# Epoch 038 | loss: 0.6932 | val_loss: 0.6932 | val_acc: 0.4950
# Epoch 039 | loss: 0.6932 | val_loss: 0.6932 | val_acc: 0.4950
# Epoch 040 | loss: 0.6932 | val_loss: 0.6932 | val_acc: 0.4950
# [RELU] Acc: 0.4950 | Final train loss: 0.6932
#
# ------------------------------------------------------------
# Training with LEAKY_RELU activation...
# Epoch 001 | loss: 0.6718 | val_loss: 0.6512 | val_acc: 0.5475
# Epoch 002 | loss: 0.6622 | val_loss: 0.6438 | val_acc: 0.5875
# Epoch 003 | loss: 0.6555 | val_loss: 0.6388 | val_acc: 0.5925
# Epoch 004 | loss: 0.6503 | val_loss: 0.6342 | val_acc: 0.6075
# Epoch 005 | loss: 0.6456 | val_loss: 0.6297 | val_acc: 0.6200
# Epoch 006 | loss: 0.6409 | val_loss: 0.6256 | val_acc: 0.6275
# Epoch 007 | loss: 0.6364 | val_loss: 0.6215 | val_acc: 0.6350
# Epoch 008 | loss: 0.6321 | val_loss: 0.6172 | val_acc: 0.6550
# Epoch 009 | loss: 0.6277 | val_loss: 0.6132 | val_acc: 0.6700
# Epoch 010 | loss: 0.6233 | val_loss: 0.6092 | val_acc: 0.6675
# Epoch 011 | loss: 0.6189 | val_loss: 0.6053 | val_acc: 0.6825
# Epoch 012 | loss: 0.6148 | val_loss: 0.6011 | val_acc: 0.6875
# Epoch 013 | loss: 0.6106 | val_loss: 0.5973 | val_acc: 0.7000
# Epoch 014 | loss: 0.6063 | val_loss: 0.5934 | val_acc: 0.7075
# Epoch 015 | loss: 0.6021 | val_loss: 0.5897 | val_acc: 0.7200
# Epoch 016 | loss: 0.5981 | val_loss: 0.5860 | val_acc: 0.7275
# Epoch 017 | loss: 0.5939 | val_loss: 0.5824 | val_acc: 0.7300
# Epoch 018 | loss: 0.5900 | val_loss: 0.5787 | val_acc: 0.7375
# Epoch 019 | loss: 0.5862 | val_loss: 0.5754 | val_acc: 0.7375
# Epoch 020 | loss: 0.5823 | val_loss: 0.5722 | val_acc: 0.7350
# Epoch 021 | loss: 0.5783 | val_loss: 0.5689 | val_acc: 0.7300
# Epoch 022 | loss: 0.5747 | val_loss: 0.5657 | val_acc: 0.7250
# Epoch 023 | loss: 0.5710 | val_loss: 0.5626 | val_acc: 0.7325
# Epoch 024 | loss: 0.5677 | val_loss: 0.5597 | val_acc: 0.7250
# Epoch 025 | loss: 0.5644 | val_loss: 0.5566 | val_acc: 0.7375
# Epoch 026 | loss: 0.5610 | val_loss: 0.5537 | val_acc: 0.7350
# Epoch 027 | loss: 0.5577 | val_loss: 0.5509 | val_acc: 0.7325
# Epoch 028 | loss: 0.5549 | val_loss: 0.5484 | val_acc: 0.7450
# Epoch 029 | loss: 0.5516 | val_loss: 0.5456 | val_acc: 0.7450
# Epoch 030 | loss: 0.5489 | val_loss: 0.5432 | val_acc: 0.7500
# Epoch 031 | loss: 0.5462 | val_loss: 0.5408 | val_acc: 0.7525
# Epoch 032 | loss: 0.5434 | val_loss: 0.5387 | val_acc: 0.7575
# Epoch 033 | loss: 0.5410 | val_loss: 0.5364 | val_acc: 0.7625
# Epoch 034 | loss: 0.5384 | val_loss: 0.5346 | val_acc: 0.7625
# Epoch 035 | loss: 0.5362 | val_loss: 0.5328 | val_acc: 0.7600
# Epoch 036 | loss: 0.5338 | val_loss: 0.5308 | val_acc: 0.7675
# Epoch 037 | loss: 0.5317 | val_loss: 0.5290 | val_acc: 0.7675
# Epoch 038 | loss: 0.5295 | val_loss: 0.5273 | val_acc: 0.7700
# Epoch 039 | loss: 0.5275 | val_loss: 0.5258 | val_acc: 0.7650
# Epoch 040 | loss: 0.5255 | val_loss: 0.5241 | val_acc: 0.7675
# [LEAKY_RELU] Acc: 0.7675 | Final train loss: 0.5255
#
# ------------------------------------------------------------
# Training with ELU activation...
# Epoch 001 | loss: 0.7304 | val_loss: 0.7367 | val_acc: 0.4950
# Epoch 002 | loss: 0.7227 | val_loss: 0.7287 | val_acc: 0.4975
# Epoch 003 | loss: 0.7167 | val_loss: 0.7226 | val_acc: 0.4925
# Epoch 004 | loss: 0.7120 | val_loss: 0.7178 | val_acc: 0.4950
# Epoch 005 | loss: 0.7084 | val_loss: 0.7139 | val_acc: 0.4975
# Epoch 006 | loss: 0.7054 | val_loss: 0.7109 | val_acc: 0.4975
# Epoch 007 | loss: 0.7031 | val_loss: 0.7084 | val_acc: 0.4975
# Epoch 008 | loss: 0.7013 | val_loss: 0.7062 | val_acc: 0.5050
# Epoch 009 | loss: 0.6997 | val_loss: 0.7046 | val_acc: 0.5000
# Epoch 010 | loss: 0.6983 | val_loss: 0.7029 | val_acc: 0.5075
# Epoch 011 | loss: 0.6972 | val_loss: 0.7019 | val_acc: 0.5100
# Epoch 012 | loss: 0.6963 | val_loss: 0.7006 | val_acc: 0.5125
# Epoch 013 | loss: 0.6956 | val_loss: 0.6998 | val_acc: 0.5125
# Epoch 014 | loss: 0.6949 | val_loss: 0.6990 | val_acc: 0.5050
# Epoch 015 | loss: 0.6943 | val_loss: 0.6985 | val_acc: 0.5150
# Epoch 016 | loss: 0.6938 | val_loss: 0.6978 | val_acc: 0.5150
# Epoch 017 | loss: 0.6934 | val_loss: 0.6973 | val_acc: 0.5125
# Epoch 018 | loss: 0.6930 | val_loss: 0.6968 | val_acc: 0.5150
# Epoch 019 | loss: 0.6927 | val_loss: 0.6965 | val_acc: 0.5125
# Epoch 020 | loss: 0.6924 | val_loss: 0.6962 | val_acc: 0.5150
# Epoch 021 | loss: 0.6920 | val_loss: 0.6958 | val_acc: 0.5150
# Epoch 022 | loss: 0.6918 | val_loss: 0.6955 | val_acc: 0.5050
# Epoch 023 | loss: 0.6915 | val_loss: 0.6953 | val_acc: 0.5175
# Epoch 024 | loss: 0.6913 | val_loss: 0.6951 | val_acc: 0.5050
# Epoch 025 | loss: 0.6911 | val_loss: 0.6948 | val_acc: 0.5275
# Epoch 026 | loss: 0.6908 | val_loss: 0.6946 | val_acc: 0.5200
# Epoch 027 | loss: 0.6906 | val_loss: 0.6944 | val_acc: 0.5125
# Epoch 028 | loss: 0.6904 | val_loss: 0.6943 | val_acc: 0.5275
# Epoch 029 | loss: 0.6901 | val_loss: 0.6940 | val_acc: 0.5225
# Epoch 030 | loss: 0.6899 | val_loss: 0.6938 | val_acc: 0.5250
# Epoch 031 | loss: 0.6897 | val_loss: 0.6937 | val_acc: 0.5250
# Epoch 032 | loss: 0.6894 | val_loss: 0.6936 | val_acc: 0.5225
# Epoch 033 | loss: 0.6892 | val_loss: 0.6933 | val_acc: 0.5275
# Epoch 034 | loss: 0.6889 | val_loss: 0.6932 | val_acc: 0.5250
# Epoch 035 | loss: 0.6887 | val_loss: 0.6930 | val_acc: 0.5225
# Epoch 036 | loss: 0.6884 | val_loss: 0.6928 | val_acc: 0.5250
# Epoch 037 | loss: 0.6881 | val_loss: 0.6927 | val_acc: 0.5225
# Epoch 038 | loss: 0.6878 | val_loss: 0.6924 | val_acc: 0.5225
# Epoch 039 | loss: 0.6875 | val_loss: 0.6922 | val_acc: 0.5225
# Epoch 040 | loss: 0.6871 | val_loss: 0.6920 | val_acc: 0.5225
# [ELU] Acc: 0.5225 | Final train loss: 0.6871
#
# ------------------------------------------------------------
# Training with SOFTPLUS activation...
# Epoch 001 | loss: 0.7285 | val_loss: 0.7151 | val_acc: 0.5025
# Epoch 002 | loss: 0.7156 | val_loss: 0.7073 | val_acc: 0.5750
# Epoch 003 | loss: 0.7082 | val_loss: 0.7021 | val_acc: 0.6375
# Epoch 004 | loss: 0.7031 | val_loss: 0.6996 | val_acc: 0.5850
# Epoch 005 | loss: 0.7001 | val_loss: 0.6981 | val_acc: 0.5450
# Epoch 006 | loss: 0.6979 | val_loss: 0.6969 | val_acc: 0.5200
# Epoch 007 | loss: 0.6965 | val_loss: 0.6962 | val_acc: 0.5075
# Epoch 008 | loss: 0.6953 | val_loss: 0.6957 | val_acc: 0.5050
# Epoch 009 | loss: 0.6944 | val_loss: 0.6952 | val_acc: 0.4725
# Epoch 010 | loss: 0.6933 | val_loss: 0.6949 | val_acc: 0.4750
# Epoch 011 | loss: 0.6924 | val_loss: 0.6945 | val_acc: 0.4625
# Epoch 012 | loss: 0.6917 | val_loss: 0.6941 | val_acc: 0.4650
# Epoch 013 | loss: 0.6910 | val_loss: 0.6937 | val_acc: 0.4675
# Epoch 014 | loss: 0.6901 | val_loss: 0.6935 | val_acc: 0.4575
# Epoch 015 | loss: 0.6895 | val_loss: 0.6931 | val_acc: 0.4725
# Epoch 016 | loss: 0.6888 | val_loss: 0.6927 | val_acc: 0.4675
# Epoch 017 | loss: 0.6881 | val_loss: 0.6925 | val_acc: 0.4600
# Epoch 018 | loss: 0.6875 | val_loss: 0.6921 | val_acc: 0.4675
# Epoch 019 | loss: 0.6869 | val_loss: 0.6919 | val_acc: 0.4475
# Epoch 020 | loss: 0.6862 | val_loss: 0.6916 | val_acc: 0.4550
# Epoch 021 | loss: 0.6856 | val_loss: 0.6913 | val_acc: 0.4600
# Epoch 022 | loss: 0.6850 | val_loss: 0.6911 | val_acc: 0.4600
# Epoch 023 | loss: 0.6843 | val_loss: 0.6907 | val_acc: 0.4700
# Epoch 024 | loss: 0.6839 | val_loss: 0.6905 | val_acc: 0.4625
# Epoch 025 | loss: 0.6832 | val_loss: 0.6901 | val_acc: 0.4975
# Epoch 026 | loss: 0.6826 | val_loss: 0.6898 | val_acc: 0.4875
# Epoch 027 | loss: 0.6819 | val_loss: 0.6896 | val_acc: 0.4950
# Epoch 028 | loss: 0.6814 | val_loss: 0.6892 | val_acc: 0.4925
# Epoch 029 | loss: 0.6807 | val_loss: 0.6889 | val_acc: 0.4950
# Epoch 030 | loss: 0.6801 | val_loss: 0.6885 | val_acc: 0.4975
# Epoch 031 | loss: 0.6794 | val_loss: 0.6882 | val_acc: 0.5000
# Epoch 032 | loss: 0.6788 | val_loss: 0.6878 | val_acc: 0.4975
# Epoch 033 | loss: 0.6782 | val_loss: 0.6874 | val_acc: 0.5025
# Epoch 034 | loss: 0.6775 | val_loss: 0.6870 | val_acc: 0.5025
# Epoch 035 | loss: 0.6769 | val_loss: 0.6867 | val_acc: 0.5000
# Epoch 036 | loss: 0.6762 | val_loss: 0.6862 | val_acc: 0.5050
# Epoch 037 | loss: 0.6755 | val_loss: 0.6857 | val_acc: 0.5050
# Epoch 038 | loss: 0.6748 | val_loss: 0.6852 | val_acc: 0.5025
# Epoch 039 | loss: 0.6741 | val_loss: 0.6848 | val_acc: 0.5025
# Epoch 040 | loss: 0.6734 | val_loss: 0.6842 | val_acc: 0.5050
# [SOFTPLUS] Acc: 0.5050 | Final train loss: 0.6734
#
# ------------------------------------------------------------
# Training with SWISH activation...
# Epoch 001 | loss: 0.6786 | val_loss: 0.6776 | val_acc: 0.4950
# Epoch 002 | loss: 0.6771 | val_loss: 0.6763 | val_acc: 0.5250
# Epoch 003 | loss: 0.6756 | val_loss: 0.6751 | val_acc: 0.5225
# Epoch 004 | loss: 0.6741 | val_loss: 0.6738 | val_acc: 0.5250
# Epoch 005 | loss: 0.6725 | val_loss: 0.6723 | val_acc: 0.5225
# Epoch 006 | loss: 0.6707 | val_loss: 0.6709 | val_acc: 0.5300
# Epoch 007 | loss: 0.6689 | val_loss: 0.6693 | val_acc: 0.5350
# Epoch 008 | loss: 0.6670 | val_loss: 0.6675 | val_acc: 0.5450
# Epoch 009 | loss: 0.6649 | val_loss: 0.6658 | val_acc: 0.5475
# Epoch 010 | loss: 0.6626 | val_loss: 0.6638 | val_acc: 0.5525
# Epoch 011 | loss: 0.6603 | val_loss: 0.6618 | val_acc: 0.5575
# Epoch 012 | loss: 0.6579 | val_loss: 0.6596 | val_acc: 0.5550
# Epoch 013 | loss: 0.6553 | val_loss: 0.6574 | val_acc: 0.5575
# Epoch 014 | loss: 0.6525 | val_loss: 0.6549 | val_acc: 0.5575
# Epoch 015 | loss: 0.6496 | val_loss: 0.6524 | val_acc: 0.5625
# Epoch 016 | loss: 0.6466 | val_loss: 0.6497 | val_acc: 0.5675
# Epoch 017 | loss: 0.6434 | val_loss: 0.6468 | val_acc: 0.5725
# Epoch 018 | loss: 0.6401 | val_loss: 0.6438 | val_acc: 0.5750
# Epoch 019 | loss: 0.6367 | val_loss: 0.6406 | val_acc: 0.5825
# Epoch 020 | loss: 0.6331 | val_loss: 0.6373 | val_acc: 0.5825
# Epoch 021 | loss: 0.6293 | val_loss: 0.6339 | val_acc: 0.5875
# Epoch 022 | loss: 0.6255 | val_loss: 0.6303 | val_acc: 0.5900
# Epoch 023 | loss: 0.6215 | val_loss: 0.6266 | val_acc: 0.5925
# Epoch 024 | loss: 0.6175 | val_loss: 0.6226 | val_acc: 0.6025
# Epoch 025 | loss: 0.6132 | val_loss: 0.6185 | val_acc: 0.6150
# Epoch 026 | loss: 0.6088 | val_loss: 0.6142 | val_acc: 0.6200
# Epoch 027 | loss: 0.6042 | val_loss: 0.6097 | val_acc: 0.6250
# Epoch 028 | loss: 0.5996 | val_loss: 0.6052 | val_acc: 0.6300
# Epoch 029 | loss: 0.5948 | val_loss: 0.6004 | val_acc: 0.6350
# Epoch 030 | loss: 0.5899 | val_loss: 0.5956 | val_acc: 0.6425
# Epoch 031 | loss: 0.5849 | val_loss: 0.5905 | val_acc: 0.6525
# Epoch 032 | loss: 0.5798 | val_loss: 0.5855 | val_acc: 0.6625
# Epoch 033 | loss: 0.5747 | val_loss: 0.5803 | val_acc: 0.6675
# Epoch 034 | loss: 0.5695 | val_loss: 0.5750 | val_acc: 0.6725
# Epoch 035 | loss: 0.5643 | val_loss: 0.5697 | val_acc: 0.6750
# Epoch 036 | loss: 0.5590 | val_loss: 0.5645 | val_acc: 0.6825
# Epoch 037 | loss: 0.5538 | val_loss: 0.5591 | val_acc: 0.6875
# Epoch 038 | loss: 0.5486 | val_loss: 0.5538 | val_acc: 0.6975
# Epoch 039 | loss: 0.5435 | val_loss: 0.5484 | val_acc: 0.7050
# Epoch 040 | loss: 0.5384 | val_loss: 0.5432 | val_acc: 0.7200
# [SWISH] Acc: 0.7200 | Final train loss: 0.5384
#
# ------------------------------------------------------------
# Training with MISH activation...
# Epoch 001 | loss: 0.6850 | val_loss: 0.6806 | val_acc: 0.6900
# Epoch 002 | loss: 0.6796 | val_loss: 0.6745 | val_acc: 0.6475
# Epoch 003 | loss: 0.6753 | val_loss: 0.6695 | val_acc: 0.5875
# Epoch 004 | loss: 0.6715 | val_loss: 0.6654 | val_acc: 0.5825
# Epoch 005 | loss: 0.6682 | val_loss: 0.6614 | val_acc: 0.5800
# Epoch 006 | loss: 0.6650 | val_loss: 0.6580 | val_acc: 0.5825
# Epoch 007 | loss: 0.6620 | val_loss: 0.6548 | val_acc: 0.5800
# Epoch 008 | loss: 0.6593 | val_loss: 0.6515 | val_acc: 0.5875
# Epoch 009 | loss: 0.6564 | val_loss: 0.6486 | val_acc: 0.5875
# Epoch 010 | loss: 0.6536 | val_loss: 0.6456 | val_acc: 0.5900
# Epoch 011 | loss: 0.6508 | val_loss: 0.6429 | val_acc: 0.5975
# Epoch 012 | loss: 0.6482 | val_loss: 0.6397 | val_acc: 0.6025
# Epoch 013 | loss: 0.6455 | val_loss: 0.6371 | val_acc: 0.6100
# Epoch 014 | loss: 0.6426 | val_loss: 0.6342 | val_acc: 0.6175
# Epoch 015 | loss: 0.6398 | val_loss: 0.6316 | val_acc: 0.6275
# Epoch 016 | loss: 0.6370 | val_loss: 0.6287 | val_acc: 0.6400
# Epoch 017 | loss: 0.6342 | val_loss: 0.6259 | val_acc: 0.6500
# Epoch 018 | loss: 0.6313 | val_loss: 0.6229 | val_acc: 0.6575
# Epoch 019 | loss: 0.6286 | val_loss: 0.6202 | val_acc: 0.6750
# Epoch 020 | loss: 0.6257 | val_loss: 0.6176 | val_acc: 0.6850
# Epoch 021 | loss: 0.6227 | val_loss: 0.6146 | val_acc: 0.6875
# Epoch 022 | loss: 0.6199 | val_loss: 0.6116 | val_acc: 0.6925
# Epoch 023 | loss: 0.6169 | val_loss: 0.6091 | val_acc: 0.6875
# Epoch 024 | loss: 0.6142 | val_loss: 0.6066 | val_acc: 0.7050
# Epoch 025 | loss: 0.6114 | val_loss: 0.6038 | val_acc: 0.7200
# Epoch 026 | loss: 0.6086 | val_loss: 0.6011 | val_acc: 0.7275
# Epoch 027 | loss: 0.6058 | val_loss: 0.5984 | val_acc: 0.7250
# Epoch 028 | loss: 0.6032 | val_loss: 0.5961 | val_acc: 0.7350
# Epoch 029 | loss: 0.6004 | val_loss: 0.5933 | val_acc: 0.7400
# Epoch 030 | loss: 0.5979 | val_loss: 0.5910 | val_acc: 0.7450
# Epoch 031 | loss: 0.5954 | val_loss: 0.5889 | val_acc: 0.7425
# Epoch 032 | loss: 0.5928 | val_loss: 0.5865 | val_acc: 0.7475
# Epoch 033 | loss: 0.5905 | val_loss: 0.5842 | val_acc: 0.7475
# Epoch 034 | loss: 0.5881 | val_loss: 0.5820 | val_acc: 0.7475
# Epoch 035 | loss: 0.5859 | val_loss: 0.5801 | val_acc: 0.7475
# Epoch 036 | loss: 0.5836 | val_loss: 0.5780 | val_acc: 0.7475
# Epoch 037 | loss: 0.5815 | val_loss: 0.5758 | val_acc: 0.7500
# Epoch 038 | loss: 0.5793 | val_loss: 0.5740 | val_acc: 0.7450
# Epoch 039 | loss: 0.5774 | val_loss: 0.5719 | val_acc: 0.7425
# Epoch 040 | loss: 0.5754 | val_loss: 0.5703 | val_acc: 0.7450
# [MISH] Acc: 0.7450 | Final train loss: 0.5754
#
# ------------------------------------------------------------
# Training with GELU activation...
# Epoch 001 | loss: 0.6915 | val_loss: 0.7073 | val_acc: 0.4900
# Epoch 002 | loss: 0.6818 | val_loss: 0.6972 | val_acc: 0.4950
# Epoch 003 | loss: 0.6740 | val_loss: 0.6890 | val_acc: 0.4975
# Epoch 004 | loss: 0.6676 | val_loss: 0.6820 | val_acc: 0.5100
# Epoch 005 | loss: 0.6621 | val_loss: 0.6760 | val_acc: 0.5150
# Epoch 006 | loss: 0.6574 | val_loss: 0.6706 | val_acc: 0.5200
# Epoch 007 | loss: 0.6530 | val_loss: 0.6659 | val_acc: 0.5225
# Epoch 008 | loss: 0.6491 | val_loss: 0.6615 | val_acc: 0.5300
# Epoch 009 | loss: 0.6454 | val_loss: 0.6575 | val_acc: 0.5375
# Epoch 010 | loss: 0.6420 | val_loss: 0.6538 | val_acc: 0.5375
# Epoch 011 | loss: 0.6388 | val_loss: 0.6504 | val_acc: 0.5425
# Epoch 012 | loss: 0.6359 | val_loss: 0.6471 | val_acc: 0.5500
# Epoch 013 | loss: 0.6332 | val_loss: 0.6442 | val_acc: 0.5500
# Epoch 014 | loss: 0.6305 | val_loss: 0.6413 | val_acc: 0.5525
# Epoch 015 | loss: 0.6280 | val_loss: 0.6387 | val_acc: 0.5575
# Epoch 016 | loss: 0.6257 | val_loss: 0.6362 | val_acc: 0.5600
# Epoch 017 | loss: 0.6234 | val_loss: 0.6338 | val_acc: 0.5600
# Epoch 018 | loss: 0.6213 | val_loss: 0.6314 | val_acc: 0.5625
# Epoch 019 | loss: 0.6193 | val_loss: 0.6292 | val_acc: 0.5600
# Epoch 020 | loss: 0.6172 | val_loss: 0.6270 | val_acc: 0.5650
# Epoch 021 | loss: 0.6152 | val_loss: 0.6248 | val_acc: 0.5700
# Epoch 022 | loss: 0.6133 | val_loss: 0.6224 | val_acc: 0.5725
# Epoch 023 | loss: 0.6112 | val_loss: 0.6202 | val_acc: 0.5825
# Epoch 024 | loss: 0.6092 | val_loss: 0.6178 | val_acc: 0.5825
# Epoch 025 | loss: 0.6072 | val_loss: 0.6152 | val_acc: 0.5925
# Epoch 026 | loss: 0.6048 | val_loss: 0.6123 | val_acc: 0.5925
# Epoch 027 | loss: 0.6024 | val_loss: 0.6091 | val_acc: 0.5950
# Epoch 028 | loss: 0.5998 | val_loss: 0.6057 | val_acc: 0.6000
# Epoch 029 | loss: 0.5967 | val_loss: 0.6016 | val_acc: 0.6000
# Epoch 030 | loss: 0.5934 | val_loss: 0.5971 | val_acc: 0.6250
# Epoch 031 | loss: 0.5897 | val_loss: 0.5920 | val_acc: 0.6700
# Epoch 032 | loss: 0.5856 | val_loss: 0.5866 | val_acc: 0.6975
# Epoch 033 | loss: 0.5812 | val_loss: 0.5805 | val_acc: 0.7400
# Epoch 034 | loss: 0.5764 | val_loss: 0.5743 | val_acc: 0.7650
# Epoch 035 | loss: 0.5714 | val_loss: 0.5681 | val_acc: 0.7850
# Epoch 036 | loss: 0.5663 | val_loss: 0.5616 | val_acc: 0.8000
# Epoch 037 | loss: 0.5613 | val_loss: 0.5551 | val_acc: 0.8025
# Epoch 038 | loss: 0.5561 | val_loss: 0.5487 | val_acc: 0.8075
# Epoch 039 | loss: 0.5512 | val_loss: 0.5426 | val_acc: 0.8025
# Epoch 040 | loss: 0.5464 | val_loss: 0.5367 | val_acc: 0.7975
# [GELU] Acc: 0.7975 | Final train loss: 0.5464
#
# ------------------------------------------------------------
# Training with SINE activation...
# Epoch 001 | loss: 0.7287 | val_loss: 0.6997 | val_acc: 0.5475
# Epoch 002 | loss: 0.7196 | val_loss: 0.6946 | val_acc: 0.5600
# Epoch 003 | loss: 0.7122 | val_loss: 0.6909 | val_acc: 0.5625
# Epoch 004 | loss: 0.7060 | val_loss: 0.6878 | val_acc: 0.5725
# Epoch 005 | loss: 0.7008 | val_loss: 0.6852 | val_acc: 0.5850
# Epoch 006 | loss: 0.6961 | val_loss: 0.6831 | val_acc: 0.6000
# Epoch 007 | loss: 0.6921 | val_loss: 0.6809 | val_acc: 0.6275
# Epoch 008 | loss: 0.6880 | val_loss: 0.6785 | val_acc: 0.6675
# Epoch 009 | loss: 0.6841 | val_loss: 0.6759 | val_acc: 0.6575
# Epoch 010 | loss: 0.6797 | val_loss: 0.6728 | val_acc: 0.6350
# Epoch 011 | loss: 0.6752 | val_loss: 0.6691 | val_acc: 0.6325
# Epoch 012 | loss: 0.6702 | val_loss: 0.6647 | val_acc: 0.6325
# Epoch 013 | loss: 0.6649 | val_loss: 0.6596 | val_acc: 0.7300
# Epoch 014 | loss: 0.6586 | val_loss: 0.6536 | val_acc: 0.7475
# Epoch 015 | loss: 0.6519 | val_loss: 0.6468 | val_acc: 0.7350
# Epoch 016 | loss: 0.6445 | val_loss: 0.6391 | val_acc: 0.7250
# Epoch 017 | loss: 0.6366 | val_loss: 0.6309 | val_acc: 0.7250
# Epoch 018 | loss: 0.6284 | val_loss: 0.6223 | val_acc: 0.7325
# Epoch 019 | loss: 0.6202 | val_loss: 0.6137 | val_acc: 0.7300
# Epoch 020 | loss: 0.6117 | val_loss: 0.6053 | val_acc: 0.7350
# Epoch 021 | loss: 0.6036 | val_loss: 0.5967 | val_acc: 0.7400
# Epoch 022 | loss: 0.5960 | val_loss: 0.5887 | val_acc: 0.7375
# Epoch 023 | loss: 0.5887 | val_loss: 0.5816 | val_acc: 0.7400
# Epoch 024 | loss: 0.5822 | val_loss: 0.5749 | val_acc: 0.7350
# Epoch 025 | loss: 0.5763 | val_loss: 0.5685 | val_acc: 0.7425
# Epoch 026 | loss: 0.5709 | val_loss: 0.5633 | val_acc: 0.7400
# Epoch 027 | loss: 0.5661 | val_loss: 0.5585 | val_acc: 0.7450
# Epoch 028 | loss: 0.5619 | val_loss: 0.5542 | val_acc: 0.7450
# Epoch 029 | loss: 0.5582 | val_loss: 0.5504 | val_acc: 0.7400
# Epoch 030 | loss: 0.5549 | val_loss: 0.5471 | val_acc: 0.7425
# Epoch 031 | loss: 0.5520 | val_loss: 0.5443 | val_acc: 0.7425
# Epoch 032 | loss: 0.5494 | val_loss: 0.5417 | val_acc: 0.7450
# Epoch 033 | loss: 0.5472 | val_loss: 0.5395 | val_acc: 0.7500
# Epoch 034 | loss: 0.5451 | val_loss: 0.5373 | val_acc: 0.7500
# Epoch 035 | loss: 0.5433 | val_loss: 0.5356 | val_acc: 0.7475
# Epoch 036 | loss: 0.5415 | val_loss: 0.5340 | val_acc: 0.7475
# Epoch 037 | loss: 0.5401 | val_loss: 0.5325 | val_acc: 0.7450
# Epoch 038 | loss: 0.5387 | val_loss: 0.5312 | val_acc: 0.7500
# Epoch 039 | loss: 0.5375 | val_loss: 0.5299 | val_acc: 0.7475
# Epoch 040 | loss: 0.5363 | val_loss: 0.5288 | val_acc: 0.7475
# [SINE] Acc: 0.7475 | Final train loss: 0.5363
#
# ------------------------------------------------------------
# Training with SIGMOID activation...
# Epoch 001 | loss: 0.7626 | val_loss: 0.7524 | val_acc: 0.5000
# Epoch 002 | loss: 0.7454 | val_loss: 0.7381 | val_acc: 0.5000
# Epoch 003 | loss: 0.7328 | val_loss: 0.7262 | val_acc: 0.5000
# Epoch 004 | loss: 0.7226 | val_loss: 0.7180 | val_acc: 0.5000
# Epoch 005 | loss: 0.7150 | val_loss: 0.7116 | val_acc: 0.5000
# Epoch 006 | loss: 0.7092 | val_loss: 0.7065 | val_acc: 0.5000
# Epoch 007 | loss: 0.7050 | val_loss: 0.7027 | val_acc: 0.5000
# Epoch 008 | loss: 0.7016 | val_loss: 0.7004 | val_acc: 0.5000
# Epoch 009 | loss: 0.6994 | val_loss: 0.6982 | val_acc: 0.5000
# Epoch 010 | loss: 0.6976 | val_loss: 0.6969 | val_acc: 0.5000
# Epoch 011 | loss: 0.6964 | val_loss: 0.6960 | val_acc: 0.5050
# Epoch 012 | loss: 0.6956 | val_loss: 0.6953 | val_acc: 0.5425
# Epoch 013 | loss: 0.6950 | val_loss: 0.6948 | val_acc: 0.5900
# Epoch 014 | loss: 0.6946 | val_loss: 0.6944 | val_acc: 0.6150
# Epoch 015 | loss: 0.6943 | val_loss: 0.6943 | val_acc: 0.6125
# Epoch 016 | loss: 0.6941 | val_loss: 0.6941 | val_acc: 0.5950
# Epoch 017 | loss: 0.6940 | val_loss: 0.6941 | val_acc: 0.5650
# Epoch 018 | loss: 0.6939 | val_loss: 0.6940 | val_acc: 0.5500
# Epoch 019 | loss: 0.6938 | val_loss: 0.6939 | val_acc: 0.5225
# Epoch 020 | loss: 0.6938 | val_loss: 0.6939 | val_acc: 0.5225
# Epoch 021 | loss: 0.6937 | val_loss: 0.6939 | val_acc: 0.5150
# Epoch 022 | loss: 0.6937 | val_loss: 0.6939 | val_acc: 0.5100
# Epoch 023 | loss: 0.6936 | val_loss: 0.6939 | val_acc: 0.5075
# Epoch 024 | loss: 0.6937 | val_loss: 0.6939 | val_acc: 0.5075
# Epoch 025 | loss: 0.6936 | val_loss: 0.6939 | val_acc: 0.5100
# Epoch 026 | loss: 0.6935 | val_loss: 0.6939 | val_acc: 0.5125
# Epoch 027 | loss: 0.6935 | val_loss: 0.6939 | val_acc: 0.5050
# Epoch 028 | loss: 0.6935 | val_loss: 0.6939 | val_acc: 0.5075
# Epoch 029 | loss: 0.6934 | val_loss: 0.6939 | val_acc: 0.5100
# Epoch 030 | loss: 0.6935 | val_loss: 0.6939 | val_acc: 0.5025
# Epoch 031 | loss: 0.6934 | val_loss: 0.6939 | val_acc: 0.5050
# Epoch 032 | loss: 0.6934 | val_loss: 0.6939 | val_acc: 0.5025
# Epoch 033 | loss: 0.6934 | val_loss: 0.6939 | val_acc: 0.5025
# Epoch 034 | loss: 0.6934 | val_loss: 0.6939 | val_acc: 0.5050
# Epoch 035 | loss: 0.6934 | val_loss: 0.6939 | val_acc: 0.5000
# Epoch 036 | loss: 0.6934 | val_loss: 0.6939 | val_acc: 0.5025
# Epoch 037 | loss: 0.6934 | val_loss: 0.6939 | val_acc: 0.5050
# Epoch 038 | loss: 0.6933 | val_loss: 0.6939 | val_acc: 0.5050
# Epoch 039 | loss: 0.6933 | val_loss: 0.6939 | val_acc: 0.4925
# Epoch 040 | loss: 0.6933 | val_loss: 0.6939 | val_acc: 0.5025
# [SIGMOID] Acc: 0.5025 | Final train loss: 0.6933
#
# ------------------------------------------------------------
# Training with TANH activation...
# Epoch 001 | loss: 0.7132 | val_loss: 0.7226 | val_acc: 0.4950
# Epoch 002 | loss: 0.7079 | val_loss: 0.7173 | val_acc: 0.4975
# Epoch 003 | loss: 0.7041 | val_loss: 0.7127 | val_acc: 0.5025
# Epoch 004 | loss: 0.7009 | val_loss: 0.7095 | val_acc: 0.5025
# Epoch 005 | loss: 0.6986 | val_loss: 0.7069 | val_acc: 0.5075
# Epoch 006 | loss: 0.6967 | val_loss: 0.7046 | val_acc: 0.5075
# Epoch 007 | loss: 0.6952 | val_loss: 0.7028 | val_acc: 0.5050
# Epoch 008 | loss: 0.6939 | val_loss: 0.7013 | val_acc: 0.5075
# Epoch 009 | loss: 0.6929 | val_loss: 0.6998 | val_acc: 0.5025
# Epoch 010 | loss: 0.6918 | val_loss: 0.6986 | val_acc: 0.5050
# Epoch 011 | loss: 0.6910 | val_loss: 0.6977 | val_acc: 0.5100
# Epoch 012 | loss: 0.6903 | val_loss: 0.6966 | val_acc: 0.5150
# Epoch 013 | loss: 0.6897 | val_loss: 0.6957 | val_acc: 0.5175
# Epoch 014 | loss: 0.6889 | val_loss: 0.6949 | val_acc: 0.5150
# Epoch 015 | loss: 0.6883 | val_loss: 0.6942 | val_acc: 0.5250
# Epoch 016 | loss: 0.6877 | val_loss: 0.6934 | val_acc: 0.5300
# Epoch 017 | loss: 0.6870 | val_loss: 0.6927 | val_acc: 0.5350
# Epoch 018 | loss: 0.6864 | val_loss: 0.6918 | val_acc: 0.5425
# Epoch 019 | loss: 0.6858 | val_loss: 0.6910 | val_acc: 0.5400
# Epoch 020 | loss: 0.6850 | val_loss: 0.6904 | val_acc: 0.5525
# Epoch 021 | loss: 0.6842 | val_loss: 0.6895 | val_acc: 0.5550
# Epoch 022 | loss: 0.6835 | val_loss: 0.6885 | val_acc: 0.5525
# Epoch 023 | loss: 0.6825 | val_loss: 0.6877 | val_acc: 0.5700
# Epoch 024 | loss: 0.6818 | val_loss: 0.6869 | val_acc: 0.5625
# Epoch 025 | loss: 0.6808 | val_loss: 0.6860 | val_acc: 0.6000
# Epoch 026 | loss: 0.6798 | val_loss: 0.6849 | val_acc: 0.6000
# Epoch 027 | loss: 0.6786 | val_loss: 0.6838 | val_acc: 0.5950
# Epoch 028 | loss: 0.6776 | val_loss: 0.6829 | val_acc: 0.6125
# Epoch 029 | loss: 0.6762 | val_loss: 0.6815 | val_acc: 0.6075
# Epoch 030 | loss: 0.6750 | val_loss: 0.6804 | val_acc: 0.6075
# Epoch 031 | loss: 0.6737 | val_loss: 0.6791 | val_acc: 0.6150
# Epoch 032 | loss: 0.6722 | val_loss: 0.6780 | val_acc: 0.6150
# Epoch 033 | loss: 0.6708 | val_loss: 0.6764 | val_acc: 0.6175
# Epoch 034 | loss: 0.6692 | val_loss: 0.6751 | val_acc: 0.6275
# Epoch 035 | loss: 0.6677 | val_loss: 0.6738 | val_acc: 0.6250
# Epoch 036 | loss: 0.6659 | val_loss: 0.6722 | val_acc: 0.6425
# Epoch 037 | loss: 0.6643 | val_loss: 0.6707 | val_acc: 0.6425
# Epoch 038 | loss: 0.6625 | val_loss: 0.6691 | val_acc: 0.6500
# Epoch 039 | loss: 0.6606 | val_loss: 0.6675 | val_acc: 0.6550
# Epoch 040 | loss: 0.6588 | val_loss: 0.6658 | val_acc: 0.6550
# [TANH] Acc: 0.6550 | Final train loss: 0.6588
#
#
# ============================================================
# ACTIVATIONS: lasa, relu, leaky_relu, elu, softplus, swish, mish, gelu, sine, sigmoid, tanh
# ============================================================
#
# ============================================================
# FINAL RESULTS COMPARISON
# ============================================================
# Rank   Activation      Accuracy     Final Train Loss
# ------------------------------------------------------------
# 1      LASA            0.9975       0.2514
# 2      GELU            0.7975       0.5464
# 3      LEAKY_RELU      0.7675       0.5255
# 4      SINE            0.7475       0.5363
# 5      MISH            0.7450       0.5754
# 6      SWISH           0.7200       0.5384
# 7      TANH            0.6550       0.6588
# 8      ELU             0.5225       0.6871
# 9      SOFTPLUS        0.5050       0.6734
# 10     SIGMOID         0.5025       0.6933
# 11     RELU            0.4950       0.6932
# ============================================================
